# %% [markdown]
# # ConvNeXt V2

# %% [markdown]
# - loss: Binary Cross Entropy
# - metrics: ROCAUC
# - trainable: after model.convnextv2.encoder.stages[3]

# %% [markdown]
# ## Load Model

# %%
from transformers import AutoImageProcessor, ConvNextV2ForImageClassification
import torch
from datasets import load_dataset

from utils.utils import load_img

print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.current_device())
print(torch.cuda.get_device_name())
print(torch.cuda.get_device_capability())
# Out:
# 1.13.1+cu117
# True
# 4
# 0
# Tesla T4
# (7, 5)

# %%
dataset = load_dataset("huggingface/cats-image")
image = dataset["test"]["image"][0]

preprocessor = AutoImageProcessor.from_pretrained("facebook/convnextv2-huge-22k-512")
model = ConvNextV2ForImageClassification.from_pretrained("facebook/convnextv2-huge-22k-512")

# %% [raw]
# inputs = preprocessor(image, return_tensors="pt")
# inputs['pixel_values'].shape

# %% [raw]
# with torch.no_grad():
#     logits = model(**inputs).logits
#
# # model predicts one of the 1000 ImageNet classes
# predicted_label = logits.argmax(-1).item()
# print(model.config.id2label[predicted_label]),

# %% [markdown]
# ## 学習データの可視化

# %%
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# 食品と飲料をランダムに5個ずつ可視化する
df_train = pd.read_csv('train.csv')
df_train['num'] = df_train['image_name'].str[:-4].astype(int)

d_vis = df_train[df_train['label']==0].sample(5)['num'].tolist()
f_vis = df_train[df_train['label']==1].sample(5)['num'].tolist()

# %%
def show5img(ilist, stitle=None):
    n_cols = 5
    n_rows = (len(ilist)-1)//5+1
    
    fig = plt.figure(figsize=(n_cols*2, n_rows*2))
    for n, i in enumerate(ilist):
        ax = fig.add_subplot(n_rows, n_cols, n+1)
        im = load_img(i)
        im = np.asarray(im)
        ax.imshow(im)
        ax.axes.xaxis.set_visible(False)
        ax.axes.yaxis.set_visible(False)
        ax.set_title(i)
    if stitle:
        fig.suptitle(stitle)
    fig.tight_layout()
    fig.show()

# %%
show5img(d_vis, stitle='drink')
show5img(f_vis, stitle='food')

# %% [markdown]
# ## 転位学習

# %%
import torch.nn as nn
from torchvision import transforms

from sklearn.model_selection import StratifiedKFold

# %%
device = torch.device('cuda')

# %% [markdown]
# データセット作成

# %%
# folding
n_folds = 5

skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=0)
df_train['fold'] = -1
for i, (_, val_idx) in enumerate(skf.split(df_train, df_train['label'])):
    df_train.loc[val_idx, 'fold'] = i

# %%
df_train
# Out:
#      image_name  label   num  fold
# 0      0000.png      0     0     4
# 1      0001.png      1     1     2
# 2      0002.png      1     2     3
# 3      0003.png      1     3     0
# 4      0004.png      0     4     3
# ...         ...    ...   ...   ...
# 2171   2171.png      1  2171     3
# 2172   2172.png      1  2172     2
# 2173   2173.png      1  2173     3
# 2174   2174.png      0  2174     2
# 2175   2175.png      0  2175     3
#
# [2176 rows x 4 columns]

# %%
# テストデータ
df_test = pd.read_csv('sample_submit.csv', header=None)
df_test.columns = ['image_name', 'label']
df_test['num'] = df_test['image_name'].str[:-4].astype(int)
df_test['label'] = -1

# %%
df_test
# Out:
#      image_name  label   num
# 0      2176.png     -1  2176
# 1      2177.png     -1  2177
# 2      2178.png     -1  2178
# 3      2179.png     -1  2179
# 4      2180.png     -1  2180
# ...         ...    ...   ...
# 2175   4351.png     -1  4351
# 2176   4352.png     -1  4352
# 2177   4353.png     -1  4353
# 2178   4354.png     -1  4354
# 2179   4355.png     -1  4355
#
# [2180 rows x 3 columns]

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomChoice([
            transforms.RandomCrop(256),
            transforms.RandomCrop(384),
            transforms.RandomCrop(512),
        ]),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomVerticalFlip(p=0.5),
#         transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5),
        transforms.RandomRotation(180, expand=True),
#         transforms.GaussianBlur(3, sigma=(0.1, 2.0)),
        transforms.Resize((512, 512)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        transforms.RandomErasing(p=0.25),
    ]),
    'valid': transforms.Compose([
#         transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
    'taa': transforms.Compose([
        transforms.RandomChoice([
            transforms.RandomCrop(384),
            transforms.RandomCrop(512),
        ]),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomVerticalFlip(p=0.5),
#         transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5),
#         transforms.RandomRotation(180, expand=True),
#         transforms.GaussianBlur(3, sigma=(0.1, 2.0)),
        transforms.Resize((512, 512)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        transforms.RandomErasing(p=0.25, scale=(0.02, 0.1)),
    ]),
}

# %%
# 例
def showTimg(n):
    image = load_img(0)
    image_t = data_transforms['train'](image)
    
    img1 = np.asarray(image)
    img2 = image_t.numpy().transpose((2,1,0))
    
    fig = plt.figure(figsize=(2*2, 1*2))
    ax1 = fig.add_subplot(1, 2, 1)
    ax1.imshow(img1)
    ax1.axes.xaxis.set_visible(False)
    ax1.axes.yaxis.set_visible(False)
    ax1.set_title(f'Raw_{n}')
    
    ax2 = fig.add_subplot(1, 2, 2)
    ax2.imshow(img2)
    ax2.axes.xaxis.set_visible(False)
    ax2.axes.yaxis.set_visible(False)
    ax2.set_title(f'Transformed_{n}')

# %%
showTimg(0)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, df, transform, tt='train'):
        if tt == 'train':
            self.dir = 'train/'
        elif tt == 'test':
            self.dir = 'test/'
        
        self.df = df
        self.transform = transform
        self.labels = np.expand_dims(df['label'].values, 1)
        self.labels = self.labels.astype(float)

    # len()を使用すると呼ばれる
    def __len__(self):
        return len(self.labels)

    # 要素を参照すると呼ばれる関数    
    def __getitem__(self, idx):
        num = self.df['num'].values[idx]
        image = load_img(num)
        image = self.transform(image)
        return image, self.labels[idx]

# %%
def foldData(fold, bs=32):
    df_train_ = df_train[df_train['fold']!=fold]
    df_valid_ = df_train[df_train['fold']==fold]
    df_test_ = df_test
    
    image_datasets = {
        'train': MyDataset(df_train_, data_transforms['train'], tt='train'),
        'valid': MyDataset(df_valid_, data_transforms['valid'], tt='train'),
        'test': MyDataset(df_test_, data_transforms['valid'], tt='test'),
        'taa': MyDataset(df_test_, data_transforms['taa'], tt='test'),
    }
    
    dataloaders = {
        'train': torch.utils.data.DataLoader(image_datasets['train'],
                                             batch_size=bs, shuffle=True, num_workers=16, pin_memory=True),
        'valid': torch.utils.data.DataLoader(image_datasets['valid'],
                                             batch_size=bs, shuffle=False, num_workers=16, pin_memory=True),
        'test': torch.utils.data.DataLoader(image_datasets['test'],
                                             batch_size=bs, shuffle=False, num_workers=16, pin_memory=True),
        'taa': torch.utils.data.DataLoader(image_datasets['taa'],
                                             batch_size=bs, shuffle=False, num_workers=16, pin_memory=True),
    }
    
#     return train_idx, valid_idx, image_datasets, dataloaders
    return image_datasets, dataloaders

# %%
# fold=0で一旦分ける
bs = 64

# train_index, valid_index, image_datasets, dataloaders = foldData(0, bs=32)
image_datasets, dataloaders = foldData(0, bs=bs)
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# モデル構築

# %%
from torcheval.metrics import BinaryAUROC
import torch.optim as optim
from torcheval.metrics.functional import binary_auroc

# %%
model.classifier = nn.Linear(2816, 1, bias=True)

# %%
# multi gpu
model = torch.nn.DataParallel(model, device_ids=[0, 1, 2, 3]) # make parallel
model.to(device)
# Out:
# DataParallel(
#   (module): ConvNextV2ForImageClassification(
#     (convnextv2): ConvNextV2Model(
#       (embeddings): ConvNextV2Embeddings(
#         (patch_embeddings): Conv2d(3, 352, kernel_size=(4, 4), stride=(4, 4))
#         (layernorm): ConvNextV2LayerNorm()
#       )
#       (encoder): ConvNextV2Encoder(
#         (stages): ModuleList(
#           (0): ConvNextV2Stage(
#             (downsampling_layer): Identity()
#             (layers): Sequential(
#               (0): ConvNextV2Layer(
#                 (dwconv): Conv2d(352, 352, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=352)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=352, out_features=1408, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=1408, out_features=352, bias=True)
#                 (drop_path): Identity()
#               )
#               (1): ConvNextV2Layer(
#                 (dwconv): Conv2d(352, 352, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=352)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=352, out_features=1408, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=1408, out_features=352, bias=True)
#                 (drop_path): Identity()
#               )
#               (2): ConvNextV2Layer(
#                 (dwconv): Conv2d(352, 352, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=352)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=352, out_features=1408, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=1408, out_features=352, bias=True)
#                 (drop_path): Identity()
#               )
#             )
#           )
#           (1): ConvNextV2Stage(
#             (downsampling_layer): Sequential(
#               (0): ConvNextV2LayerNorm()
#               (1): Conv2d(352, 704, kernel_size=(2, 2), stride=(2, 2))
#             )
#             (layers): Sequential(
#               (0): ConvNextV2Layer(
#                 (dwconv): Conv2d(704, 704, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=704)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=704, out_features=2816, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=2816, out_features=704, bias=True)
#                 (drop_path): Identity()
#               )
#               (1): ConvNextV2Layer(
#                 (dwconv): Conv2d(704, 704, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=704)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=704, out_features=2816, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=2816, out_features=704, bias=True)
#                 (drop_path): Identity()
#               )
#               (2): ConvNextV2Layer(
#                 (dwconv): Conv2d(704, 704, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=704)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=704, out_features=2816, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=2816, out_features=704, bias=True)
#                 (drop_path): Identity()
#               )
#             )
#           )
#           (2): ConvNextV2Stage(
#             (downsampling_layer): Sequential(
#               (0): ConvNextV2LayerNorm()
#               (1): Conv2d(704, 1408, kernel_size=(2, 2), stride=(2, 2))
#             )
#             (layers): Sequential(
#               (0): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (1): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (2): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (3): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (4): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (5): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (6): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (7): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (8): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (9): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (10): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (11): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (12): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (13): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (14): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (15): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (16): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (17): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (18): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (19): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (20): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (21): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (22): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (23): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (24): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (25): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#               (26): ConvNextV2Layer(
#                 (dwconv): Conv2d(1408, 1408, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1408)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=1408, out_features=5632, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=5632, out_features=1408, bias=True)
#                 (drop_path): Identity()
#               )
#             )
#           )
#           (3): ConvNextV2Stage(
#             (downsampling_layer): Sequential(
#               (0): ConvNextV2LayerNorm()
#               (1): Conv2d(1408, 2816, kernel_size=(2, 2), stride=(2, 2))
#             )
#             (layers): Sequential(
#               (0): ConvNextV2Layer(
#                 (dwconv): Conv2d(2816, 2816, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=2816)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=2816, out_features=11264, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=11264, out_features=2816, bias=True)
#                 (drop_path): Identity()
#               )
#               (1): ConvNextV2Layer(
#                 (dwconv): Conv2d(2816, 2816, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=2816)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=2816, out_features=11264, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=11264, out_features=2816, bias=True)
#                 (drop_path): Identity()
#               )
#               (2): ConvNextV2Layer(
#                 (dwconv): Conv2d(2816, 2816, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=2816)
#                 (layernorm): ConvNextV2LayerNorm()
#                 (pwconv1): Linear(in_features=2816, out_features=11264, bias=True)
#                 (act): GELUActivation()
#                 (grn): ConvNextV2GRN()
#                 (pwconv2): Linear(in_features=11264, out_features=2816, bias=True)
#                 (drop_path): Identity()
#               )
#             )
#           )
#         )
#       )
#       (layernorm): LayerNorm((2816,), eps=1e-12, elementwise_affine=True)
#     )
#     (classifier): Linear(in_features=2816, out_features=1, bias=True)
#   )
# )

# %%
### 重み固定 ###
for p in model.parameters():
    p.requires_grad = False

# %% [markdown]
# 学習

# %%
import copy, time

# %%
criterion = nn.BCEWithLogitsLoss(pos_weight=None)

# %%
def train(model, criterion, optimizer, scheduler, epochs=5):
    since = time.time()
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_auc = 0.0
    
    for epoch in range(epochs):
        print(f'Epoch {epoch}/{epochs-1}')
        print('-' * 10)
        
        for phase in ('train', 'valid'):
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode
            
            running_loss = 0.0
            running_auc = 0.0
            
            # イタレーション
            for b, (imgs, labels) in enumerate(dataloaders[phase]):
                print(f'\rBatch: {b}/{len(image_datasets[phase])//bs} ({phase})', end="")
                inputs = imgs.to(device)
                labels = labels.to(device)
                
                optimizer.zero_grad()
                
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs).logits
                    # loss = criterion(torch.flatten(outputs), torch.flatten(labels))
                    loss = criterion(outputs, labels)
                    auc = binary_auroc(torch.flatten(torch.sigmoid(outputs)),
                                       torch.flatten(labels))

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
                
                if phase == 'train':
                    scheduler.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_auc +=  auc * inputs.size(0)
                
                del loss
            
            epoch_loss = running_loss / len(image_datasets[phase])
            epoch_auc = running_auc / len(image_datasets[phase])
            
            print()
            print(f'{phase} Loss: {epoch_loss:.4f} AUC: {epoch_auc:.4f}')
            
            # deep copy the model
            if phase == 'valid' and epoch_auc > best_auc:
                best_auc = epoch_auc
                best_model_wts = copy.deepcopy(model.state_dict())
            
        print()
        
    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val AUC: {best_auc:4f}')

    # load best model weights
    model.load_state_dict(best_model_wts)
    del best_model_wts
    return model

# %%
### パラメータ変更可能な部分 ###
"""
  model.module.convnextv2.embeddings

  model.module.convnextv2.encoder.stages[0]
  -> model.module.convnextv2.encoder.stages[0].layers[0] ~ [2]

  model.module.convnextv2.encoder.stages[1]
  -> model.module.convnextv2.encoder.stages[1].layers[0] ~ [2]

  model.module.convnextv2.encoder.stages[2]
  -> model.module.convnextv2.encoder.stages[2].layers[0] ~ [26]

  model.module.convnextv2.encoder.stages[3]
  -> model.module.convnextv2.encoder.stages[3].layers[0] ~ [2]

  model.module.convnextv2.layernorm

  model.module.classifier
"""
# Out:
# '\n  model.module.convnextv2.embeddings\n\n  model.module.convnextv2.encoder.stages[0]\n  -> model.module.convnextv2.encoder.stages[0].layers[0] ~ [2]\n\n  model.module.convnextv2.encoder.stages[1]\n  -> model.module.convnextv2.encoder.stages[1].layers[0] ~ [2]\n\n  model.module.convnextv2.encoder.stages[2]\n  -> model.module.convnextv2.encoder.stages[2].layers[0] ~ [26]\n\n  model.module.convnextv2.encoder.stages[3]\n  -> model.module.convnextv2.encoder.stages[3].layers[0] ~ [2]\n\n  model.module.convnextv2.layernorm\n\n  model.module.classifier\n'

# %%
specs = [
    {
        'addTrainLayers': [model.module.classifier],
        'lr': 1e-3,
        'epochs': 1,
    },
    {
        'addTrainLayers': [model.module.convnextv2.layernorm],
        'lr': 1e-3,
        'epochs': 1,
    },
    {
        'addTrainLayers': [model.module.convnextv2.encoder.stages[3]],
        'lr': 1e-3,
        'epochs': 1,
    },
]

# %% [raw]
# specs = [
#     {
#         'addTrainLayers': [model.module.classifier, model.module.convnextv2.layernorm, model.module.convnextv2.encoder.stages[3]],
#         'lr': 1e-3,
#         'epochs': 1,
#     },
# ]

# %%
for spec in specs:
    for layer in spec['addTrainLayers']:
        for p in layer.parameters():
            p.requires_grad = True
    
    optimizer = optim.SGD(model.parameters(), lr=spec['lr'], momentum=0.9)
    exp_lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)
    
    model = train(model, criterion, optimizer, exp_lr_scheduler,
                  epochs=spec['epochs'])
# Out:
# Epoch 0/0
# ----------
# Batch: 27/27 (train)
# train Loss: 0.6519 AUC: 0.6585
# Batch: 6/6 (valid)
# valid Loss: 0.6241 AUC: 0.7416
#
# Training complete in 5m 39s
# Best val AUC: 0.741588
# Epoch 0/0
# ----------
# Batch: 27/27 (train)
# train Loss: 0.6114 AUC: 0.7265
# Batch: 6/6 (valid)
# valid Loss: 0.5716 AUC: 0.7969
#
# Training complete in 5m 19s
# Best val AUC: 0.796898
# Epoch 0/0
# ----------
# Batch: 27/27 (train)
# train Loss: 0.5895 AUC: 0.7558
# Batch: 6/6 (valid)
# valid Loss: 0.5529 AUC: 0.8135
#
# Training complete in 5m 47s
# Best val AUC: 0.813464

# %% [markdown]
# ## 検証

# %% [markdown]
# TTAを入れる

# %% [raw]
# def taa(model, n=5):
#     for i in range(n):
#         for b, (imgs, _) in enumerate(dataloaders[phase]):
#             print(f'\rBatch: {b}/{len(image_datasets[phase])//bs} ({phase})', end="")
#             inputs = imgs.to(device)
#             labels = labels.to(device)
#
#             optimizer.zero_grad()
#
#             with torch.set_grad_enabled(phase == 'train'):
#                 outputs = model(inputs).logits

# %% [markdown]
# ## 推論・提出
