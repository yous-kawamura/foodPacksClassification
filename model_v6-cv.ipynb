# %% [markdown]
# # ConvNeXt V2 Large

# %% [markdown]
# - loss: Binary Cross Entropy
# - metrics: ROCAUC
# - trainable: Full
# - CVあり
# ---
# - label smoothing
# - AugMix
# × CutMix
# × MixUp

# %% [markdown]
# ## Load Model

# %%
from transformers import AutoImageProcessor, ConvNextV2ForImageClassification, get_cosine_schedule_with_warmup
import torch, timm
from datasets import load_dataset

from utils.utils import load_img

print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.current_device())
print(torch.cuda.get_device_name())
print(torch.cuda.get_device_capability())
# Out:
# 1.13.1+cu117
# True
# 4
# 0
# Tesla T4
# (7, 5)

# %% [raw]
# dataset = load_dataset("huggingface/cats-image")
# image = dataset["test"]["image"][0]
#
# preprocessor = AutoImageProcessor.from_pretrained("facebook/convnextv2-large-22k-384")
# model = ConvNextV2ForImageClassification.from_pretrained("facebook/convnextv2-large-22k-384")

# %% [raw]
# inputs = preprocessor(image, return_tensors="pt")
# inputs['pixel_values'].shape

# %% [raw]
# with torch.no_grad():
#     logits = model(**inputs).logits
#
# # model predicts one of the 1000 ImageNet classes
# predicted_label = logits.argmax(-1).item()
# print(model.config.id2label[predicted_label]),

# %% [markdown]
# ## 学習データの可視化

# %%
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# 食品と飲料をランダムに5個ずつ可視化する
df_train = pd.read_csv('train.csv')
df_train['num'] = df_train['image_name'].str[:-4].astype(int)

d_vis = df_train[df_train['label']==0].sample(5)['num'].tolist()
f_vis = df_train[df_train['label']==1].sample(5)['num'].tolist()

# %%
# データの偏り
print(f"N of drinks: {len(df_train[df_train['label']==0])}")
print(f"N of foods: {len(df_train[df_train['label']==1])}")
# Out:
# N of drinks: 994
# N of foods: 1182

# %%
def show5img(ilist, stitle=None):
    n_cols = 5
    n_rows = (len(ilist)-1)//5+1
    
    fig = plt.figure(figsize=(n_cols*2, n_rows*2))
    for n, i in enumerate(ilist):
        ax = fig.add_subplot(n_rows, n_cols, n+1)
        im = load_img(i)
        im = np.asarray(im)
        ax.imshow(im)
        ax.axes.xaxis.set_visible(False)
        ax.axes.yaxis.set_visible(False)
        ax.set_title(i)
    if stitle:
        fig.suptitle(stitle)
    fig.tight_layout()
    fig.show()

# %%
show5img(d_vis, stitle='drink')
show5img(f_vis, stitle='food')

# %% [markdown]
# ## 転移学習/CV検証

# %%
import torch.nn as nn
from torchvision import transforms

from sklearn.model_selection import StratifiedKFold

# %%
device = torch.device('cuda')

# %% [markdown]
# データセット作成

# %%
# folding
n_folds = 5

skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=4)
df_train['fold'] = -1
for i, (_, val_idx) in enumerate(skf.split(df_train, df_train['label'])):
    df_train.loc[val_idx, 'fold'] = i

# %%
# label smoothing
df_train['label'] = df_train['label'].replace({0: 0.05, 1: 0.95})

# %%
df_train
# Out:
#      image_name  label   num  fold
# 0      0000.png   0.05     0     2
# 1      0001.png   0.95     1     3
# 2      0002.png   0.95     2     0
# 3      0003.png   0.95     3     4
# 4      0004.png   0.05     4     4
# ...         ...    ...   ...   ...
# 2171   2171.png   0.95  2171     4
# 2172   2172.png   0.95  2172     0
# 2173   2173.png   0.95  2173     0
# 2174   2174.png   0.05  2174     0
# 2175   2175.png   0.05  2175     0
#
# [2176 rows x 4 columns]

# %%
# テストデータ
df_test = pd.read_csv('sample_submit.csv', header=None)
df_test.columns = ['image_name', 'label']
df_test['num'] = df_test['image_name'].str[:-4].astype(int)
df_test['label'] = -1

# %%
df_test
# Out:
#      image_name  label   num
# 0      2176.png     -1  2176
# 1      2177.png     -1  2177
# 2      2178.png     -1  2178
# 3      2179.png     -1  2179
# 4      2180.png     -1  2180
# ...         ...    ...   ...
# 2175   4351.png     -1  4351
# 2176   4352.png     -1  4352
# 2177   4353.png     -1  4353
# 2178   4354.png     -1  4354
# 2179   4355.png     -1  4355
#
# [2180 rows x 3 columns]

# %%
train_transforms_1 = transforms.Compose([
    transforms.RandomChoice([
        transforms.RandomCrop(256),
        transforms.RandomCrop(384),
        transforms.RandomCrop(512),
    ]),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.RandomApply(
        [transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5)],
        p=0.67,
    ),
    transforms.RandomApply(
        [transforms.GaussianBlur(3, sigma=(0.1, 2.0))],
        p=0.67,
    ),
    transforms.Resize((384, 384)),
    transforms.RandomApply(
        [transforms.RandomRotation(180)],
        p=0.5,
    ),
    transforms.ToTensor(),
    transforms.RandomErasing(p=0.33, scale=(0.02, 0.3)),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])

train_transforms_2 = transforms.Compose([
    transforms.AugMix(),
    transforms.Resize((384, 384)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])


tta_transforms_1 = transforms.Compose([
    transforms.RandomChoice([
        transforms.RandomCrop(448),
        transforms.RandomCrop(512),
    ]),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.RandomApply(
        [transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5)],
        p=0.67,
    ),
    transforms.RandomApply(
        [transforms.GaussianBlur(3, sigma=(0.1, 2.0))],
        p=0.67,
    ),
    transforms.Resize((384, 384)),
    # transforms.RandomApply(
    #     [transforms.RandomRotation(180)],
    #     p=0.5,
    # ),
    transforms.ToTensor(),
    # transforms.RandomErasing(p=0.33, scale=(0.02, 0.1)),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])

tta_transforms_2 = transforms.Compose([
    transforms.AugMix(),
    transforms.Resize((384, 384)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])


data_transforms = {
    'train': transforms.RandomChoice([
        train_transforms_1, train_transforms_2
    ], p=[0.4, 0.6]),
    'valid': transforms.Compose([
        transforms.Resize((384, 384)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
    'tta': transforms.RandomChoice([
        tta_transforms_1, tta_transforms_2
    ], p=[0.5, 0.5])
}

# %%
# 例
def showTimg(n, phase='train'):
    image = load_img(0)
    image_t = data_transforms[phase](image)
    
    img1 = np.asarray(image)
    img2 = image_t.numpy().transpose((2,1,0))
    
    fig = plt.figure(figsize=(2*2, 1*2))
    ax1 = fig.add_subplot(1, 2, 1)
    ax1.imshow(img1)
    ax1.axes.xaxis.set_visible(False)
    ax1.axes.yaxis.set_visible(False)
    ax1.set_title(f'Raw_{n}')
    
    ax2 = fig.add_subplot(1, 2, 2)
    ax2.imshow(img2)
    ax2.axes.xaxis.set_visible(False)
    ax2.axes.yaxis.set_visible(False)
    ax2.set_title(f'Transformed_{n}')

# %%
showTimg(0, phase='train')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
showTimg(0, phase='valid')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
showTimg(0, phase='tta')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, df, transform, tt='train'):
        if tt == 'train':
            self.dir = 'train/'
        elif tt == 'test':
            self.dir = 'test/'
        
        self.df = df
        self.transform = transform
        self.labels = np.expand_dims(df['label'].values, 1)
        self.labels = self.labels.astype(float)

    # len()を使用すると呼ばれる
    def __len__(self):
        return len(self.labels)

    # 要素を参照すると呼ばれる関数    
    def __getitem__(self, idx):
        num = self.df['num'].values[idx]
        image = load_img(num)
        image = self.transform(image)
        return image, self.labels[idx]

# %%
def foldData(fold, bs=32):
    df_train_ = df_train[df_train['fold']!=fold]
    df_valid_ = df_train[df_train['fold']==fold]
    df_test_ = df_test
    
    image_datasets = {
        'train': MyDataset(df_train_, data_transforms['train'], tt='train'),
        'valid': MyDataset(df_valid_, data_transforms['valid'], tt='train'),
        'vta': MyDataset(df_valid_, data_transforms['tta'], tt='train'),
        'test': MyDataset(df_test_, data_transforms['valid'], tt='test'),
        'tta': MyDataset(df_test_, data_transforms['tta'], tt='test'),
    }
    
    dataloaders = {
        'train': torch.utils.data.DataLoader(image_datasets['train'],
                                             batch_size=bs, shuffle=True, num_workers=16, pin_memory=True),
        'valid': torch.utils.data.DataLoader(image_datasets['valid'],
                                             batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
        'vta': torch.utils.data.DataLoader(image_datasets['vta'],
                                           batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
        'test': torch.utils.data.DataLoader(image_datasets['test'],
                                            batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
        'tta': torch.utils.data.DataLoader(image_datasets['tta'],
                                           batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
    }
    
#     return train_idx, valid_idx, image_datasets, dataloaders
    return image_datasets, dataloaders

# %% [markdown]
# モデル構築

# %%
from torcheval.metrics import BinaryAUROC
import torch.optim as optim
from torcheval.metrics.functional import binary_auroc

# %% [raw]
# model.classifier = nn.Linear(2816, 1, bias=True)

# %% [raw]
# # multi gpu
# model = torch.nn.DataParallel(model, device_ids=[0, 1, 2, 3]) # make parallel

# %% [raw]
# model.to(device)

# %% [raw]
# ### 重み固定 ###
# for p in model.parameters():
#     p.requires_grad = False

# %%
def loadNewModel():
    m = ConvNextV2ForImageClassification.from_pretrained("facebook/convnextv2-large-22k-384")
    m.classifier = nn.Linear(1536, 1, bias=True)
    m = torch.nn.DataParallel(m, device_ids=[0, 1, 2, 3]) # make parallel
    m.to(device)
    for p in m.parameters():
        p.requires_grad = False
    return m

# %% [markdown]
# 学習

# %%
import copy, time
import torchvision
#torchvision.disable_beta_transforms_warning()
#from torchvision.transforms import v2

# %%
scaler = torch.cuda.amp.GradScaler()

# %% [raw]
# cutmix = v2.CutMix(num_classes=1)
# mixup = v2.MixUp(num_classes=1)
# cutmix_or_mixup = v2.RandomChoice([cutmix, mixup])

# %% [raw]
# -> one-hotじゃないと適用できないので今回は適用しない

# %%
def train(model, criterion, optimizer, scheduler, image_datasets, dataloaders, epochs=5):
    since = time.time()
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_auc = 0.0
    
    for epoch in range(epochs):
        print(f'Epoch {epoch}/{epochs-1}')
        print('-' * 10)
        
        for phase in ('train', 'valid'):
            if phase == 'train':
                is_train = True
                model.train()  # Set model to training mode
            else:
                is_train = False
                model.eval()   # Set model to evaluate mode
            
            running_loss = 0.0
            running_auc = 0.0
            
            # イタレーション
            for b, (inputs, labels) in enumerate(dataloaders[phase]):
                print(f'\rBatch: {b}/{len(image_datasets[phase])//dataloaders[phase].batch_size} ({phase})', end="")
                # images, labels = cutmix_or_mixup(images, labels)
                inputs = inputs.to(device)
                labels = labels.to(device)
                
                optimizer.zero_grad()
                
                with torch.set_grad_enabled(is_train):
                    with torch.cuda.amp.autocast(): 
                        outputs = model(inputs).logits
                        # loss = criterion(torch.flatten(outputs), torch.flatten(labels))
                        loss = criterion(outputs, labels)
                    auc = binary_auroc(torch.flatten(torch.sigmoid(outputs)),
                                       torch.flatten(labels))

                    # backward + optimize only if in training phase
                    if is_train:
                        scaler.scale(loss).backward()
                        scaler.step(optimizer)
                        scaler.update() 

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_auc +=  auc * inputs.size(0)
                
                del loss, auc, labels, inputs, outputs
            
            epoch_loss = running_loss / len(image_datasets[phase])
            epoch_auc = running_auc / len(image_datasets[phase])
            
            print()
            print(f'{phase} Loss: {epoch_loss:.4f} AUC: {epoch_auc:.4f}')
            
            # deep copy the model
            if phase == 'valid' and epoch_auc > best_auc:
                best_auc = epoch_auc
                best_model_wts = copy.deepcopy(model.state_dict())
            del epoch_loss, epoch_auc, running_loss, running_auc
            torch.cuda.empty_cache()
            
        scheduler.step()
        print()
        
    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val AUC: {best_auc:.4f}')
    print()

    # load best model weights
    model.load_state_dict(best_model_wts)
    del best_model_wts
    return model

# %% [markdown]
# - 通常の代入とTTAで比較

# %%
def valid(model, dataloader):
    noutputs = []
    nlabels = []
    for b, (inputs, labels) in enumerate(dataloader):
        print(f'\rBatch: {b}/{len(dataloader.dataset)//dataloader.batch_size}', end="")
        inputs = inputs.to(device)
        labels = labels.to(device)
        with torch.no_grad():
            noutputs.append(model(inputs).logits)
            nlabels.append(labels)
        del inputs, labels
    alloutputs = torch.cat(noutputs)
    alllabels = torch.cat(nlabels)
    
    preds = torch.sigmoid(torch.flatten(alloutputs))
    auc = binary_auroc(preds, torch.flatten(alllabels))
    print()
    print()
    print(f'AUC: {auc:.4f}')
    
    return preds.cpu().detach().numpy()

# %%
def tta(model, dataloader, n=5):
    alloutputs = []
    
    for i in range(n):
        print(f'n: {i}/{n-1}')
        print('-' * 10)
        noutputs = []
        nlabels = []
        for b, (inputs, labels) in enumerate(dataloader):
            print(f'\rBatch: {b}/{len(dataloader.dataset)//dataloader.batch_size}', end="")
            inputs = inputs.to(device)
            labels = labels.to(device)
            with torch.no_grad():
                noutputs.append(model(inputs).logits)
                nlabels.append(labels)
            del inputs, labels
        alloutputs.append(torch.cat(noutputs))
        alllabels = torch.cat(nlabels)
        print()
    alloutputs = torch.cat(alloutputs, 1)
    preds = torch.sigmoid(torch.mean(alloutputs, dim=1))
    auc = binary_auroc(preds, torch.flatten(alllabels))
    print()
    print(f'AUC: {auc:.4f}')
    
    return preds.cpu().detach().numpy()

# %%
def valMix(model, dataloaders, n=5, mode='valid'):
    # 通常valid
    print(f"=== Normal {'Valid' if mode=='valid' else 'Test'} ===")
    if mode =='valid':
        dataloader = dataloaders['valid']
    elif mode == 'test':
        dataloader = dataloaders['test']
    noutputs = []
    nlabels = []
    for b, (imgs, labels) in enumerate(dataloader):
        print(f'\rBatch: {b}/{len(dataloader.dataset)//dataloader.batch_size}', end="")
        inputs = imgs.to(device)
        labels = labels.to(device)
        with torch.no_grad():
            noutputs.append(model(inputs).logits)
            nlabels.append(labels)
    alloutputs = torch.cat(noutputs)
    alllabels = torch.cat(nlabels)
    
    preds1 = torch.sigmoid(torch.flatten(alloutputs))
    auc = binary_auroc(preds1, torch.flatten(alllabels))
    print()
    print()
    print(f'Norml Valid AUC: {auc:.4f}')
    print()
    
    # TTA valid
    print(f"=== {'Valid' if mode=='valid' else 'Test'} Time Augmentation ===")
    if mode =='valid':
        dataloader = dataloaders['vta']
    elif mode == 'test':
        dataloader = dataloaders['tta']
    alloutputs = [alloutputs]
    
    for i in range(n):
        print(f'n: {i}/{n-1}')
        print('-' * 10)
        noutputs = []
        for b, (imgs, labels) in enumerate(dataloader):
            print(f'\rBatch: {b}/{len(dataloader.dataset)//dataloader.batch_size}', end="")
            inputs = imgs.to(device)
            with torch.no_grad():
                noutputs.append(model(inputs).logits)
        alloutputs.append(torch.cat(noutputs))
        print()
    alloutputs = torch.cat(alloutputs, 1)
    preds2 = torch.sigmoid(torch.mean(alloutputs, dim=1))
    auc = binary_auroc(preds2, torch.flatten(alllabels))
    print()
    print(f'VTA AUC: {auc:.4f}')
    print()
    
    # Mix
    print('=== Mixed Valid ===')
    preds1to0 = preds1 - 0
    preds1to1 = 1 - preds1
    preds2to0 = preds2 - 0
    preds2to1 = 1 - preds2
    
    stack = torch.stack([preds1to0, preds1to1, preds2to0, preds2to1])
    pstack = torch.stack([preds1, preds1, preds2, preds2])
    
    argmin = torch.argmin(stack, dim=0)
    preds = torch.diag(pstack[argmin])
    auc = binary_auroc(preds, torch.flatten(alllabels))
    print()
    print(f'Mixed AUC: {auc:.4f}')
    return preds1.cpu().detach().numpy(), preds2.cpu().detach().numpy(), preds.cpu().detach().numpy()

# %% [markdown]
# ### CV

# %%
from numba import cuda

# %%
### 検証時のAugmentation
n_vta = 5

# %%
### パラメータ変更可能な部分 ###
"""
  model.module.convnextv2.embeddings

  model.module.convnextv2.encoder.stages[0]
  -> model.module.convnextv2.encoder.stages[0].layers[0] ~ [2]

  model.module.convnextv2.encoder.stages[1]
  -> model.module.convnextv2.encoder.stages[1].layers[0] ~ [2]

  model.module.convnextv2.encoder.stages[2]
  -> model.module.convnextv2.encoder.stages[2].layers[0] ~ [26]

  model.module.convnextv2.encoder.stages[3]
  -> model.module.convnextv2.encoder.stages[3].layers[0] ~ [2]

  model.module.convnextv2.layernorm

  model.module.classifier
"""
# Out:
# '\n  model.module.convnextv2.embeddings\n\n  model.module.convnextv2.encoder.stages[0]\n  -> model.module.convnextv2.encoder.stages[0].layers[0] ~ [2]\n\n  model.module.convnextv2.encoder.stages[1]\n  -> model.module.convnextv2.encoder.stages[1].layers[0] ~ [2]\n\n  model.module.convnextv2.encoder.stages[2]\n  -> model.module.convnextv2.encoder.stages[2].layers[0] ~ [26]\n\n  model.module.convnextv2.encoder.stages[3]\n  -> model.module.convnextv2.encoder.stages[3].layers[0] ~ [2]\n\n  model.module.convnextv2.layernorm\n\n  model.module.classifier\n'

# %%
specs = [
    {
        'bs': 32,
        'trainLayers': 1,
        'lr': 1e-3,
        'epochs': 15,
        'num_warmup_steps': 5,  # CosSchWarm
        'num_training_steps': 20,  # CosSchWarm
        'num_cycles': 0.5,  # CosSchWarm
    },
    {
        'bs': 32,
        'trainLayers': 2,
        'lr': 1e-3,
        'epochs': 15,
        'num_warmup_steps': 5,  # CosSchWarm
        'num_training_steps': 20,  # CosSchWarm
        'num_cycles': 0.5,  # CosSchWarm
    },
    {
        'bs': 32,
        'trainLayers': 3,
        'lr': 5e-4,
        'epochs': 20,
        'num_warmup_steps': 5,  # CosSchWarm
        'num_training_steps': 35,  # CosSchWarm
        'num_cycles': 1.5,  # CosSchWarm
    },
    {
        'bs': 24,
        'trainLayers': 4,
        'lr': 1e-4,
        'epochs': 40,
        'num_warmup_steps': 10,  # CosSchWarm
        'num_training_steps': 105,  # CosSchWarm
        'num_cycles': 4.5,  # CosSchWarm
    },
    {
        'bs': 24,
        'trainLayers': 5,
        'lr': 1e-4,
        'epochs': 20,
        'num_warmup_steps': 10,  # CosSchWarm
        'num_training_steps': 105,  # CosSchWarm
        'num_cycles': 4.5,  # CosSchWarm
    },
    {
        'bs': 24,
        'trainLayers': 6,
        'lr': 1e-4,
        'epochs': 20,
        'num_warmup_steps': 10,  # CosSchWarm
        'num_training_steps': 105,  # CosSchWarm
        'num_cycles': 4.5,  # CosSchWarm
    },
    {
        'bs': 24,
        'trainLayers': 7,
        'lr': 1e-4,
        'epochs': 20,
        'num_warmup_steps': 10,  # CosSchWarm
        'num_training_steps': 105,  # CosSchWarm
        'num_cycles': 4.5,  # CosSchWarm
    },
]

# %%
vals = {}
vtas = {}
mixs = {}

# %%
torch.backends.cudnn.benchmark = True

# %%
def train_spec(fold, i, model_path='model.pth'):
    spec = specs[i]
    
    # datasetsを作る
    image_datasets, dataloaders = foldData(fold, bs=spec['bs'])
    
    # 新しいモデルを読み込み
    if i == 0:
        model = loadNewModel()
    else:
        model = torch.load(model_path)
        model.to(device)
        for p in model.parameters():
            p.requires_grad = False
    
    layer_list = [
        model.module.classifier,
        model.module.convnextv2.layernorm,
        model.module.convnextv2.encoder.stages[3],
        model.module.convnextv2.encoder.stages[2],
        model.module.convnextv2.encoder.stages[1],
        model.module.convnextv2.encoder.stages[0],
        model.module.convnextv2.embeddings,
    ]
    
    for j in range(spec['trainLayers']):
        layer = layer_list[j]
        for p in layer.parameters():
            p.requires_grad = True
    
    criterion = nn.BCEWithLogitsLoss(pos_weight=None)
    if False:
    # if i < len(specs)-2:
        optimizer = optim.SGD(model.parameters(), lr=spec['lr'], momentum=0.9)
        lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=spec['sch_steps'], gamma=spec['sch_gamma'])
    else:
        optimizer = optim.AdamW(model.parameters(), lr=spec['lr'])
        lr_scheduler = get_cosine_schedule_with_warmup(optimizer,
                                                       num_warmup_steps=spec['num_warmup_steps'],
                                                       num_training_steps=spec['num_training_steps'],
                                                       num_cycles=spec['num_cycles'])
    
    model = train(model, criterion, optimizer, lr_scheduler, image_datasets, dataloaders,
                  epochs=spec['epochs'])
    
    torch.save(model, model_path)
    del model
    torch.cuda.empty_cache()

# %%
def fold_train(fold):
    print(f'=== Fold: {fold} ===')
    print('GPU Memory:', torch.cuda.memory_allocated())
    
    for i in range(len(specs)):
        print(f'<< Spec: {i} >>')
        train_spec(fold, i)
    
    print('- Validation -')
    model = torch.load('model.pth')
    model.to(device)
    
    image_datasets, dataloaders = foldData(fold)
    
    val, vta, mix = valMix(model, dataloaders, n=n_vta)
    vals[fold] = val
    vtas[fold] = vta
    mixs[fold] = mix
    
    print()
    
    torch.save(model, f'model_{fold}.pth')
    
    del model
    torch.cuda.empty_cache()

# %% [raw]
# for fold in range(n_folds):
#     fold_train(fold)

# %%
# %%capture cap

for fold in range(n_folds):
    fold_train(fold)

with open('log_train.txt', 'w') as f:
    f.write(cap.stdout)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 5
#       2     fold_train(fold)
#       4 with open('log_train.txt', 'w') as f:
# ----> 5     f.write(cap.stdout)
#
# NameError: name 'cap' is not defined

# %%
cap()
# Out:
# === Fold: 0 ===
# GPU Memory: 0
# << Spec: 0 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.7115 AUC: 0.5110
# Batch: 13/13 (valid)
# valid Loss: 0.6999 AUC: 0.5438
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.6393 AUC: 0.6635
# Batch: 13/13 (valid)
# valid Loss: 0.5815 AUC: 0.7604
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5830 AUC: 0.7541
# Batch: 13/13 (valid)
# valid Loss: 0.5421 AUC: 0.8078
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5406 AUC: 0.7956
# Batch: 13/13 (valid)
# valid Loss: 0.5227 AUC: 0.8239
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5270 AUC: 0.8078
# Batch: 13/13 (valid)
# valid Loss: 0.5252 AUC: 0.8242
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5179 AUC: 0.8175
# Batch: 13/13 (valid)
# valid Loss: 0.5094 AUC: 0.8298
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5039 AUC: 0.8309
# Batch: 13/13 (valid)
# valid Loss: 0.4870 AUC: 0.8451
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4922 AUC: 0.8398
# Batch: 13/13 (valid)
# valid Loss: 0.5038 AUC: 0.8397
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4747 AUC: 0.8534
# Batch: 13/13 (valid)
# valid Loss: 0.4850 AUC: 0.8468
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4593 AUC: 0.8656
# Batch: 13/13 (valid)
# valid Loss: 0.4949 AUC: 0.8403
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4649 AUC: 0.8570
# Batch: 13/13 (valid)
# valid Loss: 0.4846 AUC: 0.8469
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4686 AUC: 0.8607
# Batch: 13/13 (valid)
# valid Loss: 0.4813 AUC: 0.8513
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4424 AUC: 0.8767
# Batch: 13/13 (valid)
# valid Loss: 0.4888 AUC: 0.8512
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4532 AUC: 0.8720
# Batch: 13/13 (valid)
# valid Loss: 0.4736 AUC: 0.8559
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4532 AUC: 0.8673
# Batch: 13/13 (valid)
# valid Loss: 0.4742 AUC: 0.8524
#
# Training complete in 18m 37s
# Best val AUC: 0.8559
#
# << Spec: 1 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4586 AUC: 0.8655
# Batch: 13/13 (valid)
# valid Loss: 0.4736 AUC: 0.8559
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4550 AUC: 0.8687
# Batch: 13/13 (valid)
# valid Loss: 0.4738 AUC: 0.8557
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4451 AUC: 0.8756
# Batch: 13/13 (valid)
# valid Loss: 0.4712 AUC: 0.8548
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4522 AUC: 0.8680
# Batch: 13/13 (valid)
# valid Loss: 0.4742 AUC: 0.8573
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4540 AUC: 0.8709
# Batch: 13/13 (valid)
# valid Loss: 0.4796 AUC: 0.8553
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4556 AUC: 0.8708
# Batch: 13/13 (valid)
# valid Loss: 0.4755 AUC: 0.8493
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4489 AUC: 0.8683
# Batch: 13/13 (valid)
# valid Loss: 0.4716 AUC: 0.8598
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4458 AUC: 0.8729
# Batch: 13/13 (valid)
# valid Loss: 0.4666 AUC: 0.8558
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4403 AUC: 0.8752
# Batch: 13/13 (valid)
# valid Loss: 0.4525 AUC: 0.8671
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4391 AUC: 0.8825
# Batch: 13/13 (valid)
# valid Loss: 0.4618 AUC: 0.8656
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4293 AUC: 0.8826
# Batch: 13/13 (valid)
# valid Loss: 0.4599 AUC: 0.8660
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4231 AUC: 0.8856
# Batch: 13/13 (valid)
# valid Loss: 0.4541 AUC: 0.8626
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4172 AUC: 0.8893
# Batch: 13/13 (valid)
# valid Loss: 0.4648 AUC: 0.8669
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4253 AUC: 0.8827
# Batch: 13/13 (valid)
# valid Loss: 0.4573 AUC: 0.8663
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4198 AUC: 0.8909
# Batch: 13/13 (valid)
# valid Loss: 0.4524 AUC: 0.8679
#
# Training complete in 18m 30s
# Best val AUC: 0.8679
#
# << Spec: 2 >>
# Epoch 0/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4331 AUC: 0.8742
# Batch: 13/13 (valid)
# valid Loss: 0.4524 AUC: 0.8679
#
# Epoch 1/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4433 AUC: 0.8749
# Batch: 13/13 (valid)
# valid Loss: 0.4669 AUC: 0.8762
#
# Epoch 2/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4347 AUC: 0.8912
# Batch: 13/13 (valid)
# valid Loss: 0.4346 AUC: 0.8877
#
# Epoch 3/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4064 AUC: 0.8983
# Batch: 13/13 (valid)
# valid Loss: 0.4518 AUC: 0.9043
#
# Epoch 4/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3882 AUC: 0.9159
# Batch: 13/13 (valid)
# valid Loss: 0.4004 AUC: 0.8933
#
# Epoch 5/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3652 AUC: 0.9203
# Batch: 13/13 (valid)
# valid Loss: 0.4043 AUC: 0.9008
#
# Epoch 6/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3570 AUC: 0.9250
# Batch: 13/13 (valid)
# valid Loss: 0.3847 AUC: 0.9054
#
# Epoch 7/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3338 AUC: 0.9313
# Batch: 13/13 (valid)
# valid Loss: 0.3729 AUC: 0.9154
#
# Epoch 8/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3129 AUC: 0.9356
# Batch: 13/13 (valid)
# valid Loss: 0.3580 AUC: 0.9203
#
# Epoch 9/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2947 AUC: 0.9394
# Batch: 13/13 (valid)
# valid Loss: 0.3386 AUC: 0.9219
#
# Epoch 10/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2972 AUC: 0.9374
# Batch: 13/13 (valid)
# valid Loss: 0.3411 AUC: 0.9228
#
# Epoch 11/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2718 AUC: 0.9417
# Batch: 13/13 (valid)
# valid Loss: 0.3363 AUC: 0.9245
#
# Epoch 12/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2753 AUC: 0.9389
# Batch: 13/13 (valid)
# valid Loss: 0.3310 AUC: 0.9241
#
# Epoch 13/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2718 AUC: 0.9408
# Batch: 13/13 (valid)
# valid Loss: 0.3223 AUC: 0.9289
#
# Epoch 14/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2648 AUC: 0.9419
# Batch: 13/13 (valid)
# valid Loss: 0.3235 AUC: 0.9294
#
# Epoch 15/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2666 AUC: 0.9413
# Batch: 13/13 (valid)
# valid Loss: 0.3235 AUC: 0.9294
#
# Epoch 16/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2670 AUC: 0.9431
# Batch: 13/13 (valid)
# valid Loss: 0.3260 AUC: 0.9281
#
# Epoch 17/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2659 AUC: 0.9413
# Batch: 13/13 (valid)
# valid Loss: 0.3202 AUC: 0.9289
#
# Epoch 18/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2572 AUC: 0.9424
# Batch: 13/13 (valid)
# valid Loss: 0.3195 AUC: 0.9290
#
# Epoch 19/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2753 AUC: 0.9389
# Batch: 13/13 (valid)
# valid Loss: 0.3330 AUC: 0.9243
#
# Training complete in 25m 39s
# Best val AUC: 0.9294
#
# << Spec: 3 >>
# Epoch 0/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2599 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.3235 AUC: 0.9294
#
# Epoch 1/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2739 AUC: 0.9388
# Batch: 13/13 (valid)
# valid Loss: 0.3178 AUC: 0.9336
#
# Epoch 2/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2611 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3344 AUC: 0.9297
#
# Epoch 3/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2649 AUC: 0.9403
# Batch: 13/13 (valid)
# valid Loss: 0.3096 AUC: 0.9337
#
# Epoch 4/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2726 AUC: 0.9385
# Batch: 13/13 (valid)
# valid Loss: 0.3161 AUC: 0.9316
#
# Epoch 5/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2705 AUC: 0.9371
# Batch: 13/13 (valid)
# valid Loss: 0.3137 AUC: 0.9333
#
# Epoch 6/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2705 AUC: 0.9398
# Batch: 13/13 (valid)
# valid Loss: 0.3117 AUC: 0.9328
#
# Epoch 7/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2835 AUC: 0.9387
# Batch: 13/13 (valid)
# valid Loss: 0.3175 AUC: 0.9344
#
# Epoch 8/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2720 AUC: 0.9400
# Batch: 13/13 (valid)
# valid Loss: 0.3060 AUC: 0.9299
#
# Epoch 9/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2779 AUC: 0.9381
# Batch: 13/13 (valid)
# valid Loss: 0.3656 AUC: 0.9229
#
# Epoch 10/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2768 AUC: 0.9395
# Batch: 13/13 (valid)
# valid Loss: 0.3605 AUC: 0.9225
#
# Epoch 11/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2944 AUC: 0.9352
# Batch: 13/13 (valid)
# valid Loss: 0.3135 AUC: 0.9265
#
# Epoch 12/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2697 AUC: 0.9390
# Batch: 13/13 (valid)
# valid Loss: 0.3605 AUC: 0.9170
#
# Epoch 13/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2644 AUC: 0.9385
# Batch: 13/13 (valid)
# valid Loss: 0.3278 AUC: 0.9269
#
# Epoch 14/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2580 AUC: 0.9397
# Batch: 13/13 (valid)
# valid Loss: 0.3262 AUC: 0.9288
#
# Epoch 15/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2474 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.3130 AUC: 0.9317
#
# Epoch 16/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2352 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.2873 AUC: 0.9345
#
# Epoch 17/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2374 AUC: 0.9436
# Batch: 13/13 (valid)
# valid Loss: 0.3033 AUC: 0.9391
#
# Epoch 18/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2236 AUC: 0.9453
# Batch: 13/13 (valid)
# valid Loss: 0.2748 AUC: 0.9409
#
# Epoch 19/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2288 AUC: 0.9448
# Batch: 13/13 (valid)
# valid Loss: 0.2815 AUC: 0.9391
#
# Epoch 20/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2249 AUC: 0.9436
# Batch: 13/13 (valid)
# valid Loss: 0.2821 AUC: 0.9389
#
# Epoch 21/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2252 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.2815 AUC: 0.9389
#
# Epoch 22/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2272 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.2792 AUC: 0.9395
#
# Epoch 23/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2301 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.2792 AUC: 0.9402
#
# Epoch 24/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2296 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.2841 AUC: 0.9396
#
# Epoch 25/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2287 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3067 AUC: 0.9316
#
# Epoch 26/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2368 AUC: 0.9431
# Batch: 13/13 (valid)
# valid Loss: 0.2746 AUC: 0.9364
#
# Epoch 27/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2413 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.2808 AUC: 0.9397
#
# Epoch 28/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2377 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3165 AUC: 0.9305
#
# Epoch 29/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2672 AUC: 0.9377
# Batch: 13/13 (valid)
# valid Loss: 0.2946 AUC: 0.9344
#
# Epoch 30/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2599 AUC: 0.9409
# Batch: 13/13 (valid)
# valid Loss: 0.2984 AUC: 0.9343
#
# Epoch 31/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2586 AUC: 0.9403
# Batch: 13/13 (valid)
# valid Loss: 0.3215 AUC: 0.9281
#
# Epoch 32/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2697 AUC: 0.9392
# Batch: 13/13 (valid)
# valid Loss: 0.3640 AUC: 0.9199
#
# Epoch 33/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2588 AUC: 0.9409
# Batch: 13/13 (valid)
# valid Loss: 0.3252 AUC: 0.9305
#
# Epoch 34/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2433 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.3265 AUC: 0.9258
#
# Epoch 35/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2400 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.3417 AUC: 0.9220
#
# Epoch 36/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2400 AUC: 0.9432
# Batch: 13/13 (valid)
# valid Loss: 0.3272 AUC: 0.9298
#
# Epoch 37/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2364 AUC: 0.9449
# Batch: 13/13 (valid)
# valid Loss: 0.3535 AUC: 0.9218
#
# Epoch 38/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2282 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.3118 AUC: 0.9337
#
# Epoch 39/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2203 AUC: 0.9451
# Batch: 13/13 (valid)
# valid Loss: 0.2999 AUC: 0.9362
#
# Training complete in 70m 34s
# Best val AUC: 0.9409
#
# << Spec: 4 >>
# Epoch 0/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2304 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.2748 AUC: 0.9409
#
# Epoch 1/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2283 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.2939 AUC: 0.9382
#
# Epoch 2/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2232 AUC: 0.9447
# Batch: 13/13 (valid)
# valid Loss: 0.2674 AUC: 0.9406
#
# Epoch 3/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2339 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.3188 AUC: 0.9266
#
# Epoch 4/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2359 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.3085 AUC: 0.9340
#
# Epoch 5/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2415 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.2825 AUC: 0.9374
#
# Epoch 6/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2421 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.3303 AUC: 0.9230
#
# Epoch 7/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2521 AUC: 0.9436
# Batch: 13/13 (valid)
# valid Loss: 0.3240 AUC: 0.9307
#
# Epoch 8/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2646 AUC: 0.9398
# Batch: 13/13 (valid)
# valid Loss: 0.3255 AUC: 0.9282
#
# Epoch 9/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2720 AUC: 0.9408
# Batch: 13/13 (valid)
# valid Loss: 0.3346 AUC: 0.9279
#
# Epoch 10/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2689 AUC: 0.9400
# Batch: 13/13 (valid)
# valid Loss: 0.3288 AUC: 0.9339
#
# Epoch 11/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2694 AUC: 0.9390
# Batch: 13/13 (valid)
# valid Loss: 0.3288 AUC: 0.9270
#
# Epoch 12/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2628 AUC: 0.9419
# Batch: 13/13 (valid)
# valid Loss: 0.3410 AUC: 0.9237
#
# Epoch 13/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2553 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.2917 AUC: 0.9340
#
# Epoch 14/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2477 AUC: 0.9419
# Batch: 13/13 (valid)
# valid Loss: 0.3083 AUC: 0.9288
#
# Epoch 15/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2432 AUC: 0.9426
# Batch: 13/13 (valid)
# valid Loss: 0.2839 AUC: 0.9327
#
# Epoch 16/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2354 AUC: 0.9417
# Batch: 13/13 (valid)
# valid Loss: 0.3101 AUC: 0.9203
#
# Epoch 17/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2289 AUC: 0.9454
# Batch: 13/13 (valid)
# valid Loss: 0.2787 AUC: 0.9304
#
# Epoch 18/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2281 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.2835 AUC: 0.9306
#
# Epoch 19/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2236 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.2805 AUC: 0.9314
#
# Training complete in 37m 0s
# Best val AUC: 0.9409
#
# << Spec: 5 >>
# Epoch 0/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2210 AUC: 0.9455
# Batch: 13/13 (valid)
# valid Loss: 0.2748 AUC: 0.9409
#
# Epoch 1/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2239 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.2691 AUC: 0.9403
#
# Epoch 2/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2281 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.2758 AUC: 0.9401
#
# Epoch 3/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2396 AUC: 0.9429
# Batch: 13/13 (valid)
# valid Loss: 0.3034 AUC: 0.9365
#
# Epoch 4/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2307 AUC: 0.9454
# Batch: 13/13 (valid)
# valid Loss: 0.2951 AUC: 0.9335
#
# Epoch 5/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2554 AUC: 0.9407
# Batch: 13/13 (valid)
# valid Loss: 0.3129 AUC: 0.9293
#
# Epoch 6/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2454 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.3248 AUC: 0.9197
#
# Epoch 7/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2626 AUC: 0.9383
# Batch: 13/13 (valid)
# valid Loss: 0.3480 AUC: 0.9202
#
# Epoch 8/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2683 AUC: 0.9387
# Batch: 13/13 (valid)
# valid Loss: 0.3256 AUC: 0.9221
#
# Epoch 9/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2672 AUC: 0.9404
# Batch: 13/13 (valid)
# valid Loss: 0.4258 AUC: 0.9045
#
# Epoch 10/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2936 AUC: 0.9334
# Batch: 13/13 (valid)
# valid Loss: 0.3611 AUC: 0.9198
#
# Epoch 11/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2810 AUC: 0.9370
# Batch: 13/13 (valid)
# valid Loss: 0.3418 AUC: 0.9224
#
# Epoch 12/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2655 AUC: 0.9368
# Batch: 13/13 (valid)
# valid Loss: 0.3080 AUC: 0.9340
#
# Epoch 13/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2588 AUC: 0.9415
# Batch: 13/13 (valid)
# valid Loss: 0.3085 AUC: 0.9296
#
# Epoch 14/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2429 AUC: 0.9424
# Batch: 13/13 (valid)
# valid Loss: 0.3190 AUC: 0.9310
#
# Epoch 15/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2424 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.3035 AUC: 0.9312
#
# Epoch 16/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2282 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.2771 AUC: 0.9369
#
# Epoch 17/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2225 AUC: 0.9453
# Batch: 13/13 (valid)
# valid Loss: 0.2871 AUC: 0.9323
#
# Epoch 18/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2191 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.2914 AUC: 0.9325
#
# Epoch 19/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2220 AUC: 0.9458
# Batch: 13/13 (valid)
# valid Loss: 0.2851 AUC: 0.9329
#
# Training complete in 39m 40s
# Best val AUC: 0.9409
#
# << Spec: 6 >>
# Epoch 0/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2306 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.2748 AUC: 0.9409
#
# Epoch 1/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2216 AUC: 0.9447
# Batch: 13/13 (valid)
# valid Loss: 0.2851 AUC: 0.9389
#
# Epoch 2/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2319 AUC: 0.9451
# Batch: 13/13 (valid)
# valid Loss: 0.2766 AUC: 0.9384
#
# Epoch 3/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2339 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.3305 AUC: 0.9279
#
# Epoch 4/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2418 AUC: 0.9422
# Batch: 13/13 (valid)
# valid Loss: 0.3235 AUC: 0.9273
#
# Epoch 5/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2557 AUC: 0.9421
# Batch: 13/13 (valid)
# valid Loss: 0.3272 AUC: 0.9297
#
# Epoch 6/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2644 AUC: 0.9393
# Batch: 13/13 (valid)
# valid Loss: 0.3211 AUC: 0.9325
#
# Epoch 7/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2623 AUC: 0.9410
# Batch: 13/13 (valid)
# valid Loss: 0.3083 AUC: 0.9295
#
# Epoch 8/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2793 AUC: 0.9367
# Batch: 13/13 (valid)
# valid Loss: 0.3762 AUC: 0.9196
#
# Epoch 9/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2885 AUC: 0.9352
# Batch: 13/13 (valid)
# valid Loss: 0.3324 AUC: 0.9231
#
# Epoch 10/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2888 AUC: 0.9359
# Batch: 13/13 (valid)
# valid Loss: 0.3855 AUC: 0.9112
#
# Epoch 11/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2955 AUC: 0.9345
# Batch: 13/13 (valid)
# valid Loss: 0.3512 AUC: 0.9230
#
# Epoch 12/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2651 AUC: 0.9403
# Batch: 13/13 (valid)
# valid Loss: 0.3561 AUC: 0.9173
#
# Epoch 13/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2640 AUC: 0.9389
# Batch: 13/13 (valid)
# valid Loss: 0.3234 AUC: 0.9247
#
# Epoch 14/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2594 AUC: 0.9394
# Batch: 13/13 (valid)
# valid Loss: 0.3154 AUC: 0.9281
#
# Epoch 15/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2575 AUC: 0.9413
# Batch: 13/13 (valid)
# valid Loss: 0.2989 AUC: 0.9301
#
# Epoch 16/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2323 AUC: 0.9422
# Batch: 13/13 (valid)
# valid Loss: 0.2917 AUC: 0.9371
#
# Epoch 17/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2304 AUC: 0.9452
# Batch: 13/13 (valid)
# valid Loss: 0.2778 AUC: 0.9370
#
# Epoch 18/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2304 AUC: 0.9457
# Batch: 13/13 (valid)
# valid Loss: 0.2812 AUC: 0.9339
#
# Epoch 19/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2261 AUC: 0.9441
# Batch: 13/13 (valid)
# valid Loss: 0.2837 AUC: 0.9343
#
# Training complete in 40m 4s
# Best val AUC: 0.9409
#
# - Validation -
# === Normal Valid ===
# Batch: 13/13
#
# Norml Valid AUC: 0.9419
#
# === Valid Time Augmentation ===
# n: 0/4
# ----------
# Batch: 13/13
# n: 1/4
# ----------
# Batch: 13/13
# n: 2/4
# ----------
# Batch: 13/13
# n: 3/4
# ----------
# Batch: 13/13
# n: 4/4
# ----------
# Batch: 13/13
#
# VTA AUC: 0.9405
#
# === Mixed Valid ===
#
# Mixed AUC: 0.9414
#
# === Fold: 1 ===
# GPU Memory: 1024
# << Spec: 0 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.7272 AUC: 0.4513
# Batch: 13/13 (valid)
# valid Loss: 0.7461 AUC: 0.3990
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.6453 AUC: 0.6622
# Batch: 13/13 (valid)
# valid Loss: 0.5751 AUC: 0.7725
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5810 AUC: 0.7538
# Batch: 13/13 (valid)
# valid Loss: 0.5309 AUC: 0.8016
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5474 AUC: 0.7887
# Batch: 13/13 (valid)
# valid Loss: 0.5033 AUC: 0.8241
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5318 AUC: 0.8055
# Batch: 13/13 (valid)
# valid Loss: 0.4885 AUC: 0.8338
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5292 AUC: 0.8135
# Batch: 13/13 (valid)
# valid Loss: 0.4852 AUC: 0.8352
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5005 AUC: 0.8393
# Batch: 13/13 (valid)
# valid Loss: 0.4814 AUC: 0.8382
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4901 AUC: 0.8446
# Batch: 13/13 (valid)
# valid Loss: 0.4750 AUC: 0.8450
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4799 AUC: 0.8538
# Batch: 13/13 (valid)
# valid Loss: 0.4808 AUC: 0.8394
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4718 AUC: 0.8584
# Batch: 13/13 (valid)
# valid Loss: 0.4788 AUC: 0.8428
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4625 AUC: 0.8646
# Batch: 13/13 (valid)
# valid Loss: 0.4696 AUC: 0.8514
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4589 AUC: 0.8686
# Batch: 13/13 (valid)
# valid Loss: 0.4685 AUC: 0.8520
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4627 AUC: 0.8673
# Batch: 13/13 (valid)
# valid Loss: 0.4727 AUC: 0.8526
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4579 AUC: 0.8625
# Batch: 13/13 (valid)
# valid Loss: 0.4661 AUC: 0.8538
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4522 AUC: 0.8754
# Batch: 13/13 (valid)
# valid Loss: 0.4666 AUC: 0.8538
#
# Training complete in 18m 31s
# Best val AUC: 0.8538
#
# << Spec: 1 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4468 AUC: 0.8742
# Batch: 13/13 (valid)
# valid Loss: 0.4666 AUC: 0.8538
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4498 AUC: 0.8725
# Batch: 13/13 (valid)
# valid Loss: 0.4668 AUC: 0.8530
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4481 AUC: 0.8764
# Batch: 13/13 (valid)
# valid Loss: 0.4625 AUC: 0.8567
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4507 AUC: 0.8708
# Batch: 13/13 (valid)
# valid Loss: 0.4612 AUC: 0.8584
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4529 AUC: 0.8680
# Batch: 13/13 (valid)
# valid Loss: 0.4670 AUC: 0.8517
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4472 AUC: 0.8765
# Batch: 13/13 (valid)
# valid Loss: 0.4624 AUC: 0.8570
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4430 AUC: 0.8727
# Batch: 13/13 (valid)
# valid Loss: 0.4657 AUC: 0.8570
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4510 AUC: 0.8714
# Batch: 13/13 (valid)
# valid Loss: 0.4838 AUC: 0.8570
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4421 AUC: 0.8734
# Batch: 13/13 (valid)
# valid Loss: 0.4611 AUC: 0.8577
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4349 AUC: 0.8812
# Batch: 13/13 (valid)
# valid Loss: 0.4664 AUC: 0.8576
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4362 AUC: 0.8777
# Batch: 13/13 (valid)
# valid Loss: 0.4804 AUC: 0.8530
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4252 AUC: 0.8865
# Batch: 13/13 (valid)
# valid Loss: 0.4634 AUC: 0.8579
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4371 AUC: 0.8767
# Batch: 13/13 (valid)
# valid Loss: 0.4601 AUC: 0.8566
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4197 AUC: 0.8895
# Batch: 13/13 (valid)
# valid Loss: 0.4675 AUC: 0.8552
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4220 AUC: 0.8887
# Batch: 13/13 (valid)
# valid Loss: 0.4687 AUC: 0.8535
#
# Training complete in 18m 29s
# Best val AUC: 0.8584
#
# << Spec: 2 >>
# Epoch 0/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4380 AUC: 0.8807
# Batch: 13/13 (valid)
# valid Loss: 0.4612 AUC: 0.8584
#
# Epoch 1/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4495 AUC: 0.8763
# Batch: 13/13 (valid)
# valid Loss: 0.4433 AUC: 0.8700
#
# Epoch 2/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4285 AUC: 0.8938
# Batch: 13/13 (valid)
# valid Loss: 0.4555 AUC: 0.8894
#
# Epoch 3/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3989 AUC: 0.9059
# Batch: 13/13 (valid)
# valid Loss: 0.4159 AUC: 0.8936
#
# Epoch 4/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3696 AUC: 0.9209
# Batch: 13/13 (valid)
# valid Loss: 0.4115 AUC: 0.9008
#
# Epoch 5/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3496 AUC: 0.9235
# Batch: 13/13 (valid)
# valid Loss: 0.3800 AUC: 0.9093
#
# Epoch 6/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3437 AUC: 0.9304
# Batch: 13/13 (valid)
# valid Loss: 0.3912 AUC: 0.9042
#
# Epoch 7/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3127 AUC: 0.9347
# Batch: 13/13 (valid)
# valid Loss: 0.3725 AUC: 0.9195
#
# Epoch 8/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3001 AUC: 0.9356
# Batch: 13/13 (valid)
# valid Loss: 0.3633 AUC: 0.9173
#
# Epoch 9/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2930 AUC: 0.9380
# Batch: 13/13 (valid)
# valid Loss: 0.3497 AUC: 0.9161
#
# Epoch 10/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2928 AUC: 0.9347
# Batch: 13/13 (valid)
# valid Loss: 0.3560 AUC: 0.9162
#
# Epoch 11/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2716 AUC: 0.9416
# Batch: 13/13 (valid)
# valid Loss: 0.3303 AUC: 0.9220
#
# Epoch 12/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2628 AUC: 0.9401
# Batch: 13/13 (valid)
# valid Loss: 0.3343 AUC: 0.9252
#
# Epoch 13/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2598 AUC: 0.9422
# Batch: 13/13 (valid)
# valid Loss: 0.3336 AUC: 0.9249
#
# Epoch 14/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2575 AUC: 0.9422
# Batch: 13/13 (valid)
# valid Loss: 0.3315 AUC: 0.9244
#
# Epoch 15/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2633 AUC: 0.9403
# Batch: 13/13 (valid)
# valid Loss: 0.3315 AUC: 0.9244
#
# Epoch 16/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2640 AUC: 0.9412
# Batch: 13/13 (valid)
# valid Loss: 0.3316 AUC: 0.9255
#
# Epoch 17/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2523 AUC: 0.9431
# Batch: 13/13 (valid)
# valid Loss: 0.3342 AUC: 0.9246
#
# Epoch 18/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2652 AUC: 0.9397
# Batch: 13/13 (valid)
# valid Loss: 0.3264 AUC: 0.9302
#
# Epoch 19/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2536 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3419 AUC: 0.9228
#
# Training complete in 25m 34s
# Best val AUC: 0.9302
#
# << Spec: 3 >>
# Epoch 0/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2608 AUC: 0.9403
# Batch: 13/13 (valid)
# valid Loss: 0.3264 AUC: 0.9302
#
# Epoch 1/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2524 AUC: 0.9421
# Batch: 13/13 (valid)
# valid Loss: 0.3257 AUC: 0.9263
#
# Epoch 2/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2612 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3167 AUC: 0.9297
#
# Epoch 3/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2706 AUC: 0.9393
# Batch: 13/13 (valid)
# valid Loss: 0.3447 AUC: 0.9230
#
# Epoch 4/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2617 AUC: 0.9420
# Batch: 13/13 (valid)
# valid Loss: 0.3403 AUC: 0.9255
#
# Epoch 5/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2594 AUC: 0.9409
# Batch: 13/13 (valid)
# valid Loss: 0.3418 AUC: 0.9231
#
# Epoch 6/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2811 AUC: 0.9361
# Batch: 13/13 (valid)
# valid Loss: 0.3423 AUC: 0.9283
#
# Epoch 7/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2644 AUC: 0.9417
# Batch: 13/13 (valid)
# valid Loss: 0.3966 AUC: 0.9214
#
# Epoch 8/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2668 AUC: 0.9400
# Batch: 13/13 (valid)
# valid Loss: 0.3339 AUC: 0.9235
#
# Epoch 9/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2722 AUC: 0.9357
# Batch: 13/13 (valid)
# valid Loss: 0.3532 AUC: 0.9220
#
# Epoch 10/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2826 AUC: 0.9369
# Batch: 13/13 (valid)
# valid Loss: 0.3797 AUC: 0.9070
#
# Epoch 11/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2736 AUC: 0.9373
# Batch: 13/13 (valid)
# valid Loss: 0.3537 AUC: 0.9105
#
# Epoch 12/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2547 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.3837 AUC: 0.9155
#
# Epoch 13/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2765 AUC: 0.9384
# Batch: 13/13 (valid)
# valid Loss: 0.3372 AUC: 0.9212
#
# Epoch 14/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2386 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.3093 AUC: 0.9264
#
# Epoch 15/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2432 AUC: 0.9423
# Batch: 13/13 (valid)
# valid Loss: 0.3307 AUC: 0.9180
#
# Epoch 16/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2351 AUC: 0.9409
# Batch: 13/13 (valid)
# valid Loss: 0.3046 AUC: 0.9218
#
# Epoch 17/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2367 AUC: 0.9442
# Batch: 13/13 (valid)
# valid Loss: 0.3037 AUC: 0.9310
#
# Epoch 18/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2351 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.3023 AUC: 0.9325
#
# Epoch 19/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2272 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.2994 AUC: 0.9312
#
# Epoch 20/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2252 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.3003 AUC: 0.9309
#
# Epoch 21/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2250 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.3005 AUC: 0.9309
#
# Epoch 22/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2268 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.3078 AUC: 0.9305
#
# Epoch 23/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2233 AUC: 0.9452
# Batch: 13/13 (valid)
# valid Loss: 0.3035 AUC: 0.9304
#
# Epoch 24/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2251 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.2996 AUC: 0.9280
#
# Epoch 25/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2295 AUC: 0.9448
# Batch: 13/13 (valid)
# valid Loss: 0.3234 AUC: 0.9254
#
# Epoch 26/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2353 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.3192 AUC: 0.9251
#
# Epoch 27/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2388 AUC: 0.9426
# Batch: 13/13 (valid)
# valid Loss: 0.3373 AUC: 0.9168
#
# Epoch 28/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2464 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.4520 AUC: 0.9089
#
# Epoch 29/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2653 AUC: 0.9396
# Batch: 13/13 (valid)
# valid Loss: 0.3440 AUC: 0.9237
#
# Epoch 30/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2682 AUC: 0.9384
# Batch: 13/13 (valid)
# valid Loss: 0.3285 AUC: 0.9206
#
# Epoch 31/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2689 AUC: 0.9376
# Batch: 13/13 (valid)
# valid Loss: 0.3919 AUC: 0.9187
#
# Epoch 32/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2679 AUC: 0.9352
# Batch: 13/13 (valid)
# valid Loss: 0.3219 AUC: 0.9230
#
# Epoch 33/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2512 AUC: 0.9412
# Batch: 13/13 (valid)
# valid Loss: 0.3237 AUC: 0.9275
#
# Epoch 34/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2472 AUC: 0.9411
# Batch: 13/13 (valid)
# valid Loss: 0.3162 AUC: 0.9296
#
# Epoch 35/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2428 AUC: 0.9413
# Batch: 13/13 (valid)
# valid Loss: 0.3133 AUC: 0.9325
#
# Epoch 36/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2458 AUC: 0.9436
# Batch: 13/13 (valid)
# valid Loss: 0.3209 AUC: 0.9295
#
# Epoch 37/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2287 AUC: 0.9443
# Batch: 13/13 (valid)
# valid Loss: 0.2999 AUC: 0.9298
#
# Epoch 38/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2265 AUC: 0.9451
# Batch: 13/13 (valid)
# valid Loss: 0.2999 AUC: 0.9271
#
# Epoch 39/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2356 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.3083 AUC: 0.9307
#
# Training complete in 70m 36s
# Best val AUC: 0.9325
#
# << Spec: 4 >>
# Epoch 0/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2244 AUC: 0.9441
# Batch: 13/13 (valid)
# valid Loss: 0.3023 AUC: 0.9325
#
# Epoch 1/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2216 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.2926 AUC: 0.9335
#
# Epoch 2/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2355 AUC: 0.9429
# Batch: 13/13 (valid)
# valid Loss: 0.2985 AUC: 0.9282
#
# Epoch 3/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2348 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.3014 AUC: 0.9285
#
# Epoch 4/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2379 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.3201 AUC: 0.9317
#
# Epoch 5/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2469 AUC: 0.9423
# Batch: 13/13 (valid)
# valid Loss: 0.3462 AUC: 0.9273
#
# Epoch 6/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2481 AUC: 0.9411
# Batch: 13/13 (valid)
# valid Loss: 0.3571 AUC: 0.9112
#
# Epoch 7/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2595 AUC: 0.9398
# Batch: 13/13 (valid)
# valid Loss: 0.3218 AUC: 0.9244
#
# Epoch 8/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2603 AUC: 0.9419
# Batch: 13/13 (valid)
# valid Loss: 0.3397 AUC: 0.9185
#
# Epoch 9/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2786 AUC: 0.9390
# Batch: 13/13 (valid)
# valid Loss: 0.3275 AUC: 0.9202
#
# Epoch 10/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2797 AUC: 0.9357
# Batch: 13/13 (valid)
# valid Loss: 0.3263 AUC: 0.9244
#
# Epoch 11/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2611 AUC: 0.9406
# Batch: 13/13 (valid)
# valid Loss: 0.3767 AUC: 0.9129
#
# Epoch 12/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2575 AUC: 0.9409
# Batch: 13/13 (valid)
# valid Loss: 0.3832 AUC: 0.9177
#
# Epoch 13/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2658 AUC: 0.9410
# Batch: 13/13 (valid)
# valid Loss: 0.3504 AUC: 0.9219
#
# Epoch 14/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2565 AUC: 0.9408
# Batch: 13/13 (valid)
# valid Loss: 0.3717 AUC: 0.9228
#
# Epoch 15/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2519 AUC: 0.9404
# Batch: 13/13 (valid)
# valid Loss: 0.3201 AUC: 0.9307
#
# Epoch 16/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2339 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3346 AUC: 0.9293
#
# Epoch 17/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2293 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.3061 AUC: 0.9342
#
# Epoch 18/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2307 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.3012 AUC: 0.9345
#
# Epoch 19/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2243 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3071 AUC: 0.9329
#
# Training complete in 36m 58s
# Best val AUC: 0.9345
#
# << Spec: 5 >>
# Epoch 0/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2279 AUC: 0.9428
# Batch: 13/13 (valid)
# valid Loss: 0.3012 AUC: 0.9345
#
# Epoch 1/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2241 AUC: 0.9457
# Batch: 13/13 (valid)
# valid Loss: 0.3033 AUC: 0.9308
#
# Epoch 2/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2246 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.3039 AUC: 0.9338
#
# Epoch 3/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2222 AUC: 0.9441
# Batch: 13/13 (valid)
# valid Loss: 0.3244 AUC: 0.9188
#
# Epoch 4/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2335 AUC: 0.9441
# Batch: 13/13 (valid)
# valid Loss: 0.3094 AUC: 0.9285
#
# Epoch 5/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2365 AUC: 0.9407
# Batch: 13/13 (valid)
# valid Loss: 0.3460 AUC: 0.9215
#
# Epoch 6/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2372 AUC: 0.9424
# Batch: 13/13 (valid)
# valid Loss: 0.3089 AUC: 0.9329
#
# Epoch 7/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2450 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3121 AUC: 0.9279
#
# Epoch 8/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2522 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3342 AUC: 0.9219
#
# Epoch 9/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2568 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3199 AUC: 0.9267
#
# Epoch 10/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2932 AUC: 0.9345
# Batch: 13/13 (valid)
# valid Loss: 0.3503 AUC: 0.9175
#
# Epoch 11/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2709 AUC: 0.9402
# Batch: 13/13 (valid)
# valid Loss: 0.3284 AUC: 0.9252
#
# Epoch 12/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2550 AUC: 0.9431
# Batch: 13/13 (valid)
# valid Loss: 0.3412 AUC: 0.9166
#
# Epoch 13/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2667 AUC: 0.9407
# Batch: 13/13 (valid)
# valid Loss: 0.3443 AUC: 0.9095
#
# Epoch 14/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2439 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.3592 AUC: 0.9097
#
# Epoch 15/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2326 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.3264 AUC: 0.9176
#
# Epoch 16/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2235 AUC: 0.9454
# Batch: 13/13 (valid)
# valid Loss: 0.3399 AUC: 0.9151
#
# Epoch 17/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2287 AUC: 0.9459
# Batch: 13/13 (valid)
# valid Loss: 0.3192 AUC: 0.9244
#
# Epoch 18/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2204 AUC: 0.9449
# Batch: 13/13 (valid)
# valid Loss: 0.3064 AUC: 0.9258
#
# Epoch 19/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2170 AUC: 0.9440
# Batch: 13/13 (valid)
# valid Loss: 0.3037 AUC: 0.9255
#
# Training complete in 39m 45s
# Best val AUC: 0.9345
#
# << Spec: 6 >>
# Epoch 0/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2230 AUC: 0.9443
# Batch: 13/13 (valid)
# valid Loss: 0.3012 AUC: 0.9345
#
# Epoch 1/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2204 AUC: 0.9453
# Batch: 13/13 (valid)
# valid Loss: 0.2996 AUC: 0.9326
#
# Epoch 2/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2252 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.3127 AUC: 0.9243
#
# Epoch 3/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2349 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.3070 AUC: 0.9253
#
# Epoch 4/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2463 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3078 AUC: 0.9309
#
# Epoch 5/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2485 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3281 AUC: 0.9210
#
# Epoch 6/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2469 AUC: 0.9426
# Batch: 13/13 (valid)
# valid Loss: 0.3348 AUC: 0.9241
#
# Epoch 7/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2476 AUC: 0.9417
# Batch: 13/13 (valid)
# valid Loss: 0.3454 AUC: 0.9224
#
# Epoch 8/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2531 AUC: 0.9419
# Batch: 13/13 (valid)
# valid Loss: 0.4254 AUC: 0.8973
#
# Epoch 9/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2742 AUC: 0.9397
# Batch: 13/13 (valid)
# valid Loss: 0.3592 AUC: 0.9182
#
# Epoch 10/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2822 AUC: 0.9323
# Batch: 13/13 (valid)
# valid Loss: 0.3659 AUC: 0.9097
#
# Epoch 11/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2731 AUC: 0.9385
# Batch: 13/13 (valid)
# valid Loss: 0.3490 AUC: 0.9192
#
# Epoch 12/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2558 AUC: 0.9405
# Batch: 13/13 (valid)
# valid Loss: 0.3760 AUC: 0.9151
#
# Epoch 13/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2551 AUC: 0.9414
# Batch: 13/13 (valid)
# valid Loss: 0.3404 AUC: 0.9240
#
# Epoch 14/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2500 AUC: 0.9429
# Batch: 13/13 (valid)
# valid Loss: 0.3411 AUC: 0.9199
#
# Epoch 15/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2411 AUC: 0.9399
# Batch: 13/13 (valid)
# valid Loss: 0.3205 AUC: 0.9275
#
# Epoch 16/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2297 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.3407 AUC: 0.9230
#
# Epoch 17/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2289 AUC: 0.9448
# Batch: 13/13 (valid)
# valid Loss: 0.3068 AUC: 0.9306
#
# Epoch 18/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2249 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.2997 AUC: 0.9327
#
# Epoch 19/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2226 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.2939 AUC: 0.9331
#
# Training complete in 39m 55s
# Best val AUC: 0.9345
#
# - Validation -
# === Normal Valid ===
# Batch: 13/13
#
# Norml Valid AUC: 0.9357
#
# === Valid Time Augmentation ===
# n: 0/4
# ----------
# Batch: 13/13
# n: 1/4
# ----------
# Batch: 13/13
# n: 2/4
# ----------
# Batch: 13/13
# n: 3/4
# ----------
# Batch: 13/13
# n: 4/4
# ----------
# Batch: 13/13
#
# VTA AUC: 0.9357
#
# === Mixed Valid ===
#
# Mixed AUC: 0.9359
#
# === Fold: 2 ===
# GPU Memory: 1024
# << Spec: 0 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.7194 AUC: 0.4636
# Batch: 13/13 (valid)
# valid Loss: 0.7209 AUC: 0.4574
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.6439 AUC: 0.6591
# Batch: 13/13 (valid)
# valid Loss: 0.5733 AUC: 0.7598
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5830 AUC: 0.7589
# Batch: 13/13 (valid)
# valid Loss: 0.5275 AUC: 0.7964
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5589 AUC: 0.7788
# Batch: 13/13 (valid)
# valid Loss: 0.5026 AUC: 0.8228
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5461 AUC: 0.7905
# Batch: 13/13 (valid)
# valid Loss: 0.4987 AUC: 0.8446
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5190 AUC: 0.8153
# Batch: 13/13 (valid)
# valid Loss: 0.4751 AUC: 0.8530
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5087 AUC: 0.8268
# Batch: 13/13 (valid)
# valid Loss: 0.4621 AUC: 0.8591
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5005 AUC: 0.8317
# Batch: 13/13 (valid)
# valid Loss: 0.4507 AUC: 0.8671
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4893 AUC: 0.8436
# Batch: 13/13 (valid)
# valid Loss: 0.4456 AUC: 0.8701
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4809 AUC: 0.8538
# Batch: 13/13 (valid)
# valid Loss: 0.4537 AUC: 0.8689
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4612 AUC: 0.8630
# Batch: 13/13 (valid)
# valid Loss: 0.4452 AUC: 0.8720
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4702 AUC: 0.8537
# Batch: 13/13 (valid)
# valid Loss: 0.4408 AUC: 0.8762
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4701 AUC: 0.8578
# Batch: 13/13 (valid)
# valid Loss: 0.4396 AUC: 0.8774
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4637 AUC: 0.8613
# Batch: 13/13 (valid)
# valid Loss: 0.4371 AUC: 0.8771
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4576 AUC: 0.8644
# Batch: 13/13 (valid)
# valid Loss: 0.4360 AUC: 0.8792
#
# Training complete in 18m 26s
# Best val AUC: 0.8792
#
# << Spec: 1 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4478 AUC: 0.8723
# Batch: 13/13 (valid)
# valid Loss: 0.4360 AUC: 0.8792
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4536 AUC: 0.8668
# Batch: 13/13 (valid)
# valid Loss: 0.4332 AUC: 0.8795
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4547 AUC: 0.8648
# Batch: 13/13 (valid)
# valid Loss: 0.4321 AUC: 0.8811
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4494 AUC: 0.8727
# Batch: 13/13 (valid)
# valid Loss: 0.4346 AUC: 0.8754
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4602 AUC: 0.8655
# Batch: 13/13 (valid)
# valid Loss: 0.4314 AUC: 0.8812
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4560 AUC: 0.8720
# Batch: 13/13 (valid)
# valid Loss: 0.4273 AUC: 0.8854
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4477 AUC: 0.8677
# Batch: 13/13 (valid)
# valid Loss: 0.4364 AUC: 0.8842
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4559 AUC: 0.8703
# Batch: 13/13 (valid)
# valid Loss: 0.4298 AUC: 0.8818
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4344 AUC: 0.8827
# Batch: 13/13 (valid)
# valid Loss: 0.4250 AUC: 0.8803
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4452 AUC: 0.8720
# Batch: 13/13 (valid)
# valid Loss: 0.4233 AUC: 0.8855
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4349 AUC: 0.8826
# Batch: 13/13 (valid)
# valid Loss: 0.4250 AUC: 0.8807
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4453 AUC: 0.8774
# Batch: 13/13 (valid)
# valid Loss: 0.4248 AUC: 0.8862
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4462 AUC: 0.8769
# Batch: 13/13 (valid)
# valid Loss: 0.4276 AUC: 0.8825
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4206 AUC: 0.8871
# Batch: 13/13 (valid)
# valid Loss: 0.4217 AUC: 0.8848
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4241 AUC: 0.8878
# Batch: 13/13 (valid)
# valid Loss: 0.4215 AUC: 0.8864
#
# Training complete in 18m 31s
# Best val AUC: 0.8864
#
# << Spec: 2 >>
# Epoch 0/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4202 AUC: 0.8906
# Batch: 13/13 (valid)
# valid Loss: 0.4215 AUC: 0.8864
#
# Epoch 1/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4922 AUC: 0.8569
# Batch: 13/13 (valid)
# valid Loss: 0.4788 AUC: 0.8914
#
# Epoch 2/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4354 AUC: 0.8854
# Batch: 13/13 (valid)
# valid Loss: 0.4073 AUC: 0.8945
#
# Epoch 3/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3931 AUC: 0.9078
# Batch: 13/13 (valid)
# valid Loss: 0.3999 AUC: 0.9015
#
# Epoch 4/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3695 AUC: 0.9187
# Batch: 13/13 (valid)
# valid Loss: 0.4092 AUC: 0.9150
#
# Epoch 5/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3491 AUC: 0.9282
# Batch: 13/13 (valid)
# valid Loss: 0.3795 AUC: 0.9089
#
# Epoch 6/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3393 AUC: 0.9293
# Batch: 13/13 (valid)
# valid Loss: 0.3739 AUC: 0.9120
#
# Epoch 7/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3262 AUC: 0.9296
# Batch: 13/13 (valid)
# valid Loss: 0.3511 AUC: 0.9165
#
# Epoch 8/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3161 AUC: 0.9334
# Batch: 13/13 (valid)
# valid Loss: 0.3442 AUC: 0.9192
#
# Epoch 9/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2987 AUC: 0.9376
# Batch: 13/13 (valid)
# valid Loss: 0.3324 AUC: 0.9224
#
# Epoch 10/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2870 AUC: 0.9371
# Batch: 13/13 (valid)
# valid Loss: 0.3279 AUC: 0.9240
#
# Epoch 11/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2939 AUC: 0.9361
# Batch: 13/13 (valid)
# valid Loss: 0.3348 AUC: 0.9218
#
# Epoch 12/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2811 AUC: 0.9375
# Batch: 13/13 (valid)
# valid Loss: 0.3221 AUC: 0.9237
#
# Epoch 13/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2707 AUC: 0.9409
# Batch: 13/13 (valid)
# valid Loss: 0.3197 AUC: 0.9247
#
# Epoch 14/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2601 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3190 AUC: 0.9244
#
# Epoch 15/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2697 AUC: 0.9399
# Batch: 13/13 (valid)
# valid Loss: 0.3190 AUC: 0.9244
#
# Epoch 16/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2652 AUC: 0.9413
# Batch: 13/13 (valid)
# valid Loss: 0.3187 AUC: 0.9255
#
# Epoch 17/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2661 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3176 AUC: 0.9245
#
# Epoch 18/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2780 AUC: 0.9394
# Batch: 13/13 (valid)
# valid Loss: 0.3185 AUC: 0.9260
#
# Epoch 19/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2779 AUC: 0.9396
# Batch: 13/13 (valid)
# valid Loss: 0.3224 AUC: 0.9229
#
# Training complete in 25m 36s
# Best val AUC: 0.9260
#
# << Spec: 3 >>
# Epoch 0/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2632 AUC: 0.9406
# Batch: 13/13 (valid)
# valid Loss: 0.3185 AUC: 0.9260
#
# Epoch 1/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2691 AUC: 0.9405
# Batch: 13/13 (valid)
# valid Loss: 0.3110 AUC: 0.9286
#
# Epoch 2/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2599 AUC: 0.9422
# Batch: 13/13 (valid)
# valid Loss: 0.3177 AUC: 0.9263
#
# Epoch 3/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2743 AUC: 0.9384
# Batch: 13/13 (valid)
# valid Loss: 0.3327 AUC: 0.9223
#
# Epoch 4/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2736 AUC: 0.9395
# Batch: 13/13 (valid)
# valid Loss: 0.3275 AUC: 0.9178
#
# Epoch 5/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2637 AUC: 0.9400
# Batch: 13/13 (valid)
# valid Loss: 0.3151 AUC: 0.9237
#
# Epoch 6/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2657 AUC: 0.9416
# Batch: 13/13 (valid)
# valid Loss: 0.3250 AUC: 0.9289
#
# Epoch 7/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2757 AUC: 0.9400
# Batch: 13/13 (valid)
# valid Loss: 0.3279 AUC: 0.9211
#
# Epoch 8/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2824 AUC: 0.9367
# Batch: 13/13 (valid)
# valid Loss: 0.3372 AUC: 0.9219
#
# Epoch 9/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2696 AUC: 0.9395
# Batch: 13/13 (valid)
# valid Loss: 0.3339 AUC: 0.9181
#
# Epoch 10/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2811 AUC: 0.9369
# Batch: 13/13 (valid)
# valid Loss: 0.3483 AUC: 0.9124
#
# Epoch 11/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2731 AUC: 0.9374
# Batch: 13/13 (valid)
# ...
# train Loss: 0.4054 AUC: 0.9056
# Batch: 13/13 (valid)
# valid Loss: 0.3876 AUC: 0.9025
#
# Epoch 4/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3797 AUC: 0.9154
# Batch: 13/13 (valid)
# valid Loss: 0.3936 AUC: 0.9091
#
# Epoch 5/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3507 AUC: 0.9260
# Batch: 13/13 (valid)
# valid Loss: 0.3905 AUC: 0.9090
#
# Epoch 6/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3339 AUC: 0.9295
# Batch: 13/13 (valid)
# valid Loss: 0.3537 AUC: 0.9167
#
# Epoch 7/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3191 AUC: 0.9344
# Batch: 13/13 (valid)
# valid Loss: 0.3468 AUC: 0.9224
#
# Epoch 8/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3029 AUC: 0.9362
# Batch: 13/13 (valid)
# valid Loss: 0.3641 AUC: 0.9247
#
# Epoch 9/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2921 AUC: 0.9404
# Batch: 13/13 (valid)
# valid Loss: 0.3316 AUC: 0.9229
#
# Epoch 10/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2911 AUC: 0.9372
# Batch: 13/13 (valid)
# valid Loss: 0.3204 AUC: 0.9304
#
# Epoch 11/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2804 AUC: 0.9392
# Batch: 13/13 (valid)
# valid Loss: 0.3147 AUC: 0.9318
#
# Epoch 12/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2705 AUC: 0.9396
# Batch: 13/13 (valid)
# valid Loss: 0.3146 AUC: 0.9293
#
# Epoch 13/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2654 AUC: 0.9414
# Batch: 13/13 (valid)
# valid Loss: 0.3068 AUC: 0.9326
#
# Epoch 14/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2730 AUC: 0.9404
# Batch: 13/13 (valid)
# valid Loss: 0.3048 AUC: 0.9328
#
# Epoch 15/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2684 AUC: 0.9420
# Batch: 13/13 (valid)
# valid Loss: 0.3048 AUC: 0.9328
#
# Epoch 16/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2628 AUC: 0.9421
# Batch: 13/13 (valid)
# valid Loss: 0.3052 AUC: 0.9318
#
# Epoch 17/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2644 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3066 AUC: 0.9326
#
# Epoch 18/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2594 AUC: 0.9432
# Batch: 13/13 (valid)
# valid Loss: 0.3077 AUC: 0.9317
#
# Epoch 19/19
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2639 AUC: 0.9418
# Batch: 13/13 (valid)
# valid Loss: 0.3359 AUC: 0.9216
#
# Training complete in 25m 36s
# Best val AUC: 0.9328
#
# << Spec: 3 >>
# Epoch 0/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2624 AUC: 0.9413
# Batch: 13/13 (valid)
# valid Loss: 0.3048 AUC: 0.9328
#
# Epoch 1/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2721 AUC: 0.9417
# Batch: 13/13 (valid)
# valid Loss: 0.3138 AUC: 0.9309
#
# Epoch 2/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2550 AUC: 0.9418
# Batch: 13/13 (valid)
# valid Loss: 0.3139 AUC: 0.9296
#
# Epoch 3/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2657 AUC: 0.9398
# Batch: 13/13 (valid)
# valid Loss: 0.3306 AUC: 0.9281
#
# Epoch 4/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2679 AUC: 0.9413
# Batch: 13/13 (valid)
# valid Loss: 0.3154 AUC: 0.9308
#
# Epoch 5/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2769 AUC: 0.9386
# Batch: 13/13 (valid)
# valid Loss: 0.3118 AUC: 0.9304
#
# Epoch 6/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2874 AUC: 0.9353
# Batch: 13/13 (valid)
# valid Loss: 0.3280 AUC: 0.9256
#
# Epoch 7/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2813 AUC: 0.9368
# Batch: 13/13 (valid)
# valid Loss: 0.3467 AUC: 0.9205
#
# Epoch 8/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2807 AUC: 0.9386
# Batch: 13/13 (valid)
# valid Loss: 0.3262 AUC: 0.9267
#
# Epoch 9/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2869 AUC: 0.9348
# Batch: 13/13 (valid)
# valid Loss: 0.3171 AUC: 0.9260
#
# Epoch 10/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2844 AUC: 0.9364
# Batch: 13/13 (valid)
# valid Loss: 0.3514 AUC: 0.9178
#
# Epoch 11/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2749 AUC: 0.9377
# Batch: 13/13 (valid)
# valid Loss: 0.3596 AUC: 0.9109
#
# Epoch 12/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2777 AUC: 0.9384
# Batch: 13/13 (valid)
# valid Loss: 0.3064 AUC: 0.9288
#
# Epoch 13/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2688 AUC: 0.9383
# Batch: 13/13 (valid)
# valid Loss: 0.3358 AUC: 0.9211
#
# Epoch 14/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2553 AUC: 0.9397
# Batch: 13/13 (valid)
# valid Loss: 0.3337 AUC: 0.9293
#
# Epoch 15/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2358 AUC: 0.9440
# Batch: 13/13 (valid)
# valid Loss: 0.3137 AUC: 0.9253
#
# Epoch 16/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2342 AUC: 0.9410
# Batch: 13/13 (valid)
# valid Loss: 0.3224 AUC: 0.9261
#
# Epoch 17/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2352 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3138 AUC: 0.9278
#
# Epoch 18/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2315 AUC: 0.9447
# Batch: 13/13 (valid)
# valid Loss: 0.3136 AUC: 0.9303
#
# Epoch 19/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2303 AUC: 0.9443
# Batch: 13/13 (valid)
# valid Loss: 0.3075 AUC: 0.9322
#
# Epoch 20/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2269 AUC: 0.9431
# Batch: 13/13 (valid)
# valid Loss: 0.3071 AUC: 0.9324
#
# Epoch 21/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2258 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3070 AUC: 0.9327
#
# Epoch 22/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2304 AUC: 0.9441
# Batch: 13/13 (valid)
# valid Loss: 0.3044 AUC: 0.9332
#
# Epoch 23/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2285 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.3039 AUC: 0.9333
#
# Epoch 24/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2272 AUC: 0.9458
# Batch: 13/13 (valid)
# valid Loss: 0.3077 AUC: 0.9309
#
# Epoch 25/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2309 AUC: 0.9426
# Batch: 13/13 (valid)
# valid Loss: 0.3162 AUC: 0.9294
#
# Epoch 26/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2353 AUC: 0.9440
# Batch: 13/13 (valid)
# valid Loss: 0.3233 AUC: 0.9261
#
# Epoch 27/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2457 AUC: 0.9416
# Batch: 13/13 (valid)
# valid Loss: 0.3055 AUC: 0.9290
#
# Epoch 28/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2450 AUC: 0.9431
# Batch: 13/13 (valid)
# valid Loss: 0.3362 AUC: 0.9257
#
# Epoch 29/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2515 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3275 AUC: 0.9177
#
# Epoch 30/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2669 AUC: 0.9417
# Batch: 13/13 (valid)
# valid Loss: 0.3455 AUC: 0.9290
#
# Epoch 31/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2727 AUC: 0.9409
# Batch: 13/13 (valid)
# valid Loss: 0.3204 AUC: 0.9219
#
# Epoch 32/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2524 AUC: 0.9415
# Batch: 13/13 (valid)
# valid Loss: 0.3730 AUC: 0.9133
#
# Epoch 33/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2593 AUC: 0.9387
# Batch: 13/13 (valid)
# valid Loss: 0.3321 AUC: 0.9249
#
# Epoch 34/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2556 AUC: 0.9426
# Batch: 13/13 (valid)
# valid Loss: 0.3679 AUC: 0.9087
#
# Epoch 35/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2539 AUC: 0.9405
# Batch: 13/13 (valid)
# valid Loss: 0.3365 AUC: 0.9274
#
# Epoch 36/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2444 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.3158 AUC: 0.9204
#
# Epoch 37/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2379 AUC: 0.9441
# Batch: 13/13 (valid)
# valid Loss: 0.2990 AUC: 0.9314
#
# Epoch 38/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2230 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.2928 AUC: 0.9366
#
# Epoch 39/39
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2247 AUC: 0.9447
# Batch: 13/13 (valid)
# valid Loss: 0.2794 AUC: 0.9354
#
# Training complete in 70m 39s
# Best val AUC: 0.9366
#
# << Spec: 4 >>
# Epoch 0/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2256 AUC: 0.9454
# Batch: 13/13 (valid)
# valid Loss: 0.2928 AUC: 0.9366
#
# Epoch 1/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2280 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.2726 AUC: 0.9379
#
# Epoch 2/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2237 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.2945 AUC: 0.9361
#
# Epoch 3/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2244 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.2954 AUC: 0.9313
#
# Epoch 4/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2291 AUC: 0.9431
# Batch: 13/13 (valid)
# valid Loss: 0.2853 AUC: 0.9319
#
# Epoch 5/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2271 AUC: 0.9451
# Batch: 13/13 (valid)
# valid Loss: 0.3384 AUC: 0.9260
#
# Epoch 6/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2449 AUC: 0.9436
# Batch: 13/13 (valid)
# valid Loss: 0.3098 AUC: 0.9265
#
# Epoch 7/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2532 AUC: 0.9394
# Batch: 13/13 (valid)
# valid Loss: 0.3254 AUC: 0.9174
#
# Epoch 8/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2495 AUC: 0.9419
# Batch: 13/13 (valid)
# valid Loss: 0.3265 AUC: 0.9259
#
# Epoch 9/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2629 AUC: 0.9395
# Batch: 13/13 (valid)
# valid Loss: 0.3060 AUC: 0.9310
#
# Epoch 10/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2724 AUC: 0.9382
# Batch: 13/13 (valid)
# valid Loss: 0.3777 AUC: 0.9151
#
# Epoch 11/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2639 AUC: 0.9392
# Batch: 13/13 (valid)
# valid Loss: 0.3683 AUC: 0.9171
#
# Epoch 12/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2547 AUC: 0.9415
# Batch: 13/13 (valid)
# valid Loss: 0.3568 AUC: 0.9175
#
# Epoch 13/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2450 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.2886 AUC: 0.9347
#
# Epoch 14/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2352 AUC: 0.9431
# Batch: 13/13 (valid)
# valid Loss: 0.2941 AUC: 0.9351
#
# Epoch 15/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2305 AUC: 0.9455
# Batch: 13/13 (valid)
# valid Loss: 0.2955 AUC: 0.9337
#
# Epoch 16/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2270 AUC: 0.9404
# Batch: 13/13 (valid)
# valid Loss: 0.2833 AUC: 0.9385
#
# Epoch 17/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2260 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.2924 AUC: 0.9355
#
# Epoch 18/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2219 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.2794 AUC: 0.9368
#
# Epoch 19/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2167 AUC: 0.9455
# Batch: 13/13 (valid)
# valid Loss: 0.2768 AUC: 0.9374
#
# Training complete in 36m 59s
# Best val AUC: 0.9385
#
# << Spec: 5 >>
# Epoch 0/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2221 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.2833 AUC: 0.9385
#
# Epoch 1/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2255 AUC: 0.9432
# Batch: 13/13 (valid)
# valid Loss: 0.2859 AUC: 0.9356
#
# Epoch 2/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2248 AUC: 0.9453
# Batch: 13/13 (valid)
# valid Loss: 0.2701 AUC: 0.9367
#
# Epoch 3/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2273 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.2671 AUC: 0.9391
#
# Epoch 4/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2211 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.2626 AUC: 0.9370
#
# Epoch 5/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2306 AUC: 0.9424
# Batch: 13/13 (valid)
# valid Loss: 0.3045 AUC: 0.9225
#
# Epoch 6/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2332 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3053 AUC: 0.9284
#
# Epoch 7/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2510 AUC: 0.9404
# Batch: 13/13 (valid)
# valid Loss: 0.3118 AUC: 0.9265
#
# Epoch 8/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2419 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.3644 AUC: 0.9211
#
# Epoch 9/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2717 AUC: 0.9405
# Batch: 13/13 (valid)
# valid Loss: 0.3053 AUC: 0.9289
#
# Epoch 10/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2519 AUC: 0.9408
# Batch: 13/13 (valid)
# valid Loss: 0.3286 AUC: 0.9251
#
# Epoch 11/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2693 AUC: 0.9385
# Batch: 13/13 (valid)
# valid Loss: 0.3790 AUC: 0.9053
#
# Epoch 12/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2622 AUC: 0.9404
# Batch: 13/13 (valid)
# valid Loss: 0.3237 AUC: 0.9255
#
# Epoch 13/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2389 AUC: 0.9440
# Batch: 13/13 (valid)
# valid Loss: 0.2969 AUC: 0.9378
#
# Epoch 14/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2497 AUC: 0.9405
# Batch: 13/13 (valid)
# valid Loss: 0.2964 AUC: 0.9322
#
# Epoch 15/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2357 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.2787 AUC: 0.9356
#
# Epoch 16/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2219 AUC: 0.9452
# Batch: 13/13 (valid)
# valid Loss: 0.2903 AUC: 0.9364
#
# Epoch 17/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2209 AUC: 0.9448
# Batch: 13/13 (valid)
# valid Loss: 0.2820 AUC: 0.9356
#
# Epoch 18/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2205 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.2661 AUC: 0.9363
#
# Epoch 19/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2168 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.2669 AUC: 0.9351
#
# Training complete in 39m 42s
# Best val AUC: 0.9391
#
# << Spec: 6 >>
# Epoch 0/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2244 AUC: 0.9432
# Batch: 13/13 (valid)
# valid Loss: 0.2671 AUC: 0.9391
#
# Epoch 1/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2196 AUC: 0.9449
# Batch: 13/13 (valid)
# valid Loss: 0.2703 AUC: 0.9379
#
# Epoch 2/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2194 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.3003 AUC: 0.9324
#
# Epoch 3/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2288 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.3083 AUC: 0.9274
#
# Epoch 4/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2388 AUC: 0.9408
# Batch: 13/13 (valid)
# valid Loss: 0.2986 AUC: 0.9351
#
# Epoch 5/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2357 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3214 AUC: 0.9326
#
# Epoch 6/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2270 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3235 AUC: 0.9233
#
# Epoch 7/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2430 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.3410 AUC: 0.9256
#
# Epoch 8/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2686 AUC: 0.9371
# Batch: 13/13 (valid)
# valid Loss: 0.3450 AUC: 0.9292
#
# Epoch 9/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2701 AUC: 0.9358
# Batch: 13/13 (valid)
# valid Loss: 0.3472 AUC: 0.9137
#
# Epoch 10/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2995 AUC: 0.9281
# Batch: 13/13 (valid)
# valid Loss: 0.3427 AUC: 0.9245
#
# Epoch 11/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2712 AUC: 0.9380
# Batch: 13/13 (valid)
# valid Loss: 0.3511 AUC: 0.9262
#
# Epoch 12/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2609 AUC: 0.9407
# Batch: 13/13 (valid)
# valid Loss: 0.3593 AUC: 0.9168
#
# Epoch 13/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2439 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.3625 AUC: 0.9183
#
# Epoch 14/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2438 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.3603 AUC: 0.9204
#
# Epoch 15/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2343 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.3537 AUC: 0.9282
#
# Epoch 16/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2310 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.3418 AUC: 0.9185
#
# Epoch 17/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2185 AUC: 0.9441
# Batch: 13/13 (valid)
# valid Loss: 0.3086 AUC: 0.9333
#
# Epoch 18/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2256 AUC: 0.9451
# Batch: 13/13 (valid)
# valid Loss: 0.3052 AUC: 0.9342
#
# Epoch 19/19
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2205 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.3063 AUC: 0.9342
#
# Training complete in 40m 2s
# Best val AUC: 0.9391
#
# - Validation -
# === Normal Valid ===
# Batch: 13/13
#
# Norml Valid AUC: 0.9423
#
# === Valid Time Augmentation ===
# n: 0/4
# ----------
# Batch: 13/13
# n: 1/4
# ----------
# Batch: 13/13
# n: 2/4
# ----------
# Batch: 13/13
# n: 3/4
# ----------
# Batch: 13/13
# n: 4/4
# ----------
# Batch: 13/13
#
# VTA AUC: 0.9411
#
# === Mixed Valid ===
#
# Mixed AUC: 0.9424
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
print(torch.cuda.memory_allocated())
# Out:
# 1024

# %% [raw]
# fold = 1
#
# model = torch.load(f'model_{fold}.pth')
# model.to(device)
# val, vta, mix = valMix(model, dataloaders, n=5)

# %% [raw]
# # 例
# def showRes(n, df, preds, preds2=None, start=0):
#     n_cols = 5
#     n_rows = (n-1)//5+1
#
#     fig = plt.figure(figsize=(n_cols*2, n_rows*2))
#
#     for i in range(n):
#         loc = i + start
#         num = df['num'].iloc[loc]
#         lab = df['label'].iloc[loc]
#         im = image = load_img(num)
#
#         ax = fig.add_subplot(n_rows, n_cols, i+1)
#         im = np.asarray(im)
#         ax.imshow(im)
#         ax.axes.xaxis.set_visible(False)
#         ax.axes.yaxis.set_visible(False)
#         if preds2 is None:
#             ax.set_title(f'Label: {lab}\nPred: {preds[loc]:.2f}')
#         else:
#             ax.set_title(f'Label: {lab}\nPred: {preds[loc]:.2f}\nPred2: {preds2[loc]:.2f}')
#
#     fig.suptitle('Prediction')
#     fig.tight_layout()
#     fig.show()

# %% [raw]
# showRes(20, df_train[df_train['fold']==fold], val, vta, mix, start=20)

# %% [markdown]
# ## 推論・提出

# %%
df_submit = df_test[['image_name', 'label']].copy()

# %%
def predictCV(fold):
    model = torch.load(f'model_{fold}.pth')
    model.to(device)
    
    _, dataloaders = foldData(fold)
    test, tta, tmix = valMix(model, dataloaders, n=5, mode='test')
    
    df_submit[f'label_test_{fold}'] = test
    df_submit[f'label_tta_{fold}'] = tta
    df_submit[f'label_tmix_{fold}'] = tmix
    
    del model
    torch.cuda.empty_cache()

# %%
for fold in range(n_folds):
    predictCV(fold)
# Out:
# === Normal Test ===
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Batch: 68/68
#
# Norml Valid AUC: 0.5000
#
# === Test Time Augmentation ===
# n: 0/4
# ----------
# Batch: 68/68
# n: 1/4
# ----------
# Batch: 68/68
# n: 2/4
# ----------
# Batch: 68/68
# n: 3/4
# ----------
# Batch: 68/68
# n: 4/4
# ----------
# Batch: 68/68
#
# VTA AUC: 0.5000
#
# === Mixed Valid ===
#
# Mixed AUC: 0.5000
# === Normal Test ===
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Batch: 68/68
#
# Norml Valid AUC: 0.5000
#
# === Test Time Augmentation ===
# n: 0/4
# ----------
# Batch: 68/68
# n: 1/4
# ----------
# Batch: 68/68
# n: 2/4
# ----------
# Batch: 68/68
# n: 3/4
# ----------
# Batch: 68/68
# n: 4/4
# ----------
# Batch: 68/68
#
# VTA AUC: 0.5000
#
# === Mixed Valid ===
#
# Mixed AUC: 0.5000
# === Normal Test ===
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Batch: 68/68
#
# Norml Valid AUC: 0.5000
#
# === Test Time Augmentation ===
# n: 0/4
# ----------
# Batch: 68/68
# n: 1/4
# ----------
# Batch: 68/68
# n: 2/4
# ----------
# Batch: 68/68
# n: 3/4
# ----------
# Batch: 68/68
# n: 4/4
# ----------
# Batch: 68/68
#
# VTA AUC: 0.5000
#
# === Mixed Valid ===
#
# Mixed AUC: 0.5000
# === Normal Test ===
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Batch: 68/68
#
# Norml Valid AUC: 0.5000
#
# === Test Time Augmentation ===
# n: 0/4
# ----------
# Batch: 68/68
# n: 1/4
# ----------
# Batch: 68/68
# n: 2/4
# ----------
# Batch: 68/68
# n: 3/4
# ----------
# Batch: 68/68
# n: 4/4
# ----------
# Batch: 68/68
#
# VTA AUC: 0.5000
#
# === Mixed Valid ===
#
# Mixed AUC: 0.5000
# === Normal Test ===
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Batch: 68/68
#
# Norml Valid AUC: 0.5000
#
# === Test Time Augmentation ===
# n: 0/4
# ----------
# Batch: 68/68
# n: 1/4
# ----------
# Batch: 68/68
# n: 2/4
# ----------
# Batch: 68/68
# n: 3/4
# ----------
# Batch: 68/68
# n: 4/4
# ----------
# Batch: 68/68
#
# VTA AUC: 0.5000
#
# === Mixed Valid ===
#
# Mixed AUC: 0.5000

# %%
# 平均対象を抽出して提出
targ = 'tmix'

mean = df_submit[[f'label_{targ}_{fold}' for fold in range(n_folds)]].mean(axis=1)
df_submit['label'] = mean

df_submit[['image_name', 'label']].to_csv('submit.csv', header=None, index=None)

# %%
df_submit.to_csv('model_v6-cv.csv', index=False)

# %% [markdown]
# 提出

# %%
# %%bash
# signate submit --competition-id=1106 submit.csv --note model6_CV_tmix
# Out:
# You have successfully submitted your predictions.We will send you the submission result to your email address.

# %% [markdown]
# model_v2, v3, v4, v5とアンサンブル

# %%
df_1 = pd.read_csv('model_v2-cv.csv')
df_2 = pd.read_csv('model_v3-cv.csv')
df_3 = pd.read_csv('model_v4-cv.csv')
df_4 = pd.read_csv('model_v5-cv.csv')
df_5 = pd.read_csv('model_v6-cv.csv')

# %%
targ = 'tmix'

mean1 = df_1[[f'label_{targ}_{fold}' for fold in range(5)]].mean(axis=1)
mean2 = df_2[[f'label_{targ}_{fold}' for fold in range(5)]].mean(axis=1)
mean3 = df_3[[f'label_{targ}_{fold}' for fold in range(5)]].mean(axis=1)
mean4 = df_4[[f'label_{targ}_{fold}' for fold in range(5)]].mean(axis=1)
mean5 = df_5[[f'label_{targ}_{fold}' for fold in range(5)]].mean(axis=1)
mean = (mean1 + mean2 + mean3 + mean4 + mean5) / 5
mean = (mean2 + mean3 + mean4 + mean5) / 4

# %%
df_submit = df_1[['image_name', 'label']].copy()
df_submit['label'] = mean
df_submit.to_csv('submit.csv', header=None, index=None)

# %%
# %%bash
# signate submit --competition-id=1106 submit.csv --note model2CVtmix_model3CVtmix_model4CVtmix_model5CVtmix_model6CVtmix
# Out:
# You have successfully submitted your predictions.We will send you the submission result to your email address.
