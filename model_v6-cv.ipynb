# %% [markdown]
# # ConvNeXt V2 Large

# %% [markdown]
# - loss: Binary Cross Entropy
# - metrics: ROCAUC
# - trainable: Full
# - CVあり
# ---
# - label smoothing
# - AugMix
# × CutMix
# × MixUp

# %% [markdown]
# ## Load Model

# %%
from transformers import AutoImageProcessor, ConvNextV2ForImageClassification, get_cosine_schedule_with_warmup
import torch, timm
from datasets import load_dataset

from utils.utils import load_img

print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.current_device())
print(torch.cuda.get_device_name())
print(torch.cuda.get_device_capability())
# Out:
# 2.2.0.dev20230911+cu118
# True
# 4
# 0
# Tesla T4
# (7, 5)

# %%
dataset = load_dataset("huggingface/cats-image")
image = dataset["test"]["image"][0]

preprocessor = AutoImageProcessor.from_pretrained("facebook/convnextv2-large-22k-384")
model = ConvNextV2ForImageClassification.from_pretrained("facebook/convnextv2-large-22k-384")

# %%
inputs = preprocessor(image, return_tensors="pt")
inputs['pixel_values'].shape
# Out:
# torch.Size([1, 3, 384, 384])

# %%
with torch.no_grad():
    logits = model(**inputs).logits

# model predicts one of the 1000 ImageNet classes
predicted_label = logits.argmax(-1).item()
print(model.config.id2label[predicted_label]),

# %% [markdown]
# ## 学習データの可視化

# %%
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# 食品と飲料をランダムに5個ずつ可視化する
df_train = pd.read_csv('train.csv')
df_train['num'] = df_train['image_name'].str[:-4].astype(int)

d_vis = df_train[df_train['label']==0].sample(5)['num'].tolist()
f_vis = df_train[df_train['label']==1].sample(5)['num'].tolist()

# %%
# データの偏り
print(f"N of drinks: {len(df_train[df_train['label']==0])}")
print(f"N of foods: {len(df_train[df_train['label']==1])}")
# Out:
# N of drinks: 994
# N of foods: 1182

# %%
def show5img(ilist, stitle=None):
    n_cols = 5
    n_rows = (len(ilist)-1)//5+1
    
    fig = plt.figure(figsize=(n_cols*2, n_rows*2))
    for n, i in enumerate(ilist):
        ax = fig.add_subplot(n_rows, n_cols, n+1)
        im = load_img(i)
        im = np.asarray(im)
        ax.imshow(im)
        ax.axes.xaxis.set_visible(False)
        ax.axes.yaxis.set_visible(False)
        ax.set_title(i)
    if stitle:
        fig.suptitle(stitle)
    fig.tight_layout()
    fig.show()

# %%
show5img(d_vis, stitle='drink')
show5img(f_vis, stitle='food')

# %% [markdown]
# ## 転移学習/CV検証

# %%
import torch.nn as nn
from torchvision import transforms

from sklearn.model_selection import StratifiedKFold

# %%
device = torch.device('cuda')

# %% [markdown]
# データセット作成

# %%
# folding
n_folds = 5

skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=4)
df_train['fold'] = -1
for i, (_, val_idx) in enumerate(skf.split(df_train, df_train['label'])):
    df_train.loc[val_idx, 'fold'] = i

# %%
# label smoothing
df_train['label'] = df_train['label'].replace({0: 0.05, 1: 0.95})

# %%
df_train
# Out:
#      image_name  label   num  fold
# 0      0000.png   0.05     0     2
# 1      0001.png   0.95     1     3
# 2      0002.png   0.95     2     0
# 3      0003.png   0.95     3     4
# 4      0004.png   0.05     4     4
# ...         ...    ...   ...   ...
# 2171   2171.png   0.95  2171     4
# 2172   2172.png   0.95  2172     0
# 2173   2173.png   0.95  2173     0
# 2174   2174.png   0.05  2174     0
# 2175   2175.png   0.05  2175     0
#
# [2176 rows x 4 columns]

# %%
# テストデータ
df_test = pd.read_csv('sample_submit.csv', header=None)
df_test.columns = ['image_name', 'label']
df_test['num'] = df_test['image_name'].str[:-4].astype(int)
df_test['label'] = -1

# %%
df_test
# Out:
#      image_name  label   num
# 0      2176.png     -1  2176
# 1      2177.png     -1  2177
# 2      2178.png     -1  2178
# 3      2179.png     -1  2179
# 4      2180.png     -1  2180
# ...         ...    ...   ...
# 2175   4351.png     -1  4351
# 2176   4352.png     -1  4352
# 2177   4353.png     -1  4353
# 2178   4354.png     -1  4354
# 2179   4355.png     -1  4355
#
# [2180 rows x 3 columns]

# %%
train_transforms_1 = transforms.Compose([
    transforms.RandomChoice([
        transforms.RandomCrop(256),
        transforms.RandomCrop(384),
        transforms.RandomCrop(512),
    ]),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.RandomApply(
        [transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5)],
        p=0.67,
    ),
    transforms.RandomApply(
        [transforms.GaussianBlur(3, sigma=(0.1, 2.0))],
        p=0.67,
    ),
    transforms.Resize((384, 384)),
    transforms.RandomApply(
        [transforms.RandomRotation(180)],
        p=0.5,
    ),
    transforms.ToTensor(),
    transforms.RandomErasing(p=0.33, scale=(0.02, 0.3)),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])

train_transforms_2 = transforms.Compose([
    transforms.AugMix(),
    transforms.Resize((384, 384)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])


tta_transforms_1 = transforms.Compose([
    transforms.RandomChoice([
        transforms.RandomCrop(448),
        transforms.RandomCrop(512),
    ]),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.RandomApply(
        [transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5)],
        p=0.67,
    ),
    transforms.RandomApply(
        [transforms.GaussianBlur(3, sigma=(0.1, 2.0))],
        p=0.67,
    ),
    transforms.Resize((384, 384)),
    # transforms.RandomApply(
    #     [transforms.RandomRotation(180)],
    #     p=0.5,
    # ),
    transforms.ToTensor(),
    # transforms.RandomErasing(p=0.33, scale=(0.02, 0.1)),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])

tta_transforms_2 = transforms.Compose([
    transforms.AugMix(),
    transforms.Resize((384, 384)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])


data_transforms = {
    'train': transforms.RandomChoice([
        train_transforms_1, train_transforms_2
    ], p=[0.4, 0.6]),
    'valid': transforms.Compose([
        transforms.Resize((384, 384)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
    'tta': transforms.RandomChoice([
        tta_transforms_1, tta_transforms_2
    ], p=[0.5, 0.5])
}

# %%
# 例
def showTimg(n, phase='train'):
    image = load_img(0)
    image_t = data_transforms[phase](image)
    
    img1 = np.asarray(image)
    img2 = image_t.numpy().transpose((2,1,0))
    
    fig = plt.figure(figsize=(2*2, 1*2))
    ax1 = fig.add_subplot(1, 2, 1)
    ax1.imshow(img1)
    ax1.axes.xaxis.set_visible(False)
    ax1.axes.yaxis.set_visible(False)
    ax1.set_title(f'Raw_{n}')
    
    ax2 = fig.add_subplot(1, 2, 2)
    ax2.imshow(img2)
    ax2.axes.xaxis.set_visible(False)
    ax2.axes.yaxis.set_visible(False)
    ax2.set_title(f'Transformed_{n}')

# %%
showTimg(0, phase='train')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
showTimg(0, phase='valid')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
showTimg(0, phase='tta')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, df, transform, tt='train'):
        if tt == 'train':
            self.dir = 'train/'
        elif tt == 'test':
            self.dir = 'test/'
        
        self.df = df
        self.transform = transform
        self.labels = np.expand_dims(df['label'].values, 1)
        self.labels = self.labels.astype(float)

    # len()を使用すると呼ばれる
    def __len__(self):
        return len(self.labels)

    # 要素を参照すると呼ばれる関数    
    def __getitem__(self, idx):
        num = self.df['num'].values[idx]
        image = load_img(num)
        image = self.transform(image)
        return image, self.labels[idx]

# %%
def foldData(fold, bs=32):
    df_train_ = df_train[df_train['fold']!=fold]
    df_valid_ = df_train[df_train['fold']==fold]
    df_test_ = df_test
    
    image_datasets = {
        'train': MyDataset(df_train_, data_transforms['train'], tt='train'),
        'valid': MyDataset(df_valid_, data_transforms['valid'], tt='train'),
        'vta': MyDataset(df_valid_, data_transforms['tta'], tt='train'),
        'test': MyDataset(df_test_, data_transforms['valid'], tt='test'),
        'tta': MyDataset(df_test_, data_transforms['tta'], tt='test'),
    }
    
    dataloaders = {
        'train': torch.utils.data.DataLoader(image_datasets['train'],
                                             batch_size=bs, shuffle=True, num_workers=16, pin_memory=True),
        'valid': torch.utils.data.DataLoader(image_datasets['valid'],
                                             batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
        'vta': torch.utils.data.DataLoader(image_datasets['vta'],
                                           batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
        'test': torch.utils.data.DataLoader(image_datasets['test'],
                                            batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
        'tta': torch.utils.data.DataLoader(image_datasets['tta'],
                                           batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
    }
    
#     return train_idx, valid_idx, image_datasets, dataloaders
    return image_datasets, dataloaders

# %% [markdown]
# モデル構築

# %%
from torcheval.metrics import BinaryAUROC
import torch.optim as optim
from torcheval.metrics.functional import binary_auroc

# %% [raw]
# model.classifier = nn.Linear(2816, 1, bias=True)

# %% [raw]
# # multi gpu
# model = torch.nn.DataParallel(model, device_ids=[0, 1, 2, 3]) # make parallel

# %% [raw]
# model.to(device)

# %% [raw]
# ### 重み固定 ###
# for p in model.parameters():
#     p.requires_grad = False

# %%
def loadNewModel():
    m = ConvNextV2ForImageClassification.from_pretrained("facebook/convnextv2-large-22k-384")
    m.classifier = nn.Linear(1536, 1, bias=True)
    m = torch.nn.DataParallel(m, device_ids=[0, 1, 2, 3]) # make parallel
    m.to(device)
    for p in m.parameters():
        p.requires_grad = False
    return m

# %% [markdown]
# 学習

# %%
import copy, time
import torchvision
torchvision.disable_beta_transforms_warning()
from torchvision.transforms import v2

# %%
scaler = torch.cuda.amp.GradScaler()

# %% [raw]
# cutmix = v2.CutMix(num_classes=1)
# mixup = v2.MixUp(num_classes=1)
# cutmix_or_mixup = v2.RandomChoice([cutmix, mixup])

# %% [raw]
# -> one-hotじゃないと適用できないので今回は適用しない

# %%
def train(model, criterion, optimizer, scheduler, image_datasets, dataloaders, epochs=5):
    since = time.time()
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_auc = 0.0
    
    for epoch in range(epochs):
        print(f'Epoch {epoch}/{epochs-1}')
        print('-' * 10)
        
        for phase in ('train', 'valid'):
            if phase == 'train':
                is_train = True
                model.train()  # Set model to training mode
            else:
                is_train = False
                model.eval()   # Set model to evaluate mode
            
            running_loss = 0.0
            running_auc = 0.0
            
            # イタレーション
            for b, (inputs, labels) in enumerate(dataloaders[phase]):
                print(f'\rBatch: {b}/{len(image_datasets[phase])//dataloaders[phase].batch_size} ({phase})', end="")
                # images, labels = cutmix_or_mixup(images, labels)
                inputs = inputs.to(device)
                labels = labels.to(device)
                
                optimizer.zero_grad()
                
                with torch.set_grad_enabled(is_train):
                    with torch.cuda.amp.autocast(): 
                        outputs = model(inputs).logits
                        # loss = criterion(torch.flatten(outputs), torch.flatten(labels))
                        loss = criterion(outputs, labels)
                    auc = binary_auroc(torch.flatten(torch.sigmoid(outputs)),
                                       torch.flatten(labels))

                    # backward + optimize only if in training phase
                    if is_train:
                        scaler.scale(loss).backward()
                        scaler.step(optimizer)
                        scaler.update() 

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_auc +=  auc * inputs.size(0)
                
                del loss, auc, labels, inputs, outputs
            
            epoch_loss = running_loss / len(image_datasets[phase])
            epoch_auc = running_auc / len(image_datasets[phase])
            
            print()
            print(f'{phase} Loss: {epoch_loss:.4f} AUC: {epoch_auc:.4f}')
            
            # deep copy the model
            if phase == 'valid' and epoch_auc > best_auc:
                best_auc = epoch_auc
                best_model_wts = copy.deepcopy(model.state_dict())
            del epoch_loss, epoch_auc, running_loss, running_auc
            torch.cuda.empty_cache()
            
        scheduler.step()
        print()
        
    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val AUC: {best_auc:.4f}')
    print()

    # load best model weights
    model.load_state_dict(best_model_wts)
    del best_model_wts
    return model

# %% [markdown]
# - 通常の代入とTTAで比較

# %%
def valid(model, dataloader):
    noutputs = []
    nlabels = []
    for b, (inputs, labels) in enumerate(dataloader):
        print(f'\rBatch: {b}/{len(dataloader.dataset)//dataloader.batch_size}', end="")
        inputs = inputs.to(device)
        labels = labels.to(device)
        with torch.no_grad():
            noutputs.append(model(inputs).logits)
            nlabels.append(labels)
        del inputs, labels
    alloutputs = torch.cat(noutputs)
    alllabels = torch.cat(nlabels)
    
    preds = torch.sigmoid(torch.flatten(alloutputs))
    auc = binary_auroc(preds, torch.flatten(alllabels))
    print()
    print()
    print(f'AUC: {auc:.4f}')
    
    return preds.cpu().detach().numpy()

# %%
def tta(model, dataloader, n=5):
    alloutputs = []
    
    for i in range(n):
        print(f'n: {i}/{n-1}')
        print('-' * 10)
        noutputs = []
        nlabels = []
        for b, (inputs, labels) in enumerate(dataloader):
            print(f'\rBatch: {b}/{len(dataloader.dataset)//dataloader.batch_size}', end="")
            inputs = inputs.to(device)
            labels = labels.to(device)
            with torch.no_grad():
                noutputs.append(model(inputs).logits)
                nlabels.append(labels)
            del inputs, labels
        alloutputs.append(torch.cat(noutputs))
        alllabels = torch.cat(nlabels)
        print()
    alloutputs = torch.cat(alloutputs, 1)
    preds = torch.sigmoid(torch.mean(alloutputs, dim=1))
    auc = binary_auroc(preds, torch.flatten(alllabels))
    print()
    print(f'AUC: {auc:.4f}')
    
    return preds.cpu().detach().numpy()

# %%
def valMix(model, dataloaders, n=5, mode='valid'):
    # 通常valid
    print(f"=== Normal {'Valid' if mode=='valid' else 'Test'} ===")
    if mode =='valid':
        dataloader = dataloaders['valid']
    elif mode == 'test':
        dataloader = dataloaders['test']
    noutputs = []
    nlabels = []
    for b, (imgs, labels) in enumerate(dataloader):
        print(f'\rBatch: {b}/{len(dataloader.dataset)//dataloader.batch_size}', end="")
        inputs = imgs.to(device)
        labels = labels.to(device)
        with torch.no_grad():
            noutputs.append(model(inputs).logits)
            nlabels.append(labels)
    alloutputs = torch.cat(noutputs)
    alllabels = torch.cat(nlabels)
    
    preds1 = torch.sigmoid(torch.flatten(alloutputs))
    auc = binary_auroc(preds1, torch.flatten(alllabels))
    print()
    print()
    print(f'Norml Valid AUC: {auc:.4f}')
    print()
    
    # TTA valid
    print(f"=== {'Valid' if mode=='valid' else 'Test'} Time Augmentation ===")
    if mode =='valid':
        dataloader = dataloaders['vta']
    elif mode == 'test':
        dataloader = dataloaders['tta']
    alloutputs = [alloutputs]
    
    for i in range(n):
        print(f'n: {i}/{n-1}')
        print('-' * 10)
        noutputs = []
        for b, (imgs, labels) in enumerate(dataloader):
            print(f'\rBatch: {b}/{len(dataloader.dataset)//dataloader.batch_size}', end="")
            inputs = imgs.to(device)
            with torch.no_grad():
                noutputs.append(model(inputs).logits)
        alloutputs.append(torch.cat(noutputs))
        print()
    alloutputs = torch.cat(alloutputs, 1)
    preds2 = torch.sigmoid(torch.mean(alloutputs, dim=1))
    auc = binary_auroc(preds2, torch.flatten(alllabels))
    print()
    print(f'VTA AUC: {auc:.4f}')
    print()
    
    # Mix
    print('=== Mixed Valid ===')
    preds1to0 = preds1 - 0
    preds1to1 = 1 - preds1
    preds2to0 = preds2 - 0
    preds2to1 = 1 - preds2
    
    stack = torch.stack([preds1to0, preds1to1, preds2to0, preds2to1])
    pstack = torch.stack([preds1, preds1, preds2, preds2])
    
    argmin = torch.argmin(stack, dim=0)
    preds = torch.diag(pstack[argmin])
    auc = binary_auroc(preds, torch.flatten(alllabels))
    print()
    print(f'Mixed AUC: {auc:.4f}')
    return preds1.cpu().detach().numpy(), preds2.cpu().detach().numpy(), preds.cpu().detach().numpy()

# %% [markdown]
# ### CV

# %%
from numba import cuda

# %%
### 検証時のAugmentation
n_vta = 5

# %%
### パラメータ変更可能な部分 ###
"""
  model.module.convnextv2.embeddings

  model.module.convnextv2.encoder.stages[0]
  -> model.module.convnextv2.encoder.stages[0].layers[0] ~ [2]

  model.module.convnextv2.encoder.stages[1]
  -> model.module.convnextv2.encoder.stages[1].layers[0] ~ [2]

  model.module.convnextv2.encoder.stages[2]
  -> model.module.convnextv2.encoder.stages[2].layers[0] ~ [26]

  model.module.convnextv2.encoder.stages[3]
  -> model.module.convnextv2.encoder.stages[3].layers[0] ~ [2]

  model.module.convnextv2.layernorm

  model.module.classifier
"""
# Out:
# '\n  model.module.convnextv2.embeddings\n\n  model.module.convnextv2.encoder.stages[0]\n  -> model.module.convnextv2.encoder.stages[0].layers[0] ~ [2]\n\n  model.module.convnextv2.encoder.stages[1]\n  -> model.module.convnextv2.encoder.stages[1].layers[0] ~ [2]\n\n  model.module.convnextv2.encoder.stages[2]\n  -> model.module.convnextv2.encoder.stages[2].layers[0] ~ [26]\n\n  model.module.convnextv2.encoder.stages[3]\n  -> model.module.convnextv2.encoder.stages[3].layers[0] ~ [2]\n\n  model.module.convnextv2.layernorm\n\n  model.module.classifier\n'

# %%
specs = [
    {
        'bs': 32,
        'trainLayers': 1,
        'lr': 1e-3,
        'epochs': 15,
        'num_warmup_steps': 5,  # CosSchWarm
        'num_training_steps': 20,  # CosSchWarm
        'num_cycles': 0.5,  # CosSchWarm
    },
    {
        'bs': 32,
        'trainLayers': 2,
        'lr': 1e-3,
        'epochs': 15,
        'num_warmup_steps': 5,  # CosSchWarm
        'num_training_steps': 20,  # CosSchWarm
        'num_cycles': 0.5,  # CosSchWarm
    },
    {
        'bs': 32,
        'trainLayers': 3,
        'lr': 5e-4,
        'epochs': 20,
        'num_warmup_steps': 5,  # CosSchWarm
        'num_training_steps': 35,  # CosSchWarm
        'num_cycles': 1.5,  # CosSchWarm
    },
    {
        'bs': 24,
        'trainLayers': 4,
        'lr': 1e-4,
        'epochs': 40,
        'num_warmup_steps': 10,  # CosSchWarm
        'num_training_steps': 105,  # CosSchWarm
        'num_cycles': 4.5,  # CosSchWarm
    },
    {
        'bs': 24,
        'trainLayers': 5,
        'lr': 1e-4,
        'epochs': 20,
        'num_warmup_steps': 10,  # CosSchWarm
        'num_training_steps': 105,  # CosSchWarm
        'num_cycles': 4.5,  # CosSchWarm
    },
    {
        'bs': 24,
        'trainLayers': 6,
        'lr': 1e-4,
        'epochs': 20,
        'num_warmup_steps': 10,  # CosSchWarm
        'num_training_steps': 105,  # CosSchWarm
        'num_cycles': 4.5,  # CosSchWarm
    },
    {
        'bs': 24,
        'trainLayers': 7,
        'lr': 1e-4,
        'epochs': 20,
        'num_warmup_steps': 10,  # CosSchWarm
        'num_training_steps': 105,  # CosSchWarm
        'num_cycles': 4.5,  # CosSchWarm
    },
]

# %%
vals = {}
vtas = {}
mixs = {}

# %%
torch.backends.cudnn.benchmark = True

# %%
def train_spec(fold, i, model_path='model.pth'):
    spec = specs[i]
    
    # datasetsを作る
    image_datasets, dataloaders = foldData(fold, bs=spec['bs'])
    
    # 新しいモデルを読み込み
    if i == 0:
        model = loadNewModel()
    else:
        model = torch.load(model_path)
        model.to(device)
        for p in model.parameters():
            p.requires_grad = False
    
    layer_list = [
        model.module.classifier,
        model.module.convnextv2.layernorm,
        model.module.convnextv2.encoder.stages[3],
        model.module.convnextv2.encoder.stages[2],
        model.module.convnextv2.encoder.stages[1],
        model.module.convnextv2.encoder.stages[0],
        model.module.convnextv2.embeddings,
    ]
    
    for j in range(spec['trainLayers']):
        layer = layer_list[j]
        for p in layer.parameters():
            p.requires_grad = True
    
    criterion = nn.BCEWithLogitsLoss(pos_weight=None)
    if False:
    # if i < len(specs)-2:
        optimizer = optim.SGD(model.parameters(), lr=spec['lr'], momentum=0.9)
        lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=spec['sch_steps'], gamma=spec['sch_gamma'])
    else:
        optimizer = optim.AdamW(model.parameters(), lr=spec['lr'])
        lr_scheduler = get_cosine_schedule_with_warmup(optimizer,
                                                       num_warmup_steps=spec['num_warmup_steps'],
                                                       num_training_steps=spec['num_training_steps'],
                                                       num_cycles=spec['num_cycles'])
    
    model = train(model, criterion, optimizer, lr_scheduler, image_datasets, dataloaders,
                  epochs=spec['epochs'])
    
    torch.save(model, model_path)
    del model
    torch.cuda.empty_cache()

# %%
def fold_train(fold):
    print(f'=== Fold: {fold} ===')
    print('GPU Memory:', torch.cuda.memory_allocated())
    
    for i in range(len(specs)):
        print(f'<< Spec: {i} >>')
        train_spec(fold, i)
    
    print('- Validation -')
    model = torch.load('model.pth')
    model.to(device)
    
    image_datasets, dataloaders = foldData(fold)
    
    val, vta, mix = valMix(model, dataloaders, n=n_vta)
    vals[fold] = val
    vtas[fold] = vta
    mixs[fold] = mix
    
    print()
    
    torch.save(model, f'model_{fold}.pth')
    
    del model
    torch.cuda.empty_cache()

# %% [raw]
# for fold in range(n_folds):
#     fold_train(fold)

# %%
# %%capture cap

for fold in range(n_folds):
    fold_train(fold)

with open('log_train.txt', 'w') as f:
    f.write(cap.stdout)

# %%
cap()
# Out:
# === Fold: 0 ===
# GPU Memory: 0
# << Spec: 0 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.7235 AUC: 0.4813
# Batch: 13/13 (valid)
# valid Loss: 0.7291 AUC: 0.4652
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.6476 AUC: 0.6622
# Batch: 13/13 (valid)
# valid Loss: 0.5857 AUC: 0.7660
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5709 AUC: 0.7734
# Batch: 13/13 (valid)
# valid Loss: 0.5516 AUC: 0.7984
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5395 AUC: 0.7955
# Batch: 13/13 (valid)
# valid Loss: 0.5245 AUC: 0.8148
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5354 AUC: 0.8033
# Batch: 13/13 (valid)
# valid Loss: 0.5129 AUC: 0.8259
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5121 AUC: 0.8220
# Batch: 13/13 (valid)
# valid Loss: 0.5001 AUC: 0.8374
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4930 AUC: 0.8413
# Batch: 13/13 (valid)
# valid Loss: 0.4923 AUC: 0.8378
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4755 AUC: 0.8543
# Batch: 13/13 (valid)
# valid Loss: 0.4860 AUC: 0.8391
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4861 AUC: 0.8486
# Batch: 13/13 (valid)
# valid Loss: 0.4841 AUC: 0.8382
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4601 AUC: 0.8676
# Batch: 13/13 (valid)
# valid Loss: 0.4973 AUC: 0.8438
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4586 AUC: 0.8655
# Batch: 13/13 (valid)
# valid Loss: 0.4765 AUC: 0.8487
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4640 AUC: 0.8588
# Batch: 13/13 (valid)
# valid Loss: 0.4753 AUC: 0.8519
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4617 AUC: 0.8631
# Batch: 13/13 (valid)
# valid Loss: 0.4726 AUC: 0.8537
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4502 AUC: 0.8723
# Batch: 13/13 (valid)
# valid Loss: 0.4732 AUC: 0.8510
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4465 AUC: 0.8751
# Batch: 13/13 (valid)
# valid Loss: 0.4729 AUC: 0.8538
#
# Training complete in 21m 13s
# Best val AUC: 0.8538
#
# << Spec: 1 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4398 AUC: 0.8818
# Batch: 13/13 (valid)
# valid Loss: 0.4729 AUC: 0.8538
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4556 AUC: 0.8662
# Batch: 13/13 (valid)
# valid Loss: 0.4701 AUC: 0.8552
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4593 AUC: 0.8673
# Batch: 13/13 (valid)
# valid Loss: 0.4652 AUC: 0.8561
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4541 AUC: 0.8686
# Batch: 13/13 (valid)
# valid Loss: 0.4731 AUC: 0.8497
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4460 AUC: 0.8736
# Batch: 13/13 (valid)
# valid Loss: 0.4656 AUC: 0.8561
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4526 AUC: 0.8698
# Batch: 13/13 (valid)
# valid Loss: 0.4719 AUC: 0.8483
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4457 AUC: 0.8743
# Batch: 13/13 (valid)
# valid Loss: 0.4709 AUC: 0.8498
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4401 AUC: 0.8817
# Batch: 13/13 (valid)
# valid Loss: 0.4614 AUC: 0.8603
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4396 AUC: 0.8771
# Batch: 13/13 (valid)
# valid Loss: 0.4569 AUC: 0.8602
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4347 AUC: 0.8785
# Batch: 13/13 (valid)
# valid Loss: 0.4603 AUC: 0.8630
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4389 AUC: 0.8758
# Batch: 13/13 (valid)
# valid Loss: 0.4617 AUC: 0.8629
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4431 AUC: 0.8734
# Batch: 13/13 (valid)
# valid Loss: 0.4609 AUC: 0.8551
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4226 AUC: 0.8892
# Batch: 13/13 (valid)
# valid Loss: 0.4618 AUC: 0.8602
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4238 AUC: 0.8853
# Batch: 13/13 (valid)
# valid Loss: 0.4618 AUC: 0.8587
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4255 AUC: 0.8865
# Batch: 13/13 (valid)
# valid Loss: 0.4594 AUC: 0.8578
#
# Training complete in 20m 48s
# Best val AUC: 0.8630
#
# << Spec: 2 >>
# Epoch 0/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4287 AUC: 0.8828
# Batch: 13/13 (valid)
# valid Loss: 0.4603 AUC: 0.8630
#
# Epoch 1/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4427 AUC: 0.8799
# Batch: 13/13 (valid)
# valid Loss: 0.4931 AUC: 0.8793
#
# Epoch 2/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4423 AUC: 0.8897
# Batch: 13/13 (valid)
# valid Loss: 0.4216 AUC: 0.8938
#
# Epoch 3/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4089 AUC: 0.9002
# Batch: 13/13 (valid)
# valid Loss: 0.4278 AUC: 0.8972
#
# Epoch 4/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3518 AUC: 0.9235
# Batch: 13/13 (valid)
# valid Loss: 0.3916 AUC: 0.9106
#
# Epoch 5/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3647 AUC: 0.9192
# Batch: 13/13 (valid)
# valid Loss: 0.3804 AUC: 0.9050
#
# Epoch 6/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3392 AUC: 0.9277
# Batch: 13/13 (valid)
# valid Loss: 0.3863 AUC: 0.9138
#
# Epoch 7/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3149 AUC: 0.9330
# Batch: 13/13 (valid)
# valid Loss: 0.3647 AUC: 0.9143
#
# Epoch 8/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3109 AUC: 0.9330
# Batch: 13/13 (valid)
# valid Loss: 0.3389 AUC: 0.9239
#
# Epoch 9/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2949 AUC: 0.9365
# Batch: 13/13 (valid)
# valid Loss: 0.3399 AUC: 0.9211
#
# Epoch 10/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2810 AUC: 0.9383
# Batch: 13/13 (valid)
# valid Loss: 0.3351 AUC: 0.9241
#
# Epoch 11/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2708 AUC: 0.9418
# Batch: 13/13 (valid)
# valid Loss: 0.3567 AUC: 0.9158
#
# Epoch 12/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2724 AUC: 0.9415
# Batch: 13/13 (valid)
# valid Loss: 0.3375 AUC: 0.9206
#
# Epoch 13/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2693 AUC: 0.9399
# Batch: 13/13 (valid)
# valid Loss: 0.3424 AUC: 0.9224
#
# Epoch 14/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2665 AUC: 0.9406
# Batch: 13/13 (valid)
# valid Loss: 0.3400 AUC: 0.9216
#
# Epoch 15/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2658 AUC: 0.9399
# Batch: 13/13 (valid)
# valid Loss: 0.3400 AUC: 0.9216
#
# Epoch 16/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2637 AUC: 0.9413
# Batch: 13/13 (valid)
# valid Loss: 0.3419 AUC: 0.9222
#
# Epoch 17/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2591 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3317 AUC: 0.9235
#
# Epoch 18/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2747 AUC: 0.9396
# Batch: 13/13 (valid)
# valid Loss: 0.3227 AUC: 0.9252
#
# Epoch 19/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2594 AUC: 0.9408
# Batch: 13/13 (valid)
# valid Loss: 0.3243 AUC: 0.9246
#
# Epoch 20/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2760 AUC: 0.9384
# Batch: 13/13 (valid)
# valid Loss: 0.3569 AUC: 0.9150
#
# Epoch 21/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2865 AUC: 0.9355
# Batch: 13/13 (valid)
# valid Loss: 0.3430 AUC: 0.9181
#
# Epoch 22/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2867 AUC: 0.9365
# Batch: 13/13 (valid)
# valid Loss: 0.3565 AUC: 0.9139
#
# Epoch 23/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2966 AUC: 0.9354
# Batch: 13/13 (valid)
# valid Loss: 0.3743 AUC: 0.9123
#
# Epoch 24/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2964 AUC: 0.9335
# Batch: 13/13 (valid)
# valid Loss: 0.3515 AUC: 0.9169
#
# Epoch 25/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2866 AUC: 0.9379
# Batch: 13/13 (valid)
# valid Loss: 0.4153 AUC: 0.9029
#
# Epoch 26/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2970 AUC: 0.9353
# Batch: 13/13 (valid)
# valid Loss: 0.3802 AUC: 0.9103
#
# Epoch 27/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2897 AUC: 0.9367
# Batch: 13/13 (valid)
# valid Loss: 0.3795 AUC: 0.9097
#
# Epoch 28/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2782 AUC: 0.9397
# Batch: 13/13 (valid)
# valid Loss: 0.3648 AUC: 0.9129
#
# Epoch 29/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2674 AUC: 0.9383
# Batch: 13/13 (valid)
# valid Loss: 0.3678 AUC: 0.9234
#
# Training complete in 43m 33s
# Best val AUC: 0.9252
#
# << Spec: 3 >>
# Epoch 0/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2641 AUC: 0.9402
# Batch: 13/13 (valid)
# valid Loss: 0.3227 AUC: 0.9252
#
# Epoch 1/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2621 AUC: 0.9401
# Batch: 13/13 (valid)
# valid Loss: 0.3295 AUC: 0.9237
#
# Epoch 2/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2614 AUC: 0.9414
# Batch: 13/13 (valid)
# valid Loss: 0.3197 AUC: 0.9262
#
# Epoch 3/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2581 AUC: 0.9410
# Batch: 13/13 (valid)
# valid Loss: 0.3302 AUC: 0.9290
#
# Epoch 4/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2682 AUC: 0.9403
# Batch: 13/13 (valid)
# valid Loss: 0.3153 AUC: 0.9277
#
# Epoch 5/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2623 AUC: 0.9404
# Batch: 13/13 (valid)
# valid Loss: 0.3497 AUC: 0.9230
#
# Epoch 6/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2697 AUC: 0.9388
# Batch: 13/13 (valid)
# valid Loss: 0.3410 AUC: 0.9202
#
# Epoch 7/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2710 AUC: 0.9347
# Batch: 13/13 (valid)
# valid Loss: 0.3221 AUC: 0.9275
#
# Epoch 8/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2743 AUC: 0.9383
# Batch: 13/13 (valid)
# valid Loss: 0.3097 AUC: 0.9318
#
# Epoch 9/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2715 AUC: 0.9384
# Batch: 13/13 (valid)
# valid Loss: 0.4479 AUC: 0.8960
#
# Epoch 10/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2912 AUC: 0.9342
# Batch: 13/13 (valid)
# valid Loss: 0.3256 AUC: 0.9290
#
# Epoch 11/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2781 AUC: 0.9379
# Batch: 13/13 (valid)
# valid Loss: 0.3325 AUC: 0.9222
#
# Epoch 12/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2773 AUC: 0.9372
# Batch: 13/13 (valid)
# valid Loss: 0.3373 AUC: 0.9298
#
# Epoch 13/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2659 AUC: 0.9376
# Batch: 13/13 (valid)
# valid Loss: 0.3161 AUC: 0.9304
#
# Epoch 14/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2630 AUC: 0.9404
# Batch: 13/13 (valid)
# valid Loss: 0.2964 AUC: 0.9341
#
# Epoch 15/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2554 AUC: 0.9417
# Batch: 13/13 (valid)
# valid Loss: 0.2941 AUC: 0.9317
#
# Epoch 16/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2477 AUC: 0.9402
# Batch: 13/13 (valid)
# valid Loss: 0.3032 AUC: 0.9319
#
# Epoch 17/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2373 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.3352 AUC: 0.9243
#
# Epoch 18/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2315 AUC: 0.9442
# Batch: 13/13 (valid)
# valid Loss: 0.3061 AUC: 0.9304
#
# Epoch 19/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2312 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.3143 AUC: 0.9278
#
# Epoch 20/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2311 AUC: 0.9455
# Batch: 13/13 (valid)
# valid Loss: 0.3137 AUC: 0.9277
#
# Epoch 21/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2253 AUC: 0.9456
# Batch: 13/13 (valid)
# valid Loss: 0.3129 AUC: 0.9281
#
# Epoch 22/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2235 AUC: 0.9449
# Batch: 13/13 (valid)
# valid Loss: 0.3145 AUC: 0.9259
#
# Epoch 23/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2235 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3072 AUC: 0.9262
#
# Epoch 24/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2243 AUC: 0.9440
# Batch: 13/13 (valid)
# valid Loss: 0.3020 AUC: 0.9277
#
# Epoch 25/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2322 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.3268 AUC: 0.9319
#
# Epoch 26/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2410 AUC: 0.9441
# Batch: 13/13 (valid)
# valid Loss: 0.3149 AUC: 0.9268
#
# Epoch 27/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2460 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.3589 AUC: 0.9145
#
# Epoch 28/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2410 AUC: 0.9431
# Batch: 13/13 (valid)
# valid Loss: 0.3350 AUC: 0.9224
#
# Epoch 29/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2590 AUC: 0.9407
# Batch: 13/13 (valid)
# valid Loss: 0.3743 AUC: 0.9145
#
# Epoch 30/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2804 AUC: 0.9355
# Batch: 13/13 (valid)
# valid Loss: 0.3864 AUC: 0.8953
#
# Epoch 31/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2715 AUC: 0.9381
# Batch: 13/13 (valid)
# valid Loss: 0.3576 AUC: 0.9182
#
# Epoch 32/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2622 AUC: 0.9390
# Batch: 13/13 (valid)
# valid Loss: 0.3412 AUC: 0.9229
#
# Epoch 33/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2618 AUC: 0.9372
# Batch: 13/13 (valid)
# valid Loss: 0.3264 AUC: 0.9285
#
# Epoch 34/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2473 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.3253 AUC: 0.9336
#
# Epoch 35/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2485 AUC: 0.9415
# Batch: 13/13 (valid)
# valid Loss: 0.3128 AUC: 0.9319
#
# Epoch 36/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2378 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.2989 AUC: 0.9348
#
# Epoch 37/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2322 AUC: 0.9423
# Batch: 13/13 (valid)
# valid Loss: 0.2934 AUC: 0.9390
#
# Epoch 38/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2319 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.2805 AUC: 0.9344
#
# Epoch 39/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2301 AUC: 0.9442
# Batch: 13/13 (valid)
# valid Loss: 0.2894 AUC: 0.9356
#
# Epoch 40/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2226 AUC: 0.9448
# Batch: 13/13 (valid)
# valid Loss: 0.2816 AUC: 0.9359
#
# Epoch 41/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2241 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.2825 AUC: 0.9362
#
# Epoch 42/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2210 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.2825 AUC: 0.9362
#
# Epoch 43/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2265 AUC: 0.9426
# Batch: 13/13 (valid)
# valid Loss: 0.2835 AUC: 0.9362
#
# Epoch 44/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2212 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.2916 AUC: 0.9347
#
# Epoch 45/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2245 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.2669 AUC: 0.9374
#
# Epoch 46/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2281 AUC: 0.9451
# Batch: 13/13 (valid)
# valid Loss: 0.2802 AUC: 0.9345
#
# Epoch 47/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2207 AUC: 0.9447
# Batch: 13/13 (valid)
# valid Loss: 0.2857 AUC: 0.9358
#
# Epoch 48/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2291 AUC: 0.9416
# Batch: 13/13 (valid)
# valid Loss: 0.3976 AUC: 0.9019
#
# Epoch 49/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2430 AUC: 0.9428
# Batch: 13/13 (valid)
# valid Loss: 0.3690 AUC: 0.9193
#
# Epoch 50/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2430 AUC: 0.9426
# Batch: 13/13 (valid)
# valid Loss: 0.3612 AUC: 0.9167
#
# Epoch 51/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2589 AUC: 0.9416
# Batch: 13/13 (valid)
# valid Loss: 0.3294 AUC: 0.9262
#
# Epoch 52/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2491 AUC: 0.9414
# Batch: 13/13 (valid)
# valid Loss: 0.3459 AUC: 0.9247
#
# Epoch 53/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2468 AUC: 0.9418
# Batch: 13/13 (valid)
# valid Loss: 0.4174 AUC: 0.9039
#
# Epoch 54/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2487 AUC: 0.9410
# Batch: 13/13 (valid)
# valid Loss: 0.3277 AUC: 0.9272
#
# Epoch 55/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2511 AUC: 0.9413
# Batch: 13/13 (valid)
# valid Loss: 0.2992 AUC: 0.9350
#
# Epoch 56/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2452 AUC: 0.9415
# Batch: 13/13 (valid)
# valid Loss: 0.3544 AUC: 0.9286
#
# Epoch 57/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2478 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.3452 AUC: 0.9293
#
# Epoch 58/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2405 AUC: 0.9409
# Batch: 13/13 (valid)
# valid Loss: 0.3309 AUC: 0.9342
#
# Epoch 59/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2268 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.3381 AUC: 0.9339
#
# Epoch 60/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2195 AUC: 0.9448
# Batch: 13/13 (valid)
# valid Loss: 0.3284 AUC: 0.9326
#
# Epoch 61/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2180 AUC: 0.9448
# Batch: 13/13 (valid)
# valid Loss: 0.3246 AUC: 0.9356
#
# Epoch 62/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2168 AUC: 0.9449
# Batch: 13/13 (valid)
# valid Loss: 0.3234 AUC: 0.9351
#
# Epoch 63/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2221 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.3234 AUC: 0.9352
#
# Epoch 64/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2254 AUC: 0.9442
# Batch: 13/13 (valid)
# valid Loss: 0.3232 AUC: 0.9348
#
# Epoch 65/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2323 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.3191 AUC: 0.9353
#
# Epoch 66/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2214 AUC: 0.9455
# Batch: 13/13 (valid)
# valid Loss: 0.3212 AUC: 0.9347
#
# Epoch 67/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2149 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.3241 AUC: 0.9349
#
# Epoch 68/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2229 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.3513 AUC: 0.9149
#
# Epoch 69/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2271 AUC: 0.9432
# Batch: 13/13 (valid)
# valid Loss: 0.3361 AUC: 0.9164
#
# Epoch 70/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2345 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.3439 AUC: 0.9236
#
# Epoch 71/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2393 AUC: 0.9432
# Batch: 13/13 (valid)
# valid Loss: 0.3550 AUC: 0.9230
#
# Epoch 72/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2511 AUC: 0.9443
# Batch: 13/13 (valid)
# valid Loss: 0.3246 AUC: 0.9304
#
# Epoch 73/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2452 AUC: 0.9420
# Batch: 13/13 (valid)
# valid Loss: 0.3485 AUC: 0.9207
#
# Epoch 74/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2526 AUC: 0.9417
# Batch: 13/13 (valid)
# valid Loss: 0.3366 AUC: 0.9267
#
# Epoch 75/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2399 AUC: 0.9432
# Batch: 13/13 (valid)
# valid Loss: 0.3048 AUC: 0.9307
#
# Epoch 76/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2375 AUC: 0.9419
# Batch: 13/13 (valid)
# valid Loss: 0.3066 AUC: 0.9260
#
# Epoch 77/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2432 AUC: 0.9421
# Batch: 13/13 (valid)
# valid Loss: 0.3228 AUC: 0.9261
#
# Epoch 78/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2314 AUC: 0.9447
# Batch: 13/13 (valid)
# valid Loss: 0.3270 AUC: 0.9285
#
# Epoch 79/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2280 AUC: 0.9451
# Batch: 13/13 (valid)
# valid Loss: 0.3311 AUC: 0.9255
#
# Epoch 80/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2226 AUC: 0.9424
# Batch: 13/13 (valid)
# valid Loss: 0.2978 AUC: 0.9349
#
# Epoch 81/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2205 AUC: 0.9432
# Batch: 13/13 (valid)
# valid Loss: 0.2899 AUC: 0.9359
#
# Epoch 82/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2173 AUC: 0.9447
# Batch: 13/13 (valid)
# valid Loss: 0.2850 AUC: 0.9355
#
# Epoch 83/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2163 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.2852 AUC: 0.9354
#
# Epoch 84/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2196 AUC: 0.9443
# Batch: 13/13 (valid)
# valid Loss: 0.2852 AUC: 0.9354
#
# Epoch 85/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2096 AUC: 0.9449
# Batch: 13/13 (valid)
# valid Loss: 0.2865 AUC: 0.9355
#
# Epoch 86/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2206 AUC: 0.9423
# Batch: 13/13 (valid)
# valid Loss: 0.2936 AUC: 0.9351
#
# Epoch 87/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2159 AUC: 0.9442
# Batch: 13/13 (valid)
# valid Loss: 0.2910 AUC: 0.9331
#
# Epoch 88/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2125 AUC: 0.9440
# Batch: 13/13 (valid)
# valid Loss: 0.3229 AUC: 0.9314
#
# Epoch 89/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2221 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.3380 AUC: 0.9339
#
# Epoch 90/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2234 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.3114 AUC: 0.9320
#
# Epoch 91/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2295 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.3200 AUC: 0.9246
#
# Epoch 92/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2363 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.3017 AUC: 0.9348
#
# Epoch 93/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2376 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3543 AUC: 0.9173
#
# Epoch 94/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2652 AUC: 0.9389
# Batch: 13/13 (valid)
# valid Loss: 0.3279 AUC: 0.9301
#
# Epoch 95/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2468 AUC: 0.9418
# Batch: 13/13 (valid)
# valid Loss: 0.3313 AUC: 0.9227
#
# Epoch 96/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2336 AUC: 0.9432
# Batch: 13/13 (valid)
# valid Loss: 0.3787 AUC: 0.9148
#
# Epoch 97/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2427 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3490 AUC: 0.9277
#
# Epoch 98/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2276 AUC: 0.9410
# Batch: 13/13 (valid)
# valid Loss: 0.3423 AUC: 0.9245
#
# Epoch 99/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2305 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.3275 AUC: 0.9250
#
# Training complete in 239m 33s
# Best val AUC: 0.9390
#
# - Validation -
# === Normal Valid ===
# Batch: 13/13
#
# Norml Valid AUC: 0.9398
#
# === Valid Time Augmentation ===
# n: 0/4
# ----------
# Batch: 13/13
# n: 1/4
# ----------
# Batch: 13/13
# n: 2/4
# ----------
# Batch: 13/13
# n: 3/4
# ----------
# Batch: 13/13
# n: 4/4
# ----------
# Batch: 13/13
#
# VTA AUC: 0.9381
#
# === Mixed Valid ===
#
# Mixed AUC: 0.9391
#
# === Fold: 1 ===
# GPU Memory: 17040384
# << Spec: 0 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.6876 AUC: 0.5635
# Batch: 13/13 (valid)
# valid Loss: 0.6627 AUC: 0.6500
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.6232 AUC: 0.7048
# Batch: 13/13 (valid)
# valid Loss: 0.5466 AUC: 0.7970
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5680 AUC: 0.7596
# Batch: 13/13 (valid)
# valid Loss: 0.5109 AUC: 0.8191
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5510 AUC: 0.7875
# Batch: 13/13 (valid)
# valid Loss: 0.4973 AUC: 0.8310
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5295 AUC: 0.8128
# Batch: 13/13 (valid)
# valid Loss: 0.4880 AUC: 0.8399
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5097 AUC: 0.8257
# Batch: 13/13 (valid)
# valid Loss: 0.4807 AUC: 0.8465
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4946 AUC: 0.8416
# Batch: 13/13 (valid)
# valid Loss: 0.4766 AUC: 0.8469
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4896 AUC: 0.8429
# Batch: 13/13 (valid)
# valid Loss: 0.4718 AUC: 0.8537
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4768 AUC: 0.8532
# Batch: 13/13 (valid)
# valid Loss: 0.4777 AUC: 0.8484
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4690 AUC: 0.8523
# Batch: 13/13 (valid)
# valid Loss: 0.4821 AUC: 0.8410
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4612 AUC: 0.8660
# Batch: 13/13 (valid)
# valid Loss: 0.4738 AUC: 0.8470
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4579 AUC: 0.8645
# Batch: 13/13 (valid)
# valid Loss: 0.4744 AUC: 0.8465
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4533 AUC: 0.8731
# Batch: 13/13 (valid)
# valid Loss: 0.4723 AUC: 0.8519
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4519 AUC: 0.8683
# Batch: 13/13 (valid)
# valid Loss: 0.4660 AUC: 0.8533
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4604 AUC: 0.8673
# Batch: 13/13 (valid)
# valid Loss: 0.4680 AUC: 0.8533
#
# Training complete in 21m 4s
# Best val AUC: 0.8537
#
# << Spec: 1 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4835 AUC: 0.8484
# Batch: 13/13 (valid)
# valid Loss: 0.4718 AUC: 0.8537
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4830 AUC: 0.8466
# Batch: 13/13 (valid)
# valid Loss: 0.4686 AUC: 0.8520
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4696 AUC: 0.8605
# Batch: 13/13 (valid)
# valid Loss: 0.4679 AUC: 0.8513
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4710 AUC: 0.8591
# Batch: 13/13 (valid)
# valid Loss: 0.4712 AUC: 0.8479
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4675 AUC: 0.8598
# Batch: 13/13 (valid)
# valid Loss: 0.4678 AUC: 0.8546
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4551 AUC: 0.8735
# Batch: 13/13 (valid)
# valid Loss: 0.4691 AUC: 0.8526
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4644 AUC: 0.8624
# Batch: 13/13 (valid)
# valid Loss: 0.4626 AUC: 0.8569
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4457 AUC: 0.8771
# Batch: 13/13 (valid)
# valid Loss: 0.4701 AUC: 0.8493
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4518 AUC: 0.8744
# Batch: 13/13 (valid)
# valid Loss: 0.4766 AUC: 0.8480
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4515 AUC: 0.8711
# Batch: 13/13 (valid)
# valid Loss: 0.4769 AUC: 0.8498
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4391 AUC: 0.8810
# Batch: 13/13 (valid)
# valid Loss: 0.4657 AUC: 0.8502
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4469 AUC: 0.8756
# Batch: 13/13 (valid)
# valid Loss: 0.4725 AUC: 0.8525
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4376 AUC: 0.8808
# Batch: 13/13 (valid)
# valid Loss: 0.4612 AUC: 0.8575
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4259 AUC: 0.8894
# Batch: 13/13 (valid)
# valid Loss: 0.4623 AUC: 0.8536
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4270 AUC: 0.8837
# Batch: 13/13 (valid)
# valid Loss: 0.4694 AUC: 0.8531
#
# Training complete in 21m 7s
# Best val AUC: 0.8575
#
# << Spec: 2 >>
# Epoch 0/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4360 AUC: 0.8813
# Batch: 13/13 (valid)
# valid Loss: 0.4612 AUC: 0.8575
#
# Epoch 1/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4515 AUC: 0.8776
# Batch: 13/13 (valid)
# valid Loss: 0.4422 AUC: 0.8746
#
# Epoch 2/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4205 AUC: 0.8908
# Batch: 13/13 (valid)
# valid Loss: 0.4166 AUC: 0.8967
#
# Epoch 3/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3986 AUC: 0.9045
# Batch: 13/13 (valid)
# valid Loss: 0.4274 AUC: 0.8857
#
# Epoch 4/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3704 AUC: 0.9134
# Batch: 13/13 (valid)
# valid Loss: 0.4112 AUC: 0.8998
#
# Epoch 5/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3656 AUC: 0.9242
# Batch: 13/13 (valid)
# valid Loss: 0.3775 AUC: 0.9180
#
# Epoch 6/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3462 AUC: 0.9255
# Batch: 13/13 (valid)
# valid Loss: 0.4096 AUC: 0.9129
#
# Epoch 7/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3217 AUC: 0.9308
# Batch: 13/13 (valid)
# valid Loss: 0.4033 AUC: 0.9129
#
# Epoch 8/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3082 AUC: 0.9342
# Batch: 13/13 (valid)
# valid Loss: 0.3360 AUC: 0.9226
#
# Epoch 9/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2875 AUC: 0.9381
# Batch: 13/13 (valid)
# valid Loss: 0.3766 AUC: 0.9123
#
# Epoch 10/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2965 AUC: 0.9356
# Batch: 13/13 (valid)
# valid Loss: 0.3809 AUC: 0.9183
#
# Epoch 11/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2688 AUC: 0.9411
# Batch: 13/13 (valid)
# valid Loss: 0.3540 AUC: 0.9186
#
# Epoch 12/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2658 AUC: 0.9426
# Batch: 13/13 (valid)
# valid Loss: 0.3455 AUC: 0.9185
#
# Epoch 13/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2733 AUC: 0.9389
# Batch: 13/13 (valid)
# valid Loss: 0.3532 AUC: 0.9178
#
# Epoch 14/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2717 AUC: 0.9415
# Batch: 13/13 (valid)
# valid Loss: 0.3514 AUC: 0.9184
#
# Epoch 15/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2710 AUC: 0.9406
# Batch: 13/13 (valid)
# valid Loss: 0.3514 AUC: 0.9184
#
# Epoch 16/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2686 AUC: 0.9389
# Batch: 13/13 (valid)
# valid Loss: 0.3492 AUC: 0.9177
#
# Epoch 17/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2534 AUC: 0.9428
# Batch: 13/13 (valid)
# valid Loss: 0.3477 AUC: 0.9186
#
# Epoch 18/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2653 AUC: 0.9400
# Batch: 13/13 (valid)
# valid Loss: 0.3322 AUC: 0.9229
#
# Epoch 19/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2602 AUC: 0.9412
# Batch: 13/13 (valid)
# valid Loss: 0.3484 AUC: 0.9198
#
# Epoch 20/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2775 AUC: 0.9389
# Batch: 13/13 (valid)
# valid Loss: 0.3997 AUC: 0.9156
#
# Epoch 21/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2755 AUC: 0.9397
# Batch: 13/13 (valid)
# valid Loss: 0.3654 AUC: 0.9150
#
# Epoch 22/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2831 AUC: 0.9375
# Batch: 13/13 (valid)
# valid Loss: 0.3863 AUC: 0.9118
#
# Epoch 23/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2852 AUC: 0.9373
# Batch: 13/13 (valid)
# valid Loss: 0.4300 AUC: 0.9018
#
# Epoch 24/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3015 AUC: 0.9325
# Batch: 13/13 (valid)
# valid Loss: 0.3605 AUC: 0.9146
#
# Epoch 25/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3040 AUC: 0.9342
# Batch: 13/13 (valid)
# valid Loss: 0.3567 AUC: 0.9206
#
# Epoch 26/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2951 AUC: 0.9354
# Batch: 13/13 (valid)
# valid Loss: 0.4474 AUC: 0.8940
#
# Epoch 27/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2852 AUC: 0.9392
# Batch: 13/13 (valid)
# valid Loss: 0.3552 AUC: 0.9145
#
# Epoch 28/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2744 AUC: 0.9397
# Batch: 13/13 (valid)
# valid Loss: 0.3876 AUC: 0.9081
#
# Epoch 29/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2713 AUC: 0.9406
# Batch: 13/13 (valid)
# valid Loss: 0.3419 AUC: 0.9201
#
# Training complete in 43m 40s
# Best val AUC: 0.9229
#
# << Spec: 3 >>
# Epoch 0/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2666 AUC: 0.9404
# Batch: 13/13 (valid)
# valid Loss: 0.3322 AUC: 0.9229
#
# Epoch 1/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2479 AUC: 0.9411
# Batch: 13/13 (valid)
# valid Loss: 0.3453 AUC: 0.9208
#
# Epoch 2/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2503 AUC: 0.9436
# Batch: 13/13 (valid)
# valid Loss: 0.3380 AUC: 0.9233
#
# Epoch 3/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2670 AUC: 0.9370
# Batch: 13/13 (valid)
# valid Loss: 0.3365 AUC: 0.9226
#
# Epoch 4/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2629 AUC: 0.9412
# Batch: 13/13 (valid)
# valid Loss: 0.3244 AUC: 0.9270
#
# Epoch 5/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2716 AUC: 0.9398
# Batch: 13/13 (valid)
# valid Loss: 0.3260 AUC: 0.9343
#
# Epoch 6/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2689 AUC: 0.9382
# Batch: 13/13 (valid)
# valid Loss: 0.3337 AUC: 0.9237
#
# Epoch 7/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2746 AUC: 0.9379
# Batch: 13/13 (valid)
# valid Loss: 0.3491 AUC: 0.9181
#
# Epoch 8/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2714 AUC: 0.9385
# Batch: 13/13 (valid)
# valid Loss: 0.3274 AUC: 0.9253
#
# Epoch 9/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2871 AUC: 0.9382
# Batch: 13/13 (valid)
# valid Loss: 0.3647 AUC: 0.9182
#
# Epoch 10/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2845 AUC: 0.9367
# Batch: 13/13 (valid)
# valid Loss: 0.3666 AUC: 0.9130
#
# Epoch 11/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2691 AUC: 0.9393
# Batch: 13/13 (valid)
# valid Loss: 0.3699 AUC: 0.9095
#
# Epoch 12/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2649 AUC: 0.9402
# Batch: 13/13 (valid)
# valid Loss: 0.3721 AUC: 0.9181
#
# Epoch 13/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2531 AUC: 0.9411
# Batch: 13/13 (valid)
# valid Loss: 0.3189 AUC: 0.9242
#
# Epoch 14/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2461 AUC: 0.9419
# Batch: 13/13 (valid)
# valid Loss: 0.3360 AUC: 0.9252
#
# Epoch 15/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2492 AUC: 0.9408
# Batch: 13/13 (valid)
# valid Loss: 0.3245 AUC: 0.9247
#
# Epoch 16/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2357 AUC: 0.9423
# Batch: 13/13 (valid)
# valid Loss: 0.3374 AUC: 0.9227
#
# Epoch 17/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2326 AUC: 0.9442
# Batch: 13/13 (valid)
# valid Loss: 0.3235 AUC: 0.9231
#
# Epoch 18/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2300 AUC: 0.9441
# Batch: 13/13 (valid)
# valid Loss: 0.3039 AUC: 0.9299
#
# Epoch 19/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2255 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.3023 AUC: 0.9276
#
# Epoch 20/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2282 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.3025 AUC: 0.9281
#
# Epoch 21/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2279 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.3030 AUC: 0.9280
#
# Epoch 22/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2279 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.3019 AUC: 0.9298
#
# Epoch 23/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2245 AUC: 0.9442
# Batch: 13/13 (valid)
# valid Loss: 0.2984 AUC: 0.9309
#
# Epoch 24/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2291 AUC: 0.9426
# Batch: 13/13 (valid)
# valid Loss: 0.3268 AUC: 0.9321
#
# Epoch 25/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2296 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3194 AUC: 0.9238
#
# Epoch 26/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2456 AUC: 0.9432
# Batch: 13/13 (valid)
# valid Loss: 0.3178 AUC: 0.9289
#
# Epoch 27/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2505 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.2927 AUC: 0.9362
#
# Epoch 28/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2480 AUC: 0.9426
# Batch: 13/13 (valid)
# valid Loss: 0.3561 AUC: 0.9151
#
# Epoch 29/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2501 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.3527 AUC: 0.9132
#
# Epoch 30/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2739 AUC: 0.9371
# Batch: 13/13 (valid)
# valid Loss: 0.3365 AUC: 0.9240
#
# Epoch 31/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2805 AUC: 0.9377
# Batch: 13/13 (valid)
# valid Loss: 0.3453 AUC: 0.9222
#
# Epoch 32/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2456 AUC: 0.9424
# Batch: 13/13 (valid)
# valid Loss: 0.4162 AUC: 0.9061
#
# Epoch 33/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2636 AUC: 0.9396
# Batch: 13/13 (valid)
# valid Loss: 0.3349 AUC: 0.9133
#
# Epoch 34/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2581 AUC: 0.9411
# Batch: 13/13 (valid)
# valid Loss: 0.3485 AUC: 0.9180
#
# Epoch 35/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2537 AUC: 0.9398
# Batch: 13/13 (valid)
# valid Loss: 0.3703 AUC: 0.9213
#
# Epoch 36/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2447 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.3470 AUC: 0.9126
#
# Epoch 37/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2335 AUC: 0.9432
# Batch: 13/13 (valid)
# valid Loss: 0.3384 AUC: 0.9167
#
# Epoch 38/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2249 AUC: 0.9436
# Batch: 13/13 (valid)
# valid Loss: 0.3232 AUC: 0.9244
#
# Epoch 39/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2268 AUC: 0.9440
# Batch: 13/13 (valid)
# valid Loss: 0.3246 AUC: 0.9240
#
# Epoch 40/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2185 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.3205 AUC: 0.9234
#
# Epoch 41/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2228 AUC: 0.9457
# Batch: 13/13 (valid)
# valid Loss: 0.3206 AUC: 0.9240
#
# Epoch 42/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2314 AUC: 0.9440
# Batch: 13/13 (valid)
# valid Loss: 0.3208 AUC: 0.9240
#
# Epoch 43/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2182 AUC: 0.9449
# Batch: 13/13 (valid)
# valid Loss: 0.3240 AUC: 0.9253
#
# Epoch 44/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2275 AUC: 0.9440
# Batch: 13/13 (valid)
# valid Loss: 0.3170 AUC: 0.9240
#
# Epoch 45/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2183 AUC: 0.9454
# Batch: 13/13 (valid)
# valid Loss: 0.3375 AUC: 0.9165
#
# Epoch 46/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2222 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.3388 AUC: 0.9220
#
# Epoch 47/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2219 AUC: 0.9443
# Batch: 13/13 (valid)
# valid Loss: 0.3249 AUC: 0.9278
#
# Epoch 48/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2363 AUC: 0.9424
# Batch: 13/13 (valid)
# valid Loss: 0.3038 AUC: 0.9306
#
# Epoch 49/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2405 AUC: 0.9426
# Batch: 13/13 (valid)
# valid Loss: 0.3393 AUC: 0.9219
#
# Epoch 50/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2420 AUC: 0.9429
# Batch: 13/13 (valid)
# valid Loss: 0.3607 AUC: 0.9166
#
# Epoch 51/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2476 AUC: 0.9410
# Batch: 13/13 (valid)
# valid Loss: 0.3460 AUC: 0.9162
#
# Epoch 52/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2663 AUC: 0.9395
# Batch: 13/13 (valid)
# valid Loss: 0.3715 AUC: 0.9250
#
# Epoch 53/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2450 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.3218 AUC: 0.9280
#
# Epoch 54/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2554 AUC: 0.9416
# Batch: 13/13 (valid)
# valid Loss: 0.3473 AUC: 0.9180
#
# Epoch 55/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2410 AUC: 0.9394
# Batch: 13/13 (valid)
# valid Loss: 0.3524 AUC: 0.9113
#
# Epoch 56/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2353 AUC: 0.9458
# Batch: 13/13 (valid)
# valid Loss: 0.3501 AUC: 0.9185
#
# Epoch 57/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2295 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.2989 AUC: 0.9368
#
# Epoch 58/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2288 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3270 AUC: 0.9251
#
# Epoch 59/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2209 AUC: 0.9451
# Batch: 13/13 (valid)
# valid Loss: 0.3273 AUC: 0.9241
#
# Epoch 60/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2197 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.3234 AUC: 0.9256
#
# Epoch 61/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2178 AUC: 0.9462
# Batch: 13/13 (valid)
# valid Loss: 0.3197 AUC: 0.9241
#
# Epoch 62/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2193 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.3226 AUC: 0.9228
#
# Epoch 63/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2210 AUC: 0.9453
# Batch: 13/13 (valid)
# valid Loss: 0.3227 AUC: 0.9227
#
# Epoch 64/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2119 AUC: 0.9459
# Batch: 13/13 (valid)
# valid Loss: 0.3227 AUC: 0.9242
#
# Epoch 65/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2176 AUC: 0.9422
# Batch: 13/13 (valid)
# valid Loss: 0.3227 AUC: 0.9232
#
# Epoch 66/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2172 AUC: 0.9462
# Batch: 13/13 (valid)
# valid Loss: 0.3115 AUC: 0.9256
#
# Epoch 67/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2232 AUC: 0.9448
# Batch: 13/13 (valid)
# valid Loss: 0.3088 AUC: 0.9326
#
# Epoch 68/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2202 AUC: 0.9418
# Batch: 13/13 (valid)
# valid Loss: 0.3395 AUC: 0.9187
#
# Epoch 69/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2326 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.3213 AUC: 0.9296
#
# Epoch 70/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2347 AUC: 0.9436
# Batch: 13/13 (valid)
# valid Loss: 0.3006 AUC: 0.9368
#
# Epoch 71/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2452 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.3337 AUC: 0.9174
#
# Epoch 72/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2412 AUC: 0.9440
# Batch: 13/13 (valid)
# valid Loss: 0.4608 AUC: 0.8885
#
# Epoch 73/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2589 AUC: 0.9406
# Batch: 13/13 (valid)
# valid Loss: 0.3283 AUC: 0.9238
#
# Epoch 74/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2433 AUC: 0.9426
# Batch: 13/13 (valid)
# valid Loss: 0.3450 AUC: 0.9135
#
# Epoch 75/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2400 AUC: 0.9415
# Batch: 13/13 (valid)
# valid Loss: 0.3687 AUC: 0.9129
#
# Epoch 76/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2510 AUC: 0.9405
# Batch: 13/13 (valid)
# valid Loss: 0.3964 AUC: 0.9170
#
# Epoch 77/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2379 AUC: 0.9431
# Batch: 13/13 (valid)
# valid Loss: 0.3673 AUC: 0.9177
#
# Epoch 78/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2268 AUC: 0.9455
# Batch: 13/13 (valid)
# valid Loss: 0.3527 AUC: 0.9247
#
# Epoch 79/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2277 AUC: 0.9449
# Batch: 13/13 (valid)
# valid Loss: 0.3571 AUC: 0.9244
#
# Epoch 80/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2276 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.3342 AUC: 0.9241
#
# Epoch 81/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2225 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.3290 AUC: 0.9272
#
# Epoch 82/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2193 AUC: 0.9441
# Batch: 13/13 (valid)
# valid Loss: 0.3263 AUC: 0.9277
#
# Epoch 83/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2197 AUC: 0.9448
# Batch: 13/13 (valid)
# valid Loss: 0.3264 AUC: 0.9275
#
# Epoch 84/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2157 AUC: 0.9448
# Batch: 13/13 (valid)
# valid Loss: 0.3265 AUC: 0.9275
#
# Epoch 85/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2136 AUC: 0.9442
# Batch: 13/13 (valid)
# valid Loss: 0.3265 AUC: 0.9277
#
# Epoch 86/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2123 AUC: 0.9453
# Batch: 13/13 (valid)
# valid Loss: 0.3349 AUC: 0.9249
#
# Epoch 87/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2195 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.3213 AUC: 0.9254
#
# Epoch 88/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2147 AUC: 0.9448
# Batch: 13/13 (valid)
# valid Loss: 0.3157 AUC: 0.9263
#
# Epoch 89/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2167 AUC: 0.9442
# Batch: 13/13 (valid)
# valid Loss: 0.3196 AUC: 0.9166
#
# Epoch 90/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2304 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.3380 AUC: 0.9247
#
# Epoch 91/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2303 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.3481 AUC: 0.9191
#
# Epoch 92/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2404 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.3782 AUC: 0.9069
#
# Epoch 93/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2356 AUC: 0.9419
# Batch: 13/13 (valid)
# valid Loss: 0.3527 AUC: 0.9154
#
# Epoch 94/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2487 AUC: 0.9426
# Batch: 13/13 (valid)
# valid Loss: 0.3919 AUC: 0.9107
#
# Epoch 95/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2505 AUC: 0.9404
# Batch: 13/13 (valid)
# valid Loss: 0.3070 AUC: 0.9306
#
# Epoch 96/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2450 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.3756 AUC: 0.9195
#
# Epoch 97/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2394 AUC: 0.9428
# Batch: 13/13 (valid)
# valid Loss: 0.3849 AUC: 0.9256
#
# Epoch 98/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2362 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3279 AUC: 0.9300
#
# Epoch 99/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2244 AUC: 0.9443
# Batch: 13/13 (valid)
# valid Loss: 0.3025 AUC: 0.9380
#
# Training complete in 239m 49s
# Best val AUC: 0.9380
#
# - Validation -
# === Normal Valid ===
# Batch: 13/13
#
# Norml Valid AUC: 0.9357
#
# === Valid Time Augmentation ===
# n: 0/4
# ----------
# Batch: 13/13
# n: 1/4
# ----------
# Batch: 13/13
# n: 2/4
# ----------
# Batch: 13/13
# n: 3/4
# ----------
# Batch: 13/13
# n: 4/4
# ----------
# Batch: 13/13
#
# VTA AUC: 0.9322
#
# === Mixed Valid ===
#
# Mixed AUC: 0.9352
#
# === Fold: 2 ===
# GPU Memory: 17040384
# << Spec: 0 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.6922 AUC: 0.5503
# Batch: 13/13 (valid)
# valid Loss: 0.7011 AUC: 0.5142
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.6353 AUC: 0.6789
# Batch: 13/13 (valid)
# valid Loss: 0.5754 AUC: 0.7698
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5747 AUC: 0.7607
# Batch: 13/13 (valid)
# valid Loss: 0.5318 AUC: 0.8081
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5474 AUC: 0.7841
# Batch: 13/13 (valid)
# valid Loss: 0.5056 AUC: 0.8329
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5186 AUC: 0.8160
# Batch: 13/13 (valid)
# valid Loss: 0.4899 AUC: 0.8462
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5173 AUC: 0.8209
# Batch: 13/13 (valid)
# valid Loss: 0.4786 AUC: 0.8515
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5064 AUC: 0.8293
# Batch: 13/13 (valid)
# valid Loss: 0.4775 AUC: 0.8554
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4981 AUC: 0.8328
# Batch: 13/13 (valid)
# valid Loss: 0.4690 AUC: 0.8622
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4918 AUC: 0.8434
# Batch: 13/13 (valid)
# valid Loss: 0.4574 AUC: 0.8688
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4698 AUC: 0.8588
# Batch: 13/13 (valid)
# valid Loss: 0.4505 AUC: 0.8694
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4694 AUC: 0.8569
# Batch: 13/13 (valid)
# valid Loss: 0.4501 AUC: 0.8709
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4724 AUC: 0.8590
# Batch: 13/13 (valid)
# valid Loss: 0.4447 AUC: 0.8711
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4600 AUC: 0.8647
# Batch: 13/13 (valid)
# valid Loss: 0.4414 AUC: 0.8738
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4562 AUC: 0.8637
# Batch: 13/13 (valid)
# valid Loss: 0.4453 AUC: 0.8720
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4520 AUC: 0.8647
# Batch: 13/13 (valid)
# valid Loss: 0.4382 AUC: 0.8761
#
# Training complete in 21m 5s
# Best val AUC: 0.8761
#
# << Spec: 1 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4542 AUC: 0.8674
# Batch: 13/13 (valid)
# valid Loss: 0.4382 AUC: 0.8761
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4566 AUC: 0.8666
# Batch: 13/13 (valid)
# valid Loss: 0.4390 AUC: 0.8733
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4582 AUC: 0.8596
# Batch: 13/13 (valid)
# valid Loss: 0.4402 AUC: 0.8763
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4561 AUC: 0.8676
# Batch: 13/13 (valid)
# valid Loss: 0.4372 AUC: 0.8782
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4535 AUC: 0.8689
# Batch: 13/13 (valid)
# valid Loss: 0.4355 AUC: 0.8766
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4551 AUC: 0.8620
# Batch: 13/13 (valid)
# valid Loss: 0.4347 AUC: 0.8813
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4556 AUC: 0.8689
# Batch: 13/13 (valid)
# valid Loss: 0.4295 AUC: 0.8815
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4436 AUC: 0.8764
# Batch: 13/13 (valid)
# valid Loss: 0.4367 AUC: 0.8802
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4407 AUC: 0.8794
# Batch: 13/13 (valid)
# valid Loss: 0.4430 AUC: 0.8815
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4499 AUC: 0.8724
# Batch: 13/13 (valid)
# valid Loss: 0.4334 AUC: 0.8840
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4408 AUC: 0.8791
# Batch: 13/13 (valid)
# valid Loss: 0.4463 AUC: 0.8775
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4483 AUC: 0.8713
# Batch: 13/13 (valid)
# valid Loss: 0.4271 AUC: 0.8812
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4430 AUC: 0.8774
# Batch: 13/13 (valid)
# valid Loss: 0.4254 AUC: 0.8833
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4375 AUC: 0.8748
# Batch: 13/13 (valid)
# valid Loss: 0.4271 AUC: 0.8858
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4282 AUC: 0.8831
# Batch: 13/13 (valid)
# valid Loss: 0.4207 AUC: 0.8868
#
# Training complete in 21m 8s
# Best val AUC: 0.8868
#
# << Spec: 2 >>
# Epoch 0/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4251 AUC: 0.8900
# Batch: 13/13 (valid)
# valid Loss: 0.4207 AUC: 0.8868
#
# Epoch 1/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4341 AUC: 0.8827
# Batch: 13/13 (valid)
# valid Loss: 0.4204 AUC: 0.8969
#
# Epoch 2/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4474 AUC: 0.8956
# Batch: 13/13 (valid)
# valid Loss: 0.4206 AUC: 0.8973
#
# Epoch 3/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4079 AUC: 0.9116
# Batch: 13/13 (valid)
# valid Loss: 0.3988 AUC: 0.9026
#
# Epoch 4/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3677 AUC: 0.9149
# Batch: 13/13 (valid)
# valid Loss: 0.3859 AUC: 0.9068
#
# Epoch 5/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3562 AUC: 0.9238
# Batch: 13/13 (valid)
# valid Loss: 0.3803 AUC: 0.9108
#
# Epoch 6/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3368 AUC: 0.9258
# Batch: 13/13 (valid)
# valid Loss: 0.3910 AUC: 0.9102
#
# Epoch 7/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3208 AUC: 0.9343
# Batch: 13/13 (valid)
# valid Loss: 0.3679 AUC: 0.9064
#
# Epoch 8/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3158 AUC: 0.9302
# Batch: 13/13 (valid)
# valid Loss: 0.3588 AUC: 0.9099
#
# Epoch 9/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2967 AUC: 0.9363
# Batch: 13/13 (valid)
# valid Loss: 0.3464 AUC: 0.9137
#
# Epoch 10/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2863 AUC: 0.9377
# Batch: 13/13 (valid)
# valid Loss: 0.3394 AUC: 0.9177
#
# Epoch 11/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2809 AUC: 0.9383
# Batch: 13/13 (valid)
# valid Loss: 0.3403 AUC: 0.9161
#
# Epoch 12/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2807 AUC: 0.9398
# Batch: 13/13 (valid)
# valid Loss: 0.3344 AUC: 0.9204
#
# Epoch 13/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2665 AUC: 0.9419
# Batch: 13/13 (valid)
# valid Loss: 0.3267 AUC: 0.9209
#
# Epoch 14/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2635 AUC: 0.9425
# Batch: 13/13 (valid)
# ...
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2635 AUC: 0.9408
# Batch: 13/13 (valid)
# valid Loss: 0.3256 AUC: 0.9267
#
# Epoch 13/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2676 AUC: 0.9386
# Batch: 13/13 (valid)
# valid Loss: 0.3225 AUC: 0.9239
#
# Epoch 14/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2652 AUC: 0.9424
# Batch: 13/13 (valid)
# valid Loss: 0.3219 AUC: 0.9259
#
# Epoch 15/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2652 AUC: 0.9420
# Batch: 13/13 (valid)
# valid Loss: 0.3219 AUC: 0.9259
#
# Epoch 16/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2713 AUC: 0.9397
# Batch: 13/13 (valid)
# valid Loss: 0.3233 AUC: 0.9249
#
# Epoch 17/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2636 AUC: 0.9415
# Batch: 13/13 (valid)
# valid Loss: 0.3251 AUC: 0.9229
#
# Epoch 18/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2607 AUC: 0.9417
# Batch: 13/13 (valid)
# valid Loss: 0.3209 AUC: 0.9271
#
# Epoch 19/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2610 AUC: 0.9409
# Batch: 13/13 (valid)
# valid Loss: 0.3165 AUC: 0.9267
#
# Epoch 20/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2679 AUC: 0.9381
# Batch: 13/13 (valid)
# valid Loss: 0.3391 AUC: 0.9225
#
# Epoch 21/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2833 AUC: 0.9365
# Batch: 13/13 (valid)
# valid Loss: 0.3757 AUC: 0.9107
#
# Epoch 22/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2916 AUC: 0.9371
# Batch: 13/13 (valid)
# valid Loss: 0.3616 AUC: 0.9180
#
# Epoch 23/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2809 AUC: 0.9365
# Batch: 13/13 (valid)
# valid Loss: 0.3552 AUC: 0.9190
#
# Epoch 24/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2981 AUC: 0.9333
# Batch: 13/13 (valid)
# valid Loss: 0.3714 AUC: 0.9061
#
# Epoch 25/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2965 AUC: 0.9324
# Batch: 13/13 (valid)
# valid Loss: 0.3498 AUC: 0.9171
#
# Epoch 26/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2993 AUC: 0.9352
# Batch: 13/13 (valid)
# valid Loss: 0.3520 AUC: 0.9231
#
# Epoch 27/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2697 AUC: 0.9408
# Batch: 13/13 (valid)
# valid Loss: 0.3740 AUC: 0.9171
#
# Epoch 28/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2923 AUC: 0.9354
# Batch: 13/13 (valid)
# valid Loss: 0.3734 AUC: 0.9012
#
# Epoch 29/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2699 AUC: 0.9403
# Batch: 13/13 (valid)
# valid Loss: 0.3546 AUC: 0.9179
#
# Training complete in 43m 57s
# Best val AUC: 0.9271
#
# << Spec: 3 >>
# Epoch 0/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2616 AUC: 0.9401
# Batch: 13/13 (valid)
# valid Loss: 0.3209 AUC: 0.9271
#
# Epoch 1/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2628 AUC: 0.9414
# Batch: 13/13 (valid)
# valid Loss: 0.3250 AUC: 0.9247
#
# Epoch 2/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2586 AUC: 0.9428
# Batch: 13/13 (valid)
# valid Loss: 0.3204 AUC: 0.9275
#
# Epoch 3/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2623 AUC: 0.9393
# Batch: 13/13 (valid)
# valid Loss: 0.3058 AUC: 0.9332
#
# Epoch 4/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2700 AUC: 0.9389
# Batch: 13/13 (valid)
# valid Loss: 0.3250 AUC: 0.9257
#
# Epoch 5/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2688 AUC: 0.9402
# Batch: 13/13 (valid)
# valid Loss: 0.3339 AUC: 0.9235
#
# Epoch 6/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2725 AUC: 0.9407
# Batch: 13/13 (valid)
# valid Loss: 0.3333 AUC: 0.9170
#
# Epoch 7/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2733 AUC: 0.9391
# Batch: 13/13 (valid)
# valid Loss: 0.3082 AUC: 0.9332
#
# Epoch 8/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2745 AUC: 0.9386
# Batch: 13/13 (valid)
# valid Loss: 0.3223 AUC: 0.9271
#
# Epoch 9/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2722 AUC: 0.9402
# Batch: 13/13 (valid)
# valid Loss: 0.3268 AUC: 0.9248
#
# Epoch 10/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2800 AUC: 0.9375
# Batch: 13/13 (valid)
# valid Loss: 0.3214 AUC: 0.9268
#
# Epoch 11/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2717 AUC: 0.9399
# Batch: 13/13 (valid)
# valid Loss: 0.3354 AUC: 0.9367
#
# Epoch 12/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2685 AUC: 0.9364
# Batch: 13/13 (valid)
# valid Loss: 0.3059 AUC: 0.9311
#
# Epoch 13/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2631 AUC: 0.9412
# Batch: 13/13 (valid)
# valid Loss: 0.3003 AUC: 0.9343
#
# Epoch 14/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2497 AUC: 0.9410
# Batch: 13/13 (valid)
# valid Loss: 0.2858 AUC: 0.9340
#
# Epoch 15/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2484 AUC: 0.9423
# Batch: 13/13 (valid)
# valid Loss: 0.2863 AUC: 0.9344
#
# Epoch 16/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2386 AUC: 0.9418
# Batch: 13/13 (valid)
# valid Loss: 0.2982 AUC: 0.9300
#
# Epoch 17/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2396 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.2921 AUC: 0.9350
#
# Epoch 18/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2265 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.2758 AUC: 0.9390
#
# Epoch 19/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2260 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.2739 AUC: 0.9372
#
# Epoch 20/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2296 AUC: 0.9431
# Batch: 13/13 (valid)
# valid Loss: 0.2737 AUC: 0.9374
#
# Epoch 21/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2269 AUC: 0.9452
# Batch: 13/13 (valid)
# valid Loss: 0.2734 AUC: 0.9376
#
# Epoch 22/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2222 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.2717 AUC: 0.9383
#
# Epoch 23/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2193 AUC: 0.9449
# Batch: 13/13 (valid)
# valid Loss: 0.2722 AUC: 0.9371
#
# Epoch 24/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2266 AUC: 0.9440
# Batch: 13/13 (valid)
# valid Loss: 0.2749 AUC: 0.9347
#
# Epoch 25/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2287 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.2772 AUC: 0.9365
#
# Epoch 26/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2388 AUC: 0.9428
# Batch: 13/13 (valid)
# valid Loss: 0.3001 AUC: 0.9331
#
# Epoch 27/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2441 AUC: 0.9436
# Batch: 13/13 (valid)
# valid Loss: 0.3170 AUC: 0.9289
#
# Epoch 28/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2561 AUC: 0.9393
# Batch: 13/13 (valid)
# valid Loss: 0.3348 AUC: 0.9241
#
# Epoch 29/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2648 AUC: 0.9412
# Batch: 13/13 (valid)
# valid Loss: 0.3484 AUC: 0.9232
#
# Epoch 30/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2587 AUC: 0.9383
# Batch: 13/13 (valid)
# valid Loss: 0.3482 AUC: 0.9213
#
# Epoch 31/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2788 AUC: 0.9385
# Batch: 13/13 (valid)
# valid Loss: 0.3375 AUC: 0.9238
#
# Epoch 32/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2674 AUC: 0.9378
# Batch: 13/13 (valid)
# valid Loss: 0.3395 AUC: 0.9212
#
# Epoch 33/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2595 AUC: 0.9404
# Batch: 13/13 (valid)
# valid Loss: 0.3635 AUC: 0.9232
#
# Epoch 34/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2502 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.3005 AUC: 0.9348
#
# Epoch 35/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2495 AUC: 0.9404
# Batch: 13/13 (valid)
# valid Loss: 0.3039 AUC: 0.9324
#
# Epoch 36/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2355 AUC: 0.9420
# Batch: 13/13 (valid)
# valid Loss: 0.2953 AUC: 0.9338
#
# Epoch 37/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2323 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.3013 AUC: 0.9322
#
# Epoch 38/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2315 AUC: 0.9431
# Batch: 13/13 (valid)
# valid Loss: 0.2945 AUC: 0.9318
#
# Epoch 39/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2214 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.2954 AUC: 0.9328
#
# Epoch 40/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2239 AUC: 0.9451
# Batch: 13/13 (valid)
# valid Loss: 0.2933 AUC: 0.9333
#
# Epoch 41/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2269 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.2937 AUC: 0.9333
#
# Epoch 42/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2246 AUC: 0.9443
# Batch: 13/13 (valid)
# valid Loss: 0.2936 AUC: 0.9337
#
# Epoch 43/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2267 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.2920 AUC: 0.9341
#
# Epoch 44/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2232 AUC: 0.9449
# Batch: 13/13 (valid)
# valid Loss: 0.2868 AUC: 0.9352
#
# Epoch 45/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2221 AUC: 0.9448
# Batch: 13/13 (valid)
# valid Loss: 0.2868 AUC: 0.9334
#
# Epoch 46/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2176 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.3000 AUC: 0.9294
#
# Epoch 47/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2302 AUC: 0.9436
# Batch: 13/13 (valid)
# valid Loss: 0.2945 AUC: 0.9380
#
# Epoch 48/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2258 AUC: 0.9443
# Batch: 13/13 (valid)
# valid Loss: 0.3048 AUC: 0.9340
#
# Epoch 49/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2437 AUC: 0.9419
# Batch: 13/13 (valid)
# valid Loss: 0.3750 AUC: 0.9207
#
# Epoch 50/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2504 AUC: 0.9419
# Batch: 13/13 (valid)
# valid Loss: 0.2994 AUC: 0.9316
#
# Epoch 51/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2445 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.2936 AUC: 0.9371
#
# Epoch 52/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2547 AUC: 0.9419
# Batch: 13/13 (valid)
# valid Loss: 0.2793 AUC: 0.9389
#
# Epoch 53/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2492 AUC: 0.9429
# Batch: 13/13 (valid)
# valid Loss: 0.4194 AUC: 0.9063
#
# Epoch 54/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2526 AUC: 0.9424
# Batch: 13/13 (valid)
# valid Loss: 0.3519 AUC: 0.9220
#
# Epoch 55/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2459 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.3138 AUC: 0.9266
#
# Epoch 56/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2366 AUC: 0.9441
# Batch: 13/13 (valid)
# valid Loss: 0.2978 AUC: 0.9337
#
# Epoch 57/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2415 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.3141 AUC: 0.9359
#
# Epoch 58/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2216 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.2892 AUC: 0.9318
#
# Epoch 59/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2281 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.2910 AUC: 0.9363
#
# Epoch 60/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2154 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.2896 AUC: 0.9348
#
# Epoch 61/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2147 AUC: 0.9449
# Batch: 13/13 (valid)
# valid Loss: 0.2894 AUC: 0.9372
#
# Epoch 62/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2162 AUC: 0.9443
# Batch: 13/13 (valid)
# valid Loss: 0.2886 AUC: 0.9363
#
# Epoch 63/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2149 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.2886 AUC: 0.9363
#
# Epoch 64/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2098 AUC: 0.9460
# Batch: 13/13 (valid)
# valid Loss: 0.2892 AUC: 0.9352
#
# Epoch 65/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2154 AUC: 0.9460
# Batch: 13/13 (valid)
# valid Loss: 0.2867 AUC: 0.9350
#
# Epoch 66/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2149 AUC: 0.9456
# Batch: 13/13 (valid)
# valid Loss: 0.2820 AUC: 0.9352
#
# Epoch 67/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2183 AUC: 0.9449
# Batch: 13/13 (valid)
# valid Loss: 0.2843 AUC: 0.9367
#
# Epoch 68/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2229 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.2746 AUC: 0.9370
#
# Epoch 69/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2344 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.3054 AUC: 0.9377
#
# Epoch 70/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2323 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.3047 AUC: 0.9319
#
# Epoch 71/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2369 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.3364 AUC: 0.9284
#
# Epoch 72/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2393 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.3393 AUC: 0.9209
#
# Epoch 73/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2666 AUC: 0.9412
# Batch: 13/13 (valid)
# valid Loss: 0.3365 AUC: 0.9244
#
# Epoch 74/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2578 AUC: 0.9398
# Batch: 13/13 (valid)
# valid Loss: 0.3513 AUC: 0.9262
#
# Epoch 75/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2553 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3592 AUC: 0.9237
#
# Epoch 76/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2314 AUC: 0.9415
# Batch: 13/13 (valid)
# valid Loss: 0.3367 AUC: 0.9190
#
# Epoch 77/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2387 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.3396 AUC: 0.9231
#
# Epoch 78/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2341 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.3107 AUC: 0.9346
#
# Epoch 79/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2227 AUC: 0.9440
# Batch: 13/13 (valid)
# valid Loss: 0.2917 AUC: 0.9329
#
# Epoch 80/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2182 AUC: 0.9451
# Batch: 13/13 (valid)
# valid Loss: 0.2984 AUC: 0.9331
#
# Epoch 81/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2168 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.2979 AUC: 0.9343
#
# Epoch 82/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2232 AUC: 0.9443
# Batch: 13/13 (valid)
# valid Loss: 0.3054 AUC: 0.9350
#
# Epoch 83/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2215 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.3040 AUC: 0.9357
#
# Epoch 84/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2167 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.3040 AUC: 0.9357
#
# Epoch 85/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2197 AUC: 0.9432
# Batch: 13/13 (valid)
# valid Loss: 0.3019 AUC: 0.9355
#
# Epoch 86/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2166 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.3012 AUC: 0.9360
#
# Epoch 87/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2144 AUC: 0.9440
# Batch: 13/13 (valid)
# valid Loss: 0.2968 AUC: 0.9351
#
# Epoch 88/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2152 AUC: 0.9443
# Batch: 13/13 (valid)
# valid Loss: 0.3160 AUC: 0.9343
#
# Epoch 89/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2185 AUC: 0.9442
# Batch: 13/13 (valid)
# valid Loss: 0.3188 AUC: 0.9319
#
# Epoch 90/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2295 AUC: 0.9429
# Batch: 13/13 (valid)
# valid Loss: 0.3611 AUC: 0.9144
#
# Epoch 91/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2259 AUC: 0.9442
# Batch: 13/13 (valid)
# valid Loss: 0.3416 AUC: 0.9233
#
# Epoch 92/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2306 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3492 AUC: 0.9289
#
# Epoch 93/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2389 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.3758 AUC: 0.9173
#
# Epoch 94/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2377 AUC: 0.9447
# Batch: 13/13 (valid)
# valid Loss: 0.3425 AUC: 0.9208
#
# Epoch 95/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2433 AUC: 0.9420
# Batch: 13/13 (valid)
# valid Loss: 0.3417 AUC: 0.9197
#
# Epoch 96/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2508 AUC: 0.9429
# Batch: 13/13 (valid)
# valid Loss: 0.3223 AUC: 0.9239
#
# Epoch 97/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2380 AUC: 0.9452
# Batch: 13/13 (valid)
# valid Loss: 0.3153 AUC: 0.9273
#
# Epoch 98/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2367 AUC: 0.9417
# Batch: 13/13 (valid)
# valid Loss: 0.3252 AUC: 0.9320
#
# Epoch 99/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2313 AUC: 0.9432
# Batch: 13/13 (valid)
# valid Loss: 0.3098 AUC: 0.9350
#
# Training complete in 239m 30s
# Best val AUC: 0.9390
#
# - Validation -
# === Normal Valid ===
# Batch: 13/13
#
# Norml Valid AUC: 0.9404
#
# === Valid Time Augmentation ===
# n: 0/4
# ----------
# Batch: 13/13
# n: 1/4
# ----------
# Batch: 13/13
# n: 2/4
# ----------
# Batch: 13/13
# n: 3/4
# ----------
# Batch: 13/13
# n: 4/4
# ----------
# Batch: 13/13
#
# VTA AUC: 0.9382
#
# === Mixed Valid ===
#
# Mixed AUC: 0.9404
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
print(torch.cuda.memory_allocated())
# Out:
# 17040384

# %% [raw]
# fold = 1
#
# model = torch.load(f'model_{fold}.pth')
# model.to(device)
# val, vta, mix = valMix(model, dataloaders, n=5)

# %% [raw]
# # 例
# def showRes(n, df, preds, preds2=None, start=0):
#     n_cols = 5
#     n_rows = (n-1)//5+1
#
#     fig = plt.figure(figsize=(n_cols*2, n_rows*2))
#
#     for i in range(n):
#         loc = i + start
#         num = df['num'].iloc[loc]
#         lab = df['label'].iloc[loc]
#         im = image = load_img(num)
#
#         ax = fig.add_subplot(n_rows, n_cols, i+1)
#         im = np.asarray(im)
#         ax.imshow(im)
#         ax.axes.xaxis.set_visible(False)
#         ax.axes.yaxis.set_visible(False)
#         if preds2 is None:
#             ax.set_title(f'Label: {lab}\nPred: {preds[loc]:.2f}')
#         else:
#             ax.set_title(f'Label: {lab}\nPred: {preds[loc]:.2f}\nPred2: {preds2[loc]:.2f}')
#
#     fig.suptitle('Prediction')
#     fig.tight_layout()
#     fig.show()

# %% [raw]
# showRes(20, df_train[df_train['fold']==fold], val, vta, mix, start=20)

# %% [markdown]
# ## 推論・提出

# %%
df_submit = df_test[['image_name', 'label']].copy()

# %%
def predictCV(fold):
    model = torch.load(f'model_{fold}.pth')
    model.to(device)
    
    _, dataloaders = foldData(fold)
    test, tta, tmix = valMix(model, dataloaders, n=5, mode='test')
    
    df_submit[f'label_test_{fold}'] = test
    df_submit[f'label_tta_{fold}'] = tta
    df_submit[f'label_tmix_{fold}'] = tmix
    
    del model
    torch.cuda.empty_cache()

# %%
for fold in range(n_folds):
    predictCV(fold)
# Out:
# === Normal Test ===
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Batch: 68/68
#
# Norml Valid AUC: 0.5000
#
# === Test Time Augmentation ===
# n: 0/4
# ----------
# Batch: 68/68
# n: 1/4
# ----------
# Batch: 68/68
# n: 2/4
# ----------
# Batch: 68/68
# n: 3/4
# ----------
# Batch: 68/68
# n: 4/4
# ----------
# Batch: 68/68
#
# VTA AUC: 0.5000
#
# === Mixed Valid ===
#
# Mixed AUC: 0.5000
# === Normal Test ===
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Batch: 68/68
#
# Norml Valid AUC: 0.5000
#
# === Test Time Augmentation ===
# n: 0/4
# ----------
# Batch: 68/68
# n: 1/4
# ----------
# Batch: 68/68
# n: 2/4
# ----------
# Batch: 68/68
# n: 4/4
# ----------
# Batch: 68/68
#
# VTA AUC: 0.5000
#
# === Mixed Valid ===
#
# Mixed AUC: 0.5000
# === Normal Test ===
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Batch: 68/68
#
# Norml Valid AUC: 0.5000
#
# === Test Time Augmentation ===
# n: 0/4
# ----------
# Batch: 68/68
# n: 1/4
# ----------
# Batch: 68/68
# n: 2/4
# ----------
# Batch: 68/68
# n: 3/4
# ----------
# Batch: 68/68
# n: 4/4
# ----------
# Batch: 68/68
#
# VTA AUC: 0.5000
#
# === Mixed Valid ===
#
# Mixed AUC: 0.5000
# === Normal Test ===
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Batch: 68/68
#
# Norml Valid AUC: 0.5000
#
# === Test Time Augmentation ===
# n: 0/4
# ----------
# Batch: 68/68
# n: 1/4
# ----------
# Batch: 68/68
# n: 3/4
# ----------
# Batch: 68/68
# n: 4/4
# ----------
# Batch: 68/68
#
# VTA AUC: 0.5000
#
# === Mixed Valid ===
#
# Mixed AUC: 0.5000
# === Normal Test ===
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Batch: 68/68
#
# Norml Valid AUC: 0.5000
#
# === Test Time Augmentation ===
# n: 0/4
# ----------
# Batch: 68/68
# n: 1/4
# ----------
# Batch: 68/68
# n: 3/4
# ----------
# Batch: 68/68
# n: 4/4
# ----------
# Batch: 53/68

# %%
# 平均対象を抽出して提出
targ = 'tmix'

mean = df_submit[[f'label_{targ}_{fold}' for fold in range(n_folds)]].mean(axis=1)
df_submit['label'] = mean

df_submit[['image_name', 'label']].to_csv('submit.csv', header=None, index=None)

# %%
df_submit.to_csv('model_v4-cv.csv', index=False)

# %% [markdown]
# 提出

# %%
# %%bash
# signate submit --competition-id=1106 submit.csv --note model4_CV_tmix

# %% [markdown]
# model_v2, v3とアンサンブル

# %%
df_1 = pd.read_csv('model_v2-cv.csv')
df_2 = pd.read_csv('model_v3-cv.csv')
df_3 = pd.read_csv('model_v4-cv.csv')

# %%
targ = 'tmix'

mean1 = df_1[[f'label_{targ}_{fold}' for fold in range(5)]].mean(axis=1)
mean2 = df_2[[f'label_{targ}_{fold}' for fold in range(5)]].mean(axis=1)
mean3 = df_3[[f'label_{targ}_{fold}' for fold in range(5)]].mean(axis=1)
mean = (mean1 + mean2 + mean3) / 3

# %%
df_submit = df_1[['image_name', 'label']].copy()
df_submit['label'] = mean
df_submit.to_csv('submit.csv', header=None, index=None)

# %%
# %%bash
# signate submit --competition-id=1106 submit.csv --note model2CVtmix_model3CVtmix_model4CVtmix
# Out:
# You have successfully submitted your predictions.We will send you the submission result to your email address.
