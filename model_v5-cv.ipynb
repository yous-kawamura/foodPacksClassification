# %% [markdown]
# # CoAt Net Large

# %% [markdown]
# - loss: Binary Cross Entropy
# - metrics: ROCAUC
# - trainable:
# - CVあり
# ---
# - label smoothing
# - AugMix
# × CutMix
# × MixUp

# %% [markdown]
# ## Load Model

# %%
from transformers import AutoImageProcessor, ConvNextV2ForImageClassification, get_cosine_schedule_with_warmup
import torch, timm
from datasets import load_dataset

from utils.utils import load_img

print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.current_device())
print(torch.cuda.get_device_name())
print(torch.cuda.get_device_capability())
# Out:
# 2.2.0.dev20230911+cu118
# True
# 4
# 0
# Tesla T4
# (7, 5)

# %% [raw]
# dataset = load_dataset("huggingface/cats-image")
# image = dataset["test"]["image"][0]
#
# model = timm.create_model('coatnet_rmlp_2_rw_384.sw_in12k_ft_in1k', pretrained=True)
# data_config = timm.data.resolve_model_data_config(model)
# preprocessor = timm.data.create_transform(**data_config, is_training=False)

# %% [raw]
# inputs = preprocessor(image).unsqueeze(0)
# inputs.shape

# %% [raw]
# with torch.no_grad():
#     logits = model(inputs)
#
# # model predicts one of the 1000 ImageNet classes
# predicted_label = logits.argmax(-1).item()
# predicted_label

# %% [markdown]
# ## 学習データの可視化

# %%
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# 食品と飲料をランダムに5個ずつ可視化する
df_train = pd.read_csv('train.csv')
df_train['num'] = df_train['image_name'].str[:-4].astype(int)

d_vis = df_train[df_train['label']==0].sample(5)['num'].tolist()
f_vis = df_train[df_train['label']==1].sample(5)['num'].tolist()

# %%
# データの偏り
print(f"N of drinks: {len(df_train[df_train['label']==0])}")
print(f"N of foods: {len(df_train[df_train['label']==1])}")
# Out:
# N of drinks: 994
# N of foods: 1182

# %%
def show5img(ilist, stitle=None):
    n_cols = 5
    n_rows = (len(ilist)-1)//5+1
    
    fig = plt.figure(figsize=(n_cols*2, n_rows*2))
    for n, i in enumerate(ilist):
        ax = fig.add_subplot(n_rows, n_cols, n+1)
        im = load_img(i)
        im = np.asarray(im)
        ax.imshow(im)
        ax.axes.xaxis.set_visible(False)
        ax.axes.yaxis.set_visible(False)
        ax.set_title(i)
    if stitle:
        fig.suptitle(stitle)
    fig.tight_layout()
    fig.show()

# %%
show5img(d_vis, stitle='drink')
show5img(f_vis, stitle='food')

# %% [markdown]
# ## 転移学習/CV検証

# %%
import torch.nn as nn
from torchvision import transforms

from sklearn.model_selection import StratifiedKFold

# %%
device = torch.device('cuda')

# %% [markdown]
# データセット作成

# %%
# folding
n_folds = 5

skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=4)
df_train['fold'] = -1
for i, (_, val_idx) in enumerate(skf.split(df_train, df_train['label'])):
    df_train.loc[val_idx, 'fold'] = i

# %%
# label smoothing
df_train['label'] = df_train['label'].replace({0: 0.05, 1: 0.95})

# %%
df_train
# Out:
#      image_name  label   num  fold
# 0      0000.png   0.05     0     2
# 1      0001.png   0.95     1     3
# 2      0002.png   0.95     2     0
# 3      0003.png   0.95     3     4
# 4      0004.png   0.05     4     4
# ...         ...    ...   ...   ...
# 2171   2171.png   0.95  2171     4
# 2172   2172.png   0.95  2172     0
# 2173   2173.png   0.95  2173     0
# 2174   2174.png   0.05  2174     0
# 2175   2175.png   0.05  2175     0
#
# [2176 rows x 4 columns]

# %%
# テストデータ
df_test = pd.read_csv('sample_submit.csv', header=None)
df_test.columns = ['image_name', 'label']
df_test['num'] = df_test['image_name'].str[:-4].astype(int)
df_test['label'] = -1

# %%
df_test
# Out:
#      image_name  label   num
# 0      2176.png     -1  2176
# 1      2177.png     -1  2177
# 2      2178.png     -1  2178
# 3      2179.png     -1  2179
# 4      2180.png     -1  2180
# ...         ...    ...   ...
# 2175   4351.png     -1  4351
# 2176   4352.png     -1  4352
# 2177   4353.png     -1  4353
# 2178   4354.png     -1  4354
# 2179   4355.png     -1  4355
#
# [2180 rows x 3 columns]

# %%
train_transforms_1 = transforms.Compose([
    transforms.RandomChoice([
        transforms.RandomCrop(256),
        transforms.RandomCrop(384),
        transforms.RandomCrop(512),
    ]),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.RandomApply(
        [transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5)],
        p=0.67,
    ),
    transforms.RandomApply(
        [transforms.GaussianBlur(3, sigma=(0.1, 2.0))],
        p=0.67,
    ),
    transforms.Resize((384, 384)),
    transforms.RandomApply(
        [transforms.RandomRotation(180)],
        p=0.5,
    ),
    transforms.ToTensor(),
    transforms.RandomErasing(p=0.33, scale=(0.02, 0.3)),
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5]),
])

train_transforms_2 = transforms.Compose([
    transforms.AugMix(),
    transforms.Resize((384, 384)),
    transforms.ToTensor(),
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5]),
])


tta_transforms_1 = transforms.Compose([
    transforms.RandomChoice([
        transforms.RandomCrop(448),
        transforms.RandomCrop(512),
    ]),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.RandomApply(
        [transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5)],
        p=0.67,
    ),
    transforms.RandomApply(
        [transforms.GaussianBlur(3, sigma=(0.1, 2.0))],
        p=0.67,
    ),
    transforms.Resize((384, 384)),
    # transforms.RandomApply(
    #     [transforms.RandomRotation(180)],
    #     p=0.5,
    # ),
    transforms.ToTensor(),
    # transforms.RandomErasing(p=0.33, scale=(0.02, 0.1)),
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5]),
])

tta_transforms_2 = transforms.Compose([
    transforms.AugMix(),
    transforms.Resize((384, 384)),
    transforms.ToTensor(),
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5]),
])


data_transforms = {
    'train': transforms.RandomChoice([
        train_transforms_1, train_transforms_2
    ], p=[0.4, 0.6]),
    'valid': transforms.Compose([
        transforms.Resize((384, 384)),
        transforms.ToTensor(),
        transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5]),
    ]),
    'tta': transforms.RandomChoice([
        tta_transforms_1, tta_transforms_2
    ], p=[0.5, 0.5])
}

# %%
# 例
def showTimg(n, phase='train'):
    image = load_img(0)
    image_t = data_transforms[phase](image)
    
    img1 = np.asarray(image)
    img2 = image_t.numpy().transpose((2,1,0))
    
    fig = plt.figure(figsize=(2*2, 1*2))
    ax1 = fig.add_subplot(1, 2, 1)
    ax1.imshow(img1)
    ax1.axes.xaxis.set_visible(False)
    ax1.axes.yaxis.set_visible(False)
    ax1.set_title(f'Raw_{n}')
    
    ax2 = fig.add_subplot(1, 2, 2)
    ax2.imshow(img2)
    ax2.axes.xaxis.set_visible(False)
    ax2.axes.yaxis.set_visible(False)
    ax2.set_title(f'Transformed_{n}')

# %%
showTimg(0, phase='train')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
showTimg(0, phase='valid')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
showTimg(0, phase='tta')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, df, transform, tt='train'):
        if tt == 'train':
            self.dir = 'train/'
        elif tt == 'test':
            self.dir = 'test/'
        
        self.df = df
        self.transform = transform
        self.labels = np.expand_dims(df['label'].values, 1)
        self.labels = self.labels.astype(float)

    # len()を使用すると呼ばれる
    def __len__(self):
        return len(self.labels)

    # 要素を参照すると呼ばれる関数    
    def __getitem__(self, idx):
        num = self.df['num'].values[idx]
        image = load_img(num)
        image = self.transform(image)
        return image, self.labels[idx]

# %%
def foldData(fold, bs=32):
    df_train_ = df_train[df_train['fold']!=fold]
    df_valid_ = df_train[df_train['fold']==fold]
    df_test_ = df_test
    
    image_datasets = {
        'train': MyDataset(df_train_, data_transforms['train'], tt='train'),
        'valid': MyDataset(df_valid_, data_transforms['valid'], tt='train'),
        'vta': MyDataset(df_valid_, data_transforms['tta'], tt='train'),
        'test': MyDataset(df_test_, data_transforms['valid'], tt='test'),
        'tta': MyDataset(df_test_, data_transforms['tta'], tt='test'),
    }
    
    dataloaders = {
        'train': torch.utils.data.DataLoader(image_datasets['train'],
                                             batch_size=bs, shuffle=True, num_workers=16, pin_memory=True),
        'valid': torch.utils.data.DataLoader(image_datasets['valid'],
                                             batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
        'vta': torch.utils.data.DataLoader(image_datasets['vta'],
                                           batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
        'test': torch.utils.data.DataLoader(image_datasets['test'],
                                            batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
        'tta': torch.utils.data.DataLoader(image_datasets['tta'],
                                           batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
    }
    
    return image_datasets, dataloaders

# %% [markdown]
# モデル構築

# %%
from torcheval.metrics import BinaryAUROC
import torch.optim as optim
from torcheval.metrics.functional import binary_auroc

# %% [raw]
# model.classifier = nn.Linear(2816, 1, bias=True)

# %% [raw]
# # multi gpu
# model = torch.nn.DataParallel(model, device_ids=[0, 1, 2, 3]) # make parallel

# %% [raw]
# model.to(device)

# %% [raw]
# ### 重み固定 ###
# for p in model.parameters():
#     p.requires_grad = False

# %%
def loadNewModel():
    m = timm.create_model('coatnet_rmlp_2_rw_384.sw_in12k_ft_in1k', pretrained=True)
    m.head.fc = nn.Linear(1024, 1, bias=True)
    m = torch.nn.DataParallel(m, device_ids=[0, 1, 2, 3]) # make parallel
    m.to(device)
    for p in m.parameters():
        p.requires_grad = False
    return m

# %% [markdown]
# 学習

# %%
import copy, time
import torchvision
torchvision.disable_beta_transforms_warning()
from torchvision.transforms import v2

# %%
scaler = torch.cuda.amp.GradScaler()

# %% [raw]
# cutmix = v2.CutMix(num_classes=1)
# mixup = v2.MixUp(num_classes=1)
# cutmix_or_mixup = v2.RandomChoice([cutmix, mixup])

# %% [raw]
# -> one-hotじゃないと適用できないので今回は適用しない

# %%
def train(model, criterion, optimizer, scheduler, image_datasets, dataloaders, epochs=5):
    since = time.time()
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_auc = 0.0
    
    for epoch in range(epochs):
        print(f'Epoch {epoch}/{epochs-1}')
        print('-' * 10)
        
        for phase in ('train', 'valid'):
            if phase == 'train':
                is_train = True
                model.train()  # Set model to training mode
            else:
                is_train = False
                model.eval()   # Set model to evaluate mode
            
            running_loss = 0.0
            running_auc = 0.0
            
            # イタレーション
            for b, (inputs, labels) in enumerate(dataloaders[phase]):
                print(f'\rBatch: {b}/{len(image_datasets[phase])//dataloaders[phase].batch_size} ({phase})', end="")
                # images, labels = cutmix_or_mixup(images, labels)
                inputs = inputs.to(device)
                labels = labels.to(device)
                
                optimizer.zero_grad()
                
                with torch.set_grad_enabled(is_train):
                    with torch.cuda.amp.autocast(): 
                        outputs = model(inputs)
                        # loss = criterion(torch.flatten(outputs), torch.flatten(labels))
                        loss = criterion(outputs, labels)
                    auc = binary_auroc(torch.flatten(torch.sigmoid(outputs)),
                                       torch.flatten(labels))

                    # backward + optimize only if in training phase
                    if is_train:
                        scaler.scale(loss).backward()
                        scaler.step(optimizer)
                        scaler.update() 

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_auc +=  auc * inputs.size(0)
                
                del loss, auc, labels, inputs, outputs
            
            epoch_loss = running_loss / len(image_datasets[phase])
            epoch_auc = running_auc / len(image_datasets[phase])
            
            print()
            print(f'{phase} Loss: {epoch_loss:.4f} AUC: {epoch_auc:.4f}')
            
            # deep copy the model
            if phase == 'valid' and epoch_auc > best_auc:
                best_auc = epoch_auc
                best_model_wts = copy.deepcopy(model.state_dict())
            del epoch_loss, epoch_auc, running_loss, running_auc
            torch.cuda.empty_cache()
            
        scheduler.step()
        print()
        
    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val AUC: {best_auc:.4f}')
    print()

    # load best model weights
    model.load_state_dict(best_model_wts)
    del best_model_wts
    return model

# %% [markdown]
# - 通常の代入とTTAで比較

# %%
def valid(model, dataloader):
    noutputs = []
    nlabels = []
    for b, (inputs, labels) in enumerate(dataloader):
        print(f'\rBatch: {b}/{len(dataloader.dataset)//dataloader.batch_size}', end="")
        inputs = inputs.to(device)
        labels = labels.to(device)
        with torch.no_grad():
            noutputs.append(model(inputs))
            nlabels.append(labels)
        del inputs, labels
    alloutputs = torch.cat(noutputs)
    alllabels = torch.cat(nlabels)
    
    preds = torch.sigmoid(torch.flatten(alloutputs))
    auc = binary_auroc(preds, torch.flatten(alllabels))
    print()
    print()
    print(f'AUC: {auc:.4f}')
    
    return preds.cpu().detach().numpy()

# %%
def tta(model, dataloader, n=5):
    alloutputs = []
    
    for i in range(n):
        print(f'n: {i}/{n-1}')
        print('-' * 10)
        noutputs = []
        nlabels = []
        for b, (inputs, labels) in enumerate(dataloader):
            print(f'\rBatch: {b}/{len(dataloader.dataset)//dataloader.batch_size}', end="")
            inputs = inputs.to(device)
            labels = labels.to(device)
            with torch.no_grad():
                noutputs.append(model(inputs))
                nlabels.append(labels)
            del inputs, labels
        alloutputs.append(torch.cat(noutputs))
        alllabels = torch.cat(nlabels)
        print()
    alloutputs = torch.cat(alloutputs, 1)
    preds = torch.sigmoid(torch.mean(alloutputs, dim=1))
    auc = binary_auroc(preds, torch.flatten(alllabels))
    print()
    print(f'AUC: {auc:.4f}')
    
    return preds.cpu().detach().numpy()

# %%
def valMix(model, dataloaders, n=5, mode='valid'):
    # 通常valid
    print(f"=== Normal {'Valid' if mode=='valid' else 'Test'} ===")
    if mode =='valid':
        dataloader = dataloaders['valid']
    elif mode == 'test':
        dataloader = dataloaders['test']
    noutputs = []
    nlabels = []
    for b, (imgs, labels) in enumerate(dataloader):
        print(f'\rBatch: {b}/{len(dataloader.dataset)//dataloader.batch_size}', end="")
        inputs = imgs.to(device)
        labels = labels.to(device)
        with torch.no_grad():
            noutputs.append(model(inputs))
            nlabels.append(labels)
    alloutputs = torch.cat(noutputs)
    alllabels = torch.cat(nlabels)
    
    preds1 = torch.sigmoid(torch.flatten(alloutputs))
    auc = binary_auroc(preds1, torch.flatten(alllabels))
    print()
    print()
    print(f'Norml Valid AUC: {auc:.4f}')
    print()
    
    # TTA valid
    print(f"=== {'Valid' if mode=='valid' else 'Test'} Time Augmentation ===")
    if mode =='valid':
        dataloader = dataloaders['vta']
    elif mode == 'test':
        dataloader = dataloaders['tta']
    alloutputs = [alloutputs]
    
    for i in range(n):
        print(f'n: {i}/{n-1}')
        print('-' * 10)
        noutputs = []
        for b, (imgs, labels) in enumerate(dataloader):
            print(f'\rBatch: {b}/{len(dataloader.dataset)//dataloader.batch_size}', end="")
            inputs = imgs.to(device)
            with torch.no_grad():
                noutputs.append(model(inputs))
        alloutputs.append(torch.cat(noutputs))
        print()
    alloutputs = torch.cat(alloutputs, 1)
    preds2 = torch.sigmoid(torch.mean(alloutputs, dim=1))
    auc = binary_auroc(preds2, torch.flatten(alllabels))
    print()
    print(f'VTA AUC: {auc:.4f}')
    print()
    
    # Mix
    print('=== Mixed Valid ===')
    preds1to0 = preds1 - 0
    preds1to1 = 1 - preds1
    preds2to0 = preds2 - 0
    preds2to1 = 1 - preds2
    
    stack = torch.stack([preds1to0, preds1to1, preds2to0, preds2to1])
    pstack = torch.stack([preds1, preds1, preds2, preds2])
    
    argmin = torch.argmin(stack, dim=0)
    preds = torch.diag(pstack[argmin])
    auc = binary_auroc(preds, torch.flatten(alllabels))
    print()
    print(f'Mixed AUC: {auc:.4f}')
    return preds1.cpu().detach().numpy(), preds2.cpu().detach().numpy(), preds.cpu().detach().numpy()

# %% [markdown]
# ### CV

# %%
from numba import cuda

# %%
### 検証時のAugmentation
n_vta = 5

# %%
### パラメータ変更可能な部分 ###
"""
  model.module.stem

  model.module.stages[0]
  -> model.module.stages[0].blocks[0] ~ [1]

  model.module.stages[1]
  -> model.module.stages[1].blocks[0] ~ [5]

  model.module.stages[2]
  -> model.module.stages[2].blocks[0] ~ [13]

  model.module.stages[3]
  -> model.module.stages[3].blocks[0] ~ [1]

  model.module.norm

  model.module.head.fc
"""
# Out:
# '\n  model.module.stem\n\n  model.module.stages[0]\n  -> model.module.stages[0].blocks[0] ~ [1]\n\n  model.module.stages[1]\n  -> model.module.stages[1].blocks[0] ~ [5]\n\n  model.module.stages[2]\n  -> model.module.stages[2].blocks[0] ~ [13]\n\n  model.module.stages[3]\n  -> model.module.stages[3].blocks[0] ~ [1]\n\n  model.module.norm\n\n  model.module.head.fc\n'

# %%
specs = [
    {
        'bs': 32,
        'trainLayers': 1,
        'lr': 1e-3,
        'epochs': 15,
        'num_warmup_steps': 5,  # CosSchWarm
        'num_training_steps': 20,  # CosSchWarm
        'num_cycles': 0.5,  # CosSchWarm
    },
    {
        'bs': 32,
        'trainLayers': 2,
        'lr': 1e-3,
        'epochs': 15,
        'num_warmup_steps': 5,  # CosSchWarm
        'num_training_steps': 20,  # CosSchWarm
        'num_cycles': 0.5,  # CosSchWarm
    },
    {
        'bs': 32,
        'trainLayers': 3,
        'lr': 5e-4,
        'epochs': 30,
        'num_warmup_steps': 5,  # CosSchWarm
        'num_training_steps': 35,  # CosSchWarm
        'num_cycles': 1.5,  # CosSchWarm
    },
    {
        'bs': 24,
        'trainLayers': 4,
        'lr': 1e-4,
        'epochs': 100,
        'num_warmup_steps': 10,  # CosSchWarm
        'num_training_steps': 105,  # CosSchWarm
        'num_cycles': 4.5,  # CosSchWarm
    },
]

# %%
vals = {}
vtas = {}
mixs = {}

# %%
torch.backends.cudnn.benchmark = True

# %%
def train_spec(fold, i, model_path='model.pth'):
    spec = specs[i]
    
    # datasetsを作る
    image_datasets, dataloaders = foldData(fold, bs=spec['bs'])
    
    # 新しいモデルを読み込み
    if i == 0:
        model = loadNewModel()
    else:
        model = torch.load(model_path)
        model.to(device)
        for p in model.parameters():
            p.requires_grad = False
    
    layer_list = [
        model.module.head.fc,
        model.module.norm,
        model.module.stages[3],
        model.module.stages[2],
    ]
    
    for j in range(spec['trainLayers']):
        layer = layer_list[j]
        for p in layer.parameters():
            p.requires_grad = True
    
    criterion = nn.BCEWithLogitsLoss(pos_weight=None)
    if False:
    # if i < len(specs)-2:
        optimizer = optim.SGD(model.parameters(), lr=spec['lr'], momentum=0.9)
        lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=spec['sch_steps'], gamma=spec['sch_gamma'])
    else:
        optimizer = optim.AdamW(model.parameters(), lr=spec['lr'])
        lr_scheduler = get_cosine_schedule_with_warmup(optimizer,
                                                       num_warmup_steps=spec['num_warmup_steps'],
                                                       num_training_steps=spec['num_training_steps'],
                                                       num_cycles=spec['num_cycles'])
    
    model = train(model, criterion, optimizer, lr_scheduler, image_datasets, dataloaders,
                  epochs=spec['epochs'])
    
    torch.save(model, model_path)
    del model
    torch.cuda.empty_cache()

# %%
def fold_train(fold):
    print(f'=== Fold: {fold} ===')
    print('GPU Memory:', torch.cuda.memory_allocated())
    
    for i in range(len(specs)):
        print(f'<< Spec: {i} >>')
        train_spec(fold, i)
    
    print('- Validation -')
    model = torch.load('model.pth')
    model.to(device)
    
    image_datasets, dataloaders = foldData(fold)
    
    val, vta, mix = valMix(model, dataloaders, n=n_vta)
    vals[fold] = val
    vtas[fold] = vta
    mixs[fold] = mix
    
    print()
    
    torch.save(model, f'model_{fold}.pth')
    
    del model
    torch.cuda.empty_cache()

# %% [raw]
# for fold in range(n_folds):
#     fold_train(fold)

# %%
# %%capture cap

for fold in range(n_folds):
    fold_train(fold)

with open('log_train.txt', 'w') as f:
    f.write(cap.stdout)

# %%
cap()
# Out:
# === Fold: 0 ===
# GPU Memory: 0
# << Spec: 0 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.8087 AUC: 0.4765
# Batch: 13/13 (valid)
# valid Loss: 0.8466 AUC: 0.4583
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.6943 AUC: 0.6131
# Batch: 13/13 (valid)
# valid Loss: 0.6424 AUC: 0.7030
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.6047 AUC: 0.7290
# Batch: 13/13 (valid)
# valid Loss: 0.5789 AUC: 0.7628
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5749 AUC: 0.7677
# Batch: 13/13 (valid)
# valid Loss: 0.5629 AUC: 0.7852
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5591 AUC: 0.7761
# Batch: 13/13 (valid)
# valid Loss: 0.5450 AUC: 0.8031
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5485 AUC: 0.7951
# Batch: 13/13 (valid)
# valid Loss: 0.5184 AUC: 0.8118
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5461 AUC: 0.7944
# Batch: 13/13 (valid)
# valid Loss: 0.5107 AUC: 0.8199
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5458 AUC: 0.7992
# Batch: 13/13 (valid)
# valid Loss: 0.5044 AUC: 0.8239
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5230 AUC: 0.8193
# Batch: 13/13 (valid)
# valid Loss: 0.5100 AUC: 0.8313
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5309 AUC: 0.8130
# Batch: 13/13 (valid)
# valid Loss: 0.4957 AUC: 0.8315
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5088 AUC: 0.8271
# Batch: 13/13 (valid)
# valid Loss: 0.4959 AUC: 0.8369
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4988 AUC: 0.8338
# Batch: 13/13 (valid)
# valid Loss: 0.4934 AUC: 0.8323
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5061 AUC: 0.8253
# Batch: 13/13 (valid)
# valid Loss: 0.5194 AUC: 0.8246
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5107 AUC: 0.8237
# Batch: 13/13 (valid)
# valid Loss: 0.4926 AUC: 0.8361
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5102 AUC: 0.8286
# Batch: 13/13 (valid)
# valid Loss: 0.4882 AUC: 0.8409
#
# Training complete in 25m 28s
# Best val AUC: 0.8409
#
# << Spec: 1 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5022 AUC: 0.8348
# Batch: 13/13 (valid)
# valid Loss: 0.4918 AUC: 0.8402
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5033 AUC: 0.8259
# Batch: 13/13 (valid)
# valid Loss: 0.4862 AUC: 0.8406
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5104 AUC: 0.8242
# Batch: 13/13 (valid)
# valid Loss: 0.4930 AUC: 0.8405
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5134 AUC: 0.8238
# Batch: 13/13 (valid)
# valid Loss: 0.5023 AUC: 0.8425
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5046 AUC: 0.8364
# Batch: 13/13 (valid)
# valid Loss: 0.4925 AUC: 0.8365
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5212 AUC: 0.8229
# Batch: 13/13 (valid)
# valid Loss: 0.4894 AUC: 0.8464
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4942 AUC: 0.8373
# Batch: 13/13 (valid)
# valid Loss: 0.4901 AUC: 0.8378
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5097 AUC: 0.8308
# Batch: 13/13 (valid)
# valid Loss: 0.4856 AUC: 0.8343
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5109 AUC: 0.8254
# Batch: 13/13 (valid)
# valid Loss: 0.4886 AUC: 0.8444
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5072 AUC: 0.8299
# Batch: 13/13 (valid)
# valid Loss: 0.4915 AUC: 0.8411
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5011 AUC: 0.8317
# Batch: 13/13 (valid)
# valid Loss: 0.4875 AUC: 0.8385
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5085 AUC: 0.8307
# Batch: 13/13 (valid)
# valid Loss: 0.5033 AUC: 0.8392
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5035 AUC: 0.8325
# Batch: 13/13 (valid)
# valid Loss: 0.4759 AUC: 0.8554
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4755 AUC: 0.8534
# Batch: 13/13 (valid)
# valid Loss: 0.4817 AUC: 0.8511
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4890 AUC: 0.8414
# Batch: 13/13 (valid)
# valid Loss: 0.4759 AUC: 0.8545
#
# Training complete in 25m 20s
# Best val AUC: 0.8554
#
# << Spec: 2 >>
# Epoch 0/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4942 AUC: 0.8393
# Batch: 13/13 (valid)
# valid Loss: 0.4796 AUC: 0.8503
#
# Epoch 1/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5999 AUC: 0.8011
# Batch: 13/13 (valid)
# valid Loss: 0.4931 AUC: 0.8371
#
# Epoch 2/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5253 AUC: 0.8166
# Batch: 13/13 (valid)
# valid Loss: 0.4716 AUC: 0.8476
#
# Epoch 3/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4951 AUC: 0.8416
# Batch: 13/13 (valid)
# valid Loss: 0.4749 AUC: 0.8631
#
# Epoch 4/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5256 AUC: 0.8383
# Batch: 13/13 (valid)
# valid Loss: 0.4601 AUC: 0.8661
#
# Epoch 5/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5034 AUC: 0.8471
# Batch: 13/13 (valid)
# valid Loss: 0.4718 AUC: 0.8493
#
# Epoch 6/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4826 AUC: 0.8584
# Batch: 13/13 (valid)
# valid Loss: 0.4687 AUC: 0.8621
#
# Epoch 7/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4609 AUC: 0.8736
# Batch: 13/13 (valid)
# valid Loss: 0.4278 AUC: 0.8845
#
# Epoch 8/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4347 AUC: 0.8832
# Batch: 13/13 (valid)
# valid Loss: 0.4214 AUC: 0.8869
#
# Epoch 9/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4101 AUC: 0.8898
# Batch: 13/13 (valid)
# valid Loss: 0.4201 AUC: 0.8853
#
# Epoch 10/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3914 AUC: 0.9046
# Batch: 13/13 (valid)
# valid Loss: 0.3830 AUC: 0.9084
#
# Epoch 11/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3813 AUC: 0.9146
# Batch: 13/13 (valid)
# valid Loss: 0.3804 AUC: 0.9090
#
# Epoch 12/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3593 AUC: 0.9145
# Batch: 13/13 (valid)
# valid Loss: 0.3532 AUC: 0.9169
#
# Epoch 13/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3363 AUC: 0.9208
# Batch: 13/13 (valid)
# valid Loss: 0.3524 AUC: 0.9143
#
# Epoch 14/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3258 AUC: 0.9258
# Batch: 13/13 (valid)
# valid Loss: 0.3524 AUC: 0.9159
#
# Epoch 15/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3190 AUC: 0.9298
# Batch: 13/13 (valid)
# valid Loss: 0.3576 AUC: 0.9135
#
# Epoch 16/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3313 AUC: 0.9265
# Batch: 13/13 (valid)
# valid Loss: 0.3459 AUC: 0.9182
#
# Epoch 17/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3406 AUC: 0.9231
# Batch: 13/13 (valid)
# valid Loss: 0.3463 AUC: 0.9191
#
# Epoch 18/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3239 AUC: 0.9294
# Batch: 13/13 (valid)
# valid Loss: 0.3495 AUC: 0.9161
#
# Epoch 19/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3424 AUC: 0.9239
# Batch: 13/13 (valid)
# valid Loss: 0.3595 AUC: 0.9108
#
# Epoch 20/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3482 AUC: 0.9230
# Batch: 13/13 (valid)
# valid Loss: 0.3968 AUC: 0.9054
#
# Epoch 21/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3643 AUC: 0.9146
# Batch: 13/13 (valid)
# valid Loss: 0.3877 AUC: 0.9067
#
# Epoch 22/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3926 AUC: 0.9045
# Batch: 13/13 (valid)
# valid Loss: 0.4330 AUC: 0.8911
#
# Epoch 23/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3976 AUC: 0.9036
# Batch: 13/13 (valid)
# valid Loss: 0.3814 AUC: 0.9075
#
# Epoch 24/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3993 AUC: 0.8999
# Batch: 13/13 (valid)
# valid Loss: 0.4244 AUC: 0.8934
#
# Epoch 25/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4010 AUC: 0.9071
# Batch: 13/13 (valid)
# valid Loss: 0.3991 AUC: 0.8990
#
# Epoch 26/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3837 AUC: 0.9123
# Batch: 13/13 (valid)
# valid Loss: 0.4012 AUC: 0.9050
#
# Epoch 27/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3717 AUC: 0.9107
# Batch: 13/13 (valid)
# valid Loss: 0.3721 AUC: 0.9120
#
# Epoch 28/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3505 AUC: 0.9207
# Batch: 13/13 (valid)
# valid Loss: 0.4030 AUC: 0.9023
#
# Epoch 29/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3708 AUC: 0.9124
# Batch: 13/13 (valid)
# valid Loss: 0.4110 AUC: 0.9048
#
# Training complete in 51m 2s
# Best val AUC: 0.9191
#
# << Spec: 3 >>
# Epoch 0/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3432 AUC: 0.9204
# Batch: 13/13 (valid)
# valid Loss: 0.3431 AUC: 0.9217
#
# Epoch 1/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3527 AUC: 0.9222
# Batch: 13/13 (valid)
# valid Loss: 0.3866 AUC: 0.9100
#
# Epoch 2/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3739 AUC: 0.9126
# Batch: 13/13 (valid)
# valid Loss: 0.3398 AUC: 0.9211
#
# Epoch 3/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3660 AUC: 0.9141
# Batch: 13/13 (valid)
# valid Loss: 0.4065 AUC: 0.9154
#
# Epoch 4/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3819 AUC: 0.9093
# Batch: 13/13 (valid)
# valid Loss: 0.3733 AUC: 0.9080
#
# Epoch 5/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3701 AUC: 0.9128
# Batch: 13/13 (valid)
# valid Loss: 0.3655 AUC: 0.9148
#
# Epoch 6/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3766 AUC: 0.9098
# Batch: 13/13 (valid)
# valid Loss: 0.3769 AUC: 0.9221
#
# Epoch 7/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.4027 AUC: 0.9060
# Batch: 13/13 (valid)
# valid Loss: 0.4355 AUC: 0.8848
#
# Epoch 8/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.4250 AUC: 0.8966
# Batch: 13/13 (valid)
# valid Loss: 0.4324 AUC: 0.8914
#
# Epoch 9/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.4224 AUC: 0.8922
# Batch: 13/13 (valid)
# valid Loss: 0.4319 AUC: 0.8856
#
# Epoch 10/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.4149 AUC: 0.8996
# Batch: 13/13 (valid)
# valid Loss: 0.4234 AUC: 0.9026
#
# Epoch 11/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3877 AUC: 0.9073
# Batch: 13/13 (valid)
# valid Loss: 0.3688 AUC: 0.9092
#
# Epoch 12/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3674 AUC: 0.9192
# Batch: 13/13 (valid)
# valid Loss: 0.3885 AUC: 0.9015
#
# Epoch 13/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3474 AUC: 0.9200
# Batch: 13/13 (valid)
# valid Loss: 0.3431 AUC: 0.9242
#
# Epoch 14/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3169 AUC: 0.9331
# Batch: 13/13 (valid)
# valid Loss: 0.3220 AUC: 0.9274
#
# Epoch 15/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3087 AUC: 0.9332
# Batch: 13/13 (valid)
# valid Loss: 0.3217 AUC: 0.9319
#
# Epoch 16/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2873 AUC: 0.9361
# Batch: 13/13 (valid)
# valid Loss: 0.2862 AUC: 0.9363
#
# Epoch 17/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2753 AUC: 0.9382
# Batch: 13/13 (valid)
# valid Loss: 0.3087 AUC: 0.9305
#
# Epoch 18/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2639 AUC: 0.9406
# Batch: 13/13 (valid)
# valid Loss: 0.2804 AUC: 0.9380
#
# Epoch 19/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2551 AUC: 0.9395
# Batch: 13/13 (valid)
# valid Loss: 0.2813 AUC: 0.9363
#
# Epoch 20/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2580 AUC: 0.9409
# Batch: 13/13 (valid)
# valid Loss: 0.2769 AUC: 0.9368
#
# Epoch 21/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2603 AUC: 0.9404
# Batch: 13/13 (valid)
# valid Loss: 0.2797 AUC: 0.9366
#
# Epoch 22/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2588 AUC: 0.9419
# Batch: 13/13 (valid)
# valid Loss: 0.2756 AUC: 0.9385
#
# Epoch 23/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2488 AUC: 0.9426
# Batch: 13/13 (valid)
# valid Loss: 0.2953 AUC: 0.9372
#
# Epoch 24/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2642 AUC: 0.9406
# Batch: 13/13 (valid)
# valid Loss: 0.2797 AUC: 0.9386
#
# Epoch 25/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2785 AUC: 0.9377
# Batch: 13/13 (valid)
# valid Loss: 0.2843 AUC: 0.9359
#
# Epoch 26/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2935 AUC: 0.9331
# Batch: 13/13 (valid)
# valid Loss: 0.3292 AUC: 0.9210
#
# Epoch 27/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3216 AUC: 0.9270
# Batch: 13/13 (valid)
# valid Loss: 0.4055 AUC: 0.9164
#
# Epoch 28/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3344 AUC: 0.9232
# Batch: 13/13 (valid)
# valid Loss: 0.4329 AUC: 0.9025
#
# Epoch 29/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3417 AUC: 0.9233
# Batch: 13/13 (valid)
# valid Loss: 0.4218 AUC: 0.8899
#
# Epoch 30/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3674 AUC: 0.9168
# Batch: 13/13 (valid)
# valid Loss: 0.3889 AUC: 0.9122
#
# Epoch 31/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3510 AUC: 0.9206
# Batch: 13/13 (valid)
# valid Loss: 0.4070 AUC: 0.9134
#
# Epoch 32/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3263 AUC: 0.9292
# Batch: 13/13 (valid)
# valid Loss: 0.3822 AUC: 0.9200
#
# Epoch 33/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3399 AUC: 0.9237
# Batch: 13/13 (valid)
# valid Loss: 0.3901 AUC: 0.9179
#
# Epoch 34/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3321 AUC: 0.9293
# Batch: 13/13 (valid)
# valid Loss: 0.3771 AUC: 0.9201
#
# Epoch 35/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2909 AUC: 0.9312
# Batch: 13/13 (valid)
# valid Loss: 0.3222 AUC: 0.9311
#
# Epoch 36/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2917 AUC: 0.9377
# Batch: 13/13 (valid)
# valid Loss: 0.3351 AUC: 0.9237
#
# Epoch 37/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2655 AUC: 0.9416
# Batch: 13/13 (valid)
# valid Loss: 0.3168 AUC: 0.9286
#
# Epoch 38/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2656 AUC: 0.9395
# Batch: 13/13 (valid)
# valid Loss: 0.2999 AUC: 0.9365
#
# Epoch 39/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2526 AUC: 0.9409
# Batch: 13/13 (valid)
# valid Loss: 0.2741 AUC: 0.9398
#
# Epoch 40/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2378 AUC: 0.9431
# Batch: 13/13 (valid)
# valid Loss: 0.2837 AUC: 0.9386
#
# Epoch 41/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2421 AUC: 0.9426
# Batch: 13/13 (valid)
# valid Loss: 0.2823 AUC: 0.9390
#
# Epoch 42/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2436 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.2798 AUC: 0.9390
#
# Epoch 43/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2470 AUC: 0.9420
# Batch: 13/13 (valid)
# valid Loss: 0.2743 AUC: 0.9393
#
# Epoch 44/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2511 AUC: 0.9408
# Batch: 13/13 (valid)
# valid Loss: 0.2722 AUC: 0.9401
#
# Epoch 45/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2494 AUC: 0.9429
# Batch: 13/13 (valid)
# valid Loss: 0.2845 AUC: 0.9380
#
# Epoch 46/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2471 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.2866 AUC: 0.9352
#
# Epoch 47/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2696 AUC: 0.9384
# Batch: 13/13 (valid)
# valid Loss: 0.2939 AUC: 0.9341
#
# Epoch 48/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2828 AUC: 0.9378
# Batch: 13/13 (valid)
# valid Loss: 0.3731 AUC: 0.9107
#
# Epoch 49/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3029 AUC: 0.9353
# Batch: 13/13 (valid)
# valid Loss: 0.4270 AUC: 0.9102
#
# Epoch 50/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3263 AUC: 0.9299
# Batch: 13/13 (valid)
# valid Loss: 0.3606 AUC: 0.9173
#
# Epoch 51/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3494 AUC: 0.9218
# Batch: 13/13 (valid)
# valid Loss: 0.4017 AUC: 0.8981
#
# Epoch 52/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3522 AUC: 0.9183
# Batch: 13/13 (valid)
# valid Loss: 0.4225 AUC: 0.8807
#
# Epoch 53/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3893 AUC: 0.9065
# Batch: 13/13 (valid)
# valid Loss: 0.4062 AUC: 0.9042
#
# Epoch 54/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3685 AUC: 0.9160
# Batch: 13/13 (valid)
# valid Loss: 0.4171 AUC: 0.8889
#
# Epoch 55/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3089 AUC: 0.9302
# Batch: 13/13 (valid)
# valid Loss: 0.4096 AUC: 0.8959
#
# Epoch 56/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2871 AUC: 0.9357
# Batch: 13/13 (valid)
# valid Loss: 0.3363 AUC: 0.9187
#
# Epoch 57/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2784 AUC: 0.9381
# Batch: 13/13 (valid)
# valid Loss: 0.3542 AUC: 0.9164
#
# Epoch 58/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2696 AUC: 0.9398
# Batch: 13/13 (valid)
# valid Loss: 0.3392 AUC: 0.9193
#
# Epoch 59/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2610 AUC: 0.9413
# Batch: 13/13 (valid)
# valid Loss: 0.3129 AUC: 0.9252
#
# Epoch 60/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2565 AUC: 0.9410
# Batch: 13/13 (valid)
# valid Loss: 0.3145 AUC: 0.9247
#
# Epoch 61/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2478 AUC: 0.9431
# Batch: 13/13 (valid)
# valid Loss: 0.3159 AUC: 0.9239
#
# Epoch 62/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2451 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.3159 AUC: 0.9246
#
# Epoch 63/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2497 AUC: 0.9397
# Batch: 13/13 (valid)
# valid Loss: 0.3165 AUC: 0.9243
#
# Epoch 64/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2437 AUC: 0.9422
# Batch: 13/13 (valid)
# valid Loss: 0.3178 AUC: 0.9252
#
# Epoch 65/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2406 AUC: 0.9431
# Batch: 13/13 (valid)
# valid Loss: 0.3184 AUC: 0.9241
#
# Epoch 66/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2341 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3297 AUC: 0.9238
#
# Epoch 67/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2541 AUC: 0.9412
# Batch: 13/13 (valid)
# valid Loss: 0.3660 AUC: 0.9239
#
# Epoch 68/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2643 AUC: 0.9403
# Batch: 13/13 (valid)
# valid Loss: 0.3826 AUC: 0.8996
#
# Epoch 69/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2713 AUC: 0.9398
# Batch: 13/13 (valid)
# valid Loss: 0.3692 AUC: 0.9066
#
# Epoch 70/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2859 AUC: 0.9372
# Batch: 13/13 (valid)
# valid Loss: 0.3897 AUC: 0.9038
#
# Epoch 71/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3036 AUC: 0.9341
# Batch: 13/13 (valid)
# valid Loss: 0.3822 AUC: 0.9062
#
# Epoch 72/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3219 AUC: 0.9312
# Batch: 13/13 (valid)
# valid Loss: 0.3856 AUC: 0.9009
#
# Epoch 73/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3056 AUC: 0.9334
# Batch: 13/13 (valid)
# valid Loss: 0.3858 AUC: 0.9029
#
# Epoch 74/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3223 AUC: 0.9291
# Batch: 13/13 (valid)
# valid Loss: 0.3755 AUC: 0.9067
#
# Epoch 75/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3044 AUC: 0.9310
# Batch: 13/13 (valid)
# valid Loss: 0.4466 AUC: 0.8928
#
# Epoch 76/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3084 AUC: 0.9319
# Batch: 13/13 (valid)
# valid Loss: 0.3368 AUC: 0.9197
#
# Epoch 77/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2884 AUC: 0.9372
# Batch: 13/13 (valid)
# valid Loss: 0.3833 AUC: 0.9170
#
# Epoch 78/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2775 AUC: 0.9356
# Batch: 13/13 (valid)
# valid Loss: 0.3670 AUC: 0.9128
#
# Epoch 79/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2661 AUC: 0.9399
# Batch: 13/13 (valid)
# valid Loss: 0.3439 AUC: 0.9211
#
# Epoch 80/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2573 AUC: 0.9416
# Batch: 13/13 (valid)
# valid Loss: 0.3161 AUC: 0.9297
#
# Epoch 81/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2553 AUC: 0.9407
# Batch: 13/13 (valid)
# valid Loss: 0.3225 AUC: 0.9286
#
# Epoch 82/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2492 AUC: 0.9424
# Batch: 13/13 (valid)
# valid Loss: 0.3235 AUC: 0.9269
#
# Epoch 83/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2366 AUC: 0.9416
# Batch: 13/13 (valid)
# valid Loss: 0.3202 AUC: 0.9287
#
# Epoch 84/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2445 AUC: 0.9440
# Batch: 13/13 (valid)
# valid Loss: 0.3252 AUC: 0.9274
#
# Epoch 85/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2361 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.3233 AUC: 0.9285
#
# Epoch 86/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2476 AUC: 0.9429
# Batch: 13/13 (valid)
# valid Loss: 0.3285 AUC: 0.9308
#
# Epoch 87/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2342 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.3186 AUC: 0.9300
#
# Epoch 88/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2404 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3289 AUC: 0.9291
#
# Epoch 89/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2492 AUC: 0.9409
# Batch: 13/13 (valid)
# valid Loss: 0.5389 AUC: 0.8887
#
# Epoch 90/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2608 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.3574 AUC: 0.9193
#
# Epoch 91/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2897 AUC: 0.9353
# Batch: 13/13 (valid)
# valid Loss: 0.4194 AUC: 0.9156
#
# Epoch 92/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3021 AUC: 0.9344
# Batch: 13/13 (valid)
# valid Loss: 0.4004 AUC: 0.9046
#
# Epoch 93/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3147 AUC: 0.9307
# Batch: 13/13 (valid)
# valid Loss: 0.4064 AUC: 0.9057
#
# Epoch 94/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3150 AUC: 0.9299
# Batch: 13/13 (valid)
# valid Loss: 0.3785 AUC: 0.9104
#
# Epoch 95/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3080 AUC: 0.9335
# Batch: 13/13 (valid)
# valid Loss: 0.3733 AUC: 0.9044
#
# Epoch 96/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3100 AUC: 0.9334
# Batch: 13/13 (valid)
# valid Loss: 0.4550 AUC: 0.9103
#
# Epoch 97/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2871 AUC: 0.9370
# Batch: 13/13 (valid)
# valid Loss: 0.3672 AUC: 0.9066
#
# Epoch 98/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2900 AUC: 0.9352
# Batch: 13/13 (valid)
# valid Loss: 0.4397 AUC: 0.9075
#
# Epoch 99/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2808 AUC: 0.9408
# Batch: 13/13 (valid)
# valid Loss: 0.3306 AUC: 0.9243
#
# Training complete in 204m 52s
# Best val AUC: 0.9401
#
# - Validation -
# === Normal Valid ===
# Batch: 13/13
#
# Norml Valid AUC: 0.9427
#
# === Valid Time Augmentation ===
# n: 0/4
# ----------
# Batch: 13/13
# n: 1/4
# ----------
# Batch: 13/13
# n: 2/4
# ----------
# Batch: 13/13
# n: 3/4
# ----------
# Batch: 13/13
# n: 4/4
# ----------
# Batch: 13/13
#
# VTA AUC: 0.9417
#
# === Mixed Valid ===
#
# Mixed AUC: 0.9429
#
# === Fold: 1 ===
# GPU Memory: 17040384
# << Spec: 0 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.7295 AUC: 0.5357
# Batch: 13/13 (valid)
# valid Loss: 0.7112 AUC: 0.5562
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.6636 AUC: 0.6427
# Batch: 13/13 (valid)
# valid Loss: 0.5605 AUC: 0.7997
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.6080 AUC: 0.7339
# Batch: 13/13 (valid)
# valid Loss: 0.5162 AUC: 0.8303
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5922 AUC: 0.7493
# Batch: 13/13 (valid)
# valid Loss: 0.5030 AUC: 0.8458
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5684 AUC: 0.7682
# Batch: 13/13 (valid)
# valid Loss: 0.5084 AUC: 0.8483
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5629 AUC: 0.7786
# Batch: 13/13 (valid)
# valid Loss: 0.4762 AUC: 0.8560
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5330 AUC: 0.8049
# Batch: 13/13 (valid)
# valid Loss: 0.4740 AUC: 0.8556
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5403 AUC: 0.8093
# Batch: 13/13 (valid)
# valid Loss: 0.4969 AUC: 0.8441
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5281 AUC: 0.8074
# Batch: 13/13 (valid)
# valid Loss: 0.4879 AUC: 0.8528
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5328 AUC: 0.8057
# Batch: 13/13 (valid)
# valid Loss: 0.4867 AUC: 0.8491
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5221 AUC: 0.8133
# Batch: 13/13 (valid)
# valid Loss: 0.4752 AUC: 0.8571
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5138 AUC: 0.8258
# Batch: 13/13 (valid)
# valid Loss: 0.4729 AUC: 0.8557
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5083 AUC: 0.8258
# Batch: 13/13 (valid)
# valid Loss: 0.4765 AUC: 0.8578
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5035 AUC: 0.8326
# Batch: 13/13 (valid)
# valid Loss: 0.4774 AUC: 0.8563
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5024 AUC: 0.8320
# Batch: 13/13 (valid)
# valid Loss: 0.4689 AUC: 0.8579
#
# Training complete in 25m 28s
# Best val AUC: 0.8579
#
# << Spec: 1 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4918 AUC: 0.8436
# Batch: 13/13 (valid)
# valid Loss: 0.4731 AUC: 0.8555
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5070 AUC: 0.8333
# Batch: 13/13 (valid)
# valid Loss: 0.4683 AUC: 0.8593
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4955 AUC: 0.8361
# Batch: 13/13 (valid)
# valid Loss: 0.4697 AUC: 0.8593
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4966 AUC: 0.8380
# Batch: 13/13 (valid)
# valid Loss: 0.4717 AUC: 0.8604
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5095 AUC: 0.8235
# Batch: 13/13 (valid)
# valid Loss: 0.4776 AUC: 0.8531
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5067 AUC: 0.8268
# Batch: 13/13 (valid)
# valid Loss: 0.4816 AUC: 0.8497
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5009 AUC: 0.8358
# Batch: 13/13 (valid)
# valid Loss: 0.4821 AUC: 0.8502
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4985 AUC: 0.8389
# Batch: 13/13 (valid)
# valid Loss: 0.4814 AUC: 0.8602
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4932 AUC: 0.8397
# Batch: 13/13 (valid)
# valid Loss: 0.4836 AUC: 0.8558
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4974 AUC: 0.8359
# Batch: 13/13 (valid)
# valid Loss: 0.4856 AUC: 0.8531
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4966 AUC: 0.8383
# Batch: 13/13 (valid)
# valid Loss: 0.4827 AUC: 0.8497
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5016 AUC: 0.8357
# Batch: 13/13 (valid)
# valid Loss: 0.4822 AUC: 0.8555
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4853 AUC: 0.8489
# Batch: 13/13 (valid)
# valid Loss: 0.4768 AUC: 0.8545
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4889 AUC: 0.8444
# Batch: 13/13 (valid)
# valid Loss: 0.4674 AUC: 0.8604
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4841 AUC: 0.8428
# Batch: 13/13 (valid)
# valid Loss: 0.4823 AUC: 0.8558
#
# Training complete in 25m 26s
# Best val AUC: 0.8604
#
# << Spec: 2 >>
# Epoch 0/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4919 AUC: 0.8396
# Batch: 13/13 (valid)
# valid Loss: 0.4658 AUC: 0.8605
#
# Epoch 1/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5667 AUC: 0.7918
# Batch: 13/13 (valid)
# valid Loss: 0.4747 AUC: 0.8576
#
# Epoch 2/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5454 AUC: 0.8338
# Batch: 13/13 (valid)
# valid Loss: 0.4663 AUC: 0.8679
#
# Epoch 3/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5122 AUC: 0.8449
# Batch: 13/13 (valid)
# valid Loss: 0.4472 AUC: 0.8765
#
# Epoch 4/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5138 AUC: 0.8483
# Batch: 13/13 (valid)
# valid Loss: 0.4563 AUC: 0.8662
#
# Epoch 5/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4754 AUC: 0.8672
# Batch: 13/13 (valid)
# valid Loss: 0.4838 AUC: 0.8759
#
# Epoch 6/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4603 AUC: 0.8753
# Batch: 13/13 (valid)
# valid Loss: 0.5021 AUC: 0.8626
#
# Epoch 7/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4399 AUC: 0.8813
# Batch: 13/13 (valid)
# valid Loss: 0.4364 AUC: 0.8763
#
# Epoch 8/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4147 AUC: 0.8950
# Batch: 13/13 (valid)
# valid Loss: 0.4894 AUC: 0.8780
#
# Epoch 9/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3900 AUC: 0.9091
# Batch: 13/13 (valid)
# valid Loss: 0.4813 AUC: 0.8770
#
# Epoch 10/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3727 AUC: 0.9140
# Batch: 13/13 (valid)
# valid Loss: 0.4638 AUC: 0.8829
#
# Epoch 11/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3535 AUC: 0.9196
# Batch: 13/13 (valid)
# valid Loss: 0.4397 AUC: 0.8812
#
# Epoch 12/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3362 AUC: 0.9210
# Batch: 13/13 (valid)
# valid Loss: 0.4310 AUC: 0.8911
#
# Epoch 13/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3256 AUC: 0.9263
# Batch: 13/13 (valid)
# valid Loss: 0.4321 AUC: 0.8923
#
# Epoch 14/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3285 AUC: 0.9254
# Batch: 13/13 (valid)
# valid Loss: 0.4206 AUC: 0.8925
#
# Epoch 15/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3188 AUC: 0.9287
# Batch: 13/13 (valid)
# valid Loss: 0.4196 AUC: 0.8900
#
# Epoch 16/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3194 AUC: 0.9282
# Batch: 13/13 (valid)
# valid Loss: 0.4187 AUC: 0.8924
#
# Epoch 17/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3100 AUC: 0.9307
# Batch: 13/13 (valid)
# valid Loss: 0.4355 AUC: 0.8915
#
# Epoch 18/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3248 AUC: 0.9259
# Batch: 13/13 (valid)
# valid Loss: 0.4079 AUC: 0.8977
#
# Epoch 19/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3526 AUC: 0.9208
# Batch: 13/13 (valid)
# valid Loss: 0.4469 AUC: 0.8876
#
# Epoch 20/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3506 AUC: 0.9226
# Batch: 13/13 (valid)
# valid Loss: 0.4224 AUC: 0.8838
#
# Epoch 21/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3643 AUC: 0.9161
# Batch: 13/13 (valid)
# valid Loss: 0.4587 AUC: 0.8840
#
# Epoch 22/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3856 AUC: 0.9090
# Batch: 13/13 (valid)
# valid Loss: 0.4396 AUC: 0.8782
#
# Epoch 23/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3891 AUC: 0.9101
# Batch: 13/13 (valid)
# valid Loss: 0.4411 AUC: 0.8901
#
# Epoch 24/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3770 AUC: 0.9129
# Batch: 13/13 (valid)
# valid Loss: 0.4488 AUC: 0.8856
#
# Epoch 25/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3691 AUC: 0.9151
# Batch: 13/13 (valid)
# valid Loss: 0.4376 AUC: 0.8857
#
# Epoch 26/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3839 AUC: 0.9091
# Batch: 13/13 (valid)
# valid Loss: 0.4607 AUC: 0.8742
#
# Epoch 27/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3734 AUC: 0.9173
# Batch: 13/13 (valid)
# valid Loss: 0.4141 AUC: 0.8928
#
# Epoch 28/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3633 AUC: 0.9165
# Batch: 13/13 (valid)
# valid Loss: 0.4392 AUC: 0.8894
#
# Epoch 29/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3412 AUC: 0.9232
# Batch: 13/13 (valid)
# valid Loss: 0.4125 AUC: 0.8969
#
# Training complete in 51m 31s
# Best val AUC: 0.8977
#
# << Spec: 3 >>
# Epoch 0/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3271 AUC: 0.9257
# Batch: 13/13 (valid)
# valid Loss: 0.4127 AUC: 0.8945
#
# Epoch 1/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3426 AUC: 0.9212
# Batch: 13/13 (valid)
# valid Loss: 0.4001 AUC: 0.8915
#
# Epoch 2/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3492 AUC: 0.9183
# Batch: 13/13 (valid)
# valid Loss: 0.3892 AUC: 0.9010
#
# Epoch 3/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3694 AUC: 0.9117
# Batch: 13/13 (valid)
# valid Loss: 0.3953 AUC: 0.9001
#
# Epoch 4/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3672 AUC: 0.9141
# Batch: 13/13 (valid)
# valid Loss: 0.5009 AUC: 0.8901
#
# Epoch 5/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3733 AUC: 0.9189
# Batch: 13/13 (valid)
# valid Loss: 0.4098 AUC: 0.8990
#
# Epoch 6/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.4013 AUC: 0.9124
# Batch: 13/13 (valid)
# valid Loss: 0.3847 AUC: 0.9073
#
# Epoch 7/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3805 AUC: 0.9149
# Batch: 13/13 (valid)
# valid Loss: 0.4185 AUC: 0.8862
#
# Epoch 8/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3710 AUC: 0.9174
# Batch: 13/13 (valid)
# valid Loss: 0.3414 AUC: 0.9195
#
# Epoch 9/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3780 AUC: 0.9148
# Batch: 13/13 (valid)
# valid Loss: 0.4299 AUC: 0.9034
#
# Epoch 10/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3564 AUC: 0.9207
# Batch: 13/13 (valid)
# valid Loss: 0.3689 AUC: 0.9134
#
# Epoch 11/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3333 AUC: 0.9253
# Batch: 13/13 (valid)
# valid Loss: 0.4022 AUC: 0.8984
#
# Epoch 12/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3420 AUC: 0.9249
# Batch: 13/13 (valid)
# valid Loss: 0.4036 AUC: 0.9036
#
# Epoch 13/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3381 AUC: 0.9243
# Batch: 13/13 (valid)
# valid Loss: 0.3620 AUC: 0.9140
#
# Epoch 14/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3136 AUC: 0.9330
# Batch: 13/13 (valid)
# valid Loss: 0.3800 AUC: 0.9205
#
# Epoch 15/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2947 AUC: 0.9316
# Batch: 13/13 (valid)
# valid Loss: 0.3234 AUC: 0.9249
#
# Epoch 16/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2711 AUC: 0.9388
# Batch: 13/13 (valid)
# valid Loss: 0.3359 AUC: 0.9169
#
# Epoch 17/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2650 AUC: 0.9400
# Batch: 13/13 (valid)
# valid Loss: 0.3129 AUC: 0.9301
#
# Epoch 18/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2493 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3142 AUC: 0.9269
#
# Epoch 19/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2478 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.3258 AUC: 0.9218
#
# Epoch 20/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2421 AUC: 0.9414
# Batch: 13/13 (valid)
# valid Loss: 0.3234 AUC: 0.9228
#
# Epoch 21/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2390 AUC: 0.9421
# Batch: 13/13 (valid)
# valid Loss: 0.3291 AUC: 0.9211
#
# Epoch 22/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2330 AUC: 0.9441
# Batch: 13/13 (valid)
# valid Loss: 0.3299 AUC: 0.9198
#
# Epoch 23/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2516 AUC: 0.9415
# Batch: 13/13 (valid)
# valid Loss: 0.3310 AUC: 0.9251
#
# Epoch 24/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2569 AUC: 0.9412
# Batch: 13/13 (valid)
# valid Loss: 0.3078 AUC: 0.9310
#
# Epoch 25/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2633 AUC: 0.9421
# Batch: 13/13 (valid)
# valid Loss: 0.3506 AUC: 0.9220
#
# Epoch 26/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2862 AUC: 0.9371
# Batch: 13/13 (valid)
# valid Loss: 0.3396 AUC: 0.9233
#
# Epoch 27/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2993 AUC: 0.9339
# Batch: 13/13 (valid)
# valid Loss: 0.3809 AUC: 0.9160
#
# Epoch 28/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3260 AUC: 0.9265
# Batch: 13/13 (valid)
# valid Loss: 0.3431 AUC: 0.9283
#
# Epoch 29/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3332 AUC: 0.9274
# Batch: 13/13 (valid)
# valid Loss: 0.4280 AUC: 0.9164
#
# Epoch 30/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3341 AUC: 0.9231
# Batch: 13/13 (valid)
# valid Loss: 0.3969 AUC: 0.9144
#
# Epoch 31/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3408 AUC: 0.9261
# Batch: 13/13 (valid)
# valid Loss: 0.4247 AUC: 0.9087
#
# Epoch 32/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3510 AUC: 0.9215
# Batch: 13/13 (valid)
# valid Loss: 0.3448 AUC: 0.9214
#
# Epoch 33/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3204 AUC: 0.9273
# Batch: 13/13 (valid)
# valid Loss: 0.4174 AUC: 0.8982
#
# Epoch 34/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3214 AUC: 0.9315
# Batch: 13/13 (valid)
# valid Loss: 0.3750 AUC: 0.9093
#
# Epoch 35/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3029 AUC: 0.9331
# Batch: 13/13 (valid)
# valid Loss: 0.3469 AUC: 0.9203
#
# Epoch 36/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2761 AUC: 0.9396
# Batch: 13/13 (valid)
# valid Loss: 0.3670 AUC: 0.9205
#
# Epoch 37/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2741 AUC: 0.9371
# Batch: 13/13 (valid)
# valid Loss: 0.3468 AUC: 0.9277
#
# Epoch 38/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2617 AUC: 0.9417
# Batch: 13/13 (valid)
# valid Loss: 0.3319 AUC: 0.9276
#
# Epoch 39/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2485 AUC: 0.9413
# Batch: 13/13 (valid)
# valid Loss: 0.3005 AUC: 0.9359
#
# Epoch 40/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2398 AUC: 0.9415
# Batch: 13/13 (valid)
# valid Loss: 0.2975 AUC: 0.9360
#
# Epoch 41/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2397 AUC: 0.9441
# Batch: 13/13 (valid)
# valid Loss: 0.2978 AUC: 0.9349
#
# Epoch 42/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2440 AUC: 0.9422
# Batch: 13/13 (valid)
# valid Loss: 0.2988 AUC: 0.9354
#
# Epoch 43/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2374 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.3029 AUC: 0.9352
#
# Epoch 44/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2442 AUC: 0.9431
# Batch: 13/13 (valid)
# valid Loss: 0.3016 AUC: 0.9353
#
# Epoch 45/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2400 AUC: 0.9440
# Batch: 13/13 (valid)
# valid Loss: 0.3344 AUC: 0.9278
#
# Epoch 46/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2600 AUC: 0.9416
# Batch: 13/13 (valid)
# valid Loss: 0.3182 AUC: 0.9285
#
# Epoch 47/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2660 AUC: 0.9397
# Batch: 13/13 (valid)
# valid Loss: 0.3795 AUC: 0.9083
#
# Epoch 48/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2770 AUC: 0.9393
# Batch: 13/13 (valid)
# valid Loss: 0.3717 AUC: 0.9113
#
# Epoch 49/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2922 AUC: 0.9365
# Batch: 13/13 (valid)
# valid Loss: 0.4172 AUC: 0.8935
#
# Epoch 50/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3079 AUC: 0.9322
# Batch: 13/13 (valid)
# valid Loss: 0.3872 AUC: 0.9127
#
# Epoch 51/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3465 AUC: 0.9208
# Batch: 13/13 (valid)
# valid Loss: 0.4258 AUC: 0.8882
#
# Epoch 52/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3457 AUC: 0.9267
# Batch: 13/13 (valid)
# valid Loss: 0.3667 AUC: 0.9150
#
# Epoch 53/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3159 AUC: 0.9266
# Batch: 13/13 (valid)
# valid Loss: 0.3816 AUC: 0.9136
#
# Epoch 54/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3126 AUC: 0.9300
# Batch: 13/13 (valid)
# valid Loss: 0.3526 AUC: 0.9140
#
# Epoch 55/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3080 AUC: 0.9343
# Batch: 13/13 (valid)
# valid Loss: 0.3560 AUC: 0.9199
#
# Epoch 56/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2850 AUC: 0.9383
# Batch: 13/13 (valid)
# valid Loss: 0.3341 AUC: 0.9255
#
# Epoch 57/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2574 AUC: 0.9412
# Batch: 13/13 (valid)
# valid Loss: 0.3195 AUC: 0.9238
#
# Epoch 58/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2577 AUC: 0.9413
# Batch: 13/13 (valid)
# valid Loss: 0.3080 AUC: 0.9314
#
# Epoch 59/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2549 AUC: 0.9405
# Batch: 13/13 (valid)
# valid Loss: 0.3034 AUC: 0.9302
#
# Epoch 60/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2453 AUC: 0.9421
# Batch: 13/13 (valid)
# valid Loss: 0.2991 AUC: 0.9318
#
# Epoch 61/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2346 AUC: 0.9421
# Batch: 13/13 (valid)
# valid Loss: 0.2956 AUC: 0.9312
#
# Epoch 62/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2390 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.2947 AUC: 0.9307
#
# Epoch 63/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2385 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.2904 AUC: 0.9310
#
# Epoch 64/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2342 AUC: 0.9436
# Batch: 13/13 (valid)
# valid Loss: 0.2943 AUC: 0.9314
#
# Epoch 65/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2434 AUC: 0.9420
# Batch: 13/13 (valid)
# valid Loss: 0.2903 AUC: 0.9331
#
# Epoch 66/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2367 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.3099 AUC: 0.9270
#
# Epoch 67/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2487 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.2928 AUC: 0.9316
#
# Epoch 68/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2420 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.3008 AUC: 0.9326
#
# Epoch 69/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2731 AUC: 0.9386
# Batch: 13/13 (valid)
# valid Loss: 0.3605 AUC: 0.9283
#
# Epoch 70/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2679 AUC: 0.9385
# Batch: 13/13 (valid)
# valid Loss: 0.3852 AUC: 0.9117
#
# Epoch 71/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2845 AUC: 0.9350
# Batch: 13/13 (valid)
# valid Loss: 0.4762 AUC: 0.8964
#
# Epoch 72/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3069 AUC: 0.9344
# Batch: 13/13 (valid)
# valid Loss: 0.3362 AUC: 0.9222
#
# Epoch 73/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3061 AUC: 0.9323
# Batch: 13/13 (valid)
# valid Loss: 0.3905 AUC: 0.9055
#
# Epoch 74/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3033 AUC: 0.9325
# Batch: 13/13 (valid)
# valid Loss: 0.3824 AUC: 0.9115
#
# Epoch 75/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3085 AUC: 0.9314
# Batch: 13/13 (valid)
# valid Loss: 0.3446 AUC: 0.9214
#
# Epoch 76/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2872 AUC: 0.9361
# Batch: 13/13 (valid)
# valid Loss: 0.3671 AUC: 0.9270
#
# Epoch 77/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2757 AUC: 0.9388
# Batch: 13/13 (valid)
# valid Loss: 0.3636 AUC: 0.9225
#
# Epoch 78/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2614 AUC: 0.9412
# Batch: 13/13 (valid)
# valid Loss: 0.3783 AUC: 0.9200
#
# Epoch 79/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2549 AUC: 0.9441
# Batch: 13/13 (valid)
# valid Loss: 0.3885 AUC: 0.9134
#
# Epoch 80/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2562 AUC: 0.9412
# Batch: 13/13 (valid)
# valid Loss: 0.3432 AUC: 0.9299
#
# Epoch 81/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2402 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.3234 AUC: 0.9284
#
# Epoch 82/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2382 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3288 AUC: 0.9290
#
# Epoch 83/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2340 AUC: 0.9429
# Batch: 13/13 (valid)
# valid Loss: 0.3243 AUC: 0.9319
#
# Epoch 84/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2303 AUC: 0.9443
# Batch: 13/13 (valid)
# valid Loss: 0.3231 AUC: 0.9302
#
# Epoch 85/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2306 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.3213 AUC: 0.9298
#
# Epoch 86/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2395 AUC: 0.9417
# Batch: 13/13 (valid)
# valid Loss: 0.3108 AUC: 0.9308
#
# Epoch 87/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2296 AUC: 0.9436
# Batch: 13/13 (valid)
# valid Loss: 0.3138 AUC: 0.9309
#
# Epoch 88/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2474 AUC: 0.9417
# Batch: 13/13 (valid)
# valid Loss: 0.3359 AUC: 0.9194
#
# Epoch 89/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2424 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.3205 AUC: 0.9329
#
# Epoch 90/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2481 AUC: 0.9406
# Batch: 13/13 (valid)
# valid Loss: 0.3880 AUC: 0.9266
#
# Epoch 91/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2697 AUC: 0.9400
# Batch: 13/13 (valid)
# valid Loss: 0.3414 AUC: 0.9239
#
# Epoch 92/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3034 AUC: 0.9321
# Batch: 13/13 (valid)
# valid Loss: 0.3737 AUC: 0.9175
#
# Epoch 93/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2972 AUC: 0.9354
# Batch: 13/13 (valid)
# valid Loss: 0.4345 AUC: 0.9045
#
# Epoch 94/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3119 AUC: 0.9294
# Batch: 13/13 (valid)
# valid Loss: 0.3781 AUC: 0.9060
#
# Epoch 95/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2935 AUC: 0.9380
# Batch: 13/13 (valid)
# valid Loss: 0.3598 AUC: 0.9236
#
# Epoch 96/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2783 AUC: 0.9375
# Batch: 13/13 (valid)
# valid Loss: 0.3615 AUC: 0.9253
#
# Epoch 97/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2817 AUC: 0.9369
# Batch: 13/13 (valid)
# valid Loss: 0.3527 AUC: 0.9218
#
# Epoch 98/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2608 AUC: 0.9414
# Batch: 13/13 (valid)
# valid Loss: 0.3325 AUC: 0.9160
#
# Epoch 99/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2546 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.4463 AUC: 0.9181
#
# Training complete in 208m 9s
# Best val AUC: 0.9360
#
# - Validation -
# === Normal Valid ===
# Batch: 13/13
#
# Norml Valid AUC: 0.9354
#
# === Valid Time Augmentation ===
# n: 0/4
# ----------
# Batch: 13/13
# n: 1/4
# ----------
# Batch: 13/13
# n: 2/4
# ----------
# Batch: 13/13
# n: 3/4
# ----------
# Batch: 13/13
# n: 4/4
# ----------
# Batch: 13/13
#
# VTA AUC: 0.9359
#
# === Mixed Valid ===
#
# Mixed AUC: 0.9355
#
# === Fold: 2 ===
# GPU Memory: 17040384
# << Spec: 0 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.7717 AUC: 0.4657
# Batch: 13/13 (valid)
# valid Loss: 0.7807 AUC: 0.4625
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.6719 AUC: 0.6273
# Batch: 13/13 (valid)
# valid Loss: 0.5944 AUC: 0.7466
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5996 AUC: 0.7457
# Batch: 13/13 (valid)
# valid Loss: 0.5640 AUC: 0.7846
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5732 AUC: 0.7661
# Batch: 13/13 (valid)
# valid Loss: 0.5312 AUC: 0.8040
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5638 AUC: 0.7806
# Batch: 13/13 (valid)
# valid Loss: 0.5316 AUC: 0.8083
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5639 AUC: 0.7883
# Batch: 13/13 (valid)
# valid Loss: 0.5221 AUC: 0.8277
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5446 AUC: 0.7976
# Batch: 13/13 (valid)
# valid Loss: 0.5333 AUC: 0.8155
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5440 AUC: 0.8054
# Batch: 13/13 (valid)
# valid Loss: 0.4991 AUC: 0.8353
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5353 AUC: 0.8061
# Batch: 13/13 (valid)
# valid Loss: 0.5010 AUC: 0.8356
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5158 AUC: 0.8231
# Batch: 13/13 (valid)
# valid Loss: 0.4949 AUC: 0.8372
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5176 AUC: 0.8174
# Batch: 13/13 (valid)
# valid Loss: 0.4933 AUC: 0.8345
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5246 AUC: 0.8134
# Batch: 13/13 (valid)
# valid Loss: 0.5177 AUC: 0.8343
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5121 AUC: 0.8239
# Batch: 13/13 (valid)
# valid Loss: 0.4949 AUC: 0.8325
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5141 AUC: 0.8252
# Batch: 13/13 (valid)
# valid Loss: 0.4999 AUC: 0.8391
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4963 AUC: 0.8387
# Batch: 13/13 (valid)
# valid Loss: 0.4963 AUC: 0.8409
#
# Training complete in 25m 28s
# Best val AUC: 0.8409
#
# << Spec: 1 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5108 AUC: 0.8243
# Batch: 13/13 (valid)
# valid Loss: 0.4929 AUC: 0.8389
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5019 AUC: 0.8319
# Batch: 13/13 (valid)
# valid Loss: 0.4910 AUC: 0.8408
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4990 AUC: 0.8377
# Batch: 13/13 (valid)
# valid Loss: 0.4953 AUC: 0.8417
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5090 AUC: 0.8300
# Batch: 13/13 (valid)
# valid Loss: 0.4882 AUC: 0.8409
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4976 AUC: 0.8385
# Batch: 13/13 (valid)
# valid Loss: 0.4907 AUC: 0.8405
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5171 AUC: 0.8274
# Batch: 13/13 (valid)
# valid Loss: 0.4970 AUC: 0.8389
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5121 AUC: 0.8264
# Batch: 13/13 (valid)
# valid Loss: 0.4935 AUC: 0.8403
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5083 AUC: 0.8289
# Batch: 13/13 (valid)
# valid Loss: 0.4942 AUC: 0.8399
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5002 AUC: 0.8324
# Batch: 13/13 (valid)
# valid Loss: 0.4880 AUC: 0.8458
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4985 AUC: 0.8382
# Batch: 13/13 (valid)
# valid Loss: 0.4914 AUC: 0.8453
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4904 AUC: 0.8419
# Batch: 13/13 (valid)
# valid Loss: 0.4791 AUC: 0.8522
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4908 AUC: 0.8402
# Batch: 13/13 (valid)
# valid Loss: 0.4881 AUC: 0.8421
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4914 AUC: 0.8353
# Batch: 13/13 (valid)
# valid Loss: 0.4830 AUC: 0.8476
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4949 AUC: 0.8419
# Batch: 13/13 (valid)
# valid Loss: 0.4928 AUC: 0.8451
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4857 AUC: 0.8406
# Batch: 13/13 (valid)
# valid Loss: 0.4845 AUC: 0.8452
#
# Training complete in 25m 21s
# Best val AUC: 0.8522
#
# << Spec: 2 >>
# Epoch 0/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4896 AUC: 0.8403
# Batch: 13/13 (valid)
# valid Loss: 0.4798 AUC: 0.8485
#
# Epoch 1/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5925 AUC: 0.8098
# Batch: 13/13 (valid)
# valid Loss: 0.5358 AUC: 0.8504
#
# Epoch 2/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5385 AUC: 0.8278
# Batch: 13/13 (valid)
# valid Loss: 0.4892 AUC: 0.8522
#
# Epoch 3/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5187 AUC: 0.8434
# Batch: 13/13 (valid)
# valid Loss: 0.5870 AUC: 0.8490
#
# Epoch 4/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4974 AUC: 0.8520
# Batch: 13/13 (valid)
# valid Loss: 0.5157 AUC: 0.8648
#
# Epoch 5/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4870 AUC: 0.8524
# Batch: 13/13 (valid)
# valid Loss: 0.4642 AUC: 0.8779
#
# Epoch 6/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4797 AUC: 0.8605
# Batch: 13/13 (valid)
# valid Loss: 0.4304 AUC: 0.8789
#
# Epoch 7/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4532 AUC: 0.8685
# Batch: 13/13 (valid)
# valid Loss: 0.4256 AUC: 0.8793
#
# Epoch 8/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4281 AUC: 0.8863
# Batch: 13/13 (valid)
# valid Loss: 0.4346 AUC: 0.8791
#
# Epoch 9/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4301 AUC: 0.8914
# Batch: 13/13 (valid)
# valid Loss: 0.4136 AUC: 0.8943
#
# Epoch 10/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4105 AUC: 0.8974
# Batch: 13/13 (valid)
# valid Loss: 0.4122 AUC: 0.8942
#
# Epoch 11/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3800 AUC: 0.9083
# Batch: 13/13 (valid)
# valid Loss: 0.3976 AUC: 0.8971
#
# Epoch 12/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3555 AUC: 0.9168
# Batch: 13/13 (valid)
# valid Loss: 0.3813 AUC: 0.9078
#
# Epoch 13/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3446 AUC: 0.9224
# Batch: 13/13 (valid)
# valid Loss: 0.3731 AUC: 0.9081
#
# Epoch 14/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3246 AUC: 0.9278
# Batch: 13/13 (valid)
# ...
# Batch: 13/13 (valid)
# valid Loss: 0.3819 AUC: 0.9122
#
# Epoch 15/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3300 AUC: 0.9251
# Batch: 13/13 (valid)
# valid Loss: 0.3798 AUC: 0.9118
#
# Epoch 16/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3280 AUC: 0.9257
# Batch: 13/13 (valid)
# valid Loss: 0.3823 AUC: 0.9105
#
# Epoch 17/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3350 AUC: 0.9247
# Batch: 13/13 (valid)
# valid Loss: 0.3805 AUC: 0.9102
#
# Epoch 18/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3303 AUC: 0.9276
# Batch: 13/13 (valid)
# valid Loss: 0.3727 AUC: 0.9095
#
# Epoch 19/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3540 AUC: 0.9190
# Batch: 13/13 (valid)
# valid Loss: 0.3833 AUC: 0.9093
#
# Epoch 20/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3664 AUC: 0.9152
# Batch: 13/13 (valid)
# valid Loss: 0.3940 AUC: 0.9041
#
# Epoch 21/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3795 AUC: 0.9095
# Batch: 13/13 (valid)
# valid Loss: 0.3858 AUC: 0.9093
#
# Epoch 22/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3713 AUC: 0.9093
# Batch: 13/13 (valid)
# valid Loss: 0.4003 AUC: 0.8986
#
# Epoch 23/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4018 AUC: 0.8977
# Batch: 13/13 (valid)
# valid Loss: 0.4439 AUC: 0.8829
#
# Epoch 24/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4205 AUC: 0.8920
# Batch: 13/13 (valid)
# valid Loss: 0.4127 AUC: 0.8967
#
# Epoch 25/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4027 AUC: 0.9054
# Batch: 13/13 (valid)
# valid Loss: 0.4681 AUC: 0.8932
#
# Epoch 26/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3906 AUC: 0.9091
# Batch: 13/13 (valid)
# valid Loss: 0.3854 AUC: 0.9077
#
# Epoch 27/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3662 AUC: 0.9135
# Batch: 13/13 (valid)
# valid Loss: 0.4306 AUC: 0.8821
#
# Epoch 28/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3566 AUC: 0.9183
# Batch: 13/13 (valid)
# valid Loss: 0.3908 AUC: 0.9061
#
# Epoch 29/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3445 AUC: 0.9212
# Batch: 13/13 (valid)
# valid Loss: 0.4173 AUC: 0.8943
#
# Training complete in 51m 10s
# Best val AUC: 0.9122
#
# << Spec: 3 >>
# Epoch 0/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3222 AUC: 0.9273
# Batch: 13/13 (valid)
# valid Loss: 0.3736 AUC: 0.9133
#
# Epoch 1/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3739 AUC: 0.9178
# Batch: 13/13 (valid)
# valid Loss: 0.3983 AUC: 0.9065
#
# Epoch 2/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3535 AUC: 0.9208
# Batch: 13/13 (valid)
# valid Loss: 0.3690 AUC: 0.9100
#
# Epoch 3/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3683 AUC: 0.9111
# Batch: 13/13 (valid)
# valid Loss: 0.3380 AUC: 0.9231
#
# Epoch 4/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3600 AUC: 0.9203
# Batch: 13/13 (valid)
# valid Loss: 0.4229 AUC: 0.9156
#
# Epoch 5/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3780 AUC: 0.9126
# Batch: 13/13 (valid)
# valid Loss: 0.4211 AUC: 0.9091
#
# Epoch 6/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3727 AUC: 0.9181
# Batch: 13/13 (valid)
# valid Loss: 0.3573 AUC: 0.9126
#
# Epoch 7/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3705 AUC: 0.9141
# Batch: 13/13 (valid)
# valid Loss: 0.4282 AUC: 0.8921
#
# Epoch 8/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3755 AUC: 0.9107
# Batch: 13/13 (valid)
# valid Loss: 0.3780 AUC: 0.9069
#
# Epoch 9/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3682 AUC: 0.9186
# Batch: 13/13 (valid)
# valid Loss: 0.4248 AUC: 0.8981
#
# Epoch 10/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3787 AUC: 0.9114
# Batch: 13/13 (valid)
# valid Loss: 0.4646 AUC: 0.9020
#
# Epoch 11/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3712 AUC: 0.9151
# Batch: 13/13 (valid)
# valid Loss: 0.3900 AUC: 0.9082
#
# Epoch 12/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3525 AUC: 0.9211
# Batch: 13/13 (valid)
# valid Loss: 0.3938 AUC: 0.9014
#
# Epoch 13/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3269 AUC: 0.9279
# Batch: 13/13 (valid)
# valid Loss: 0.3906 AUC: 0.9071
#
# Epoch 14/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2946 AUC: 0.9344
# Batch: 13/13 (valid)
# valid Loss: 0.4385 AUC: 0.8985
#
# Epoch 15/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3076 AUC: 0.9332
# Batch: 13/13 (valid)
# valid Loss: 0.3416 AUC: 0.9313
#
# Epoch 16/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2698 AUC: 0.9361
# Batch: 13/13 (valid)
# valid Loss: 0.3200 AUC: 0.9269
#
# Epoch 17/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2705 AUC: 0.9396
# Batch: 13/13 (valid)
# valid Loss: 0.3361 AUC: 0.9269
#
# Epoch 18/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2513 AUC: 0.9418
# Batch: 13/13 (valid)
# valid Loss: 0.3179 AUC: 0.9300
#
# Epoch 19/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2555 AUC: 0.9411
# Batch: 13/13 (valid)
# valid Loss: 0.3124 AUC: 0.9325
#
# Epoch 20/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2500 AUC: 0.9419
# Batch: 13/13 (valid)
# valid Loss: 0.3125 AUC: 0.9326
#
# Epoch 21/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2486 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.3167 AUC: 0.9311
#
# Epoch 22/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2417 AUC: 0.9423
# Batch: 13/13 (valid)
# valid Loss: 0.3250 AUC: 0.9296
#
# Epoch 23/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2420 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.3152 AUC: 0.9289
#
# Epoch 24/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2519 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.3226 AUC: 0.9354
#
# Epoch 25/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2708 AUC: 0.9376
# Batch: 13/13 (valid)
# valid Loss: 0.3348 AUC: 0.9276
#
# Epoch 26/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2826 AUC: 0.9390
# Batch: 13/13 (valid)
# valid Loss: 0.3362 AUC: 0.9199
#
# Epoch 27/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3050 AUC: 0.9303
# Batch: 13/13 (valid)
# valid Loss: 0.3609 AUC: 0.9155
#
# Epoch 28/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3385 AUC: 0.9235
# Batch: 13/13 (valid)
# valid Loss: 0.4027 AUC: 0.8956
#
# Epoch 29/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3678 AUC: 0.9189
# Batch: 13/13 (valid)
# valid Loss: 0.3620 AUC: 0.9146
#
# Epoch 30/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3558 AUC: 0.9214
# Batch: 13/13 (valid)
# valid Loss: 0.3800 AUC: 0.9119
#
# Epoch 31/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3430 AUC: 0.9250
# Batch: 13/13 (valid)
# valid Loss: 0.4036 AUC: 0.8977
#
# Epoch 32/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3413 AUC: 0.9244
# Batch: 13/13 (valid)
# valid Loss: 0.4653 AUC: 0.8934
#
# Epoch 33/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3119 AUC: 0.9308
# Batch: 13/13 (valid)
# valid Loss: 0.3859 AUC: 0.9140
#
# Epoch 34/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3094 AUC: 0.9304
# Batch: 13/13 (valid)
# valid Loss: 0.3838 AUC: 0.9103
#
# Epoch 35/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2928 AUC: 0.9350
# Batch: 13/13 (valid)
# valid Loss: 0.3442 AUC: 0.9224
#
# Epoch 36/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2851 AUC: 0.9367
# Batch: 13/13 (valid)
# valid Loss: 0.3433 AUC: 0.9289
#
# Epoch 37/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2660 AUC: 0.9412
# Batch: 13/13 (valid)
# valid Loss: 0.3510 AUC: 0.9227
#
# Epoch 38/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2606 AUC: 0.9405
# Batch: 13/13 (valid)
# valid Loss: 0.3199 AUC: 0.9326
#
# Epoch 39/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2465 AUC: 0.9419
# Batch: 13/13 (valid)
# valid Loss: 0.3279 AUC: 0.9261
#
# Epoch 40/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2441 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3428 AUC: 0.9250
#
# Epoch 41/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2387 AUC: 0.9429
# Batch: 13/13 (valid)
# valid Loss: 0.3276 AUC: 0.9259
#
# Epoch 42/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2356 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.3263 AUC: 0.9264
#
# Epoch 43/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2344 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.3301 AUC: 0.9269
#
# Epoch 44/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2354 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.3224 AUC: 0.9308
#
# Epoch 45/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2430 AUC: 0.9428
# Batch: 13/13 (valid)
# valid Loss: 0.3102 AUC: 0.9331
#
# Epoch 46/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2479 AUC: 0.9410
# Batch: 13/13 (valid)
# valid Loss: 0.3229 AUC: 0.9340
#
# Epoch 47/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2598 AUC: 0.9405
# Batch: 13/13 (valid)
# valid Loss: 0.3420 AUC: 0.9237
#
# Epoch 48/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2621 AUC: 0.9404
# Batch: 13/13 (valid)
# valid Loss: 0.3799 AUC: 0.9185
#
# Epoch 49/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3033 AUC: 0.9354
# Batch: 13/13 (valid)
# valid Loss: 0.3982 AUC: 0.9003
#
# Epoch 50/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3199 AUC: 0.9299
# Batch: 13/13 (valid)
# valid Loss: 0.3740 AUC: 0.9064
#
# Epoch 51/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3271 AUC: 0.9268
# Batch: 13/13 (valid)
# valid Loss: 0.4079 AUC: 0.9090
#
# Epoch 52/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3053 AUC: 0.9330
# Batch: 13/13 (valid)
# valid Loss: 0.4344 AUC: 0.8987
#
# Epoch 53/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3297 AUC: 0.9251
# Batch: 13/13 (valid)
# valid Loss: 0.3931 AUC: 0.9064
#
# Epoch 54/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3071 AUC: 0.9301
# Batch: 13/13 (valid)
# valid Loss: 0.4041 AUC: 0.9099
#
# Epoch 55/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3073 AUC: 0.9344
# Batch: 13/13 (valid)
# valid Loss: 0.3388 AUC: 0.9245
#
# Epoch 56/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2732 AUC: 0.9387
# Batch: 13/13 (valid)
# valid Loss: 0.3161 AUC: 0.9307
#
# Epoch 57/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2706 AUC: 0.9387
# Batch: 13/13 (valid)
# valid Loss: 0.3509 AUC: 0.9206
#
# Epoch 58/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2638 AUC: 0.9402
# Batch: 13/13 (valid)
# valid Loss: 0.3236 AUC: 0.9292
#
# Epoch 59/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2520 AUC: 0.9409
# Batch: 13/13 (valid)
# valid Loss: 0.2997 AUC: 0.9328
#
# Epoch 60/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2361 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3391 AUC: 0.9289
#
# Epoch 61/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2411 AUC: 0.9419
# Batch: 13/13 (valid)
# valid Loss: 0.3132 AUC: 0.9280
#
# Epoch 62/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2349 AUC: 0.9436
# Batch: 13/13 (valid)
# valid Loss: 0.3146 AUC: 0.9277
#
# Epoch 63/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2435 AUC: 0.9429
# Batch: 13/13 (valid)
# valid Loss: 0.3150 AUC: 0.9290
#
# Epoch 64/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2358 AUC: 0.9423
# Batch: 13/13 (valid)
# valid Loss: 0.3168 AUC: 0.9279
#
# Epoch 65/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2279 AUC: 0.9426
# Batch: 13/13 (valid)
# valid Loss: 0.3138 AUC: 0.9300
#
# Epoch 66/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2394 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3337 AUC: 0.9187
#
# Epoch 67/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2385 AUC: 0.9429
# Batch: 13/13 (valid)
# valid Loss: 0.3619 AUC: 0.9181
#
# Epoch 68/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2514 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3481 AUC: 0.9222
#
# Epoch 69/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2642 AUC: 0.9396
# Batch: 13/13 (valid)
# valid Loss: 0.3425 AUC: 0.9190
#
# Epoch 70/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2679 AUC: 0.9404
# Batch: 13/13 (valid)
# valid Loss: 0.3424 AUC: 0.9280
#
# Epoch 71/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2917 AUC: 0.9379
# Batch: 13/13 (valid)
# valid Loss: 0.3417 AUC: 0.9167
#
# Epoch 72/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3255 AUC: 0.9286
# Batch: 13/13 (valid)
# valid Loss: 0.4065 AUC: 0.8998
#
# Epoch 73/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2997 AUC: 0.9330
# Batch: 13/13 (valid)
# valid Loss: 0.3660 AUC: 0.9195
#
# Epoch 74/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3221 AUC: 0.9313
# Batch: 13/13 (valid)
# valid Loss: 0.4443 AUC: 0.9047
#
# Epoch 75/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2997 AUC: 0.9339
# Batch: 13/13 (valid)
# valid Loss: 0.4262 AUC: 0.9190
#
# Epoch 76/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2975 AUC: 0.9360
# Batch: 13/13 (valid)
# valid Loss: 0.3346 AUC: 0.9238
#
# Epoch 77/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2731 AUC: 0.9406
# Batch: 13/13 (valid)
# valid Loss: 0.3466 AUC: 0.9186
#
# Epoch 78/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2666 AUC: 0.9400
# Batch: 13/13 (valid)
# valid Loss: 0.3423 AUC: 0.9247
#
# Epoch 79/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2528 AUC: 0.9414
# Batch: 13/13 (valid)
# valid Loss: 0.3336 AUC: 0.9265
#
# Epoch 80/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2509 AUC: 0.9410
# Batch: 13/13 (valid)
# valid Loss: 0.3173 AUC: 0.9271
#
# Epoch 81/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2353 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.3352 AUC: 0.9259
#
# Epoch 82/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2497 AUC: 0.9423
# Batch: 13/13 (valid)
# valid Loss: 0.3093 AUC: 0.9260
#
# Epoch 83/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2309 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.3072 AUC: 0.9293
#
# Epoch 84/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2278 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.3097 AUC: 0.9275
#
# Epoch 85/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2370 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.3093 AUC: 0.9282
#
# Epoch 86/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2419 AUC: 0.9419
# Batch: 13/13 (valid)
# valid Loss: 0.3101 AUC: 0.9284
#
# Epoch 87/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2327 AUC: 0.9428
# Batch: 13/13 (valid)
# valid Loss: 0.3312 AUC: 0.9216
#
# Epoch 88/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2429 AUC: 0.9442
# Batch: 13/13 (valid)
# valid Loss: 0.3157 AUC: 0.9306
#
# Epoch 89/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2478 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3338 AUC: 0.9235
#
# Epoch 90/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2545 AUC: 0.9412
# Batch: 13/13 (valid)
# valid Loss: 0.3042 AUC: 0.9313
#
# Epoch 91/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2684 AUC: 0.9398
# Batch: 13/13 (valid)
# valid Loss: 0.3772 AUC: 0.9067
#
# Epoch 92/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2850 AUC: 0.9351
# Batch: 13/13 (valid)
# valid Loss: 0.3607 AUC: 0.9219
#
# Epoch 93/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2864 AUC: 0.9350
# Batch: 13/13 (valid)
# valid Loss: 0.3681 AUC: 0.9127
#
# Epoch 94/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.3000 AUC: 0.9330
# Batch: 13/13 (valid)
# valid Loss: 0.3591 AUC: 0.9167
#
# Epoch 95/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2908 AUC: 0.9368
# Batch: 13/13 (valid)
# valid Loss: 0.3489 AUC: 0.9189
#
# Epoch 96/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2957 AUC: 0.9362
# Batch: 13/13 (valid)
# valid Loss: 0.4099 AUC: 0.8992
#
# Epoch 97/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2888 AUC: 0.9344
# Batch: 13/13 (valid)
# valid Loss: 0.3568 AUC: 0.9135
#
# Epoch 98/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2736 AUC: 0.9374
# Batch: 13/13 (valid)
# valid Loss: 0.3646 AUC: 0.9217
#
# Epoch 99/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2583 AUC: 0.9415
# Batch: 13/13 (valid)
# valid Loss: 0.3390 AUC: 0.9243
#
# Training complete in 207m 60s
# Best val AUC: 0.9354
#
# - Validation -
# === Normal Valid ===
# Batch: 13/13
#
# Norml Valid AUC: 0.9355
#
# === Valid Time Augmentation ===
# n: 0/4
# ----------
# Batch: 13/13
# n: 1/4
# ----------
# Batch: 13/13
# n: 2/4
# ----------
# Batch: 13/13
# n: 3/4
# ----------
# Batch: 13/13
# n: 4/4
# ----------
# Batch: 13/13
#
# VTA AUC: 0.9320
#
# === Mixed Valid ===
#
# Mixed AUC: 0.9349
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
print(torch.cuda.memory_allocated())
# Out:
# 0

# %%
fold = 1

model = torch.load(f'model_{fold}.pth')
model.to(device)
val, vta, mix = valMix(model, foldData(fold, bs=32)[1], n=5)
# Out:
# === Normal Valid ===
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Batch: 13/13
#
# Norml Valid AUC: 0.9354
#
# === Valid Time Augmentation ===
# n: 0/4
# ----------
# Batch: 13/13
# n: 1/4
# ----------
# Batch: 13/13
# n: 2/4
# ----------
# Batch: 13/13
# n: 3/4
# ----------
# Batch: 13/13
# n: 4/4
# ----------
# Batch: 13/13
#
# VTA AUC: 0.9354
#
# === Mixed Valid ===
#
# Mixed AUC: 0.9360

# %%
# 例
def showRes(n, df, preds, preds2=None, preds3=None, start=0, sort=False):
    n_cols = 5
    n_rows = (n-1)//5+1
    
    if sort == 1:
        difs = pd.Series(preds, index=df['label'].index) - df['label']
    elif sort == 2:
        difs = pd.Series(preds2, index=df['label'].index) - df['label']
    elif sort == 3:
        difs = pd.Series(preds3, index=df['label'].index) - df['label']
    
    difs = difs.reset_index(drop=True)
    difs = difs.abs().sort_values(ascending=False)
    
    fig = plt.figure(figsize=(n_cols*2, n_rows*2))
    
    for i in range(n):
        loc = i + start
        if sort:
            loc = difs.index[loc]
        num = df['num'].iloc[loc]
        lab = df['label'].iloc[loc]
        im = image = load_img(num)
        
        ax = fig.add_subplot(n_rows, n_cols, i+1)
        im = np.asarray(im)
        ax.imshow(im)
        ax.axes.xaxis.set_visible(False)
        ax.axes.yaxis.set_visible(False)
        tit = f'Label: {lab}\nPred: {preds[loc]:.2f}'
        if preds2 is not None:
            tit += f'\nPred2: {preds2[loc]:.2f}'
        if preds3 is not None:
            tit += f'\nPred3: {preds3[loc]:.2f}'
        
        ax.set_title(tit)
        
    fig.suptitle('Prediction')
    fig.tight_layout()
    fig.show()

# %%
showRes(30, df_train[df_train['fold']==fold], val, vta, mix, start=0, sort=3)

# %% [markdown]
# ## 推論・提出

# %%
df_submit = df_test[['image_name', 'label']].copy()

# %%
def predictCV(fold):
    model = torch.load(f'model_{fold}.pth')
    model.to(device)
    
    _, dataloaders = foldData(fold)
    test, tta, tmix = valMix(model, dataloaders, n=5, mode='test')
    
    df_submit[f'label_test_{fold}'] = test
    df_submit[f'label_tta_{fold}'] = tta
    df_submit[f'label_tmix_{fold}'] = tmix
    
    del model
    torch.cuda.empty_cache()

# %%
for fold in range(n_folds):
    predictCV(fold)
# Out:
# === Normal Test ===
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Batch: 68/68
#
# Norml Valid AUC: 0.5000
#
# === Test Time Augmentation ===
# n: 0/4
# ----------
# Batch: 68/68
# n: 1/4
# ----------
# Batch: 68/68
# n: 2/4
# ----------
# Batch: 68/68
# n: 3/4
# ----------
# Batch: 30/68

# %%
# 平均対象を抽出して提出
targ = 'tmix'

mean = df_submit[[f'label_{targ}_{fold}' for fold in range(n_folds)]].mean(axis=1)
df_submit['label'] = mean

df_submit[['image_name', 'label']].to_csv('submit.csv', header=None, index=None)

# %%
df_submit.to_csv('model_v5-cv.csv', index=False)

# %% [markdown]
# 提出

# %%
# %%bash
# signate submit --competition-id=1106 submit.csv --note model5_CV_tmix
# Out:
# You have successfully submitted your predictions.We will send you the submission result to your email address.

# %% [markdown]
# model_v2, v3, v4とアンサンブル

# %%
df_1 = pd.read_csv('model_v2-cv.csv')
df_2 = pd.read_csv('model_v3-cv.csv')
df_3 = pd.read_csv('model_v4-cv.csv')
df_4 = pd.read_csv('model_v5-cv.csv')

# %%
targ = 'tmix'

mean1 = df_1[[f'label_{targ}_{fold}' for fold in range(5)]].mean(axis=1)
mean2 = df_2[[f'label_{targ}_{fold}' for fold in range(5)]].mean(axis=1)
mean3 = df_3[[f'label_{targ}_{fold}' for fold in range(5)]].mean(axis=1)
mean4 = df_4[[f'label_{targ}_{fold}' for fold in range(5)]].mean(axis=1)
mean = (mean1 + mean2 + mean3 + mean4) / 4

# %%
df_submit = df_1[['image_name', 'label']].copy()
df_submit['label'] = mean
df_submit.to_csv('submit.csv', header=None, index=None)

# %%
# %%bash
# signate submit --competition-id=1106 submit.csv --note model2CVtmix_model3CVtmix_model4CVtmix_model5CVtmix
# Out:
# You have successfully submitted your predictions.We will send you the submission result to your email address.

# %% [markdown]
# ## スタッキングモデル

# %% [markdown]
# foldによって各予測を作成

# %%
def predVal(fold):
    model = torch.load(f'model_{fold}.pth')
    model.to(device)
    val = valid(model, foldData(fold, bs=32)[1]['valid'])
    return val

# %%
try:
    df_train_new = pd.read_csv('model_v5-vpred.csv')
except:
    df_train_new = pd.DataFrame()
    
    for fold in range(n_folds):
        print(f'Fold: {fold}')
        df_train_new_ = df_train[df_train['fold']==fold]
        val = predVal(fold)
        df_train_new_.loc[:,'pred'] = val
        df_train_new_['label2'] = df_train_new_['label'].replace({0.05: 0, 0.95: 1}) - val
        df_train_new = pd.concat([df_train_new, df_train_new_])
    
    df_train_new['diff'] = df_train_new['label2']
    df_train_new['label2'] = df_train_new['label2'] / 2 + 0.5
    
    df_train_new['label_old'] = df_train_new['label']
    df_train_new['label'] = df_train_new['label2']
    df_train_new = df_train_new.drop('label2', axis=1)
    df_train_new.to_csv('model_v5-vpred.csv', index=False)

# %%
def foldData2(fold, bs=32):
    df_train_new_ = df_train_new[df_train_new['fold']!=fold]
    df_valid_new_ = df_train_new[df_train_new['fold']==fold]
    df_test_ = df_test
    
    image_datasets = {
        'train': MyDataset(df_train_new_, data_transforms['train'], tt='train'),
        'valid': MyDataset(df_valid_new_, data_transforms['valid'], tt='train'),
        'vta': MyDataset(df_valid_new_, data_transforms['tta'], tt='train'),
        'test': MyDataset(df_test_, data_transforms['valid'], tt='test'),
        'tta': MyDataset(df_test_, data_transforms['tta'], tt='test'),
    }
    
    dataloaders = {
        'train': torch.utils.data.DataLoader(image_datasets['train'],
                                             batch_size=bs, shuffle=True, num_workers=16, pin_memory=True),
        'valid': torch.utils.data.DataLoader(image_datasets['valid'],
                                             batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
        'vta': torch.utils.data.DataLoader(image_datasets['vta'],
                                           batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
        'test': torch.utils.data.DataLoader(image_datasets['test'],
                                            batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
        'tta': torch.utils.data.DataLoader(image_datasets['tta'],
                                           batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
    }
    
    return image_datasets, dataloaders

# %%
def train_spec_2(fold, i, model_path='model.pth'):
    spec = specs[i]
    
    # datasetsを作る
    image_datasets, dataloaders = foldData2(fold, bs=spec['bs'])
    
    # 新しいモデルを読み込み
    if i == 0:
        model = loadNewModel()
    else:
        model = torch.load(model_path)
        model.to(device)
        for p in model.parameters():
            p.requires_grad = False
    
    layer_list = [
        model.module.head.fc,
        model.module.norm,
        model.module.stages[3],
        model.module.stages[2],
    ]
    
    for j in range(spec['trainLayers']):
        layer = layer_list[j]
        for p in layer.parameters():
            p.requires_grad = True
    
    criterion = nn.BCEWithLogitsLoss(pos_weight=None)
    if False:
    # if i < len(specs)-2:
        optimizer = optim.SGD(model.parameters(), lr=spec['lr'], momentum=0.9)
        lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=spec['sch_steps'], gamma=spec['sch_gamma'])
    else:
        optimizer = optim.AdamW(model.parameters(), lr=spec['lr'])
        lr_scheduler = get_cosine_schedule_with_warmup(optimizer,
                                                       num_warmup_steps=spec['num_warmup_steps'],
                                                       num_training_steps=spec['num_training_steps'],
                                                       num_cycles=spec['num_cycles'])
    
    model = train(model, criterion, optimizer, lr_scheduler, image_datasets, dataloaders,
                  epochs=spec['epochs'])
    
    torch.save(model, model_path)
    del model
    torch.cuda.empty_cache()

# %%
def fold_train_2(fold):
    print(f'=== Fold: {fold} ===')
    print('GPU Memory:', torch.cuda.memory_allocated())
    
    for i in range(len(specs)):
        print(f'<< Spec: {i} >>')
        train_spec_2(fold, i)
    
    print('- Validation -')
    model = torch.load('model.pth')
    model.to(device)
    
    image_datasets, dataloaders = foldData2(fold)
    
    val, vta, mix = valMix(model, dataloaders, n=n_vta)
    vals[fold] = val
    vtas[fold] = vta
    mixs[fold] = mix
    
    print()
    
    torch.save(model, f'model2_{fold}.pth')
    
    del model
    torch.cuda.empty_cache()

# %% [raw]
# for fold in range(n_folds):
#     fold_train_2(fold)

# %%
# %%capture cap

for fold in range(n_folds):
    fold_train_2(fold)

with open('log_train.txt', 'w') as f:
    f.write(cap.stdout)

# %%
cap()

# %%
print(torch.cuda.memory_allocated())
