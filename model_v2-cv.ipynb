# %% [markdown]
# # ConvNeXt V2 Huge

# %% [markdown]
# - loss: Binary Cross Entropy
# - metrics: ROCAUC
# - trainable: after model.convnextv2.encoder.stages[3]
# - CVあり
# ---
# - label smoothing
# - AugMix
# × CutMix
# × MixUp

# %% [markdown]
# ## Load Model

# %%
from transformers import AutoImageProcessor, ConvNextV2ForImageClassification, get_cosine_schedule_with_warmup
import torch
from datasets import load_dataset

from utils.utils import load_img

print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.current_device())
print(torch.cuda.get_device_name())
print(torch.cuda.get_device_capability())
# Out:
# 2.2.0.dev20230911+cu118
# True
# 4
# 0
# Tesla T4
# (7, 5)

# %% [raw]
# dataset = load_dataset("huggingface/cats-image")
# image = dataset["test"]["image"][0]
#
# preprocessor = AutoImageProcessor.from_pretrained("facebook/convnextv2-huge-22k-512")
# model = ConvNextV2ForImageClassification.from_pretrained("facebook/convnextv2-huge-22k-512")

# %% [raw]
# inputs = preprocessor(image, return_tensors="pt")
# inputs['pixel_values'].shape

# %% [raw]
# with torch.no_grad():
#     logits = model(**inputs).logits
#
# # model predicts one of the 1000 ImageNet classes
# predicted_label = logits.argmax(-1).item()
# print(model.config.id2label[predicted_label]),

# %% [markdown]
# ## 学習データの可視化

# %%
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# 食品と飲料をランダムに5個ずつ可視化する
df_train = pd.read_csv('train.csv')
df_train['num'] = df_train['image_name'].str[:-4].astype(int)

d_vis = df_train[df_train['label']==0].sample(5)['num'].tolist()
f_vis = df_train[df_train['label']==1].sample(5)['num'].tolist()

# %%
# データの偏り
print(f"N of drinks: {len(df_train[df_train['label']==0])}")
print(f"N of foods: {len(df_train[df_train['label']==1])}")
# Out:
# N of drinks: 994
# N of foods: 1182

# %%
def show5img(ilist, stitle=None):
    n_cols = 5
    n_rows = (len(ilist)-1)//5+1
    
    fig = plt.figure(figsize=(n_cols*2, n_rows*2))
    for n, i in enumerate(ilist):
        ax = fig.add_subplot(n_rows, n_cols, n+1)
        im = load_img(i)
        im = np.asarray(im)
        ax.imshow(im)
        ax.axes.xaxis.set_visible(False)
        ax.axes.yaxis.set_visible(False)
        ax.set_title(i)
    if stitle:
        fig.suptitle(stitle)
    fig.tight_layout()
    fig.show()

# %%
show5img(d_vis, stitle='drink')
show5img(f_vis, stitle='food')

# %% [markdown]
# ## 転移学習/CV検証

# %%
import torch.nn as nn
from torchvision import transforms

from sklearn.model_selection import StratifiedKFold

# %%
device = torch.device('cuda')

# %% [markdown]
# データセット作成

# %%
# folding
n_folds = 5

skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=0)
df_train['fold'] = -1
for i, (_, val_idx) in enumerate(skf.split(df_train, df_train['label'])):
    df_train.loc[val_idx, 'fold'] = i

# %%
# label smoothing
df_train['label'] = df_train['label'].replace({0: 0.05, 1: 0.95})

# %%
df_train
# Out:
#      image_name  label   num  fold
# 0      0000.png   0.05     0     4
# 1      0001.png   0.95     1     2
# 2      0002.png   0.95     2     3
# 3      0003.png   0.95     3     0
# 4      0004.png   0.05     4     3
# ...         ...    ...   ...   ...
# 2171   2171.png   0.95  2171     3
# 2172   2172.png   0.95  2172     2
# 2173   2173.png   0.95  2173     3
# 2174   2174.png   0.05  2174     2
# 2175   2175.png   0.05  2175     3
#
# [2176 rows x 4 columns]

# %%
# テストデータ
df_test = pd.read_csv('sample_submit.csv', header=None)
df_test.columns = ['image_name', 'label']
df_test['num'] = df_test['image_name'].str[:-4].astype(int)
df_test['label'] = -1

# %%
df_test
# Out:
#      image_name  label   num
# 0      2176.png     -1  2176
# 1      2177.png     -1  2177
# 2      2178.png     -1  2178
# 3      2179.png     -1  2179
# 4      2180.png     -1  2180
# ...         ...    ...   ...
# 2175   4351.png     -1  4351
# 2176   4352.png     -1  4352
# 2177   4353.png     -1  4353
# 2178   4354.png     -1  4354
# 2179   4355.png     -1  4355
#
# [2180 rows x 3 columns]

# %%
train_transforms_1 = transforms.Compose([
    transforms.RandomChoice([
        transforms.RandomCrop(256),
        transforms.RandomCrop(384),
        transforms.RandomCrop(512),
    ]),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.RandomApply(
        [transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5)],
        p=0.67,
    ),
    transforms.RandomApply(
        [transforms.GaussianBlur(3, sigma=(0.1, 2.0))],
        p=0.67,
    ),
    transforms.Resize((512, 512)),
    transforms.RandomApply(
        [transforms.RandomRotation(180)],
        p=0.5,
    ),
    transforms.ToTensor(),
    transforms.RandomErasing(p=0.33, scale=(0.02, 0.3)),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])

train_transforms_2 = transforms.Compose([
    transforms.AugMix(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])


tta_transforms_1 = transforms.Compose([
    transforms.RandomChoice([
        transforms.RandomCrop(448),
        transforms.RandomCrop(512),
    ]),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.RandomApply(
        [transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5)],
        p=0.67,
    ),
    transforms.RandomApply(
        [transforms.GaussianBlur(3, sigma=(0.1, 2.0))],
        p=0.67,
    ),
    transforms.Resize((512, 512)),
    # transforms.RandomApply(
    #     [transforms.RandomRotation(180)],
    #     p=0.5,
    # ),
    transforms.ToTensor(),
    # transforms.RandomErasing(p=0.33, scale=(0.02, 0.1)),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])

tta_transforms_2 = transforms.Compose([
    transforms.AugMix(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])


data_transforms = {
    'train': transforms.RandomChoice([
        train_transforms_1, train_transforms_2
    ], p=[0.4, 0.6]),
    'valid': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
    'tta': transforms.RandomChoice([
        tta_transforms_1, tta_transforms_2
    ], p=[0.5, 0.5])
}

# %%
# 例
def showTimg(n, phase='train'):
    image = load_img(0)
    image_t = data_transforms[phase](image)
    
    img1 = np.asarray(image)
    img2 = image_t.numpy().transpose((2,1,0))
    
    fig = plt.figure(figsize=(2*2, 1*2))
    ax1 = fig.add_subplot(1, 2, 1)
    ax1.imshow(img1)
    ax1.axes.xaxis.set_visible(False)
    ax1.axes.yaxis.set_visible(False)
    ax1.set_title(f'Raw_{n}')
    
    ax2 = fig.add_subplot(1, 2, 2)
    ax2.imshow(img2)
    ax2.axes.xaxis.set_visible(False)
    ax2.axes.yaxis.set_visible(False)
    ax2.set_title(f'Transformed_{n}')

# %%
showTimg(0, phase='train')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
showTimg(0, phase='valid')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
showTimg(0, phase='tta')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, df, transform, tt='train'):
        if tt == 'train':
            self.dir = 'train/'
        elif tt == 'test':
            self.dir = 'test/'
        
        self.df = df
        self.transform = transform
        self.labels = np.expand_dims(df['label'].values, 1)
        self.labels = self.labels.astype(float)

    # len()を使用すると呼ばれる
    def __len__(self):
        return len(self.labels)

    # 要素を参照すると呼ばれる関数    
    def __getitem__(self, idx):
        num = self.df['num'].values[idx]
        image = load_img(num)
        image = self.transform(image)
        return image, self.labels[idx]

# %%
def foldData(fold, bs=32):
    df_train_ = df_train[df_train['fold']!=fold]
    df_valid_ = df_train[df_train['fold']==fold]
    df_test_ = df_test
    
    image_datasets = {
        'train': MyDataset(df_train_, data_transforms['train'], tt='train'),
        'valid': MyDataset(df_valid_, data_transforms['valid'], tt='train'),
        'vta': MyDataset(df_valid_, data_transforms['tta'], tt='train'),
        'test': MyDataset(df_test_, data_transforms['valid'], tt='test'),
        'tta': MyDataset(df_test_, data_transforms['tta'], tt='test'),
    }
    
    dataloaders = {
        'train': torch.utils.data.DataLoader(image_datasets['train'],
                                             batch_size=bs, shuffle=True, num_workers=16, pin_memory=True),
        'valid': torch.utils.data.DataLoader(image_datasets['valid'],
                                             batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
        'vta': torch.utils.data.DataLoader(image_datasets['vta'],
                                           batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
        'test': torch.utils.data.DataLoader(image_datasets['test'],
                                            batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
        'tta': torch.utils.data.DataLoader(image_datasets['tta'],
                                           batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
    }
    
#     return train_idx, valid_idx, image_datasets, dataloaders
    return image_datasets, dataloaders

# %% [markdown]
# モデル構築

# %%
from torcheval.metrics import BinaryAUROC
import torch.optim as optim
from torcheval.metrics.functional import binary_auroc

# %% [raw]
# model.classifier = nn.Linear(2816, 1, bias=True)

# %% [raw]
# # multi gpu
# model = torch.nn.DataParallel(model, device_ids=[0, 1, 2, 3]) # make parallel

# %% [raw]
# model.to(device)

# %% [raw]
# ### 重み固定 ###
# for p in model.parameters():
#     p.requires_grad = False

# %%
def loadNewModel():
    m = ConvNextV2ForImageClassification.from_pretrained("facebook/convnextv2-huge-22k-512")
    m.classifier = nn.Linear(2816, 1, bias=True)
    m = torch.nn.DataParallel(m, device_ids=[0, 1, 2, 3]) # make parallel
    m.to(device)
    for p in m.parameters():
        p.requires_grad = False
    return m

# %% [markdown]
# 学習

# %%
import copy, time
import torchvision
torchvision.disable_beta_transforms_warning()
from torchvision.transforms import v2

# %%
scaler = torch.cuda.amp.GradScaler()

# %% [raw]
# cutmix = v2.CutMix(num_classes=1)
# mixup = v2.MixUp(num_classes=1)
# cutmix_or_mixup = v2.RandomChoice([cutmix, mixup])

# %% [raw]
# -> one-hotじゃないと適用できないので今回は適用しない

# %%
def train(model, criterion, optimizer, scheduler, image_datasets, dataloaders, epochs=5):
    since = time.time()
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_auc = 0.0
    
    for epoch in range(epochs):
        print(f'Epoch {epoch}/{epochs-1}')
        print('-' * 10)
        
        for phase in ('train', 'valid'):
            if phase == 'train':
                is_train = True
                model.train()  # Set model to training mode
            else:
                is_train = False
                model.eval()   # Set model to evaluate mode
            
            running_loss = 0.0
            running_auc = 0.0
            
            # イタレーション
            for b, (inputs, labels) in enumerate(dataloaders[phase]):
                print(f'\rBatch: {b}/{len(image_datasets[phase])//dataloaders[phase].batch_size} ({phase})', end="")
                # images, labels = cutmix_or_mixup(images, labels)
                inputs = inputs.to(device)
                labels = labels.to(device)
                
                optimizer.zero_grad()
                
                with torch.set_grad_enabled(is_train):
                    with torch.cuda.amp.autocast(): 
                        outputs = model(inputs).logits
                        # loss = criterion(torch.flatten(outputs), torch.flatten(labels))
                        loss = criterion(outputs, labels)
                    auc = binary_auroc(torch.flatten(torch.sigmoid(outputs)),
                                       torch.flatten(labels))

                    # backward + optimize only if in training phase
                    if is_train:
                        scaler.scale(loss).backward()
                        scaler.step(optimizer)
                        scaler.update() 

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_auc +=  auc * inputs.size(0)
                
                del loss, auc, labels, inputs, outputs
            
            epoch_loss = running_loss / len(image_datasets[phase])
            epoch_auc = running_auc / len(image_datasets[phase])
            
            print()
            print(f'{phase} Loss: {epoch_loss:.4f} AUC: {epoch_auc:.4f}')
            
            # deep copy the model
            if phase == 'valid' and epoch_auc > best_auc:
                best_auc = epoch_auc
                best_model_wts = copy.deepcopy(model.state_dict())
            del epoch_loss, epoch_auc, running_loss, running_auc
            torch.cuda.empty_cache()
            
        scheduler.step()
        print()
        
    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val AUC: {best_auc:.4f}')
    print()

    # load best model weights
    model.load_state_dict(best_model_wts)
    del best_model_wts
    return model

# %% [markdown]
# - 通常の代入とTTAで比較

# %%
def valid(model, dataloader):
    noutputs = []
    nlabels = []
    for b, (inputs, labels) in enumerate(dataloader):
        print(f'\rBatch: {b}/{len(dataloader.dataset)//dataloader.batch_size}', end="")
        inputs = inputs.to(device)
        labels = labels.to(device)
        with torch.no_grad():
            noutputs.append(model(inputs).logits)
            nlabels.append(labels)
        del inputs, labels
    alloutputs = torch.cat(noutputs)
    alllabels = torch.cat(nlabels)
    
    preds = torch.sigmoid(torch.flatten(alloutputs))
    auc = binary_auroc(preds, torch.flatten(alllabels))
    print()
    print()
    print(f'AUC: {auc:.4f}')
    
    return preds.cpu().detach().numpy()

# %%
def tta(model, dataloader, n=5):
    alloutputs = []
    
    for i in range(n):
        print(f'n: {i}/{n-1}')
        print('-' * 10)
        noutputs = []
        nlabels = []
        for b, (inputs, labels) in enumerate(dataloader):
            print(f'\rBatch: {b}/{len(dataloader.dataset)//dataloader.batch_size}', end="")
            inputs = inputs.to(device)
            labels = labels.to(device)
            with torch.no_grad():
                noutputs.append(model(inputs).logits)
                nlabels.append(labels)
            del inputs, labels
        alloutputs.append(torch.cat(noutputs))
        alllabels = torch.cat(nlabels)
        print()
    alloutputs = torch.cat(alloutputs, 1)
    preds = torch.sigmoid(torch.mean(alloutputs, dim=1))
    auc = binary_auroc(preds, torch.flatten(alllabels))
    print()
    print(f'AUC: {auc:.4f}')
    
    return preds.cpu().detach().numpy()

# %%
def valMix(model, dataloaders, n=5, mode='valid'):
    # 通常valid
    print(f"=== Normal {'Valid' if mode=='valid' else 'Test'} ===")
    if mode =='valid':
        dataloader = dataloaders['valid']
    elif mode == 'test':
        dataloader = dataloaders['test']
    noutputs = []
    nlabels = []
    for b, (imgs, labels) in enumerate(dataloader):
        print(f'\rBatch: {b}/{len(dataloader.dataset)//dataloader.batch_size}', end="")
        inputs = imgs.to(device)
        labels = labels.to(device)
        with torch.no_grad():
            noutputs.append(model(inputs).logits)
            nlabels.append(labels)
    alloutputs = torch.cat(noutputs)
    alllabels = torch.cat(nlabels)
    
    preds1 = torch.sigmoid(torch.flatten(alloutputs))
    auc = binary_auroc(preds1, torch.flatten(alllabels))
    print()
    print()
    print(f'Norml Valid AUC: {auc:.4f}')
    print()
    
    # TTA valid
    print(f"=== {'Valid' if mode=='valid' else 'Test'} Time Augmentation ===")
    if mode =='valid':
        dataloader = dataloaders['vta']
    elif mode == 'test':
        dataloader = dataloaders['tta']
    alloutputs = [alloutputs]
    
    for i in range(n):
        print(f'n: {i}/{n-1}')
        print('-' * 10)
        noutputs = []
        for b, (imgs, labels) in enumerate(dataloader):
            print(f'\rBatch: {b}/{len(dataloader.dataset)//dataloader.batch_size}', end="")
            inputs = imgs.to(device)
            with torch.no_grad():
                noutputs.append(model(inputs).logits)
        alloutputs.append(torch.cat(noutputs))
        print()
    alloutputs = torch.cat(alloutputs, 1)
    preds2 = torch.sigmoid(torch.mean(alloutputs, dim=1))
    auc = binary_auroc(preds2, torch.flatten(alllabels))
    print()
    print(f'VTA AUC: {auc:.4f}')
    print()
    
    # Mix
    print('=== Mixed Valid ===')
    preds1to0 = preds1 - 0
    preds1to1 = 1 - preds1
    preds2to0 = preds2 - 0
    preds2to1 = 1 - preds2
    
    stack = torch.stack([preds1to0, preds1to1, preds2to0, preds2to1])
    pstack = torch.stack([preds1, preds1, preds2, preds2])
    
    argmin = torch.argmin(stack, dim=0)
    preds = torch.diag(pstack[argmin])
    auc = binary_auroc(preds, torch.flatten(alllabels))
    print()
    print(f'Mixed AUC: {auc:.4f}')
    return preds1.cpu().detach().numpy(), preds2.cpu().detach().numpy(), preds.cpu().detach().numpy()

# %% [markdown]
# ### CV

# %%
from numba import cuda

# %%
### 検証時のAugmentation
n_vta = 5

# %%
### パラメータ変更可能な部分 ###
"""
  model.module.convnextv2.embeddings

  model.module.convnextv2.encoder.stages[0]
  -> model.module.convnextv2.encoder.stages[0].layers[0] ~ [2]

  model.module.convnextv2.encoder.stages[1]
  -> model.module.convnextv2.encoder.stages[1].layers[0] ~ [2]

  model.module.convnextv2.encoder.stages[2]
  -> model.module.convnextv2.encoder.stages[2].layers[0] ~ [26]

  model.module.convnextv2.encoder.stages[3]
  -> model.module.convnextv2.encoder.stages[3].layers[0] ~ [2]

  model.module.convnextv2.layernorm

  model.module.classifier
"""
# Out:
# '\n  model.module.convnextv2.embeddings\n\n  model.module.convnextv2.encoder.stages[0]\n  -> model.module.convnextv2.encoder.stages[0].layers[0] ~ [2]\n\n  model.module.convnextv2.encoder.stages[1]\n  -> model.module.convnextv2.encoder.stages[1].layers[0] ~ [2]\n\n  model.module.convnextv2.encoder.stages[2]\n  -> model.module.convnextv2.encoder.stages[2].layers[0] ~ [26]\n\n  model.module.convnextv2.encoder.stages[3]\n  -> model.module.convnextv2.encoder.stages[3].layers[0] ~ [2]\n\n  model.module.convnextv2.layernorm\n\n  model.module.classifier\n'

# %%
specs = [
    {
        'bs': 32,
        'trainLayers': 1,
        'lr': 1e-3,
        'epochs': 15,
        'num_warmup_steps': 5,  # CosSchWarm
        'num_training_steps': 20,  # CosSchWarm
        'num_cycles': 0.5,  # CosSchWarm
    },
    {
        'bs': 32,
        'trainLayers': 2,
        'lr': 1e-3,
        'epochs': 15,
        'num_warmup_steps': 5,  # CosSchWarm
        'num_training_steps': 20,  # CosSchWarm
        'num_cycles': 0.5,  # CosSchWarm
    },
    {
        'bs': 32,
        'trainLayers': 3,
        'lr': 5e-4,
        'epochs': 30,
        'num_warmup_steps': 5,  # CosSchWarm
        'num_training_steps': 35,  # CosSchWarm
        'num_cycles': 1.5,  # CosSchWarm
    },
    {
        'bs': 24,
        'trainLayers': 6,
        'lr': 1e-4,
        'epochs': 100,
        'num_warmup_steps': 10,  # CosSchWarm
        'num_training_steps': 105,  # CosSchWarm
        'num_cycles': 4.5,  # CosSchWarm
    },
]

# %%
vals = {}
vtas = {}
mixs = {}

# %%
torch.backends.cudnn.benchmark = True

# %%
def train_spec(fold, i, model_path='model.pth'):
    spec = specs[i]
    
    # datasetsを作る
    image_datasets, dataloaders = foldData(fold, bs=spec['bs'])
    
    # 新しいモデルを読み込み
    if i == 0:
        model = loadNewModel()
    else:
        model = torch.load(model_path)
        model.to(device)
        for p in model.parameters():
            p.requires_grad = False
    
    layer_list = [
        model.module.classifier,
        model.module.convnextv2.layernorm,
        model.module.convnextv2.encoder.stages[3],
        model.module.convnextv2.encoder.stages[2].layers[26],
        model.module.convnextv2.encoder.stages[2].layers[25],
        model.module.convnextv2.encoder.stages[2].layers[24],
        model.module.convnextv2.encoder.stages[2].layers[22],
        model.module.convnextv2.encoder.stages[2].layers[21],
    ]
    
    for j in range(spec['trainLayers']):
        layer = layer_list[j]
        for p in layer.parameters():
            p.requires_grad = True
    
    criterion = nn.BCEWithLogitsLoss(pos_weight=None)
    if False:
    # if i < len(specs)-2:
        optimizer = optim.SGD(model.parameters(), lr=spec['lr'], momentum=0.9)
        lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=spec['sch_steps'], gamma=spec['sch_gamma'])
    else:
        optimizer = optim.AdamW(model.parameters(), lr=spec['lr'])
        lr_scheduler = get_cosine_schedule_with_warmup(optimizer,
                                                       num_warmup_steps=spec['num_warmup_steps'],
                                                       num_training_steps=spec['num_training_steps'],
                                                       num_cycles=spec['num_cycles'])
    
    model = train(model, criterion, optimizer, lr_scheduler, image_datasets, dataloaders,
                  epochs=spec['epochs'])
    
    torch.save(model, model_path)
    del model
    torch.cuda.empty_cache()

# %%
def fold_train(fold):
    print(f'=== Fold: {fold} ===')
    print('GPU Memory:', torch.cuda.memory_allocated())
    
    for i in range(len(specs)):
        print(f'<< Spec: {i} >>')
        train_spec(fold, i)
    
    print('- Validation -')
    model = torch.load('model.pth')
    model.to(device)
    
    image_datasets, dataloaders = foldData(fold)
    
    val, vta, mix = valMix(model, dataloaders, n=n_vta)
    vals[fold] = val
    vtas[fold] = vta
    mixs[fold] = mix
    
    print()
    
    torch.save(model, f'model_{fold}.pth')
    
    del model
    torch.cuda.empty_cache()

# %% [raw]
# for fold in range(n_folds):
#     fold_train(fold)

# %%
# %%capture cap

for fold in range(n_folds):
    fold_train(fold)

with open('log_train.txt', 'w') as f:
    f.write(cap.stdout)

# %%
cap()
# Out:
# === Fold: 0 ===
# GPU Memory: 0
# << Spec: 0 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.7070 AUC: 0.4903
# Batch: 13/13 (valid)
# valid Loss: 0.7203 AUC: 0.4600
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.6091 AUC: 0.7188
# Batch: 13/13 (valid)
# valid Loss: 0.5429 AUC: 0.8007
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5437 AUC: 0.7952
# Batch: 13/13 (valid)
# valid Loss: 0.5097 AUC: 0.8250
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5182 AUC: 0.8216
# Batch: 13/13 (valid)
# valid Loss: 0.4886 AUC: 0.8393
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4881 AUC: 0.8443
# Batch: 13/13 (valid)
# valid Loss: 0.4768 AUC: 0.8477
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4762 AUC: 0.8568
# Batch: 13/13 (valid)
# valid Loss: 0.4588 AUC: 0.8605
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4653 AUC: 0.8627
# Batch: 13/13 (valid)
# valid Loss: 0.4554 AUC: 0.8661
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4517 AUC: 0.8695
# Batch: 13/13 (valid)
# valid Loss: 0.4433 AUC: 0.8686
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4390 AUC: 0.8766
# Batch: 13/13 (valid)
# valid Loss: 0.4353 AUC: 0.8747
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4252 AUC: 0.8852
# Batch: 13/13 (valid)
# valid Loss: 0.4407 AUC: 0.8704
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4266 AUC: 0.8896
# Batch: 13/13 (valid)
# valid Loss: 0.4448 AUC: 0.8738
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4157 AUC: 0.8920
# Batch: 13/13 (valid)
# valid Loss: 0.4394 AUC: 0.8697
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4149 AUC: 0.8920
# Batch: 13/13 (valid)
# valid Loss: 0.4381 AUC: 0.8760
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4057 AUC: 0.8960
# Batch: 13/13 (valid)
# valid Loss: 0.4396 AUC: 0.8734
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3991 AUC: 0.9007
# Batch: 13/13 (valid)
# valid Loss: 0.4332 AUC: 0.8740
#
# Training complete in 55m 15s
# Best val AUC: 0.8760
#
# << Spec: 1 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4137 AUC: 0.8908
# Batch: 13/13 (valid)
# valid Loss: 0.4381 AUC: 0.8760
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4116 AUC: 0.8914
# Batch: 13/13 (valid)
# valid Loss: 0.4315 AUC: 0.8780
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4021 AUC: 0.8977
# Batch: 13/13 (valid)
# valid Loss: 0.4293 AUC: 0.8759
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4151 AUC: 0.8900
# Batch: 13/13 (valid)
# valid Loss: 0.4344 AUC: 0.8747
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4032 AUC: 0.8994
# Batch: 13/13 (valid)
# valid Loss: 0.4354 AUC: 0.8714
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4091 AUC: 0.8963
# Batch: 13/13 (valid)
# valid Loss: 0.4539 AUC: 0.8723
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4123 AUC: 0.8958
# Batch: 13/13 (valid)
# valid Loss: 0.4231 AUC: 0.8883
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4225 AUC: 0.8881
# Batch: 13/13 (valid)
# valid Loss: 0.4252 AUC: 0.8820
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4005 AUC: 0.8995
# Batch: 13/13 (valid)
# valid Loss: 0.4306 AUC: 0.8790
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4002 AUC: 0.9027
# Batch: 13/13 (valid)
# valid Loss: 0.4353 AUC: 0.8787
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3881 AUC: 0.9034
# Batch: 13/13 (valid)
# valid Loss: 0.4285 AUC: 0.8821
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3869 AUC: 0.9044
# Batch: 13/13 (valid)
# valid Loss: 0.4377 AUC: 0.8818
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3843 AUC: 0.9101
# Batch: 13/13 (valid)
# valid Loss: 0.4213 AUC: 0.8837
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3870 AUC: 0.9051
# Batch: 13/13 (valid)
# valid Loss: 0.4239 AUC: 0.8822
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3889 AUC: 0.9041
# Batch: 13/13 (valid)
# valid Loss: 0.4211 AUC: 0.8865
#
# Training complete in 55m 0s
# Best val AUC: 0.8883
#
# << Spec: 2 >>
# Epoch 0/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3920 AUC: 0.9056
# Batch: 13/13 (valid)
# valid Loss: 0.4231 AUC: 0.8883
#
# Epoch 1/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4454 AUC: 0.8882
# Batch: 13/13 (valid)
# valid Loss: 0.4340 AUC: 0.8853
#
# Epoch 2/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4187 AUC: 0.9002
# Batch: 13/13 (valid)
# valid Loss: 0.4215 AUC: 0.8975
#
# Epoch 3/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3889 AUC: 0.9181
# Batch: 13/13 (valid)
# valid Loss: 0.3718 AUC: 0.9117
#
# Epoch 4/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3578 AUC: 0.9240
# Batch: 13/13 (valid)
# valid Loss: 0.3746 AUC: 0.9148
#
# Epoch 5/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3346 AUC: 0.9286
# Batch: 13/13 (valid)
# valid Loss: 0.3694 AUC: 0.9137
#
# Epoch 6/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3190 AUC: 0.9304
# Batch: 13/13 (valid)
# valid Loss: 0.3376 AUC: 0.9222
#
# Epoch 7/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3009 AUC: 0.9358
# Batch: 13/13 (valid)
# valid Loss: 0.3243 AUC: 0.9226
#
# Epoch 8/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2924 AUC: 0.9358
# Batch: 13/13 (valid)
# valid Loss: 0.3278 AUC: 0.9253
#
# Epoch 9/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2809 AUC: 0.9379
# Batch: 13/13 (valid)
# valid Loss: 0.3287 AUC: 0.9284
#
# Epoch 10/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2711 AUC: 0.9404
# Batch: 13/13 (valid)
# valid Loss: 0.3259 AUC: 0.9261
#
# Epoch 11/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2608 AUC: 0.9410
# Batch: 13/13 (valid)
# valid Loss: 0.3210 AUC: 0.9251
#
# Epoch 12/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2432 AUC: 0.9456
# Batch: 13/13 (valid)
# valid Loss: 0.3192 AUC: 0.9243
#
# Epoch 13/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2503 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.3092 AUC: 0.9273
#
# Epoch 14/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2528 AUC: 0.9414
# Batch: 13/13 (valid)
# valid Loss: 0.3093 AUC: 0.9273
#
# Epoch 15/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2489 AUC: 0.9443
# Batch: 13/13 (valid)
# valid Loss: 0.3093 AUC: 0.9273
#
# Epoch 16/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2510 AUC: 0.9428
# Batch: 13/13 (valid)
# valid Loss: 0.3081 AUC: 0.9276
#
# Epoch 17/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2410 AUC: 0.9440
# Batch: 13/13 (valid)
# valid Loss: 0.3080 AUC: 0.9261
#
# Epoch 18/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2434 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.2871 AUC: 0.9341
#
# Epoch 19/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2523 AUC: 0.9432
# Batch: 13/13 (valid)
# valid Loss: 0.3060 AUC: 0.9246
#
# Epoch 20/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2642 AUC: 0.9407
# Batch: 13/13 (valid)
# valid Loss: 0.3155 AUC: 0.9264
#
# Epoch 21/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2591 AUC: 0.9422
# Batch: 13/13 (valid)
# valid Loss: 0.3538 AUC: 0.9150
#
# Epoch 22/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2906 AUC: 0.9379
# Batch: 13/13 (valid)
# valid Loss: 0.3771 AUC: 0.9093
#
# Epoch 23/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2884 AUC: 0.9378
# Batch: 13/13 (valid)
# valid Loss: 0.3671 AUC: 0.9132
#
# Epoch 24/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2925 AUC: 0.9368
# Batch: 13/13 (valid)
# valid Loss: 0.4071 AUC: 0.9217
#
# Epoch 25/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3031 AUC: 0.9363
# Batch: 13/13 (valid)
# valid Loss: 0.3652 AUC: 0.9113
#
# Epoch 26/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2847 AUC: 0.9396
# Batch: 13/13 (valid)
# valid Loss: 0.3584 AUC: 0.9203
#
# Epoch 27/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2817 AUC: 0.9343
# Batch: 13/13 (valid)
# valid Loss: 0.3611 AUC: 0.9074
#
# Epoch 28/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2767 AUC: 0.9369
# Batch: 13/13 (valid)
# valid Loss: 0.3650 AUC: 0.9111
#
# Epoch 29/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2697 AUC: 0.9397
# Batch: 13/13 (valid)
# valid Loss: 0.3443 AUC: 0.9166
#
# Training complete in 119m 23s
# Best val AUC: 0.9341
#
# << Spec: 3 >>
# Epoch 0/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2545 AUC: 0.9392
# Batch: 13/13 (valid)
# valid Loss: 0.2871 AUC: 0.9341
#
# Epoch 1/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2500 AUC: 0.9420
# Batch: 13/13 (valid)
# valid Loss: 0.2886 AUC: 0.9328
#
# Epoch 2/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2487 AUC: 0.9422
# Batch: 13/13 (valid)
# valid Loss: 0.2945 AUC: 0.9331
#
# Epoch 3/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2458 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3046 AUC: 0.9306
#
# Epoch 4/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2451 AUC: 0.9401
# Batch: 13/13 (valid)
# valid Loss: 0.2971 AUC: 0.9328
#
# Epoch 5/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2392 AUC: 0.9423
# Batch: 13/13 (valid)
# valid Loss: 0.3155 AUC: 0.9250
#
# Epoch 6/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2379 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.3358 AUC: 0.9206
#
# Epoch 7/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2561 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.3224 AUC: 0.9276
#
# Epoch 8/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2521 AUC: 0.9423
# Batch: 13/13 (valid)
# valid Loss: 0.3268 AUC: 0.9279
#
# Epoch 9/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2437 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.3259 AUC: 0.9218
#
# Epoch 10/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2509 AUC: 0.9385
# Batch: 13/13 (valid)
# valid Loss: 0.2968 AUC: 0.9351
#
# Epoch 11/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2534 AUC: 0.9393
# Batch: 13/13 (valid)
# valid Loss: 0.3210 AUC: 0.9281
#
# Epoch 12/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2606 AUC: 0.9415
# Batch: 13/13 (valid)
# valid Loss: 0.2886 AUC: 0.9330
#
# Epoch 13/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2546 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.3229 AUC: 0.9270
#
# Epoch 14/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2425 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.2952 AUC: 0.9311
#
# Epoch 15/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2444 AUC: 0.9423
# Batch: 13/13 (valid)
# valid Loss: 0.3055 AUC: 0.9282
#
# Epoch 16/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2347 AUC: 0.9452
# Batch: 13/13 (valid)
# valid Loss: 0.3040 AUC: 0.9294
#
# Epoch 17/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2327 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.2953 AUC: 0.9301
#
# Epoch 18/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2339 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.2889 AUC: 0.9342
#
# Epoch 19/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2275 AUC: 0.9436
# Batch: 13/13 (valid)
# valid Loss: 0.2891 AUC: 0.9337
#
# Epoch 20/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2275 AUC: 0.9448
# Batch: 13/13 (valid)
# valid Loss: 0.2886 AUC: 0.9337
#
# Epoch 21/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2415 AUC: 0.9419
# Batch: 13/13 (valid)
# valid Loss: 0.2886 AUC: 0.9337
#
# Epoch 22/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2328 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.2900 AUC: 0.9313
#
# Epoch 23/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2319 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.2868 AUC: 0.9325
#
# Epoch 24/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2321 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.2846 AUC: 0.9282
#
# Epoch 25/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2322 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.2884 AUC: 0.9303
#
# Epoch 26/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2411 AUC: 0.9418
# Batch: 13/13 (valid)
# valid Loss: 0.2751 AUC: 0.9354
#
# Epoch 27/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2344 AUC: 0.9436
# Batch: 13/13 (valid)
# valid Loss: 0.2872 AUC: 0.9350
#
# Epoch 28/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2290 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.2882 AUC: 0.9378
#
# Epoch 29/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2400 AUC: 0.9429
# Batch: 13/13 (valid)
# valid Loss: 0.2776 AUC: 0.9337
#
# Epoch 30/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2464 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3095 AUC: 0.9251
#
# Epoch 31/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2399 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.2960 AUC: 0.9258
#
# Epoch 32/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2387 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.3227 AUC: 0.9286
#
# Epoch 33/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2421 AUC: 0.9405
# Batch: 13/13 (valid)
# valid Loss: 0.2919 AUC: 0.9356
#
# Epoch 34/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2431 AUC: 0.9418
# Batch: 13/13 (valid)
# valid Loss: 0.2799 AUC: 0.9343
#
# Epoch 35/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2399 AUC: 0.9441
# Batch: 13/13 (valid)
# valid Loss: 0.3035 AUC: 0.9318
#
# Epoch 36/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2316 AUC: 0.9441
# Batch: 13/13 (valid)
# valid Loss: 0.2883 AUC: 0.9330
#
# Epoch 37/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2304 AUC: 0.9449
# Batch: 13/13 (valid)
# valid Loss: 0.2899 AUC: 0.9317
#
# Epoch 38/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2209 AUC: 0.9432
# Batch: 13/13 (valid)
# valid Loss: 0.2904 AUC: 0.9314
#
# Epoch 39/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2268 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.2883 AUC: 0.9336
#
# Epoch 40/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2319 AUC: 0.9420
# Batch: 13/13 (valid)
# valid Loss: 0.2847 AUC: 0.9336
#
# Epoch 41/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2247 AUC: 0.9454
# Batch: 13/13 (valid)
# valid Loss: 0.2844 AUC: 0.9336
#
# Epoch 42/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2226 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.2845 AUC: 0.9336
#
# Epoch 43/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2287 AUC: 0.9453
# Batch: 13/13 (valid)
# valid Loss: 0.2839 AUC: 0.9351
#
# Epoch 44/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2230 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.2810 AUC: 0.9338
#
# Epoch 45/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2379 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.2801 AUC: 0.9348
#
# Epoch 46/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2250 AUC: 0.9455
# Batch: 13/13 (valid)
# valid Loss: 0.2792 AUC: 0.9306
#
# Epoch 47/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2283 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.2887 AUC: 0.9307
#
# Epoch 48/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2255 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.2852 AUC: 0.9353
#
# Epoch 49/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2359 AUC: 0.9432
# Batch: 13/13 (valid)
# valid Loss: 0.2747 AUC: 0.9387
#
# Epoch 50/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2237 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.3115 AUC: 0.9281
#
# Epoch 51/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2401 AUC: 0.9432
# Batch: 13/13 (valid)
# valid Loss: 0.2920 AUC: 0.9286
#
# Epoch 52/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2351 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.2920 AUC: 0.9324
#
# Epoch 53/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2344 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.2991 AUC: 0.9273
#
# Epoch 54/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2370 AUC: 0.9424
# Batch: 13/13 (valid)
# valid Loss: 0.2996 AUC: 0.9345
#
# Epoch 55/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2275 AUC: 0.9428
# Batch: 13/13 (valid)
# valid Loss: 0.2894 AUC: 0.9294
#
# Epoch 56/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2370 AUC: 0.9436
# Batch: 13/13 (valid)
# valid Loss: 0.2765 AUC: 0.9349
#
# Epoch 57/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2337 AUC: 0.9442
# Batch: 13/13 (valid)
# valid Loss: 0.2775 AUC: 0.9364
#
# Epoch 58/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2305 AUC: 0.9452
# Batch: 13/13 (valid)
# valid Loss: 0.2708 AUC: 0.9362
#
# Epoch 59/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2232 AUC: 0.9455
# Batch: 13/13 (valid)
# valid Loss: 0.2687 AUC: 0.9360
#
# Epoch 60/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2300 AUC: 0.9440
# Batch: 13/13 (valid)
# valid Loss: 0.2681 AUC: 0.9358
#
# Epoch 61/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2235 AUC: 0.9453
# Batch: 13/13 (valid)
# valid Loss: 0.2700 AUC: 0.9352
#
# Epoch 62/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2242 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.2697 AUC: 0.9353
#
# Epoch 63/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2199 AUC: 0.9449
# Batch: 13/13 (valid)
# valid Loss: 0.2697 AUC: 0.9353
#
# Epoch 64/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2190 AUC: 0.9441
# Batch: 13/13 (valid)
# valid Loss: 0.2697 AUC: 0.9353
#
# Epoch 65/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2283 AUC: 0.9436
# Batch: 13/13 (valid)
# valid Loss: 0.2675 AUC: 0.9362
#
# Epoch 66/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2221 AUC: 0.9440
# Batch: 13/13 (valid)
# valid Loss: 0.2711 AUC: 0.9355
#
# Epoch 67/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2152 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.2678 AUC: 0.9347
#
# Epoch 68/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2215 AUC: 0.9448
# Batch: 13/13 (valid)
# valid Loss: 0.2746 AUC: 0.9326
#
# Epoch 69/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2240 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.2830 AUC: 0.9335
#
# Epoch 70/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2314 AUC: 0.9443
# Batch: 13/13 (valid)
# valid Loss: 0.2933 AUC: 0.9343
#
# Epoch 71/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2352 AUC: 0.9428
# Batch: 13/13 (valid)
# valid Loss: 0.3030 AUC: 0.9312
#
# Epoch 72/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2311 AUC: 0.9447
# Batch: 13/13 (valid)
# valid Loss: 0.3073 AUC: 0.9317
#
# Epoch 73/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2290 AUC: 0.9448
# Batch: 13/13 (valid)
# valid Loss: 0.3360 AUC: 0.9321
#
# Epoch 74/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2382 AUC: 0.9428
# Batch: 13/13 (valid)
# valid Loss: 0.3175 AUC: 0.9252
#
# Epoch 75/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2311 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.3022 AUC: 0.9358
#
# Epoch 76/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2232 AUC: 0.9453
# Batch: 13/13 (valid)
# valid Loss: 0.2938 AUC: 0.9292
#
# Epoch 77/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2207 AUC: 0.9454
# Batch: 13/13 (valid)
# valid Loss: 0.3075 AUC: 0.9248
#
# Epoch 78/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2309 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.2963 AUC: 0.9300
#
# Epoch 79/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2261 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.3098 AUC: 0.9284
#
# Epoch 80/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2235 AUC: 0.9449
# Batch: 13/13 (valid)
# valid Loss: 0.2898 AUC: 0.9276
#
# Epoch 81/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2215 AUC: 0.9436
# Batch: 13/13 (valid)
# valid Loss: 0.2866 AUC: 0.9287
#
# Epoch 82/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2202 AUC: 0.9428
# Batch: 13/13 (valid)
# valid Loss: 0.2853 AUC: 0.9292
#
# Epoch 83/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2208 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.2854 AUC: 0.9291
#
# Epoch 84/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2194 AUC: 0.9431
# Batch: 13/13 (valid)
# valid Loss: 0.2854 AUC: 0.9291
#
# Epoch 85/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2215 AUC: 0.9436
# Batch: 13/13 (valid)
# valid Loss: 0.2848 AUC: 0.9289
#
# Epoch 86/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2178 AUC: 0.9448
# Batch: 13/13 (valid)
# valid Loss: 0.2883 AUC: 0.9280
#
# Epoch 87/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2245 AUC: 0.9443
# Batch: 13/13 (valid)
# valid Loss: 0.2905 AUC: 0.9278
#
# Epoch 88/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2150 AUC: 0.9460
# Batch: 13/13 (valid)
# valid Loss: 0.2923 AUC: 0.9294
#
# Epoch 89/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2169 AUC: 0.9454
# Batch: 13/13 (valid)
# valid Loss: 0.3002 AUC: 0.9288
#
# Epoch 90/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2330 AUC: 0.9440
# Batch: 13/13 (valid)
# valid Loss: 0.3029 AUC: 0.9322
#
# Epoch 91/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2287 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.3158 AUC: 0.9290
#
# Epoch 92/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2277 AUC: 0.9440
# Batch: 13/13 (valid)
# valid Loss: 0.3077 AUC: 0.9295
#
# Epoch 93/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2219 AUC: 0.9443
# Batch: 13/13 (valid)
# valid Loss: 0.3338 AUC: 0.9256
#
# Epoch 94/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2272 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.2966 AUC: 0.9309
#
# Epoch 95/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2338 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.3251 AUC: 0.9269
#
# Epoch 96/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2299 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.3135 AUC: 0.9311
#
# Epoch 97/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2299 AUC: 0.9423
# Batch: 13/13 (valid)
# valid Loss: 0.3171 AUC: 0.9286
#
# Epoch 98/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2197 AUC: 0.9455
# Batch: 13/13 (valid)
# valid Loss: 0.3199 AUC: 0.9279
#
# Epoch 99/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2284 AUC: 0.9449
# Batch: 13/13 (valid)
# valid Loss: 0.3059 AUC: 0.9330
#
# Training complete in 447m 43s
# Best val AUC: 0.9387
#
# - Validation -
# === Normal Valid ===
# Batch: 13/13
#
# Norml Valid AUC: 0.9430
#
# === Valid Time Augmentation ===
# n: 0/4
# ----------
# Batch: 13/13
# n: 1/4
# ----------
# Batch: 13/13
# n: 2/4
# ----------
# Batch: 13/13
# n: 3/4
# ----------
# Batch: 13/13
# n: 4/4
# ----------
# Batch: 13/13
#
# VTA AUC: 0.9424
#
# === Mixed Valid ===
#
# Mixed AUC: 0.9430
#
# === Fold: 1 ===
# GPU Memory: 17040384
# << Spec: 0 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.7149 AUC: 0.4861
# Batch: 13/13 (valid)
# valid Loss: 0.7272 AUC: 0.4424
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.6118 AUC: 0.7126
# Batch: 13/13 (valid)
# valid Loss: 0.5383 AUC: 0.8099
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5345 AUC: 0.8012
# Batch: 13/13 (valid)
# valid Loss: 0.5006 AUC: 0.8375
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5048 AUC: 0.8308
# Batch: 13/13 (valid)
# valid Loss: 0.4796 AUC: 0.8516
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4892 AUC: 0.8460
# Batch: 13/13 (valid)
# valid Loss: 0.4659 AUC: 0.8570
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4681 AUC: 0.8621
# Batch: 13/13 (valid)
# valid Loss: 0.4492 AUC: 0.8709
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4543 AUC: 0.8676
# Batch: 13/13 (valid)
# valid Loss: 0.4371 AUC: 0.8707
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4539 AUC: 0.8664
# Batch: 13/13 (valid)
# valid Loss: 0.4339 AUC: 0.8788
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4317 AUC: 0.8818
# Batch: 13/13 (valid)
# valid Loss: 0.4527 AUC: 0.8751
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4368 AUC: 0.8814
# Batch: 13/13 (valid)
# valid Loss: 0.4327 AUC: 0.8773
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4237 AUC: 0.8844
# Batch: 13/13 (valid)
# valid Loss: 0.4321 AUC: 0.8774
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4337 AUC: 0.8789
# Batch: 13/13 (valid)
# valid Loss: 0.4322 AUC: 0.8786
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4135 AUC: 0.8903
# Batch: 13/13 (valid)
# valid Loss: 0.4258 AUC: 0.8833
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4295 AUC: 0.8833
# Batch: 13/13 (valid)
# valid Loss: 0.4192 AUC: 0.8845
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4107 AUC: 0.8932
# Batch: 13/13 (valid)
# valid Loss: 0.4246 AUC: 0.8855
#
# Training complete in 57m 1s
# Best val AUC: 0.8855
#
# << Spec: 1 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4055 AUC: 0.8983
# Batch: 13/13 (valid)
# valid Loss: 0.4246 AUC: 0.8855
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4056 AUC: 0.8935
# Batch: 13/13 (valid)
# valid Loss: 0.4208 AUC: 0.8846
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3990 AUC: 0.9008
# Batch: 13/13 (valid)
# valid Loss: 0.4182 AUC: 0.8861
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4092 AUC: 0.8963
# Batch: 13/13 (valid)
# valid Loss: 0.4230 AUC: 0.8834
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4095 AUC: 0.8934
# Batch: 13/13 (valid)
# valid Loss: 0.4428 AUC: 0.8841
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4128 AUC: 0.8962
# Batch: 13/13 (valid)
# valid Loss: 0.4202 AUC: 0.8845
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4125 AUC: 0.8948
# Batch: 13/13 (valid)
# valid Loss: 0.4262 AUC: 0.8854
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4043 AUC: 0.8960
# Batch: 13/13 (valid)
# valid Loss: 0.4232 AUC: 0.8863
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3956 AUC: 0.9010
# Batch: 13/13 (valid)
# valid Loss: 0.4300 AUC: 0.8901
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4130 AUC: 0.8947
# Batch: 13/13 (valid)
# valid Loss: 0.4119 AUC: 0.8888
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3957 AUC: 0.9020
# Batch: 13/13 (valid)
# valid Loss: 0.4232 AUC: 0.8845
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3892 AUC: 0.9064
# Batch: 13/13 (valid)
# valid Loss: 0.4130 AUC: 0.8878
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3923 AUC: 0.9054
# Batch: 13/13 (valid)
# valid Loss: 0.4129 AUC: 0.8884
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3860 AUC: 0.9060
# Batch: 13/13 (valid)
# valid Loss: 0.4151 AUC: 0.8889
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3839 AUC: 0.9072
# Batch: 13/13 (valid)
# valid Loss: 0.4122 AUC: 0.8909
#
# Training complete in 57m 5s
# Best val AUC: 0.8909
#
# << Spec: 2 >>
# Epoch 0/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3811 AUC: 0.9095
# Batch: 13/13 (valid)
# valid Loss: 0.4122 AUC: 0.8909
#
# Epoch 1/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4622 AUC: 0.8781
# Batch: 13/13 (valid)
# valid Loss: 0.4188 AUC: 0.9006
#
# Epoch 2/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4375 AUC: 0.8893
# Batch: 13/13 (valid)
# valid Loss: 0.3997 AUC: 0.9089
#
# Epoch 3/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3670 AUC: 0.9179
# Batch: 13/13 (valid)
# valid Loss: 0.3594 AUC: 0.9195
#
# Epoch 4/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3306 AUC: 0.9306
# Batch: 13/13 (valid)
# valid Loss: 0.3690 AUC: 0.9154
#
# Epoch 5/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3464 AUC: 0.9287
# Batch: 13/13 (valid)
# valid Loss: 0.4101 AUC: 0.9110
#
# Epoch 6/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3333 AUC: 0.9303
# Batch: 13/13 (valid)
# valid Loss: 0.3567 AUC: 0.9237
#
# Epoch 7/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2931 AUC: 0.9381
# Batch: 13/13 (valid)
# valid Loss: 0.3360 AUC: 0.9299
#
# Epoch 8/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2863 AUC: 0.9378
# Batch: 13/13 (valid)
# valid Loss: 0.3234 AUC: 0.9323
#
# Epoch 9/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2830 AUC: 0.9388
# Batch: 13/13 (valid)
# valid Loss: 0.3123 AUC: 0.9317
#
# Epoch 10/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2688 AUC: 0.9407
# Batch: 13/13 (valid)
# valid Loss: 0.2912 AUC: 0.9354
#
# Epoch 11/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2659 AUC: 0.9405
# Batch: 13/13 (valid)
# valid Loss: 0.3079 AUC: 0.9319
#
# Epoch 12/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2558 AUC: 0.9432
# Batch: 13/13 (valid)
# valid Loss: 0.2948 AUC: 0.9352
#
# Epoch 13/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2538 AUC: 0.9410
# Batch: 13/13 (valid)
# valid Loss: 0.2995 AUC: 0.9339
#
# Epoch 14/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2532 AUC: 0.9423
# Batch: 13/13 (valid)
# valid Loss: 0.2971 AUC: 0.9352
#
# Epoch 15/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2492 AUC: 0.9422
# Batch: 13/13 (valid)
# valid Loss: 0.2971 AUC: 0.9352
#
# Epoch 16/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2504 AUC: 0.9422
# Batch: 13/13 (valid)
# valid Loss: 0.2961 AUC: 0.9357
#
# Epoch 17/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2431 AUC: 0.9422
# Batch: 13/13 (valid)
# valid Loss: 0.3106 AUC: 0.9335
#
# Epoch 18/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2494 AUC: 0.9421
# Batch: 13/13 (valid)
# valid Loss: 0.3121 AUC: 0.9313
#
# Epoch 19/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2485 AUC: 0.9449
# Batch: 13/13 (valid)
# valid Loss: 0.3051 AUC: 0.9338
#
# Epoch 20/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2623 AUC: 0.9392
# Batch: 13/13 (valid)
# valid Loss: 0.3229 AUC: 0.9288
#
# Epoch 21/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2600 AUC: 0.9415
# Batch: 13/13 (valid)
# valid Loss: 0.3752 AUC: 0.9227
#
# Epoch 22/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2752 AUC: 0.9381
# Batch: 13/13 (valid)
# valid Loss: 0.3249 AUC: 0.9289
#
# Epoch 23/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2950 AUC: 0.9366
# Batch: 13/13 (valid)
# valid Loss: 0.3903 AUC: 0.9131
#
# Epoch 24/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3003 AUC: 0.9354
# Batch: 13/13 (valid)
# valid Loss: 0.3163 AUC: 0.9285
#
# Epoch 25/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2960 AUC: 0.9334
# Batch: 13/13 (valid)
# valid Loss: 0.3260 AUC: 0.9241
#
# Epoch 26/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2992 AUC: 0.9367
# Batch: 13/13 (valid)
# valid Loss: 0.3467 AUC: 0.9178
#
# Epoch 27/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2794 AUC: 0.9393
# Batch: 13/13 (valid)
# valid Loss: 0.3297 AUC: 0.9244
#
# Epoch 28/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2701 AUC: 0.9405
# Batch: 13/13 (valid)
# valid Loss: 0.3868 AUC: 0.9069
#
# Epoch 29/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2701 AUC: 0.9412
# Batch: 13/13 (valid)
# valid Loss: 0.3432 AUC: 0.9201
#
# Training complete in 117m 39s
# Best val AUC: 0.9357
#
# << Spec: 3 >>
# Epoch 0/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2555 AUC: 0.9408
# Batch: 13/13 (valid)
# valid Loss: 0.2961 AUC: 0.9357
#
# Epoch 1/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2535 AUC: 0.9402
# Batch: 13/13 (valid)
# valid Loss: 0.2917 AUC: 0.9362
#
# Epoch 2/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2519 AUC: 0.9392
# Batch: 13/13 (valid)
# valid Loss: 0.2999 AUC: 0.9362
#
# Epoch 3/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2485 AUC: 0.9420
# Batch: 13/13 (valid)
# valid Loss: 0.2915 AUC: 0.9365
#
# Epoch 4/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2445 AUC: 0.9428
# Batch: 13/13 (valid)
# valid Loss: 0.2897 AUC: 0.9388
#
# Epoch 5/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2530 AUC: 0.9412
# Batch: 13/13 (valid)
# valid Loss: 0.2934 AUC: 0.9342
#
# Epoch 6/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2544 AUC: 0.9421
# Batch: 13/13 (valid)
# valid Loss: 0.2863 AUC: 0.9363
#
# Epoch 7/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2488 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.2997 AUC: 0.9356
#
# Epoch 8/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2511 AUC: 0.9404
# Batch: 13/13 (valid)
# valid Loss: 0.3155 AUC: 0.9321
#
# Epoch 9/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2546 AUC: 0.9395
# Batch: 13/13 (valid)
# valid Loss: 0.2963 AUC: 0.9354
#
# Epoch 10/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2563 AUC: 0.9407
# Batch: 13/13 (valid)
# valid Loss: 0.3259 AUC: 0.9294
#
# Epoch 11/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2493 AUC: 0.9420
# Batch: 13/13 (valid)
# valid Loss: 0.3469 AUC: 0.9253
#
# Epoch 12/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2631 AUC: 0.9414
# Batch: 13/13 (valid)
# valid Loss: 0.3078 AUC: 0.9316
#
# Epoch 13/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2442 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3217 AUC: 0.9307
#
# Epoch 14/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2475 AUC: 0.9422
# Batch: 13/13 (valid)
# valid Loss: 0.3088 AUC: 0.9323
#
# Epoch 15/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2420 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.3079 AUC: 0.9332
#
# Epoch 16/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2369 AUC: 0.9442
# Batch: 13/13 (valid)
# valid Loss: 0.3091 AUC: 0.9341
#
# Epoch 17/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2368 AUC: 0.9408
# Batch: 13/13 (valid)
# valid Loss: 0.3016 AUC: 0.9336
#
# Epoch 18/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2345 AUC: 0.9429
# Batch: 13/13 (valid)
# valid Loss: 0.3029 AUC: 0.9331
#
# Epoch 19/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2241 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3030 AUC: 0.9337
#
# Epoch 20/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2343 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.3027 AUC: 0.9337
#
# Epoch 21/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2306 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.3026 AUC: 0.9334
#
# Epoch 22/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2257 AUC: 0.9448
# Batch: 13/13 (valid)
# valid Loss: 0.3018 AUC: 0.9342
#
# Epoch 23/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2352 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.2981 AUC: 0.9342
#
# Epoch 24/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2291 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.2980 AUC: 0.9337
#
# Epoch 25/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2320 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.2850 AUC: 0.9349
#
# Epoch 26/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2349 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.2962 AUC: 0.9343
#
# Epoch 27/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2349 AUC: 0.9436
# Batch: 13/13 (valid)
# valid Loss: 0.2955 AUC: 0.9346
#
# Epoch 28/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2359 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3016 AUC: 0.9336
#
# Epoch 29/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2383 AUC: 0.9443
# Batch: 13/13 (valid)
# valid Loss: 0.3111 AUC: 0.9294
#
# Epoch 30/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2375 AUC: 0.9432
# Batch: 13/13 (valid)
# valid Loss: 0.3128 AUC: 0.9344
#
# Epoch 31/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2316 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.3039 AUC: 0.9301
#
# Epoch 32/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2378 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.3367 AUC: 0.9204
#
# Epoch 33/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2456 AUC: 0.9421
# Batch: 13/13 (valid)
# valid Loss: 0.3244 AUC: 0.9338
#
# Epoch 34/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2441 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.3065 AUC: 0.9357
#
# Epoch 35/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2354 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.3046 AUC: 0.9351
#
# Epoch 36/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2288 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.3112 AUC: 0.9325
#
# Epoch 37/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2312 AUC: 0.9442
# Batch: 13/13 (valid)
# valid Loss: 0.3192 AUC: 0.9348
#
# Epoch 38/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2296 AUC: 0.9422
# Batch: 13/13 (valid)
# valid Loss: 0.3074 AUC: 0.9335
#
# Epoch 39/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2295 AUC: 0.9451
# Batch: 13/13 (valid)
# valid Loss: 0.3054 AUC: 0.9351
#
# Epoch 40/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2369 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.3032 AUC: 0.9361
#
# Epoch 41/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2266 AUC: 0.9452
# Batch: 13/13 (valid)
# valid Loss: 0.3031 AUC: 0.9362
#
# Epoch 42/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2265 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.3031 AUC: 0.9362
#
# Epoch 43/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2263 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.3005 AUC: 0.9364
#
# Epoch 44/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2254 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.3018 AUC: 0.9362
#
# Epoch 45/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2271 AUC: 0.9452
# Batch: 13/13 (valid)
# valid Loss: 0.3054 AUC: 0.9381
#
# Epoch 46/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2270 AUC: 0.9429
# Batch: 13/13 (valid)
# valid Loss: 0.3089 AUC: 0.9370
#
# Epoch 47/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2299 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.3112 AUC: 0.9337
#
# Epoch 48/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2229 AUC: 0.9448
# Batch: 13/13 (valid)
# valid Loss: 0.3283 AUC: 0.9323
#
# Epoch 49/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2265 AUC: 0.9453
# Batch: 13/13 (valid)
# valid Loss: 0.3238 AUC: 0.9337
#
# Epoch 50/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2325 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.3359 AUC: 0.9308
#
# Epoch 51/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2365 AUC: 0.9428
# Batch: 13/13 (valid)
# valid Loss: 0.3215 AUC: 0.9326
#
# Epoch 52/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2324 AUC: 0.9428
# Batch: 13/13 (valid)
# valid Loss: 0.3433 AUC: 0.9249
#
# Epoch 53/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2412 AUC: 0.9436
# Batch: 13/13 (valid)
# valid Loss: 0.3284 AUC: 0.9336
#
# Epoch 54/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2362 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.3340 AUC: 0.9292
#
# Epoch 55/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2302 AUC: 0.9428
# Batch: 13/13 (valid)
# valid Loss: 0.3106 AUC: 0.9346
#
# Epoch 56/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2301 AUC: 0.9432
# Batch: 13/13 (valid)
# valid Loss: 0.2973 AUC: 0.9356
#
# Epoch 57/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2312 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.3182 AUC: 0.9298
#
# Epoch 58/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2324 AUC: 0.9440
# Batch: 13/13 (valid)
# valid Loss: 0.3014 AUC: 0.9354
#
# Epoch 59/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2213 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.2991 AUC: 0.9326
#
# Epoch 60/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2223 AUC: 0.9447
# Batch: 13/13 (valid)
# valid Loss: 0.2954 AUC: 0.9362
#
# Epoch 61/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2219 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.2963 AUC: 0.9371
#
# Epoch 62/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2254 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.2959 AUC: 0.9366
#
# Epoch 63/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2219 AUC: 0.9441
# Batch: 13/13 (valid)
# valid Loss: 0.2959 AUC: 0.9366
#
# Epoch 64/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2201 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.2961 AUC: 0.9364
#
# Epoch 65/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2212 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.2966 AUC: 0.9369
#
# Epoch 66/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2178 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.2974 AUC: 0.9366
#
# Epoch 67/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2231 AUC: 0.9458
# Batch: 13/13 (valid)
# valid Loss: 0.2961 AUC: 0.9368
#
# Epoch 68/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2239 AUC: 0.9443
# Batch: 13/13 (valid)
# valid Loss: 0.2944 AUC: 0.9374
#
# Epoch 69/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2287 AUC: 0.9417
# Batch: 13/13 (valid)
# valid Loss: 0.2946 AUC: 0.9373
#
# Epoch 70/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2309 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.2961 AUC: 0.9360
#
# Epoch 71/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2328 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.3126 AUC: 0.9371
#
# Epoch 72/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2348 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.3143 AUC: 0.9339
#
# Epoch 73/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2379 AUC: 0.9418
# Batch: 13/13 (valid)
# valid Loss: 0.3025 AUC: 0.9335
#
# Epoch 74/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2326 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3384 AUC: 0.9273
#
# Epoch 75/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2341 AUC: 0.9441
# Batch: 13/13 (valid)
# valid Loss: 0.3087 AUC: 0.9316
#
# Epoch 76/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2333 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3208 AUC: 0.9344
#
# Epoch 77/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2261 AUC: 0.9426
# Batch: 13/13 (valid)
# valid Loss: 0.3145 AUC: 0.9359
#
# Epoch 78/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2249 AUC: 0.9453
# Batch: 13/13 (valid)
# valid Loss: 0.3053 AUC: 0.9330
#
# Epoch 79/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2201 AUC: 0.9431
# Batch: 13/13 (valid)
# valid Loss: 0.2984 AUC: 0.9373
#
# Epoch 80/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2249 AUC: 0.9432
# Batch: 13/13 (valid)
# valid Loss: 0.3098 AUC: 0.9341
#
# Epoch 81/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2269 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.2976 AUC: 0.9352
#
# Epoch 82/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2173 AUC: 0.9461
# Batch: 13/13 (valid)
# valid Loss: 0.2995 AUC: 0.9353
#
# Epoch 83/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2219 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.2999 AUC: 0.9355
#
# Epoch 84/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2232 AUC: 0.9452
# Batch: 13/13 (valid)
# valid Loss: 0.2999 AUC: 0.9353
#
# Epoch 85/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2207 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.2998 AUC: 0.9356
#
# Epoch 86/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2167 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.3021 AUC: 0.9345
#
# Epoch 87/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2161 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3028 AUC: 0.9360
#
# Epoch 88/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2192 AUC: 0.9449
# Batch: 13/13 (valid)
# valid Loss: 0.3013 AUC: 0.9378
#
# Epoch 89/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2233 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.2988 AUC: 0.9365
#
# Epoch 90/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2181 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.3136 AUC: 0.9341
#
# Epoch 91/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2252 AUC: 0.9419
# Batch: 13/13 (valid)
# valid Loss: 0.3156 AUC: 0.9232
#
# Epoch 92/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2169 AUC: 0.9459
# Batch: 13/13 (valid)
# valid Loss: 0.3122 AUC: 0.9282
#
# Epoch 93/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2274 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.3025 AUC: 0.9316
#
# Epoch 94/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2333 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.2933 AUC: 0.9324
#
# Epoch 95/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2318 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.2953 AUC: 0.9372
#
# Epoch 96/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2298 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.2942 AUC: 0.9323
#
# Epoch 97/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2278 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3220 AUC: 0.9263
#
# Epoch 98/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2289 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.3035 AUC: 0.9299
#
# Epoch 99/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2210 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.3042 AUC: 0.9315
#
# Training complete in 442m 56s
# Best val AUC: 0.9388
#
# - Validation -
# === Normal Valid ===
# Batch: 13/13
#
# Norml Valid AUC: 0.9405
#
# === Valid Time Augmentation ===
# n: 0/4
# ----------
# Batch: 13/13
# n: 1/4
# ----------
# Batch: 13/13
# n: 2/4
# ----------
# Batch: 13/13
# n: 3/4
# ----------
# Batch: 13/13
# n: 4/4
# ----------
# Batch: 13/13
#
# VTA AUC: 0.9382
#
# === Mixed Valid ===
#
# Mixed AUC: 0.9405
#
# === Fold: 2 ===
# GPU Memory: 17040384
# << Spec: 0 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.7322 AUC: 0.5485
# Batch: 13/13 (valid)
# valid Loss: 0.7259 AUC: 0.5709
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.6074 AUC: 0.7278
# Batch: 13/13 (valid)
# valid Loss: 0.5836 AUC: 0.7576
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5321 AUC: 0.8028
# Batch: 13/13 (valid)
# valid Loss: 0.5559 AUC: 0.7914
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5070 AUC: 0.8280
# Batch: 13/13 (valid)
# valid Loss: 0.5317 AUC: 0.8138
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4858 AUC: 0.8425
# Batch: 13/13 (valid)
# valid Loss: 0.4996 AUC: 0.8343
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4773 AUC: 0.8525
# Batch: 13/13 (valid)
# valid Loss: 0.4945 AUC: 0.8410
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4471 AUC: 0.8751
# Batch: 13/13 (valid)
# valid Loss: 0.4980 AUC: 0.8475
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4386 AUC: 0.8789
# Batch: 13/13 (valid)
# valid Loss: 0.4791 AUC: 0.8513
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4354 AUC: 0.8785
# Batch: 13/13 (valid)
# valid Loss: 0.4755 AUC: 0.8550
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4355 AUC: 0.8766
# Batch: 13/13 (valid)
# valid Loss: 0.4582 AUC: 0.8650
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4262 AUC: 0.8842
# Batch: 13/13 (valid)
# valid Loss: 0.4679 AUC: 0.8611
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4179 AUC: 0.8965
# Batch: 13/13 (valid)
# valid Loss: 0.4579 AUC: 0.8664
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4169 AUC: 0.8909
# Batch: 13/13 (valid)
# valid Loss: 0.4588 AUC: 0.8666
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4212 AUC: 0.8909
# Batch: 13/13 (valid)
# valid Loss: 0.4485 AUC: 0.8722
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4025 AUC: 0.8996
# Batch: 13/13 (valid)
# valid Loss: 0.4479 AUC: 0.8726
#
# Training complete in 57m 13s
# Best val AUC: 0.8726
#
# << Spec: 1 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4024 AUC: 0.8994
# Batch: 13/13 (valid)
# valid Loss: 0.4479 AUC: 0.8726
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4043 AUC: 0.8965
# Batch: 13/13 (valid)
# valid Loss: 0.4469 AUC: 0.8738
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4064 AUC: 0.8948
# Batch: 13/13 (valid)
# valid Loss: 0.4432 AUC: 0.8757
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4084 AUC: 0.8941
# Batch: 13/13 (valid)
# valid Loss: 0.4558 AUC: 0.8731
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3918 AUC: 0.9026
# Batch: 13/13 (valid)
# valid Loss: 0.4447 AUC: 0.8763
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4054 AUC: 0.8942
# Batch: 13/13 (valid)
# valid Loss: 0.4420 AUC: 0.8768
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3952 AUC: 0.9010
# Batch: 13/13 (valid)
# valid Loss: 0.4581 AUC: 0.8688
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4118 AUC: 0.8928
# Batch: 13/13 (valid)
# valid Loss: 0.4544 AUC: 0.8712
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3934 AUC: 0.9039
# Batch: 13/13 (valid)
# valid Loss: 0.4463 AUC: 0.8771
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3956 AUC: 0.8985
# Batch: 13/13 (valid)
# valid Loss: 0.4480 AUC: 0.8743
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3945 AUC: 0.9008
# Batch: 13/13 (valid)
# valid Loss: 0.4431 AUC: 0.8813
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3968 AUC: 0.9017
# Batch: 13/13 (valid)
# valid Loss: 0.4312 AUC: 0.8827
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3913 AUC: 0.8998
# Batch: 13/13 (valid)
# valid Loss: 0.4369 AUC: 0.8814
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3795 AUC: 0.9044
# Batch: 13/13 (valid)
# valid Loss: 0.4291 AUC: 0.8827
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3814 AUC: 0.9099
# Batch: 13/13 (valid)
# valid Loss: 0.4344 AUC: 0.8817
#
# Training complete in 56m 47s
# Best val AUC: 0.8827
#
# << Spec: 2 >>
# Epoch 0/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3843 AUC: 0.9060
# Batch: 13/13 (valid)
# valid Loss: 0.4312 AUC: 0.8827
#
# Epoch 1/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4579 AUC: 0.8969
# Batch: 13/13 (valid)
# valid Loss: 0.5285 AUC: 0.8610
#
# Epoch 2/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4161 AUC: 0.8979
# Batch: 13/13 (valid)
# valid Loss: 0.4587 AUC: 0.8774
#
# Epoch 3/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3775 AUC: 0.9133
# Batch: 13/13 (valid)
# valid Loss: 0.4449 AUC: 0.8880
#
# Epoch 4/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3296 AUC: 0.9297
# Batch: 13/13 (valid)
# valid Loss: 0.3766 AUC: 0.9104
#
# Epoch 5/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3362 AUC: 0.9280
# Batch: 13/13 (valid)
# valid Loss: 0.3607 AUC: 0.9181
#
# Epoch 6/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3052 AUC: 0.9373
# Batch: 13/13 (valid)
# valid Loss: 0.3842 AUC: 0.9138
#
# Epoch 7/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3092 AUC: 0.9335
# Batch: 13/13 (valid)
# valid Loss: 0.3448 AUC: 0.9171
#
# Epoch 8/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2931 AUC: 0.9360
# Batch: 13/13 (valid)
# valid Loss: 0.3719 AUC: 0.9122
#
# Epoch 9/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2760 AUC: 0.9404
# Batch: 13/13 (valid)
# valid Loss: 0.3556 AUC: 0.9224
#
# Epoch 10/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2762 AUC: 0.9379
# Batch: 13/13 (valid)
# valid Loss: 0.3307 AUC: 0.9287
#
# Epoch 11/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2652 AUC: 0.9424
# Batch: 13/13 (valid)
# valid Loss: 0.3390 AUC: 0.9275
#
# Epoch 12/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2566 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.3429 AUC: 0.9308
#
# Epoch 13/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2547 AUC: 0.9432
# Batch: 13/13 (valid)
# valid Loss: 0.3217 AUC: 0.9280
#
# Epoch 14/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2475 AUC: 0.9419
# Batch: 13/13 (valid)
# ...
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2576 AUC: 0.9418
# Batch: 13/13 (valid)
# valid Loss: 0.2928 AUC: 0.9327
#
# Epoch 13/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2549 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.2902 AUC: 0.9329
#
# Epoch 14/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2466 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.2906 AUC: 0.9330
#
# Epoch 15/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2513 AUC: 0.9426
# Batch: 13/13 (valid)
# valid Loss: 0.2906 AUC: 0.9330
#
# Epoch 16/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2450 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.2887 AUC: 0.9327
#
# Epoch 17/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2517 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.2854 AUC: 0.9351
#
# Epoch 18/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2562 AUC: 0.9415
# Batch: 13/13 (valid)
# valid Loss: 0.2944 AUC: 0.9332
#
# Epoch 19/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2522 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.3020 AUC: 0.9300
#
# Epoch 20/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2484 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.2956 AUC: 0.9317
#
# Epoch 21/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2548 AUC: 0.9426
# Batch: 13/13 (valid)
# valid Loss: 0.3493 AUC: 0.9230
#
# Epoch 22/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2849 AUC: 0.9391
# Batch: 13/13 (valid)
# valid Loss: 0.3277 AUC: 0.9259
#
# Epoch 23/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2978 AUC: 0.9367
# Batch: 13/13 (valid)
# valid Loss: 0.3480 AUC: 0.9222
#
# Epoch 24/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3012 AUC: 0.9347
# Batch: 13/13 (valid)
# valid Loss: 0.3264 AUC: 0.9244
#
# Epoch 25/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2952 AUC: 0.9347
# Batch: 13/13 (valid)
# valid Loss: 0.3549 AUC: 0.9171
#
# Epoch 26/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2950 AUC: 0.9349
# Batch: 13/13 (valid)
# valid Loss: 0.3366 AUC: 0.9232
#
# Epoch 27/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2809 AUC: 0.9379
# Batch: 13/13 (valid)
# valid Loss: 0.3242 AUC: 0.9171
#
# Epoch 28/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2646 AUC: 0.9420
# Batch: 13/13 (valid)
# valid Loss: 0.3462 AUC: 0.9228
#
# Epoch 29/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2640 AUC: 0.9418
# Batch: 13/13 (valid)
# valid Loss: 0.3077 AUC: 0.9210
#
# Training complete in 116m 29s
# Best val AUC: 0.9351
#
# << Spec: 3 >>
# Epoch 0/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2548 AUC: 0.9400
# Batch: 13/13 (valid)
# valid Loss: 0.2854 AUC: 0.9351
#
# Epoch 1/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2555 AUC: 0.9403
# Batch: 13/13 (valid)
# valid Loss: 0.2870 AUC: 0.9353
#
# Epoch 2/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2477 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.2833 AUC: 0.9340
#
# Epoch 3/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2512 AUC: 0.9424
# Batch: 13/13 (valid)
# valid Loss: 0.2821 AUC: 0.9334
#
# Epoch 4/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2497 AUC: 0.9406
# Batch: 13/13 (valid)
# valid Loss: 0.2913 AUC: 0.9333
#
# Epoch 5/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2474 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.2882 AUC: 0.9330
#
# Epoch 6/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2567 AUC: 0.9413
# Batch: 13/13 (valid)
# valid Loss: 0.2812 AUC: 0.9356
#
# Epoch 7/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2475 AUC: 0.9424
# Batch: 13/13 (valid)
# valid Loss: 0.2873 AUC: 0.9318
#
# Epoch 8/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2546 AUC: 0.9428
# Batch: 13/13 (valid)
# valid Loss: 0.2979 AUC: 0.9336
#
# Epoch 9/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2468 AUC: 0.9448
# Batch: 13/13 (valid)
# valid Loss: 0.3150 AUC: 0.9325
#
# Epoch 10/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2526 AUC: 0.9410
# Batch: 13/13 (valid)
# valid Loss: 0.2952 AUC: 0.9285
#
# Epoch 11/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2560 AUC: 0.9407
# Batch: 13/13 (valid)
# valid Loss: 0.2963 AUC: 0.9307
#
# Epoch 12/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2524 AUC: 0.9418
# Batch: 13/13 (valid)
# valid Loss: 0.2988 AUC: 0.9290
#
# Epoch 13/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2503 AUC: 0.9410
# Batch: 13/13 (valid)
# valid Loss: 0.3023 AUC: 0.9277
#
# Epoch 14/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2408 AUC: 0.9424
# Batch: 13/13 (valid)
# valid Loss: 0.2835 AUC: 0.9333
#
# Epoch 15/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2410 AUC: 0.9440
# Batch: 13/13 (valid)
# valid Loss: 0.2802 AUC: 0.9353
#
# Epoch 16/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2406 AUC: 0.9428
# Batch: 13/13 (valid)
# valid Loss: 0.2651 AUC: 0.9387
#
# Epoch 17/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2307 AUC: 0.9436
# Batch: 13/13 (valid)
# valid Loss: 0.2692 AUC: 0.9382
#
# Epoch 18/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2318 AUC: 0.9423
# Batch: 13/13 (valid)
# valid Loss: 0.2644 AUC: 0.9379
#
# Epoch 19/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2275 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.2626 AUC: 0.9363
#
# Epoch 20/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2400 AUC: 0.9426
# Batch: 13/13 (valid)
# valid Loss: 0.2628 AUC: 0.9369
#
# Epoch 21/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2281 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.2629 AUC: 0.9368
#
# Epoch 22/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2312 AUC: 0.9442
# Batch: 13/13 (valid)
# valid Loss: 0.2611 AUC: 0.9364
#
# Epoch 23/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2361 AUC: 0.9428
# Batch: 13/13 (valid)
# valid Loss: 0.2622 AUC: 0.9379
#
# Epoch 24/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2356 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.2577 AUC: 0.9368
#
# Epoch 25/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2410 AUC: 0.9426
# Batch: 13/13 (valid)
# valid Loss: 0.2585 AUC: 0.9367
#
# Epoch 26/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2348 AUC: 0.9449
# Batch: 13/13 (valid)
# valid Loss: 0.2682 AUC: 0.9365
#
# Epoch 27/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2359 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.2781 AUC: 0.9309
#
# Epoch 28/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2449 AUC: 0.9428
# Batch: 13/13 (valid)
# valid Loss: 0.2845 AUC: 0.9340
#
# Epoch 29/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2457 AUC: 0.9421
# Batch: 13/13 (valid)
# valid Loss: 0.2897 AUC: 0.9327
#
# Epoch 30/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2366 AUC: 0.9422
# Batch: 13/13 (valid)
# valid Loss: 0.2858 AUC: 0.9330
#
# Epoch 31/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2447 AUC: 0.9424
# Batch: 13/13 (valid)
# valid Loss: 0.3152 AUC: 0.9293
#
# Epoch 32/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2440 AUC: 0.9416
# Batch: 13/13 (valid)
# valid Loss: 0.3255 AUC: 0.9329
#
# Epoch 33/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2450 AUC: 0.9429
# Batch: 13/13 (valid)
# valid Loss: 0.3181 AUC: 0.9276
#
# Epoch 34/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2327 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.3056 AUC: 0.9199
#
# Epoch 35/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2418 AUC: 0.9424
# Batch: 13/13 (valid)
# valid Loss: 0.2837 AUC: 0.9335
#
# Epoch 36/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2368 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.2928 AUC: 0.9269
#
# Epoch 37/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2307 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.2858 AUC: 0.9318
#
# Epoch 38/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2324 AUC: 0.9422
# Batch: 13/13 (valid)
# valid Loss: 0.2783 AUC: 0.9341
#
# Epoch 39/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2289 AUC: 0.9442
# Batch: 13/13 (valid)
# valid Loss: 0.2714 AUC: 0.9364
#
# Epoch 40/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2240 AUC: 0.9449
# Batch: 13/13 (valid)
# valid Loss: 0.2721 AUC: 0.9342
#
# Epoch 41/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2192 AUC: 0.9429
# Batch: 13/13 (valid)
# valid Loss: 0.2721 AUC: 0.9337
#
# Epoch 42/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2274 AUC: 0.9441
# Batch: 13/13 (valid)
# valid Loss: 0.2722 AUC: 0.9338
#
# Epoch 43/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2206 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.2722 AUC: 0.9342
#
# Epoch 44/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2275 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.2825 AUC: 0.9322
#
# Epoch 45/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2294 AUC: 0.9458
# Batch: 13/13 (valid)
# valid Loss: 0.2836 AUC: 0.9336
#
# Epoch 46/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2279 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.2765 AUC: 0.9337
#
# Epoch 47/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2229 AUC: 0.9438
# Batch: 13/13 (valid)
# valid Loss: 0.2813 AUC: 0.9339
#
# Epoch 48/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2304 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.2768 AUC: 0.9339
#
# Epoch 49/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2304 AUC: 0.9453
# Batch: 13/13 (valid)
# valid Loss: 0.2881 AUC: 0.9345
#
# Epoch 50/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2386 AUC: 0.9435
# Batch: 13/13 (valid)
# valid Loss: 0.2837 AUC: 0.9349
#
# Epoch 51/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2376 AUC: 0.9429
# Batch: 13/13 (valid)
# valid Loss: 0.2889 AUC: 0.9336
#
# Epoch 52/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2383 AUC: 0.9422
# Batch: 13/13 (valid)
# valid Loss: 0.3017 AUC: 0.9300
#
# Epoch 53/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2358 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.2850 AUC: 0.9334
#
# Epoch 54/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2374 AUC: 0.9433
# Batch: 13/13 (valid)
# valid Loss: 0.2961 AUC: 0.9268
#
# Epoch 55/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2281 AUC: 0.9455
# Batch: 13/13 (valid)
# valid Loss: 0.2768 AUC: 0.9353
#
# Epoch 56/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2368 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.2816 AUC: 0.9353
#
# Epoch 57/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2266 AUC: 0.9456
# Batch: 13/13 (valid)
# valid Loss: 0.2825 AUC: 0.9322
#
# Epoch 58/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2291 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.2820 AUC: 0.9340
#
# Epoch 59/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2301 AUC: 0.9428
# Batch: 13/13 (valid)
# valid Loss: 0.2723 AUC: 0.9358
#
# Epoch 60/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2266 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.2706 AUC: 0.9374
#
# Epoch 61/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2237 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.2733 AUC: 0.9363
#
# Epoch 62/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2261 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.2731 AUC: 0.9363
#
# Epoch 63/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2254 AUC: 0.9447
# Batch: 13/13 (valid)
# valid Loss: 0.2732 AUC: 0.9359
#
# Epoch 64/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2216 AUC: 0.9448
# Batch: 13/13 (valid)
# valid Loss: 0.2741 AUC: 0.9367
#
# Epoch 65/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2263 AUC: 0.9441
# Batch: 13/13 (valid)
# valid Loss: 0.2731 AUC: 0.9384
#
# Epoch 66/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2195 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.2690 AUC: 0.9381
#
# Epoch 67/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2277 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.2778 AUC: 0.9358
#
# Epoch 68/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2264 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.2777 AUC: 0.9331
#
# Epoch 69/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2267 AUC: 0.9443
# Batch: 13/13 (valid)
# valid Loss: 0.2643 AUC: 0.9371
#
# Epoch 70/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2362 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.2854 AUC: 0.9374
#
# Epoch 71/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2241 AUC: 0.9443
# Batch: 13/13 (valid)
# valid Loss: 0.2850 AUC: 0.9361
#
# Epoch 72/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2309 AUC: 0.9425
# Batch: 13/13 (valid)
# valid Loss: 0.2984 AUC: 0.9186
#
# Epoch 73/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2292 AUC: 0.9415
# Batch: 13/13 (valid)
# valid Loss: 0.2866 AUC: 0.9243
#
# Epoch 74/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2291 AUC: 0.9432
# Batch: 13/13 (valid)
# valid Loss: 0.2990 AUC: 0.9275
#
# Epoch 75/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2271 AUC: 0.9452
# Batch: 13/13 (valid)
# valid Loss: 0.2958 AUC: 0.9319
#
# Epoch 76/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2301 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.2775 AUC: 0.9361
#
# Epoch 77/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2228 AUC: 0.9444
# Batch: 13/13 (valid)
# valid Loss: 0.2801 AUC: 0.9360
#
# Epoch 78/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2235 AUC: 0.9453
# Batch: 13/13 (valid)
# valid Loss: 0.2745 AUC: 0.9342
#
# Epoch 79/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2244 AUC: 0.9427
# Batch: 13/13 (valid)
# valid Loss: 0.2799 AUC: 0.9310
#
# Epoch 80/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2254 AUC: 0.9442
# Batch: 13/13 (valid)
# valid Loss: 0.2663 AUC: 0.9366
#
# Epoch 81/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2239 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.2676 AUC: 0.9372
#
# Epoch 82/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2183 AUC: 0.9448
# Batch: 13/13 (valid)
# valid Loss: 0.2675 AUC: 0.9369
#
# Epoch 83/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2191 AUC: 0.9456
# Batch: 13/13 (valid)
# valid Loss: 0.2667 AUC: 0.9368
#
# Epoch 84/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2207 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.2666 AUC: 0.9368
#
# Epoch 85/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2214 AUC: 0.9441
# Batch: 13/13 (valid)
# valid Loss: 0.2649 AUC: 0.9368
#
# Epoch 86/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2211 AUC: 0.9450
# Batch: 13/13 (valid)
# valid Loss: 0.2640 AUC: 0.9360
#
# Epoch 87/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2219 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.2723 AUC: 0.9366
#
# Epoch 88/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2248 AUC: 0.9448
# Batch: 13/13 (valid)
# valid Loss: 0.2666 AUC: 0.9370
#
# Epoch 89/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2229 AUC: 0.9446
# Batch: 13/13 (valid)
# valid Loss: 0.2639 AUC: 0.9338
#
# Epoch 90/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2322 AUC: 0.9445
# Batch: 13/13 (valid)
# valid Loss: 0.2742 AUC: 0.9339
#
# Epoch 91/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2241 AUC: 0.9439
# Batch: 13/13 (valid)
# valid Loss: 0.2910 AUC: 0.9327
#
# Epoch 92/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2250 AUC: 0.9441
# Batch: 13/13 (valid)
# valid Loss: 0.2849 AUC: 0.9286
#
# Epoch 93/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2235 AUC: 0.9465
# Batch: 13/13 (valid)
# valid Loss: 0.2954 AUC: 0.9284
#
# Epoch 94/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2219 AUC: 0.9447
# Batch: 13/13 (valid)
# valid Loss: 0.3196 AUC: 0.9259
#
# Epoch 95/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2157 AUC: 0.9437
# Batch: 13/13 (valid)
# valid Loss: 0.2925 AUC: 0.9229
#
# Epoch 96/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2279 AUC: 0.9421
# Batch: 13/13 (valid)
# valid Loss: 0.2953 AUC: 0.9333
#
# Epoch 97/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2279 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.2784 AUC: 0.9367
#
# Epoch 98/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2212 AUC: 0.9451
# Batch: 13/13 (valid)
# valid Loss: 0.2874 AUC: 0.9336
#
# Epoch 99/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2266 AUC: 0.9434
# Batch: 13/13 (valid)
# valid Loss: 0.2936 AUC: 0.9322
#
# Training complete in 442m 56s
# Best val AUC: 0.9387
#
# - Validation -
# === Normal Valid ===
# Batch: 13/13
#
# Norml Valid AUC: 0.9396
#
# === Valid Time Augmentation ===
# n: 0/4
# ----------
# Batch: 13/13
# n: 1/4
# ----------
# Batch: 13/13
# n: 2/4
# ----------
# Batch: 13/13
# n: 3/4
# ----------
# Batch: 13/13
# n: 4/4
# ----------
# Batch: 13/13
#
# VTA AUC: 0.9394
#
# === Mixed Valid ===
#
# Mixed AUC: 0.9393
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
print(torch.cuda.memory_allocated())
# Out:
# 17040384

# %% [raw]
# fold = 1
#
# model = torch.load(f'model_{fold}.pth')
# model.to(device)
# val, vta, mix = valMix(model, dataloaders, n=5)

# %% [raw]
# # 例
# def showRes(n, df, preds, preds2=None, start=0):
#     n_cols = 5
#     n_rows = (n-1)//5+1
#
#     fig = plt.figure(figsize=(n_cols*2, n_rows*2))
#
#     for i in range(n):
#         loc = i + start
#         num = df['num'].iloc[loc]
#         lab = df['label'].iloc[loc]
#         im = image = load_img(num)
#
#         ax = fig.add_subplot(n_rows, n_cols, i+1)
#         im = np.asarray(im)
#         ax.imshow(im)
#         ax.axes.xaxis.set_visible(False)
#         ax.axes.yaxis.set_visible(False)
#         if preds2 is None:
#             ax.set_title(f'Label: {lab}\nPred: {preds[loc]:.2f}')
#         else:
#             ax.set_title(f'Label: {lab}\nPred: {preds[loc]:.2f}\nPred2: {preds2[loc]:.2f}')
#
#     fig.suptitle('Prediction')
#     fig.tight_layout()
#     fig.show()

# %% [raw]
# showRes(20, df_train[df_train['fold']==fold], val, vta, mix, start=20)

# %% [markdown]
# ## 推論・提出

# %%
df_submit = df_test[['image_name', 'label']].copy()

# %%
def predictCV(fold):
    model = torch.load(f'model_{fold}.pth')
    model.to(device)
    
    _, dataloaders = foldData(fold)
    test, tta, tmix = valMix(model, dataloaders, n=5, mode='test')
    
    df_submit[f'label_test_{fold}'] = test
    df_submit[f'label_tta_{fold}'] = tta
    df_submit[f'label_tmix_{fold}'] = tmix
    
    del model
    torch.cuda.empty_cache()

# %%
for fold in range(n_folds):
    predictCV(fold)
# Out:
# === Normal Test ===
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Batch: 68/68
#
# Norml Valid AUC: 0.5000
#
# === Test Time Augmentation ===
# n: 0/4
# ----------
# Batch: 68/68
# n: 1/4
# ----------
# Batch: 68/68
# n: 2/4
# ----------
# Batch: 68/68
# n: 3/4
# ----------
# Batch: 68/68
# n: 4/4
# ----------
# Batch: 68/68
#
# VTA AUC: 0.5000
#
# === Mixed Valid ===
#
# Mixed AUC: 0.5000
# === Normal Test ===
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Batch: 68/68
#
# Norml Valid AUC: 0.5000
#
# === Test Time Augmentation ===
# n: 0/4
# ----------
# Batch: 68/68
# n: 1/4
# ----------
# Batch: 68/68
# n: 2/4
# ----------
# Batch: 68/68
# n: 3/4
# ----------
# Batch: 68/68
# n: 4/4
# ----------
# Batch: 68/68
#
# VTA AUC: 0.5000
#
# === Mixed Valid ===
#
# Mixed AUC: 0.5000
# === Normal Test ===
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Batch: 68/68
#
# Norml Valid AUC: 0.5000
#
# === Test Time Augmentation ===
# n: 0/4
# ----------
# Batch: 68/68
# n: 1/4
# ----------
# Batch: 68/68
# n: 2/4
# ----------
# Batch: 68/68
# n: 3/4
# ----------
# Batch: 68/68
# n: 4/4
# ----------
# Batch: 68/68
#
# VTA AUC: 0.5000
#
# === Mixed Valid ===
#
# Mixed AUC: 0.5000
# === Normal Test ===
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Batch: 68/68
#
# Norml Valid AUC: 0.5000
#
# === Test Time Augmentation ===
# n: 0/4
# ----------
# Batch: 68/68
# n: 1/4
# ----------
# Batch: 68/68
# n: 2/4
# ----------
# Batch: 68/68
# n: 3/4
# ----------
# Batch: 68/68
# n: 4/4
# ----------
# Batch: 68/68
#
# VTA AUC: 0.5000
#
# === Mixed Valid ===
#
# Mixed AUC: 0.5000
# === Normal Test ===
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Batch: 68/68
#
# Norml Valid AUC: 0.5000
#
# === Test Time Augmentation ===
# n: 0/4
# ----------
# Batch: 68/68
# n: 1/4
# ----------
# Batch: 68/68
# n: 2/4
# ----------
# Batch: 68/68
# n: 3/4
# ----------
# Batch: 68/68
# n: 4/4
# ----------
# Batch: 68/68
#
# VTA AUC: 0.5000
#
# === Mixed Valid ===
#
# Mixed AUC: 0.5000

# %%
# 平均対象を抽出して提出
targ = 'tmix'

mean = df_submit[[f'label_{targ}_{fold}' for fold in range(n_folds)]].mean(axis=1)
df_submit['label'] = mean

df_submit[['image_name', 'label']].to_csv('submit.csv', header=None, index=None)

# %%
df_submit.to_csv('model_v2-cv.csv', index=False)

# %% [markdown]
# 提出

# %%
# %%bash
# signate submit --competition-id=1106 submit.csv --note model2_CV_tmix
# Out:
# You have successfully submitted your predictions.We will send you the submission result to your email address.
