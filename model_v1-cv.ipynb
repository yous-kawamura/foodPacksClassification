# %% [markdown]
# # ConvNeXt V2

# %% [markdown]
# - loss: Binary Cross Entropy
# - metrics: ROCAUC
# - trainable: after model.convnextv2.encoder.stages[3]
# - CVあり

# %% [markdown]
# ## Load Model

# %%
from transformers import AutoImageProcessor, ConvNextV2ForImageClassification, get_cosine_schedule_with_warmup
import torch
from datasets import load_dataset

from utils.utils import load_img

print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.current_device())
print(torch.cuda.get_device_name())
print(torch.cuda.get_device_capability())
# Out:
# 2.2.0.dev20230911+cu118
# True
# 4
# 0
# Tesla T4
# (7, 5)

# %% [raw]
# dataset = load_dataset("huggingface/cats-image")
# image = dataset["test"]["image"][0]
#
# preprocessor = AutoImageProcessor.from_pretrained("facebook/convnextv2-huge-22k-512")
# model = ConvNextV2ForImageClassification.from_pretrained("facebook/convnextv2-huge-22k-512")

# %% [raw]
# inputs = preprocessor(image, return_tensors="pt")
# inputs['pixel_values'].shape

# %% [raw]
# with torch.no_grad():
#     logits = model(**inputs).logits
#
# # model predicts one of the 1000 ImageNet classes
# predicted_label = logits.argmax(-1).item()
# print(model.config.id2label[predicted_label]),

# %% [markdown]
# ## 学習データの可視化

# %%
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# 食品と飲料をランダムに5個ずつ可視化する
df_train = pd.read_csv('train.csv')
df_train['num'] = df_train['image_name'].str[:-4].astype(int)

d_vis = df_train[df_train['label']==0].sample(5)['num'].tolist()
f_vis = df_train[df_train['label']==1].sample(5)['num'].tolist()

# %%
# データの偏り
print(f"N of drinks: {len(df_train[df_train['label']==0])}")
print(f"N of foods: {len(df_train[df_train['label']==1])}")
# Out:
# N of drinks: 994
# N of foods: 1182

# %%
def show5img(ilist, stitle=None):
    n_cols = 5
    n_rows = (len(ilist)-1)//5+1
    
    fig = plt.figure(figsize=(n_cols*2, n_rows*2))
    for n, i in enumerate(ilist):
        ax = fig.add_subplot(n_rows, n_cols, n+1)
        im = load_img(i)
        im = np.asarray(im)
        ax.imshow(im)
        ax.axes.xaxis.set_visible(False)
        ax.axes.yaxis.set_visible(False)
        ax.set_title(i)
    if stitle:
        fig.suptitle(stitle)
    fig.tight_layout()
    fig.show()

# %%
show5img(d_vis, stitle='drink')
show5img(f_vis, stitle='food')

# %% [markdown]
# ## 転移学習/CV検証

# %%
import torch.nn as nn
from torchvision import transforms

from sklearn.model_selection import StratifiedKFold

# %%
device = torch.device('cuda')

# %% [markdown]
# データセット作成

# %%
# folding
n_folds = 5

skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=0)
df_train['fold'] = -1
for i, (_, val_idx) in enumerate(skf.split(df_train, df_train['label'])):
    df_train.loc[val_idx, 'fold'] = i

# %%
df_train
# Out:
#      image_name  label   num  fold
# 0      0000.png      0     0     4
# 1      0001.png      1     1     2
# 2      0002.png      1     2     3
# 3      0003.png      1     3     0
# 4      0004.png      0     4     3
# ...         ...    ...   ...   ...
# 2171   2171.png      1  2171     3
# 2172   2172.png      1  2172     2
# 2173   2173.png      1  2173     3
# 2174   2174.png      0  2174     2
# 2175   2175.png      0  2175     3
#
# [2176 rows x 4 columns]

# %%
# テストデータ
df_test = pd.read_csv('sample_submit.csv', header=None)
df_test.columns = ['image_name', 'label']
df_test['num'] = df_test['image_name'].str[:-4].astype(int)
df_test['label'] = -1

# %%
df_test
# Out:
#      image_name  label   num
# 0      2176.png     -1  2176
# 1      2177.png     -1  2177
# 2      2178.png     -1  2178
# 3      2179.png     -1  2179
# 4      2180.png     -1  2180
# ...         ...    ...   ...
# 2175   4351.png     -1  4351
# 2176   4352.png     -1  4352
# 2177   4353.png     -1  4353
# 2178   4354.png     -1  4354
# 2179   4355.png     -1  4355
#
# [2180 rows x 3 columns]

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomChoice([
            transforms.RandomCrop(256),
            transforms.RandomCrop(384),
            transforms.RandomCrop(512),
        ]),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomVerticalFlip(p=0.5),
        transforms.RandomApply(
            [transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5)],
            p=0.67,
        ),
        transforms.RandomApply(
            [transforms.GaussianBlur(3, sigma=(0.1, 2.0))],
            p=0.67,
        ),
        transforms.Resize((512, 512)),
        transforms.RandomApply(
            [transforms.RandomRotation(180)],
            p=0.5,
        ),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        transforms.RandomErasing(p=0.33, scale=(0.02, 0.3)),
    ]),
    'valid': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
    'tta': transforms.Compose([
        transforms.RandomChoice([
            transforms.RandomCrop(448),
            transforms.RandomCrop(512),
        ]),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomVerticalFlip(p=0.5),
        transforms.RandomApply(
            [transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5)],
            p=0.67,
        ),
        transforms.RandomApply(
            [transforms.GaussianBlur(3, sigma=(0.1, 2.0))],
            p=0.67,
        ),
        transforms.Resize((512, 512)),
        # transforms.RandomApply(
        #     [transforms.RandomRotation(180)],
        #     p=0.5,
        # ),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        # transforms.RandomErasing(p=0.33, scale=(0.02, 0.1)),
    ]),
}

# %%
# 例
def showTimg(n, phase='train'):
    image = load_img(0)
    image_t = data_transforms[phase](image)
    
    img1 = np.asarray(image)
    img2 = image_t.numpy().transpose((2,1,0))
    
    fig = plt.figure(figsize=(2*2, 1*2))
    ax1 = fig.add_subplot(1, 2, 1)
    ax1.imshow(img1)
    ax1.axes.xaxis.set_visible(False)
    ax1.axes.yaxis.set_visible(False)
    ax1.set_title(f'Raw_{n}')
    
    ax2 = fig.add_subplot(1, 2, 2)
    ax2.imshow(img2)
    ax2.axes.xaxis.set_visible(False)
    ax2.axes.yaxis.set_visible(False)
    ax2.set_title(f'Transformed_{n}')

# %%
showTimg(0, phase='train')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
showTimg(0, phase='valid')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
showTimg(0, phase='tta')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, df, transform, tt='train'):
        if tt == 'train':
            self.dir = 'train/'
        elif tt == 'test':
            self.dir = 'test/'
        
        self.df = df
        self.transform = transform
        self.labels = np.expand_dims(df['label'].values, 1)
        self.labels = self.labels.astype(float)

    # len()を使用すると呼ばれる
    def __len__(self):
        return len(self.labels)

    # 要素を参照すると呼ばれる関数    
    def __getitem__(self, idx):
        num = self.df['num'].values[idx]
        image = load_img(num)
        image = self.transform(image)
        return image, self.labels[idx]

# %%
def foldData(fold, bs=32):
    df_train_ = df_train[df_train['fold']!=fold]
    df_valid_ = df_train[df_train['fold']==fold]
    df_test_ = df_test
    
    image_datasets = {
        'train': MyDataset(df_train_, data_transforms['train'], tt='train'),
        'valid': MyDataset(df_valid_, data_transforms['valid'], tt='train'),
        'vta': MyDataset(df_valid_, data_transforms['tta'], tt='train'),
        'test': MyDataset(df_test_, data_transforms['valid'], tt='test'),
        'tta': MyDataset(df_test_, data_transforms['tta'], tt='test'),
    }
    
    dataloaders = {
        'train': torch.utils.data.DataLoader(image_datasets['train'],
                                             batch_size=bs, shuffle=True, num_workers=16, pin_memory=True),
        'valid': torch.utils.data.DataLoader(image_datasets['valid'],
                                             batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
        'vta': torch.utils.data.DataLoader(image_datasets['vta'],
                                           batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
        'test': torch.utils.data.DataLoader(image_datasets['test'],
                                            batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
        'tta': torch.utils.data.DataLoader(image_datasets['tta'],
                                           batch_size=32, shuffle=False, num_workers=16, pin_memory=True),
    }
    
#     return train_idx, valid_idx, image_datasets, dataloaders
    return image_datasets, dataloaders

# %% [markdown]
# モデル構築

# %%
from torcheval.metrics import BinaryAUROC
import torch.optim as optim
from torcheval.metrics.functional import binary_auroc

# %% [raw]
# model.classifier = nn.Linear(2816, 1, bias=True)

# %% [raw]
# # multi gpu
# model = torch.nn.DataParallel(model, device_ids=[0, 1, 2, 3]) # make parallel

# %% [raw]
# model.to(device)

# %% [raw]
# ### 重み固定 ###
# for p in model.parameters():
#     p.requires_grad = False

# %%
def loadNewModel():
    m = ConvNextV2ForImageClassification.from_pretrained("facebook/convnextv2-huge-22k-512")
    m.classifier = nn.Linear(2816, 1, bias=True)
    m = torch.nn.DataParallel(m, device_ids=[0, 1, 2, 3]) # make parallel
    m.to(device)
    for p in m.parameters():
        p.requires_grad = False
    return m

# %% [markdown]
# 学習

# %%
import copy, time

# %%
scaler = torch.cuda.amp.GradScaler()

# %%
def train(model, criterion, optimizer, scheduler, image_datasets, dataloaders, epochs=5):
    since = time.time()
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_auc = 0.0
    
    for epoch in range(epochs):
        print(f'Epoch {epoch}/{epochs-1}')
        print('-' * 10)
        
        for phase in ('train', 'valid'):
            if phase == 'train':
                is_train = True
                model.train()  # Set model to training mode
            else:
                is_train = False
                model.eval()   # Set model to evaluate mode
            
            running_loss = 0.0
            running_auc = 0.0
            
            # イタレーション
            for b, (inputs, labels) in enumerate(dataloaders[phase]):
                print(f'\rBatch: {b}/{len(image_datasets[phase])//dataloaders[phase].batch_size} ({phase})', end="")
                inputs = inputs.to(device)
                labels = labels.to(device)
                
                optimizer.zero_grad()
                
                with torch.set_grad_enabled(is_train):
                    with torch.cuda.amp.autocast(): 
                        outputs = model(inputs).logits
                        # loss = criterion(torch.flatten(outputs), torch.flatten(labels))
                        loss = criterion(outputs, labels)
                    auc = binary_auroc(torch.flatten(torch.sigmoid(outputs)),
                                       torch.flatten(labels))

                    # backward + optimize only if in training phase
                    if is_train:
                        scaler.scale(loss).backward()
                        scaler.step(optimizer)
                        scaler.update() 

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_auc +=  auc * inputs.size(0)
                
                del loss, auc, labels, inputs, outputs
            
            epoch_loss = running_loss / len(image_datasets[phase])
            epoch_auc = running_auc / len(image_datasets[phase])
            
            print()
            print(f'{phase} Loss: {epoch_loss:.4f} AUC: {epoch_auc:.4f}')
            
            # deep copy the model
            if phase == 'valid' and epoch_auc > best_auc:
                best_auc = epoch_auc
                best_model_wts = copy.deepcopy(model.state_dict())
            del epoch_loss, epoch_auc, running_loss, running_auc
            torch.cuda.empty_cache()
            
        scheduler.step()
        print()
        
    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val AUC: {best_auc:.4f}')
    print()

    # load best model weights
    model.load_state_dict(best_model_wts)
    del best_model_wts
    return model

# %% [markdown]
# - 通常の代入とTTAで比較

# %%
def valid(model, dataloader):
    noutputs = []
    nlabels = []
    for b, (inputs, labels) in enumerate(dataloader):
        print(f'\rBatch: {b}/{len(dataloader.dataset)//dataloader.batch_size}', end="")
        inputs = inputs.to(device)
        labels = labels.to(device)
        with torch.no_grad():
            noutputs.append(model(inputs).logits)
            nlabels.append(labels)
        del inputs, labels
    alloutputs = torch.cat(noutputs)
    alllabels = torch.cat(nlabels)
    
    preds = torch.sigmoid(torch.flatten(alloutputs))
    auc = binary_auroc(preds, torch.flatten(alllabels))
    print()
    print()
    print(f'AUC: {auc:.4f}')
    
    return preds.cpu().detach().numpy()

# %%
def tta(model, dataloader, n=5):
    alloutputs = []
    
    for i in range(n):
        print(f'n: {i}/{n-1}')
        print('-' * 10)
        noutputs = []
        nlabels = []
        for b, (inputs, labels) in enumerate(dataloader):
            print(f'\rBatch: {b}/{len(dataloader.dataset)//dataloader.batch_size}', end="")
            inputs = inputs.to(device)
            labels = labels.to(device)
            with torch.no_grad():
                noutputs.append(model(inputs).logits)
                nlabels.append(labels)
            del inputs, labels
        alloutputs.append(torch.cat(noutputs))
        alllabels = torch.cat(nlabels)
        print()
    alloutputs = torch.cat(alloutputs, 1)
    preds = torch.sigmoid(torch.mean(alloutputs, dim=1))
    auc = binary_auroc(preds, torch.flatten(alllabels))
    print()
    print(f'AUC: {auc:.4f}')
    
    return preds.cpu().detach().numpy()

# %%
def valMix(model, dataloaders, n=5, mode='valid'):
    # 通常valid
    print(f"=== Normal {'Valid' if mode=='valid' else 'Test'} ===")
    if mode =='valid':
        dataloader = dataloaders['valid']
    elif mode == 'test':
        dataloader = dataloaders['test']
    noutputs = []
    nlabels = []
    for b, (imgs, labels) in enumerate(dataloader):
        print(f'\rBatch: {b}/{len(dataloader.dataset)//dataloader.batch_size}', end="")
        inputs = imgs.to(device)
        labels = labels.to(device)
        with torch.no_grad():
            noutputs.append(model(inputs).logits)
            nlabels.append(labels)
    alloutputs = torch.cat(noutputs)
    alllabels = torch.cat(nlabels)
    
    preds1 = torch.sigmoid(torch.flatten(alloutputs))
    auc = binary_auroc(preds1, torch.flatten(alllabels))
    print()
    print()
    print(f'Norml Valid AUC: {auc:.4f}')
    print()
    
    # TTA valid
    print(f"=== {'Valid' if mode=='valid' else 'Test'} Time Augmentation ===")
    if mode =='valid':
        dataloader = dataloaders['vta']
    elif mode == 'test':
        dataloader = dataloaders['tta']
    alloutputs = [alloutputs]
    
    for i in range(n):
        print(f'n: {i}/{n-1}')
        print('-' * 10)
        noutputs = []
        for b, (imgs, labels) in enumerate(dataloader):
            print(f'\rBatch: {b}/{len(dataloader.dataset)//dataloader.batch_size}', end="")
            inputs = imgs.to(device)
            with torch.no_grad():
                noutputs.append(model(inputs).logits)
        alloutputs.append(torch.cat(noutputs))
        print()
    alloutputs = torch.cat(alloutputs, 1)
    preds2 = torch.sigmoid(torch.mean(alloutputs, dim=1))
    auc = binary_auroc(preds2, torch.flatten(alllabels))
    print()
    print(f'VTA AUC: {auc:.4f}')
    print()
    
    # Mix
    print('=== Mixed Valid ===')
    preds1to0 = preds1 - 0
    preds1to1 = 1 - preds1
    preds2to0 = preds2 - 0
    preds2to1 = 1 - preds2
    
    stack = torch.stack([preds1to0, preds1to1, preds2to0, preds2to1])
    pstack = torch.stack([preds1, preds1, preds2, preds2])
    
    argmin = torch.argmin(stack, dim=0)
    preds = torch.diag(pstack[argmin])
    auc = binary_auroc(preds, torch.flatten(alllabels))
    print()
    print(f'Mixed AUC: {auc:.4f}')
    return preds1.cpu().detach().numpy(), preds2.cpu().detach().numpy(), preds.cpu().detach().numpy()

# %% [markdown]
# ### CV

# %%
from numba import cuda

# %%
### 検証時のAugmentation
n_vta = 5

# %%
### パラメータ変更可能な部分 ###
"""
  model.module.convnextv2.embeddings

  model.module.convnextv2.encoder.stages[0]
  -> model.module.convnextv2.encoder.stages[0].layers[0] ~ [2]

  model.module.convnextv2.encoder.stages[1]
  -> model.module.convnextv2.encoder.stages[1].layers[0] ~ [2]

  model.module.convnextv2.encoder.stages[2]
  -> model.module.convnextv2.encoder.stages[2].layers[0] ~ [26]

  model.module.convnextv2.encoder.stages[3]
  -> model.module.convnextv2.encoder.stages[3].layers[0] ~ [2]

  model.module.convnextv2.layernorm

  model.module.classifier
"""
# Out:
# '\n  model.module.convnextv2.embeddings\n\n  model.module.convnextv2.encoder.stages[0]\n  -> model.module.convnextv2.encoder.stages[0].layers[0] ~ [2]\n\n  model.module.convnextv2.encoder.stages[1]\n  -> model.module.convnextv2.encoder.stages[1].layers[0] ~ [2]\n\n  model.module.convnextv2.encoder.stages[2]\n  -> model.module.convnextv2.encoder.stages[2].layers[0] ~ [26]\n\n  model.module.convnextv2.encoder.stages[3]\n  -> model.module.convnextv2.encoder.stages[3].layers[0] ~ [2]\n\n  model.module.convnextv2.layernorm\n\n  model.module.classifier\n'

# %%
specs = [
    {
        'bs': 32,
        'trainLayers': 1,
        'lr': 1e-3,
        'epochs': 15,
        'num_warmup_steps': 5,  # CosSchWarm
        'num_training_steps': 20,  # CosSchWarm
        'num_cycles': 0.5,  # CosSchWarm
    },
    {
        'bs': 32,
        'trainLayers': 2,
        'lr': 1e-3,
        'epochs': 15,
        'num_warmup_steps': 5,  # CosSchWarm
        'num_training_steps': 20,  # CosSchWarm
        'num_cycles': 0.5,  # CosSchWarm
    },
    {
        'bs': 32,
        'trainLayers': 3,
        'lr': 5e-4,
        'epochs': 30,
        'num_warmup_steps': 5,  # CosSchWarm
        'num_training_steps': 35,  # CosSchWarm
        'num_cycles': 1.5,  # CosSchWarm
    },
    {
        'bs': 24,
        'trainLayers': 6,
        'lr': 1e-4,
        'epochs': 100,
        'num_warmup_steps': 10,  # CosSchWarm
        'num_training_steps': 105,  # CosSchWarm
        'num_cycles': 4.5,  # CosSchWarm
    },
]

# %%
vals = {}
vtas = {}
mixs = {}

# %%
torch.backends.cudnn.benchmark = True

# %%
def train_spec(fold, i, model_path='model.pth'):
    spec = specs[i]
    
    # datasetsを作る
    image_datasets, dataloaders = foldData(fold, bs=spec['bs'])
    
    # 新しいモデルを読み込み
    if i == 0:
        model = loadNewModel()
    else:
        model = torch.load(model_path)
        model.to(device)
        for p in model.parameters():
            p.requires_grad = False
    
    layer_list = [
        model.module.classifier,
        model.module.convnextv2.layernorm,
        model.module.convnextv2.encoder.stages[3],
        model.module.convnextv2.encoder.stages[2].layers[26],
        model.module.convnextv2.encoder.stages[2].layers[25],
        model.module.convnextv2.encoder.stages[2].layers[24],
        model.module.convnextv2.encoder.stages[2].layers[22],
        model.module.convnextv2.encoder.stages[2].layers[21],
    ]
    
    for j in range(spec['trainLayers']):
        layer = layer_list[j]
        for p in layer.parameters():
            p.requires_grad = True
    
    criterion = nn.BCEWithLogitsLoss(pos_weight=None)
    if False:
    # if i < len(specs)-2:
        optimizer = optim.SGD(model.parameters(), lr=spec['lr'], momentum=0.9)
        lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=spec['sch_steps'], gamma=spec['sch_gamma'])
    else:
        optimizer = optim.AdamW(model.parameters(), lr=spec['lr'])
        lr_scheduler = get_cosine_schedule_with_warmup(optimizer,
                                                       num_warmup_steps=spec['num_warmup_steps'],
                                                       num_training_steps=spec['num_training_steps'],
                                                       num_cycles=spec['num_cycles'])
    
    model = train(model, criterion, optimizer, lr_scheduler, image_datasets, dataloaders,
                  epochs=spec['epochs'])
    
    torch.save(model, model_path)
    del model
    torch.cuda.empty_cache()

# %%
def fold_train(fold):
    print(f'=== Fold: {fold} ===')
    print('GPU Memory:', torch.cuda.memory_allocated())
    
    for i in range(len(specs)):
        print(f'<< Spec: {i} >>')
        train_spec(fold, i)
    
    print('- Validation -')
    model = torch.load('model.pth')
    model.to(device)
    
    image_datasets, dataloaders = foldData(fold)
    
    val, vta, mix = valMix(model, dataloaders, n=n_vta)
    vals[fold] = val
    vtas[fold] = vta
    mixs[fold] = mix
    
    print()
    
    torch.save(model, f'model_{fold}.pth')
    
    del model
    torch.cuda.empty_cache()

# %%
# %%capture cap

for fold in range(n_folds):
    fold_train(fold)

with open('log_train.txt', 'w') as f:
    f.write(cap.stdout)

# %%
cap()
# Out:
# === Fold: 0 ===
# GPU Memory: 0
# << Spec: 0 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.7128 AUC: 0.4690
# Batch: 13/13 (valid)
# valid Loss: 0.7371 AUC: 0.4261
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.6242 AUC: 0.6989
# Batch: 13/13 (valid)
# valid Loss: 0.5414 AUC: 0.8079
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5625 AUC: 0.7830
# Batch: 13/13 (valid)
# valid Loss: 0.4771 AUC: 0.8487
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5317 AUC: 0.8024
# Batch: 13/13 (valid)
# valid Loss: 0.4400 AUC: 0.8742
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5186 AUC: 0.8204
# Batch: 13/13 (valid)
# valid Loss: 0.4317 AUC: 0.8760
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5025 AUC: 0.8324
# Batch: 13/13 (valid)
# valid Loss: 0.4109 AUC: 0.8910
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4747 AUC: 0.8546
# Batch: 13/13 (valid)
# valid Loss: 0.4041 AUC: 0.8914
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4629 AUC: 0.8612
# Batch: 13/13 (valid)
# valid Loss: 0.3987 AUC: 0.9007
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4685 AUC: 0.8655
# Batch: 13/13 (valid)
# valid Loss: 0.3831 AUC: 0.9043
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4416 AUC: 0.8788
# Batch: 13/13 (valid)
# valid Loss: 0.3873 AUC: 0.9028
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4466 AUC: 0.8712
# Batch: 13/13 (valid)
# valid Loss: 0.3735 AUC: 0.9072
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4528 AUC: 0.8653
# Batch: 13/13 (valid)
# valid Loss: 0.3807 AUC: 0.9014
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4416 AUC: 0.8716
# Batch: 13/13 (valid)
# valid Loss: 0.3682 AUC: 0.9112
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4209 AUC: 0.8890
# Batch: 13/13 (valid)
# valid Loss: 0.3670 AUC: 0.9126
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4216 AUC: 0.8855
# Batch: 13/13 (valid)
# valid Loss: 0.3690 AUC: 0.9129
#
# Training complete in 52m 51s
# Best val AUC: 0.9129
#
# << Spec: 1 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4307 AUC: 0.8873
# Batch: 13/13 (valid)
# valid Loss: 0.3691 AUC: 0.9129
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4296 AUC: 0.8818
# Batch: 13/13 (valid)
# valid Loss: 0.3639 AUC: 0.9125
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4197 AUC: 0.8874
# Batch: 13/13 (valid)
# valid Loss: 0.3608 AUC: 0.9128
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4100 AUC: 0.9043
# Batch: 13/13 (valid)
# valid Loss: 0.3637 AUC: 0.9109
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4257 AUC: 0.8842
# Batch: 13/13 (valid)
# valid Loss: 0.3679 AUC: 0.9200
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4511 AUC: 0.8741
# Batch: 13/13 (valid)
# valid Loss: 0.3651 AUC: 0.9149
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4362 AUC: 0.8756
# Batch: 13/13 (valid)
# valid Loss: 0.3516 AUC: 0.9161
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4499 AUC: 0.8774
# Batch: 13/13 (valid)
# valid Loss: 0.3588 AUC: 0.9138
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4300 AUC: 0.8830
# Batch: 13/13 (valid)
# valid Loss: 0.3496 AUC: 0.9207
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4324 AUC: 0.8767
# Batch: 13/13 (valid)
# valid Loss: 0.3509 AUC: 0.9266
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4255 AUC: 0.8868
# Batch: 13/13 (valid)
# valid Loss: 0.3398 AUC: 0.9226
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3967 AUC: 0.9051
# Batch: 13/13 (valid)
# valid Loss: 0.3459 AUC: 0.9219
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4193 AUC: 0.8858
# Batch: 13/13 (valid)
# valid Loss: 0.3387 AUC: 0.9277
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3999 AUC: 0.8955
# Batch: 13/13 (valid)
# valid Loss: 0.3439 AUC: 0.9228
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4060 AUC: 0.8960
# Batch: 13/13 (valid)
# valid Loss: 0.3450 AUC: 0.9217
#
# Training complete in 52m 52s
# Best val AUC: 0.9277
#
# << Spec: 2 >>
# Epoch 0/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4031 AUC: 0.8974
# Batch: 13/13 (valid)
# valid Loss: 0.3387 AUC: 0.9277
#
# Epoch 1/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5066 AUC: 0.8615
# Batch: 13/13 (valid)
# valid Loss: 0.3249 AUC: 0.9392
#
# Epoch 2/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4625 AUC: 0.8824
# Batch: 13/13 (valid)
# valid Loss: 0.3084 AUC: 0.9380
#
# Epoch 3/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4137 AUC: 0.9070
# Batch: 13/13 (valid)
# valid Loss: 0.2818 AUC: 0.9485
#
# Epoch 4/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3716 AUC: 0.9272
# Batch: 13/13 (valid)
# valid Loss: 0.2292 AUC: 0.9704
#
# Epoch 5/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3379 AUC: 0.9330
# Batch: 13/13 (valid)
# valid Loss: 0.2862 AUC: 0.9469
#
# Epoch 6/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3205 AUC: 0.9364
# Batch: 13/13 (valid)
# valid Loss: 0.2085 AUC: 0.9749
#
# Epoch 7/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2944 AUC: 0.9553
# Batch: 13/13 (valid)
# valid Loss: 0.3121 AUC: 0.9538
#
# Epoch 8/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2775 AUC: 0.9567
# Batch: 13/13 (valid)
# valid Loss: 0.3199 AUC: 0.9642
#
# Epoch 9/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2162 AUC: 0.9724
# Batch: 13/13 (valid)
# valid Loss: 0.3327 AUC: 0.9601
#
# Epoch 10/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2171 AUC: 0.9707
# Batch: 13/13 (valid)
# valid Loss: 0.2274 AUC: 0.9762
#
# Epoch 11/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1910 AUC: 0.9787
# Batch: 13/13 (valid)
# valid Loss: 0.2322 AUC: 0.9745
#
# Epoch 12/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1683 AUC: 0.9832
# Batch: 13/13 (valid)
# valid Loss: 0.2065 AUC: 0.9799
#
# Epoch 13/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1448 AUC: 0.9880
# Batch: 13/13 (valid)
# valid Loss: 0.2245 AUC: 0.9783
#
# Epoch 14/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1443 AUC: 0.9850
# Batch: 13/13 (valid)
# valid Loss: 0.2217 AUC: 0.9779
#
# Epoch 15/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1509 AUC: 0.9869
# Batch: 13/13 (valid)
# valid Loss: 0.2217 AUC: 0.9779
#
# Epoch 16/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1561 AUC: 0.9842
# Batch: 13/13 (valid)
# valid Loss: 0.2203 AUC: 0.9784
#
# Epoch 17/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1310 AUC: 0.9893
# Batch: 13/13 (valid)
# valid Loss: 0.2272 AUC: 0.9787
#
# Epoch 18/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1345 AUC: 0.9889
# Batch: 13/13 (valid)
# valid Loss: 0.2499 AUC: 0.9754
#
# Epoch 19/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1521 AUC: 0.9887
# Batch: 13/13 (valid)
# valid Loss: 0.2731 AUC: 0.9717
#
# Epoch 20/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1694 AUC: 0.9828
# Batch: 13/13 (valid)
# valid Loss: 0.2786 AUC: 0.9717
#
# Epoch 21/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1955 AUC: 0.9828
# Batch: 13/13 (valid)
# valid Loss: 0.2422 AUC: 0.9727
#
# Epoch 22/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2158 AUC: 0.9786
# Batch: 13/13 (valid)
# valid Loss: 0.2555 AUC: 0.9688
#
# Epoch 23/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2445 AUC: 0.9712
# Batch: 13/13 (valid)
# valid Loss: 0.2903 AUC: 0.9605
#
# Epoch 24/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2299 AUC: 0.9698
# Batch: 13/13 (valid)
# valid Loss: 0.2451 AUC: 0.9718
#
# Epoch 25/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2009 AUC: 0.9753
# Batch: 13/13 (valid)
# valid Loss: 0.2523 AUC: 0.9696
#
# Epoch 26/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2289 AUC: 0.9763
# Batch: 13/13 (valid)
# valid Loss: 0.2743 AUC: 0.9660
#
# Epoch 27/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2171 AUC: 0.9762
# Batch: 13/13 (valid)
# valid Loss: 0.2180 AUC: 0.9776
#
# Epoch 28/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1893 AUC: 0.9808
# Batch: 13/13 (valid)
# valid Loss: 0.2241 AUC: 0.9799
#
# Epoch 29/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1730 AUC: 0.9841
# Batch: 13/13 (valid)
# valid Loss: 0.2020 AUC: 0.9796
#
# Training complete in 113m 2s
# Best val AUC: 0.9799
#
# << Spec: 3 >>
# Epoch 0/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.2016 AUC: 0.9828
# Batch: 13/13 (valid)
# valid Loss: 0.2241 AUC: 0.9799
#
# Epoch 1/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1721 AUC: 0.9834
# Batch: 13/13 (valid)
# valid Loss: 0.1915 AUC: 0.9804
#
# Epoch 2/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1516 AUC: 0.9853
# Batch: 13/13 (valid)
# valid Loss: 0.1978 AUC: 0.9821
#
# Epoch 3/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1269 AUC: 0.9892
# Batch: 13/13 (valid)
# valid Loss: 0.1828 AUC: 0.9854
#
# Epoch 4/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1109 AUC: 0.9923
# Batch: 13/13 (valid)
# valid Loss: 0.2006 AUC: 0.9842
#
# Epoch 5/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1073 AUC: 0.9917
# Batch: 13/13 (valid)
# valid Loss: 0.1936 AUC: 0.9837
#
# Epoch 6/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1224 AUC: 0.9895
# Batch: 13/13 (valid)
# valid Loss: 0.2644 AUC: 0.9794
#
# Epoch 7/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1085 AUC: 0.9936
# Batch: 13/13 (valid)
# valid Loss: 0.2085 AUC: 0.9799
#
# Epoch 8/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1119 AUC: 0.9928
# Batch: 13/13 (valid)
# valid Loss: 0.2164 AUC: 0.9866
#
# Epoch 9/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1261 AUC: 0.9932
# Batch: 13/13 (valid)
# valid Loss: 0.1770 AUC: 0.9845
#
# Epoch 10/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1211 AUC: 0.9922
# Batch: 13/13 (valid)
# valid Loss: 0.2004 AUC: 0.9839
#
# Epoch 11/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1305 AUC: 0.9921
# Batch: 13/13 (valid)
# valid Loss: 0.1722 AUC: 0.9849
#
# Epoch 12/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1162 AUC: 0.9938
# Batch: 13/13 (valid)
# valid Loss: 0.1405 AUC: 0.9879
#
# Epoch 13/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1083 AUC: 0.9926
# Batch: 13/13 (valid)
# valid Loss: 0.2086 AUC: 0.9810
#
# Epoch 14/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0966 AUC: 0.9942
# Batch: 13/13 (valid)
# valid Loss: 0.1940 AUC: 0.9828
#
# Epoch 15/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1068 AUC: 0.9934
# Batch: 13/13 (valid)
# valid Loss: 0.2202 AUC: 0.9820
#
# Epoch 16/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0998 AUC: 0.9952
# Batch: 13/13 (valid)
# valid Loss: 0.2051 AUC: 0.9863
#
# Epoch 17/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0853 AUC: 0.9961
# Batch: 13/13 (valid)
# valid Loss: 0.1970 AUC: 0.9854
#
# Epoch 18/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0778 AUC: 0.9961
# Batch: 13/13 (valid)
# valid Loss: 0.2056 AUC: 0.9846
#
# Epoch 19/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0726 AUC: 0.9961
# Batch: 13/13 (valid)
# valid Loss: 0.2045 AUC: 0.9849
#
# Epoch 20/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0781 AUC: 0.9966
# Batch: 13/13 (valid)
# valid Loss: 0.2048 AUC: 0.9849
#
# Epoch 21/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0907 AUC: 0.9954
# Batch: 13/13 (valid)
# valid Loss: 0.2044 AUC: 0.9850
#
# Epoch 22/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0595 AUC: 0.9983
# Batch: 13/13 (valid)
# valid Loss: 0.2089 AUC: 0.9833
#
# Epoch 23/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0572 AUC: 0.9983
# Batch: 13/13 (valid)
# valid Loss: 0.2274 AUC: 0.9824
#
# Epoch 24/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0688 AUC: 0.9973
# Batch: 13/13 (valid)
# valid Loss: 0.2395 AUC: 0.9824
#
# Epoch 25/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0566 AUC: 0.9981
# Batch: 13/13 (valid)
# valid Loss: 0.2343 AUC: 0.9837
#
# Epoch 26/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0789 AUC: 0.9972
# Batch: 13/13 (valid)
# valid Loss: 0.2059 AUC: 0.9831
#
# Epoch 27/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0716 AUC: 0.9978
# Batch: 13/13 (valid)
# valid Loss: 0.2193 AUC: 0.9832
#
# Epoch 28/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0919 AUC: 0.9959
# Batch: 13/13 (valid)
# valid Loss: 0.2084 AUC: 0.9863
#
# Epoch 29/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1067 AUC: 0.9920
# Batch: 13/13 (valid)
# valid Loss: 0.1849 AUC: 0.9824
#
# Epoch 30/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0688 AUC: 0.9971
# Batch: 13/13 (valid)
# valid Loss: 0.2528 AUC: 0.9795
#
# Epoch 31/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1123 AUC: 0.9931
# Batch: 13/13 (valid)
# valid Loss: 0.2149 AUC: 0.9781
#
# Epoch 32/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0973 AUC: 0.9957
# Batch: 13/13 (valid)
# valid Loss: 0.1879 AUC: 0.9828
#
# Epoch 33/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0931 AUC: 0.9943
# Batch: 13/13 (valid)
# valid Loss: 0.2004 AUC: 0.9865
#
# Epoch 34/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0890 AUC: 0.9959
# Batch: 13/13 (valid)
# valid Loss: 0.1892 AUC: 0.9858
#
# Epoch 35/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0641 AUC: 0.9981
# Batch: 13/13 (valid)
# valid Loss: 0.2507 AUC: 0.9859
#
# Epoch 36/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0794 AUC: 0.9967
# Batch: 13/13 (valid)
# valid Loss: 0.2052 AUC: 0.9862
#
# Epoch 37/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0696 AUC: 0.9969
# Batch: 13/13 (valid)
# valid Loss: 0.2252 AUC: 0.9848
#
# Epoch 38/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0678 AUC: 0.9977
# Batch: 13/13 (valid)
# valid Loss: 0.1885 AUC: 0.9883
#
# Epoch 39/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0539 AUC: 0.9980
# Batch: 13/13 (valid)
# valid Loss: 0.2091 AUC: 0.9866
#
# Epoch 40/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0594 AUC: 0.9975
# Batch: 13/13 (valid)
# valid Loss: 0.2054 AUC: 0.9861
#
# Epoch 41/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0603 AUC: 0.9975
# Batch: 13/13 (valid)
# valid Loss: 0.2044 AUC: 0.9862
#
# Epoch 42/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0451 AUC: 0.9990
# Batch: 13/13 (valid)
# valid Loss: 0.2046 AUC: 0.9862
#
# Epoch 43/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0548 AUC: 0.9980
# Batch: 13/13 (valid)
# valid Loss: 0.2047 AUC: 0.9863
#
# Epoch 44/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0584 AUC: 0.9981
# Batch: 13/13 (valid)
# valid Loss: 0.2134 AUC: 0.9852
#
# Epoch 45/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0544 AUC: 0.9986
# Batch: 13/13 (valid)
# valid Loss: 0.2165 AUC: 0.9858
#
# Epoch 46/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0601 AUC: 0.9979
# Batch: 13/13 (valid)
# valid Loss: 0.2113 AUC: 0.9876
#
# Epoch 47/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0624 AUC: 0.9975
# Batch: 13/13 (valid)
# valid Loss: 0.1975 AUC: 0.9875
#
# Epoch 48/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0681 AUC: 0.9965
# Batch: 13/13 (valid)
# valid Loss: 0.1807 AUC: 0.9901
#
# Epoch 49/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0652 AUC: 0.9974
# Batch: 13/13 (valid)
# valid Loss: 0.2122 AUC: 0.9915
#
# Epoch 50/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0700 AUC: 0.9980
# Batch: 13/13 (valid)
# valid Loss: 0.1837 AUC: 0.9900
#
# Epoch 51/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0907 AUC: 0.9963
# Batch: 13/13 (valid)
# valid Loss: 0.1542 AUC: 0.9925
#
# Epoch 52/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0878 AUC: 0.9957
# Batch: 13/13 (valid)
# valid Loss: 0.1715 AUC: 0.9895
#
# Epoch 53/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0592 AUC: 0.9980
# Batch: 13/13 (valid)
# valid Loss: 0.2263 AUC: 0.9791
#
# Epoch 54/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0653 AUC: 0.9977
# Batch: 13/13 (valid)
# valid Loss: 0.1829 AUC: 0.9878
#
# Epoch 55/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0679 AUC: 0.9979
# Batch: 13/13 (valid)
# valid Loss: 0.1886 AUC: 0.9881
#
# Epoch 56/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0596 AUC: 0.9974
# Batch: 13/13 (valid)
# valid Loss: 0.2083 AUC: 0.9873
#
# Epoch 57/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0715 AUC: 0.9972
# Batch: 13/13 (valid)
# valid Loss: 0.1746 AUC: 0.9920
#
# Epoch 58/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0645 AUC: 0.9981
# Batch: 13/13 (valid)
# valid Loss: 0.1864 AUC: 0.9892
#
# Epoch 59/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0516 AUC: 0.9981
# Batch: 13/13 (valid)
# valid Loss: 0.1655 AUC: 0.9895
#
# Epoch 60/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0523 AUC: 0.9986
# Batch: 13/13 (valid)
# valid Loss: 0.1616 AUC: 0.9904
#
# Epoch 61/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0523 AUC: 0.9984
# Batch: 13/13 (valid)
# valid Loss: 0.1614 AUC: 0.9928
#
# Epoch 62/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0429 AUC: 0.9990
# Batch: 13/13 (valid)
# valid Loss: 0.1618 AUC: 0.9928
#
# Epoch 63/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0377 AUC: 0.9996
# Batch: 13/13 (valid)
# valid Loss: 0.1619 AUC: 0.9928
#
# Epoch 64/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0573 AUC: 0.9979
# Batch: 13/13 (valid)
# valid Loss: 0.1603 AUC: 0.9925
#
# Epoch 65/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0574 AUC: 0.9971
# Batch: 13/13 (valid)
# valid Loss: 0.1558 AUC: 0.9929
#
# Epoch 66/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0498 AUC: 0.9983
# Batch: 13/13 (valid)
# valid Loss: 0.1711 AUC: 0.9917
#
# Epoch 67/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0440 AUC: 0.9994
# Batch: 13/13 (valid)
# valid Loss: 0.1833 AUC: 0.9916
#
# Epoch 68/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0525 AUC: 0.9981
# Batch: 13/13 (valid)
# valid Loss: 0.2132 AUC: 0.9875
#
# Epoch 69/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0487 AUC: 0.9981
# Batch: 13/13 (valid)
# valid Loss: 0.1728 AUC: 0.9906
#
# Epoch 70/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0560 AUC: 0.9985
# Batch: 13/13 (valid)
# valid Loss: 0.1654 AUC: 0.9916
#
# Epoch 71/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0782 AUC: 0.9959
# Batch: 13/13 (valid)
# valid Loss: 0.1624 AUC: 0.9878
#
# Epoch 72/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0651 AUC: 0.9985
# Batch: 13/13 (valid)
# valid Loss: 0.1889 AUC: 0.9869
#
# Epoch 73/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0671 AUC: 0.9982
# Batch: 13/13 (valid)
# valid Loss: 0.1780 AUC: 0.9888
#
# Epoch 74/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0759 AUC: 0.9960
# Batch: 13/13 (valid)
# valid Loss: 0.1634 AUC: 0.9885
#
# Epoch 75/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0683 AUC: 0.9972
# Batch: 13/13 (valid)
# valid Loss: 0.1565 AUC: 0.9898
#
# Epoch 76/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0746 AUC: 0.9974
# Batch: 13/13 (valid)
# valid Loss: 0.1774 AUC: 0.9888
#
# Epoch 77/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0546 AUC: 0.9989
# Batch: 13/13 (valid)
# valid Loss: 0.1893 AUC: 0.9901
#
# Epoch 78/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0553 AUC: 0.9975
# Batch: 13/13 (valid)
# valid Loss: 0.1288 AUC: 0.9925
#
# Epoch 79/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0462 AUC: 0.9994
# Batch: 13/13 (valid)
# valid Loss: 0.1187 AUC: 0.9933
#
# Epoch 80/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0352 AUC: 0.9990
# Batch: 13/13 (valid)
# valid Loss: 0.1501 AUC: 0.9917
#
# Epoch 81/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0503 AUC: 0.9979
# Batch: 13/13 (valid)
# valid Loss: 0.1530 AUC: 0.9907
#
# Epoch 82/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0497 AUC: 0.9983
# Batch: 13/13 (valid)
# valid Loss: 0.1535 AUC: 0.9907
#
# Epoch 83/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0468 AUC: 0.9986
# Batch: 13/13 (valid)
# valid Loss: 0.1530 AUC: 0.9907
#
# Epoch 84/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0632 AUC: 0.9982
# Batch: 13/13 (valid)
# valid Loss: 0.1529 AUC: 0.9907
#
# Epoch 85/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0518 AUC: 0.9979
# Batch: 13/13 (valid)
# valid Loss: 0.1526 AUC: 0.9904
#
# Epoch 86/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0424 AUC: 0.9991
# Batch: 13/13 (valid)
# valid Loss: 0.1444 AUC: 0.9922
#
# Epoch 87/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0507 AUC: 0.9990
# Batch: 13/13 (valid)
# valid Loss: 0.1493 AUC: 0.9918
#
# Epoch 88/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0324 AUC: 0.9993
# Batch: 13/13 (valid)
# valid Loss: 0.1663 AUC: 0.9907
#
# Epoch 89/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0373 AUC: 0.9989
# Batch: 13/13 (valid)
# valid Loss: 0.1982 AUC: 0.9917
#
# Epoch 90/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0481 AUC: 0.9986
# Batch: 13/13 (valid)
# valid Loss: 0.1710 AUC: 0.9903
#
# Epoch 91/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0437 AUC: 0.9990
# Batch: 13/13 (valid)
# valid Loss: 0.1647 AUC: 0.9903
#
# Epoch 92/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0533 AUC: 0.9990
# Batch: 13/13 (valid)
# valid Loss: 0.1748 AUC: 0.9894
#
# Epoch 93/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0627 AUC: 0.9984
# Batch: 13/13 (valid)
# valid Loss: 0.2044 AUC: 0.9887
#
# Epoch 94/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0794 AUC: 0.9970
# Batch: 13/13 (valid)
# valid Loss: 0.1773 AUC: 0.9897
#
# Epoch 95/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0703 AUC: 0.9969
# Batch: 13/13 (valid)
# valid Loss: 0.1965 AUC: 0.9842
#
# Epoch 96/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0543 AUC: 0.9979
# Batch: 13/13 (valid)
# valid Loss: 0.1863 AUC: 0.9877
#
# Epoch 97/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0532 AUC: 0.9986
# Batch: 13/13 (valid)
# valid Loss: 0.1828 AUC: 0.9884
#
# Epoch 98/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0556 AUC: 0.9987
# Batch: 13/13 (valid)
# valid Loss: 0.2114 AUC: 0.9846
#
# Epoch 99/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0503 AUC: 0.9981
# Batch: 13/13 (valid)
# valid Loss: 0.1905 AUC: 0.9881
#
# Training complete in 431m 1s
# Best val AUC: 0.9933
#
# - Validation -
# === Normal Valid ===
# Batch: 13/13
#
# Norml Valid AUC: 0.9940
#
# === Valid Time Augmentation ===
# n: 0/4
# ----------
# Batch: 13/13
# n: 1/4
# ----------
# Batch: 13/13
# n: 2/4
# ----------
# Batch: 13/13
# n: 3/4
# ----------
# Batch: 13/13
# n: 4/4
# ----------
# Batch: 13/13
#
# VTA AUC: 0.9926
#
# === Mixed Valid ===
#
# Mixed AUC: 0.9940
#
# === Fold: 1 ===
# GPU Memory: 17040384
# << Spec: 0 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.7020 AUC: 0.5731
# Batch: 13/13 (valid)
# valid Loss: 0.6867 AUC: 0.6299
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.6067 AUC: 0.7321
# Batch: 13/13 (valid)
# valid Loss: 0.5005 AUC: 0.8639
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5473 AUC: 0.7898
# Batch: 13/13 (valid)
# valid Loss: 0.4615 AUC: 0.8795
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5312 AUC: 0.8074
# Batch: 13/13 (valid)
# valid Loss: 0.4384 AUC: 0.8903
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5086 AUC: 0.8296
# Batch: 13/13 (valid)
# valid Loss: 0.4178 AUC: 0.8976
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4917 AUC: 0.8381
# Batch: 13/13 (valid)
# valid Loss: 0.4051 AUC: 0.9061
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4857 AUC: 0.8471
# Batch: 13/13 (valid)
# valid Loss: 0.3923 AUC: 0.9160
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4608 AUC: 0.8601
# Batch: 13/13 (valid)
# valid Loss: 0.3830 AUC: 0.9115
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4640 AUC: 0.8544
# Batch: 13/13 (valid)
# valid Loss: 0.3794 AUC: 0.9164
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4547 AUC: 0.8636
# Batch: 13/13 (valid)
# valid Loss: 0.3789 AUC: 0.9205
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4314 AUC: 0.8806
# Batch: 13/13 (valid)
# valid Loss: 0.3794 AUC: 0.9180
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4298 AUC: 0.8832
# Batch: 13/13 (valid)
# valid Loss: 0.3743 AUC: 0.9181
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4399 AUC: 0.8740
# Batch: 13/13 (valid)
# valid Loss: 0.3640 AUC: 0.9232
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4199 AUC: 0.8886
# Batch: 13/13 (valid)
# valid Loss: 0.3580 AUC: 0.9257
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4157 AUC: 0.8919
# Batch: 13/13 (valid)
# valid Loss: 0.3557 AUC: 0.9242
#
# Training complete in 53m 40s
# Best val AUC: 0.9257
#
# << Spec: 1 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4230 AUC: 0.8814
# Batch: 13/13 (valid)
# valid Loss: 0.3580 AUC: 0.9257
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4083 AUC: 0.8965
# Batch: 13/13 (valid)
# valid Loss: 0.3529 AUC: 0.9257
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4269 AUC: 0.8770
# Batch: 13/13 (valid)
# valid Loss: 0.3628 AUC: 0.9190
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4359 AUC: 0.8779
# Batch: 13/13 (valid)
# valid Loss: 0.3590 AUC: 0.9216
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4181 AUC: 0.8942
# Batch: 13/13 (valid)
# valid Loss: 0.3899 AUC: 0.9159
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4371 AUC: 0.8772
# Batch: 13/13 (valid)
# valid Loss: 0.3805 AUC: 0.9227
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4480 AUC: 0.8750
# Batch: 13/13 (valid)
# valid Loss: 0.3633 AUC: 0.9212
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4099 AUC: 0.8934
# Batch: 13/13 (valid)
# valid Loss: 0.3718 AUC: 0.9223
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4312 AUC: 0.8812
# Batch: 13/13 (valid)
# valid Loss: 0.3628 AUC: 0.9185
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4075 AUC: 0.8957
# Batch: 13/13 (valid)
# valid Loss: 0.3449 AUC: 0.9251
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4223 AUC: 0.8917
# Batch: 13/13 (valid)
# valid Loss: 0.3503 AUC: 0.9245
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4060 AUC: 0.8950
# Batch: 13/13 (valid)
# valid Loss: 0.3489 AUC: 0.9249
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3973 AUC: 0.8998
# Batch: 13/13 (valid)
# valid Loss: 0.3535 AUC: 0.9241
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4174 AUC: 0.8908
# Batch: 13/13 (valid)
# valid Loss: 0.3373 AUC: 0.9299
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3909 AUC: 0.8988
# Batch: 13/13 (valid)
# valid Loss: 0.3391 AUC: 0.9282
#
# Training complete in 53m 35s
# Best val AUC: 0.9299
#
# << Spec: 2 >>
# Epoch 0/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4096 AUC: 0.8947
# Batch: 13/13 (valid)
# valid Loss: 0.3373 AUC: 0.9299
#
# Epoch 1/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5119 AUC: 0.8635
# Batch: 13/13 (valid)
# valid Loss: 0.4587 AUC: 0.9173
#
# Epoch 2/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4940 AUC: 0.8731
# Batch: 13/13 (valid)
# valid Loss: 0.3110 AUC: 0.9441
#
# Epoch 3/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3909 AUC: 0.9129
# Batch: 13/13 (valid)
# valid Loss: 0.3037 AUC: 0.9561
#
# Epoch 4/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3767 AUC: 0.9102
# Batch: 13/13 (valid)
# valid Loss: 0.2723 AUC: 0.9546
#
# Epoch 5/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3853 AUC: 0.9230
# Batch: 13/13 (valid)
# valid Loss: 0.2810 AUC: 0.9508
#
# Epoch 6/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3327 AUC: 0.9373
# Batch: 13/13 (valid)
# valid Loss: 0.3757 AUC: 0.9433
#
# Epoch 7/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2881 AUC: 0.9547
# Batch: 13/13 (valid)
# valid Loss: 0.2510 AUC: 0.9762
#
# Epoch 8/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2779 AUC: 0.9528
# Batch: 13/13 (valid)
# valid Loss: 0.2411 AUC: 0.9719
#
# Epoch 9/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2247 AUC: 0.9719
# Batch: 13/13 (valid)
# valid Loss: 0.2549 AUC: 0.9736
#
# Epoch 10/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2100 AUC: 0.9760
# Batch: 13/13 (valid)
# valid Loss: 0.2599 AUC: 0.9709
#
# Epoch 11/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1874 AUC: 0.9818
# Batch: 13/13 (valid)
# valid Loss: 0.2706 AUC: 0.9717
#
# Epoch 12/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1664 AUC: 0.9832
# Batch: 13/13 (valid)
# valid Loss: 0.2853 AUC: 0.9720
#
# Epoch 13/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1438 AUC: 0.9877
# Batch: 13/13 (valid)
# valid Loss: 0.2626 AUC: 0.9739
#
# Epoch 14/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1310 AUC: 0.9896
# Batch: 13/13 (valid)
# valid Loss: 0.2732 AUC: 0.9739
#
# Epoch 15/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1531 AUC: 0.9864
# Batch: 13/13 (valid)
# valid Loss: 0.2732 AUC: 0.9739
#
# Epoch 16/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1328 AUC: 0.9881
# Batch: 13/13 (valid)
# valid Loss: 0.2635 AUC: 0.9748
#
# Epoch 17/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1362 AUC: 0.9893
# Batch: 13/13 (valid)
# valid Loss: 0.2390 AUC: 0.9791
#
# Epoch 18/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1395 AUC: 0.9891
# Batch: 13/13 (valid)
# valid Loss: 0.2496 AUC: 0.9789
#
# Epoch 19/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1647 AUC: 0.9843
# Batch: 13/13 (valid)
# valid Loss: 0.3072 AUC: 0.9762
#
# Epoch 20/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1844 AUC: 0.9829
# Batch: 13/13 (valid)
# valid Loss: 0.3096 AUC: 0.9708
#
# Epoch 21/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1779 AUC: 0.9857
# Batch: 13/13 (valid)
# valid Loss: 0.2255 AUC: 0.9736
#
# Epoch 22/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2241 AUC: 0.9753
# Batch: 13/13 (valid)
# valid Loss: 0.3411 AUC: 0.9569
#
# Epoch 23/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2194 AUC: 0.9752
# Batch: 13/13 (valid)
# valid Loss: 0.2349 AUC: 0.9736
#
# Epoch 24/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1948 AUC: 0.9798
# Batch: 13/13 (valid)
# valid Loss: 0.2409 AUC: 0.9808
#
# Epoch 25/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2561 AUC: 0.9696
# Batch: 13/13 (valid)
# valid Loss: 0.1977 AUC: 0.9811
#
# Epoch 26/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2278 AUC: 0.9722
# Batch: 13/13 (valid)
# valid Loss: 0.2083 AUC: 0.9833
#
# Epoch 27/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1977 AUC: 0.9744
# Batch: 13/13 (valid)
# valid Loss: 0.1863 AUC: 0.9849
#
# Epoch 28/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1819 AUC: 0.9840
# Batch: 13/13 (valid)
# valid Loss: 0.2589 AUC: 0.9813
#
# Epoch 29/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1572 AUC: 0.9853
# Batch: 13/13 (valid)
# valid Loss: 0.2421 AUC: 0.9757
#
# Training complete in 113m 50s
# Best val AUC: 0.9849
#
# << Spec: 3 >>
# Epoch 0/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1580 AUC: 0.9870
# Batch: 13/13 (valid)
# valid Loss: 0.1863 AUC: 0.9849
#
# Epoch 1/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1458 AUC: 0.9882
# Batch: 13/13 (valid)
# valid Loss: 0.1858 AUC: 0.9866
#
# Epoch 2/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1459 AUC: 0.9883
# Batch: 13/13 (valid)
# valid Loss: 0.1756 AUC: 0.9869
#
# Epoch 3/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1216 AUC: 0.9908
# Batch: 13/13 (valid)
# valid Loss: 0.1640 AUC: 0.9892
#
# Epoch 4/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1449 AUC: 0.9886
# Batch: 13/13 (valid)
# valid Loss: 0.1567 AUC: 0.9876
#
# Epoch 5/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1041 AUC: 0.9940
# Batch: 13/13 (valid)
# valid Loss: 0.1919 AUC: 0.9861
#
# Epoch 6/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1255 AUC: 0.9902
# Batch: 13/13 (valid)
# valid Loss: 0.2074 AUC: 0.9854
#
# Epoch 7/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1185 AUC: 0.9906
# Batch: 13/13 (valid)
# valid Loss: 0.2318 AUC: 0.9849
#
# Epoch 8/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1282 AUC: 0.9914
# Batch: 13/13 (valid)
# valid Loss: 0.2366 AUC: 0.9835
#
# Epoch 9/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1248 AUC: 0.9903
# Batch: 13/13 (valid)
# valid Loss: 0.1957 AUC: 0.9857
#
# Epoch 10/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1201 AUC: 0.9902
# Batch: 13/13 (valid)
# valid Loss: 0.1655 AUC: 0.9882
#
# Epoch 11/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0967 AUC: 0.9942
# Batch: 13/13 (valid)
# valid Loss: 0.3229 AUC: 0.9862
#
# Epoch 12/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1206 AUC: 0.9934
# Batch: 13/13 (valid)
# valid Loss: 0.1897 AUC: 0.9873
#
# Epoch 13/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1033 AUC: 0.9945
# Batch: 13/13 (valid)
# valid Loss: 0.1601 AUC: 0.9924
#
# Epoch 14/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1053 AUC: 0.9940
# Batch: 13/13 (valid)
# valid Loss: 0.1825 AUC: 0.9894
#
# Epoch 15/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1061 AUC: 0.9936
# Batch: 13/13 (valid)
# valid Loss: 0.1552 AUC: 0.9911
#
# Epoch 16/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0955 AUC: 0.9952
# Batch: 13/13 (valid)
# valid Loss: 0.1585 AUC: 0.9909
#
# Epoch 17/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0812 AUC: 0.9965
# Batch: 13/13 (valid)
# valid Loss: 0.1655 AUC: 0.9903
#
# Epoch 18/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0710 AUC: 0.9969
# Batch: 13/13 (valid)
# valid Loss: 0.1727 AUC: 0.9900
#
# Epoch 19/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0748 AUC: 0.9972
# Batch: 13/13 (valid)
# valid Loss: 0.1710 AUC: 0.9906
#
# Epoch 20/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0766 AUC: 0.9965
# Batch: 13/13 (valid)
# valid Loss: 0.1716 AUC: 0.9906
#
# Epoch 21/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0741 AUC: 0.9962
# Batch: 13/13 (valid)
# valid Loss: 0.1723 AUC: 0.9903
#
# Epoch 22/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0692 AUC: 0.9975
# Batch: 13/13 (valid)
# valid Loss: 0.1749 AUC: 0.9897
#
# Epoch 23/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0622 AUC: 0.9978
# Batch: 13/13 (valid)
# valid Loss: 0.1789 AUC: 0.9909
#
# Epoch 24/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0766 AUC: 0.9965
# Batch: 13/13 (valid)
# valid Loss: 0.1918 AUC: 0.9901
#
# Epoch 25/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0702 AUC: 0.9974
# Batch: 13/13 (valid)
# valid Loss: 0.1878 AUC: 0.9898
#
# Epoch 26/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0773 AUC: 0.9964
# Batch: 13/13 (valid)
# valid Loss: 0.1812 AUC: 0.9897
#
# Epoch 27/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0825 AUC: 0.9969
# Batch: 13/13 (valid)
# valid Loss: 0.1656 AUC: 0.9909
#
# Epoch 28/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0857 AUC: 0.9969
# Batch: 13/13 (valid)
# valid Loss: 0.2220 AUC: 0.9858
#
# Epoch 29/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0851 AUC: 0.9973
# Batch: 13/13 (valid)
# valid Loss: 0.2388 AUC: 0.9850
#
# Epoch 30/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1000 AUC: 0.9948
# Batch: 13/13 (valid)
# valid Loss: 0.2267 AUC: 0.9838
#
# Epoch 31/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0941 AUC: 0.9946
# Batch: 13/13 (valid)
# valid Loss: 0.2664 AUC: 0.9793
#
# Epoch 32/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0956 AUC: 0.9942
# Batch: 13/13 (valid)
# valid Loss: 0.1899 AUC: 0.9861
#
# Epoch 33/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0645 AUC: 0.9974
# Batch: 13/13 (valid)
# valid Loss: 0.2739 AUC: 0.9828
#
# Epoch 34/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0906 AUC: 0.9952
# Batch: 13/13 (valid)
# valid Loss: 0.2194 AUC: 0.9844
#
# Epoch 35/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0866 AUC: 0.9960
# Batch: 13/13 (valid)
# valid Loss: 0.2177 AUC: 0.9875
#
# Epoch 36/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0741 AUC: 0.9964
# Batch: 13/13 (valid)
# valid Loss: 0.2461 AUC: 0.9846
#
# Epoch 37/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0760 AUC: 0.9969
# Batch: 13/13 (valid)
# valid Loss: 0.2122 AUC: 0.9868
#
# Epoch 38/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0634 AUC: 0.9983
# Batch: 13/13 (valid)
# valid Loss: 0.2511 AUC: 0.9856
#
# Epoch 39/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0600 AUC: 0.9986
# Batch: 13/13 (valid)
# valid Loss: 0.2277 AUC: 0.9860
#
# Epoch 40/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0583 AUC: 0.9974
# Batch: 13/13 (valid)
# valid Loss: 0.2311 AUC: 0.9858
#
# Epoch 41/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0796 AUC: 0.9969
# Batch: 13/13 (valid)
# valid Loss: 0.2297 AUC: 0.9863
#
# Epoch 42/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0571 AUC: 0.9973
# Batch: 13/13 (valid)
# valid Loss: 0.2296 AUC: 0.9863
#
# Epoch 43/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0576 AUC: 0.9977
# Batch: 13/13 (valid)
# valid Loss: 0.2302 AUC: 0.9861
#
# Epoch 44/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0567 AUC: 0.9988
# Batch: 13/13 (valid)
# valid Loss: 0.2395 AUC: 0.9873
#
# Epoch 45/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0766 AUC: 0.9965
# Batch: 13/13 (valid)
# valid Loss: 0.2321 AUC: 0.9850
#
# Epoch 46/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0606 AUC: 0.9982
# Batch: 13/13 (valid)
# valid Loss: 0.2299 AUC: 0.9864
#
# Epoch 47/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0542 AUC: 0.9980
# Batch: 13/13 (valid)
# valid Loss: 0.2451 AUC: 0.9852
#
# Epoch 48/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0554 AUC: 0.9976
# Batch: 13/13 (valid)
# valid Loss: 0.2643 AUC: 0.9840
#
# Epoch 49/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0551 AUC: 0.9993
# Batch: 13/13 (valid)
# valid Loss: 0.2935 AUC: 0.9814
#
# Epoch 50/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0703 AUC: 0.9972
# Batch: 13/13 (valid)
# valid Loss: 0.2567 AUC: 0.9795
#
# Epoch 51/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0905 AUC: 0.9954
# Batch: 13/13 (valid)
# valid Loss: 0.2584 AUC: 0.9813
#
# Epoch 52/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0665 AUC: 0.9980
# Batch: 13/13 (valid)
# valid Loss: 0.3150 AUC: 0.9814
#
# Epoch 53/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0856 AUC: 0.9960
# Batch: 13/13 (valid)
# valid Loss: 0.2444 AUC: 0.9800
#
# Epoch 54/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0693 AUC: 0.9974
# Batch: 13/13 (valid)
# valid Loss: 0.2447 AUC: 0.9833
#
# Epoch 55/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0764 AUC: 0.9969
# Batch: 13/13 (valid)
# valid Loss: 0.2222 AUC: 0.9867
#
# Epoch 56/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0562 AUC: 0.9979
# Batch: 13/13 (valid)
# valid Loss: 0.2511 AUC: 0.9846
#
# Epoch 57/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0569 AUC: 0.9989
# Batch: 13/13 (valid)
# valid Loss: 0.1858 AUC: 0.9874
#
# Epoch 58/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0531 AUC: 0.9988
# Batch: 13/13 (valid)
# valid Loss: 0.2045 AUC: 0.9900
#
# Epoch 59/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0505 AUC: 0.9985
# Batch: 13/13 (valid)
# valid Loss: 0.2173 AUC: 0.9896
#
# Epoch 60/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0408 AUC: 0.9992
# Batch: 13/13 (valid)
# valid Loss: 0.2185 AUC: 0.9894
#
# Epoch 61/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0545 AUC: 0.9980
# Batch: 13/13 (valid)
# valid Loss: 0.2159 AUC: 0.9898
#
# Epoch 62/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0428 AUC: 0.9986
# Batch: 13/13 (valid)
# valid Loss: 0.2154 AUC: 0.9898
#
# Epoch 63/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0592 AUC: 0.9976
# Batch: 13/13 (valid)
# valid Loss: 0.2154 AUC: 0.9898
#
# Epoch 64/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0506 AUC: 0.9987
# Batch: 13/13 (valid)
# valid Loss: 0.2144 AUC: 0.9901
#
# Epoch 65/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0568 AUC: 0.9989
# Batch: 13/13 (valid)
# valid Loss: 0.2105 AUC: 0.9905
#
# Epoch 66/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0419 AUC: 0.9987
# Batch: 13/13 (valid)
# valid Loss: 0.2132 AUC: 0.9913
#
# Epoch 67/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0446 AUC: 0.9989
# Batch: 13/13 (valid)
# valid Loss: 0.2158 AUC: 0.9879
#
# Epoch 68/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0427 AUC: 0.9986
# Batch: 13/13 (valid)
# valid Loss: 0.2660 AUC: 0.9896
#
# Epoch 69/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0549 AUC: 0.9977
# Batch: 13/13 (valid)
# valid Loss: 0.2102 AUC: 0.9886
#
# Epoch 70/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0559 AUC: 0.9978
# Batch: 13/13 (valid)
# valid Loss: 0.2653 AUC: 0.9836
#
# Epoch 71/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0775 AUC: 0.9971
# Batch: 13/13 (valid)
# valid Loss: 0.1824 AUC: 0.9876
#
# Epoch 72/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0514 AUC: 0.9992
# Batch: 13/13 (valid)
# valid Loss: 0.2839 AUC: 0.9865
#
# Epoch 73/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0691 AUC: 0.9979
# Batch: 13/13 (valid)
# valid Loss: 0.2622 AUC: 0.9798
#
# Epoch 74/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0688 AUC: 0.9970
# Batch: 13/13 (valid)
# valid Loss: 0.2225 AUC: 0.9846
#
# Epoch 75/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0501 AUC: 0.9994
# Batch: 13/13 (valid)
# valid Loss: 0.3461 AUC: 0.9813
#
# Epoch 76/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0838 AUC: 0.9972
# Batch: 13/13 (valid)
# valid Loss: 0.3008 AUC: 0.9819
#
# Epoch 77/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0529 AUC: 0.9979
# Batch: 13/13 (valid)
# valid Loss: 0.2748 AUC: 0.9828
#
# Epoch 78/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0690 AUC: 0.9974
# Batch: 13/13 (valid)
# valid Loss: 0.2383 AUC: 0.9834
#
# Epoch 79/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0576 AUC: 0.9978
# Batch: 13/13 (valid)
# valid Loss: 0.2563 AUC: 0.9865
#
# Epoch 80/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0453 AUC: 0.9983
# Batch: 13/13 (valid)
# valid Loss: 0.2887 AUC: 0.9842
#
# Epoch 81/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0506 AUC: 0.9983
# Batch: 13/13 (valid)
# valid Loss: 0.2774 AUC: 0.9820
#
# Epoch 82/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0489 AUC: 0.9989
# Batch: 13/13 (valid)
# valid Loss: 0.2704 AUC: 0.9835
#
# Epoch 83/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0479 AUC: 0.9984
# Batch: 13/13 (valid)
# valid Loss: 0.2699 AUC: 0.9838
#
# Epoch 84/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0512 AUC: 0.9986
# Batch: 13/13 (valid)
# valid Loss: 0.2698 AUC: 0.9838
#
# Epoch 85/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0548 AUC: 0.9985
# Batch: 13/13 (valid)
# valid Loss: 0.2672 AUC: 0.9835
#
# Epoch 86/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0420 AUC: 0.9986
# Batch: 13/13 (valid)
# valid Loss: 0.2580 AUC: 0.9845
#
# Epoch 87/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0403 AUC: 0.9990
# Batch: 13/13 (valid)
# valid Loss: 0.2492 AUC: 0.9834
#
# Epoch 88/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0450 AUC: 0.9988
# Batch: 13/13 (valid)
# valid Loss: 0.2469 AUC: 0.9825
#
# Epoch 89/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0402 AUC: 0.9993
# Batch: 13/13 (valid)
# valid Loss: 0.2518 AUC: 0.9821
#
# Epoch 90/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0490 AUC: 0.9991
# Batch: 13/13 (valid)
# valid Loss: 0.2582 AUC: 0.9840
#
# Epoch 91/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0576 AUC: 0.9982
# Batch: 13/13 (valid)
# valid Loss: 0.2296 AUC: 0.9837
#
# Epoch 92/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0481 AUC: 0.9986
# Batch: 13/13 (valid)
# valid Loss: 0.3327 AUC: 0.9771
#
# Epoch 93/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0420 AUC: 0.9988
# Batch: 13/13 (valid)
# valid Loss: 0.2593 AUC: 0.9870
#
# Epoch 94/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0628 AUC: 0.9983
# Batch: 13/13 (valid)
# valid Loss: 0.2409 AUC: 0.9855
#
# Epoch 95/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0721 AUC: 0.9975
# Batch: 13/13 (valid)
# valid Loss: 0.2467 AUC: 0.9856
#
# Epoch 96/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0532 AUC: 0.9982
# Batch: 13/13 (valid)
# valid Loss: 0.3102 AUC: 0.9852
#
# Epoch 97/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0660 AUC: 0.9973
# Batch: 13/13 (valid)
# valid Loss: 0.2819 AUC: 0.9884
#
# Epoch 98/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0673 AUC: 0.9972
# Batch: 13/13 (valid)
# valid Loss: 0.2386 AUC: 0.9874
#
# Epoch 99/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0581 AUC: 0.9978
# Batch: 13/13 (valid)
# valid Loss: 0.2889 AUC: 0.9854
#
# Training complete in 432m 31s
# Best val AUC: 0.9924
#
# - Validation -
# === Normal Valid ===
# Batch: 13/13
#
# Norml Valid AUC: 0.9889
#
# === Valid Time Augmentation ===
# n: 0/4
# ----------
# Batch: 13/13
# n: 1/4
# ----------
# Batch: 13/13
# n: 2/4
# ----------
# Batch: 13/13
# n: 3/4
# ----------
# Batch: 13/13
# n: 4/4
# ----------
# Batch: 13/13
#
# VTA AUC: 0.9859
#
# === Mixed Valid ===
#
# Mixed AUC: 0.9888
#
# === Fold: 2 ===
# GPU Memory: 17040384
# << Spec: 0 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.6867 AUC: 0.5678
# Batch: 13/13 (valid)
# valid Loss: 0.6924 AUC: 0.5571
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.6051 AUC: 0.7320
# Batch: 13/13 (valid)
# valid Loss: 0.5589 AUC: 0.7905
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5462 AUC: 0.7963
# Batch: 13/13 (valid)
# valid Loss: 0.5325 AUC: 0.8049
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.5054 AUC: 0.8300
# Batch: 13/13 (valid)
# valid Loss: 0.5015 AUC: 0.8295
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4888 AUC: 0.8378
# Batch: 13/13 (valid)
# valid Loss: 0.4815 AUC: 0.8382
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4747 AUC: 0.8562
# Batch: 13/13 (valid)
# valid Loss: 0.4838 AUC: 0.8570
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4627 AUC: 0.8554
# Batch: 13/13 (valid)
# valid Loss: 0.4570 AUC: 0.8617
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4602 AUC: 0.8602
# Batch: 13/13 (valid)
# valid Loss: 0.4329 AUC: 0.8814
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4429 AUC: 0.8700
# Batch: 13/13 (valid)
# valid Loss: 0.4305 AUC: 0.8820
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4387 AUC: 0.8762
# Batch: 13/13 (valid)
# valid Loss: 0.4176 AUC: 0.8966
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4341 AUC: 0.8771
# Batch: 13/13 (valid)
# valid Loss: 0.4308 AUC: 0.8857
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4256 AUC: 0.8841
# Batch: 13/13 (valid)
# valid Loss: 0.4238 AUC: 0.8858
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4318 AUC: 0.8794
# Batch: 13/13 (valid)
# valid Loss: 0.4267 AUC: 0.8825
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4260 AUC: 0.8872
# Batch: 13/13 (valid)
# valid Loss: 0.4196 AUC: 0.8869
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4145 AUC: 0.8900
# Batch: 13/13 (valid)
# valid Loss: 0.4276 AUC: 0.8920
#
# Training complete in 53m 35s
# Best val AUC: 0.8966
#
# << Spec: 1 >>
# Epoch 0/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4283 AUC: 0.8837
# Batch: 13/13 (valid)
# valid Loss: 0.4176 AUC: 0.8966
#
# Epoch 1/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4248 AUC: 0.8892
# Batch: 13/13 (valid)
# valid Loss: 0.4186 AUC: 0.8898
#
# Epoch 2/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4287 AUC: 0.8821
# Batch: 13/13 (valid)
# valid Loss: 0.4292 AUC: 0.8854
#
# Epoch 3/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4257 AUC: 0.8814
# Batch: 13/13 (valid)
# valid Loss: 0.4354 AUC: 0.8861
#
# Epoch 4/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4121 AUC: 0.8945
# Batch: 13/13 (valid)
# valid Loss: 0.4279 AUC: 0.8867
#
# Epoch 5/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4228 AUC: 0.8884
# Batch: 13/13 (valid)
# valid Loss: 0.4365 AUC: 0.8822
#
# Epoch 6/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4256 AUC: 0.8848
# Batch: 13/13 (valid)
# valid Loss: 0.4123 AUC: 0.8958
#
# Epoch 7/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4243 AUC: 0.8869
# Batch: 13/13 (valid)
# valid Loss: 0.4101 AUC: 0.8925
#
# Epoch 8/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4237 AUC: 0.8891
# Batch: 13/13 (valid)
# valid Loss: 0.4233 AUC: 0.8917
#
# Epoch 9/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3987 AUC: 0.8986
# Batch: 13/13 (valid)
# valid Loss: 0.4105 AUC: 0.8934
#
# Epoch 10/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4117 AUC: 0.8936
# Batch: 13/13 (valid)
# valid Loss: 0.4004 AUC: 0.9030
#
# Epoch 11/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4142 AUC: 0.9000
# Batch: 13/13 (valid)
# valid Loss: 0.3932 AUC: 0.9003
#
# Epoch 12/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3820 AUC: 0.9100
# Batch: 13/13 (valid)
# valid Loss: 0.3881 AUC: 0.9012
#
# Epoch 13/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4111 AUC: 0.8901
# Batch: 13/13 (valid)
# valid Loss: 0.3894 AUC: 0.9044
#
# Epoch 14/14
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3931 AUC: 0.9018
# Batch: 13/13 (valid)
# valid Loss: 0.3922 AUC: 0.9041
#
# Training complete in 53m 50s
# Best val AUC: 0.9044
#
# << Spec: 2 >>
# Epoch 0/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3886 AUC: 0.9071
# Batch: 13/13 (valid)
# valid Loss: 0.3894 AUC: 0.9044
#
# Epoch 1/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4533 AUC: 0.8810
# Batch: 13/13 (valid)
# valid Loss: 0.3775 AUC: 0.9112
#
# Epoch 2/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.4967 AUC: 0.8806
# Batch: 13/13 (valid)
# valid Loss: 0.5156 AUC: 0.8938
#
# Epoch 3/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3960 AUC: 0.9129
# Batch: 13/13 (valid)
# valid Loss: 0.4130 AUC: 0.9129
#
# Epoch 4/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3565 AUC: 0.9278
# Batch: 13/13 (valid)
# valid Loss: 0.3130 AUC: 0.9457
#
# Epoch 5/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3588 AUC: 0.9301
# Batch: 13/13 (valid)
# valid Loss: 0.3326 AUC: 0.9416
#
# Epoch 6/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2875 AUC: 0.9495
# Batch: 13/13 (valid)
# valid Loss: 0.3362 AUC: 0.9417
#
# Epoch 7/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.3151 AUC: 0.9430
# Batch: 13/13 (valid)
# valid Loss: 0.2934 AUC: 0.9542
#
# Epoch 8/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2738 AUC: 0.9594
# Batch: 13/13 (valid)
# valid Loss: 0.2508 AUC: 0.9687
#
# Epoch 9/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2646 AUC: 0.9682
# Batch: 13/13 (valid)
# valid Loss: 0.3547 AUC: 0.9556
#
# Epoch 10/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2169 AUC: 0.9732
# Batch: 13/13 (valid)
# valid Loss: 0.3180 AUC: 0.9591
#
# Epoch 11/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2100 AUC: 0.9739
# Batch: 13/13 (valid)
# valid Loss: 0.2915 AUC: 0.9634
#
# Epoch 12/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1659 AUC: 0.9846
# Batch: 13/13 (valid)
# valid Loss: 0.2785 AUC: 0.9713
#
# Epoch 13/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1321 AUC: 0.9888
# Batch: 13/13 (valid)
# valid Loss: 0.2820 AUC: 0.9732
#
# Epoch 14/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1206 AUC: 0.9930
# Batch: 13/13 (valid)
# ...
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1717 AUC: 0.9823
# Batch: 13/13 (valid)
# valid Loss: 0.2281 AUC: 0.9779
#
# Epoch 13/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1573 AUC: 0.9849
# Batch: 13/13 (valid)
# valid Loss: 0.2101 AUC: 0.9807
#
# Epoch 14/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1584 AUC: 0.9848
# Batch: 13/13 (valid)
# valid Loss: 0.2081 AUC: 0.9806
#
# Epoch 15/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1307 AUC: 0.9887
# Batch: 13/13 (valid)
# valid Loss: 0.2081 AUC: 0.9806
#
# Epoch 16/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1594 AUC: 0.9869
# Batch: 13/13 (valid)
# valid Loss: 0.1985 AUC: 0.9822
#
# Epoch 17/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1283 AUC: 0.9913
# Batch: 13/13 (valid)
# valid Loss: 0.2224 AUC: 0.9820
#
# Epoch 18/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1464 AUC: 0.9868
# Batch: 13/13 (valid)
# valid Loss: 0.2263 AUC: 0.9774
#
# Epoch 19/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1532 AUC: 0.9868
# Batch: 13/13 (valid)
# valid Loss: 0.2012 AUC: 0.9811
#
# Epoch 20/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1839 AUC: 0.9794
# Batch: 13/13 (valid)
# valid Loss: 0.2948 AUC: 0.9771
#
# Epoch 21/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1812 AUC: 0.9819
# Batch: 13/13 (valid)
# valid Loss: 0.2261 AUC: 0.9758
#
# Epoch 22/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2263 AUC: 0.9727
# Batch: 13/13 (valid)
# valid Loss: 0.2534 AUC: 0.9727
#
# Epoch 23/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2238 AUC: 0.9716
# Batch: 13/13 (valid)
# valid Loss: 0.3235 AUC: 0.9627
#
# Epoch 24/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2420 AUC: 0.9764
# Batch: 13/13 (valid)
# valid Loss: 0.2883 AUC: 0.9651
#
# Epoch 25/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2461 AUC: 0.9701
# Batch: 13/13 (valid)
# valid Loss: 0.2461 AUC: 0.9676
#
# Epoch 26/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.2207 AUC: 0.9730
# Batch: 13/13 (valid)
# valid Loss: 0.3149 AUC: 0.9620
#
# Epoch 27/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1899 AUC: 0.9823
# Batch: 13/13 (valid)
# valid Loss: 0.3083 AUC: 0.9713
#
# Epoch 28/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1922 AUC: 0.9763
# Batch: 13/13 (valid)
# valid Loss: 0.2280 AUC: 0.9756
#
# Epoch 29/29
# ----------
# Batch: 54/54 (train)
# train Loss: 0.1669 AUC: 0.9841
# Batch: 13/13 (valid)
# valid Loss: 0.2835 AUC: 0.9731
#
# Training complete in 113m 29s
# Best val AUC: 0.9822
#
# << Spec: 3 >>
# Epoch 0/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1537 AUC: 0.9872
# Batch: 13/13 (valid)
# valid Loss: 0.1985 AUC: 0.9822
#
# Epoch 1/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1509 AUC: 0.9869
# Batch: 13/13 (valid)
# valid Loss: 0.2062 AUC: 0.9810
#
# Epoch 2/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1232 AUC: 0.9911
# Batch: 13/13 (valid)
# valid Loss: 0.2091 AUC: 0.9823
#
# Epoch 3/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1369 AUC: 0.9904
# Batch: 13/13 (valid)
# valid Loss: 0.2000 AUC: 0.9816
#
# Epoch 4/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1392 AUC: 0.9896
# Batch: 13/13 (valid)
# valid Loss: 0.1936 AUC: 0.9831
#
# Epoch 5/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1495 AUC: 0.9893
# Batch: 13/13 (valid)
# valid Loss: 0.2561 AUC: 0.9806
#
# Epoch 6/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1440 AUC: 0.9877
# Batch: 13/13 (valid)
# valid Loss: 0.2352 AUC: 0.9808
#
# Epoch 7/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1433 AUC: 0.9886
# Batch: 13/13 (valid)
# valid Loss: 0.2248 AUC: 0.9848
#
# Epoch 8/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1209 AUC: 0.9925
# Batch: 13/13 (valid)
# valid Loss: 0.1838 AUC: 0.9854
#
# Epoch 9/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1539 AUC: 0.9872
# Batch: 13/13 (valid)
# valid Loss: 0.2242 AUC: 0.9803
#
# Epoch 10/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1586 AUC: 0.9862
# Batch: 13/13 (valid)
# valid Loss: 0.1966 AUC: 0.9862
#
# Epoch 11/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1441 AUC: 0.9892
# Batch: 13/13 (valid)
# valid Loss: 0.2433 AUC: 0.9807
#
# Epoch 12/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1273 AUC: 0.9904
# Batch: 13/13 (valid)
# valid Loss: 0.2127 AUC: 0.9810
#
# Epoch 13/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1171 AUC: 0.9924
# Batch: 13/13 (valid)
# valid Loss: 0.2259 AUC: 0.9837
#
# Epoch 14/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1122 AUC: 0.9933
# Batch: 13/13 (valid)
# valid Loss: 0.2420 AUC: 0.9845
#
# Epoch 15/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1094 AUC: 0.9929
# Batch: 13/13 (valid)
# valid Loss: 0.1783 AUC: 0.9884
#
# Epoch 16/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0932 AUC: 0.9962
# Batch: 13/13 (valid)
# valid Loss: 0.1948 AUC: 0.9887
#
# Epoch 17/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0997 AUC: 0.9938
# Batch: 13/13 (valid)
# valid Loss: 0.1815 AUC: 0.9903
#
# Epoch 18/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0767 AUC: 0.9964
# Batch: 13/13 (valid)
# valid Loss: 0.1847 AUC: 0.9888
#
# Epoch 19/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0908 AUC: 0.9948
# Batch: 13/13 (valid)
# valid Loss: 0.1800 AUC: 0.9892
#
# Epoch 20/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0920 AUC: 0.9949
# Batch: 13/13 (valid)
# valid Loss: 0.1797 AUC: 0.9892
#
# Epoch 21/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0769 AUC: 0.9970
# Batch: 13/13 (valid)
# valid Loss: 0.1800 AUC: 0.9892
#
# Epoch 22/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0734 AUC: 0.9969
# Batch: 13/13 (valid)
# valid Loss: 0.1811 AUC: 0.9891
#
# Epoch 23/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0856 AUC: 0.9966
# Batch: 13/13 (valid)
# valid Loss: 0.1832 AUC: 0.9888
#
# Epoch 24/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0759 AUC: 0.9961
# Batch: 13/13 (valid)
# valid Loss: 0.1862 AUC: 0.9896
#
# Epoch 25/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0808 AUC: 0.9966
# Batch: 13/13 (valid)
# valid Loss: 0.1960 AUC: 0.9881
#
# Epoch 26/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0803 AUC: 0.9963
# Batch: 13/13 (valid)
# valid Loss: 0.2055 AUC: 0.9865
#
# Epoch 27/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1105 AUC: 0.9937
# Batch: 13/13 (valid)
# valid Loss: 0.1594 AUC: 0.9886
#
# Epoch 28/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0949 AUC: 0.9939
# Batch: 13/13 (valid)
# valid Loss: 0.2346 AUC: 0.9856
#
# Epoch 29/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0964 AUC: 0.9952
# Batch: 13/13 (valid)
# valid Loss: 0.1551 AUC: 0.9874
#
# Epoch 30/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1166 AUC: 0.9922
# Batch: 13/13 (valid)
# valid Loss: 0.1925 AUC: 0.9848
#
# Epoch 31/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1134 AUC: 0.9925
# Batch: 13/13 (valid)
# valid Loss: 0.1661 AUC: 0.9906
#
# Epoch 32/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0884 AUC: 0.9963
# Batch: 13/13 (valid)
# valid Loss: 0.1306 AUC: 0.9943
#
# Epoch 33/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1049 AUC: 0.9941
# Batch: 13/13 (valid)
# valid Loss: 0.1497 AUC: 0.9888
#
# Epoch 34/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.1118 AUC: 0.9926
# Batch: 13/13 (valid)
# valid Loss: 0.1463 AUC: 0.9900
#
# Epoch 35/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0801 AUC: 0.9968
# Batch: 13/13 (valid)
# valid Loss: 0.2045 AUC: 0.9848
#
# Epoch 36/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0781 AUC: 0.9967
# Batch: 13/13 (valid)
# valid Loss: 0.1701 AUC: 0.9870
#
# Epoch 37/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0794 AUC: 0.9960
# Batch: 13/13 (valid)
# valid Loss: 0.1791 AUC: 0.9875
#
# Epoch 38/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0765 AUC: 0.9971
# Batch: 13/13 (valid)
# valid Loss: 0.1757 AUC: 0.9894
#
# Epoch 39/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0800 AUC: 0.9965
# Batch: 13/13 (valid)
# valid Loss: 0.1702 AUC: 0.9894
#
# Epoch 40/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0493 AUC: 0.9987
# Batch: 13/13 (valid)
# valid Loss: 0.1717 AUC: 0.9894
#
# Epoch 41/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0579 AUC: 0.9981
# Batch: 13/13 (valid)
# valid Loss: 0.1716 AUC: 0.9894
#
# Epoch 42/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0698 AUC: 0.9978
# Batch: 13/13 (valid)
# valid Loss: 0.1715 AUC: 0.9894
#
# Epoch 43/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0593 AUC: 0.9983
# Batch: 13/13 (valid)
# valid Loss: 0.1714 AUC: 0.9894
#
# Epoch 44/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0554 AUC: 0.9982
# Batch: 13/13 (valid)
# valid Loss: 0.1721 AUC: 0.9888
#
# Epoch 45/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0702 AUC: 0.9976
# Batch: 13/13 (valid)
# valid Loss: 0.1660 AUC: 0.9900
#
# Epoch 46/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0671 AUC: 0.9972
# Batch: 13/13 (valid)
# valid Loss: 0.1724 AUC: 0.9871
#
# Epoch 47/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0785 AUC: 0.9971
# Batch: 13/13 (valid)
# valid Loss: 0.1784 AUC: 0.9870
#
# Epoch 48/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0617 AUC: 0.9974
# Batch: 13/13 (valid)
# valid Loss: 0.2115 AUC: 0.9873
#
# Epoch 49/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0731 AUC: 0.9962
# Batch: 13/13 (valid)
# valid Loss: 0.2257 AUC: 0.9858
#
# Epoch 50/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0698 AUC: 0.9966
# Batch: 13/13 (valid)
# valid Loss: 0.2473 AUC: 0.9845
#
# Epoch 51/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0919 AUC: 0.9969
# Batch: 13/13 (valid)
# valid Loss: 0.2045 AUC: 0.9867
#
# Epoch 52/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0881 AUC: 0.9961
# Batch: 13/13 (valid)
# valid Loss: 0.1846 AUC: 0.9838
#
# Epoch 53/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0902 AUC: 0.9954
# Batch: 13/13 (valid)
# valid Loss: 0.3025 AUC: 0.9770
#
# Epoch 54/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0908 AUC: 0.9941
# Batch: 13/13 (valid)
# valid Loss: 0.2023 AUC: 0.9842
#
# Epoch 55/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0841 AUC: 0.9963
# Batch: 13/13 (valid)
# valid Loss: 0.2105 AUC: 0.9796
#
# Epoch 56/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0795 AUC: 0.9965
# Batch: 13/13 (valid)
# valid Loss: 0.2173 AUC: 0.9823
#
# Epoch 57/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0747 AUC: 0.9962
# Batch: 13/13 (valid)
# valid Loss: 0.2019 AUC: 0.9852
#
# Epoch 58/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0681 AUC: 0.9973
# Batch: 13/13 (valid)
# valid Loss: 0.2101 AUC: 0.9824
#
# Epoch 59/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0499 AUC: 0.9990
# Batch: 13/13 (valid)
# valid Loss: 0.2135 AUC: 0.9856
#
# Epoch 60/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0511 AUC: 0.9989
# Batch: 13/13 (valid)
# valid Loss: 0.2094 AUC: 0.9861
#
# Epoch 61/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0604 AUC: 0.9979
# Batch: 13/13 (valid)
# valid Loss: 0.1995 AUC: 0.9861
#
# Epoch 62/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0464 AUC: 0.9989
# Batch: 13/13 (valid)
# valid Loss: 0.2012 AUC: 0.9862
#
# Epoch 63/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0545 AUC: 0.9974
# Batch: 13/13 (valid)
# valid Loss: 0.2010 AUC: 0.9861
#
# Epoch 64/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0481 AUC: 0.9989
# Batch: 13/13 (valid)
# valid Loss: 0.2016 AUC: 0.9861
#
# Epoch 65/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0390 AUC: 0.9987
# Batch: 13/13 (valid)
# valid Loss: 0.2014 AUC: 0.9861
#
# Epoch 66/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0534 AUC: 0.9981
# Batch: 13/13 (valid)
# valid Loss: 0.1782 AUC: 0.9859
#
# Epoch 67/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0467 AUC: 0.9985
# Batch: 13/13 (valid)
# valid Loss: 0.2080 AUC: 0.9874
#
# Epoch 68/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0663 AUC: 0.9974
# Batch: 13/13 (valid)
# valid Loss: 0.1980 AUC: 0.9882
#
# Epoch 69/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0636 AUC: 0.9974
# Batch: 13/13 (valid)
# valid Loss: 0.1892 AUC: 0.9885
#
# Epoch 70/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0646 AUC: 0.9981
# Batch: 13/13 (valid)
# valid Loss: 0.1987 AUC: 0.9834
#
# Epoch 71/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0599 AUC: 0.9980
# Batch: 13/13 (valid)
# valid Loss: 0.2247 AUC: 0.9831
#
# Epoch 72/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0676 AUC: 0.9991
# Batch: 13/13 (valid)
# valid Loss: 0.2182 AUC: 0.9830
#
# Epoch 73/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0708 AUC: 0.9977
# Batch: 13/13 (valid)
# valid Loss: 0.3024 AUC: 0.9802
#
# Epoch 74/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0917 AUC: 0.9964
# Batch: 13/13 (valid)
# valid Loss: 0.2526 AUC: 0.9798
#
# Epoch 75/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0759 AUC: 0.9966
# Batch: 13/13 (valid)
# valid Loss: 0.2631 AUC: 0.9833
#
# Epoch 76/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0740 AUC: 0.9971
# Batch: 13/13 (valid)
# valid Loss: 0.2447 AUC: 0.9866
#
# Epoch 77/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0609 AUC: 0.9975
# Batch: 13/13 (valid)
# valid Loss: 0.2082 AUC: 0.9895
#
# Epoch 78/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0677 AUC: 0.9972
# Batch: 13/13 (valid)
# valid Loss: 0.1647 AUC: 0.9917
#
# Epoch 79/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0569 AUC: 0.9981
# Batch: 13/13 (valid)
# valid Loss: 0.1791 AUC: 0.9915
#
# Epoch 80/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0453 AUC: 0.9984
# Batch: 13/13 (valid)
# valid Loss: 0.2208 AUC: 0.9895
#
# Epoch 81/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0453 AUC: 0.9990
# Batch: 13/13 (valid)
# valid Loss: 0.1793 AUC: 0.9910
#
# Epoch 82/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0564 AUC: 0.9983
# Batch: 13/13 (valid)
# valid Loss: 0.1792 AUC: 0.9921
#
# Epoch 83/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0401 AUC: 0.9992
# Batch: 13/13 (valid)
# valid Loss: 0.1784 AUC: 0.9921
#
# Epoch 84/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0487 AUC: 0.9976
# Batch: 13/13 (valid)
# valid Loss: 0.1784 AUC: 0.9921
#
# Epoch 85/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0484 AUC: 0.9992
# Batch: 13/13 (valid)
# valid Loss: 0.1789 AUC: 0.9918
#
# Epoch 86/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0470 AUC: 0.9982
# Batch: 13/13 (valid)
# valid Loss: 0.1779 AUC: 0.9921
#
# Epoch 87/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0503 AUC: 0.9986
# Batch: 13/13 (valid)
# valid Loss: 0.1751 AUC: 0.9923
#
# Epoch 88/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0399 AUC: 0.9996
# Batch: 13/13 (valid)
# valid Loss: 0.1551 AUC: 0.9920
#
# Epoch 89/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0569 AUC: 0.9978
# Batch: 13/13 (valid)
# valid Loss: 0.1636 AUC: 0.9921
#
# Epoch 90/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0379 AUC: 0.9996
# Batch: 13/13 (valid)
# valid Loss: 0.1876 AUC: 0.9880
#
# Epoch 91/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0571 AUC: 0.9986
# Batch: 13/13 (valid)
# valid Loss: 0.2505 AUC: 0.9788
#
# Epoch 92/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0689 AUC: 0.9975
# Batch: 13/13 (valid)
# valid Loss: 0.1610 AUC: 0.9880
#
# Epoch 93/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0604 AUC: 0.9983
# Batch: 13/13 (valid)
# valid Loss: 0.2161 AUC: 0.9816
#
# Epoch 94/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0572 AUC: 0.9979
# Batch: 13/13 (valid)
# valid Loss: 0.2413 AUC: 0.9839
#
# Epoch 95/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0688 AUC: 0.9983
# Batch: 13/13 (valid)
# valid Loss: 0.1773 AUC: 0.9886
#
# Epoch 96/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0701 AUC: 0.9978
# Batch: 13/13 (valid)
# valid Loss: 0.1569 AUC: 0.9883
#
# Epoch 97/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0536 AUC: 0.9987
# Batch: 13/13 (valid)
# valid Loss: 0.1634 AUC: 0.9879
#
# Epoch 98/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0620 AUC: 0.9977
# Batch: 13/13 (valid)
# valid Loss: 0.1884 AUC: 0.9881
#
# Epoch 99/99
# ----------
# Batch: 72/72 (train)
# train Loss: 0.0561 AUC: 0.9992
# Batch: 13/13 (valid)
# valid Loss: 0.1837 AUC: 0.9886
#
# Training complete in 431m 39s
# Best val AUC: 0.9943
#
# - Validation -
# === Normal Valid ===
# Batch: 13/13
#
# Norml Valid AUC: 0.9928
#
# === Valid Time Augmentation ===
# n: 0/4
# ----------
# Batch: 13/13
# n: 1/4
# ----------
# Batch: 13/13
# n: 2/4
# ----------
# Batch: 13/13
# n: 3/4
# ----------
# Batch: 13/13
# n: 4/4
# ----------
# Batch: 13/13
#
# VTA AUC: 0.9938
#
# === Mixed Valid ===
#
# Mixed AUC: 0.9940
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
print(torch.cuda.memory_allocated())
# Out:
# 17040384

# %% [raw]
# fold = 1
#
# model = torch.load(f'model_{fold}.pth')
# model.to(device)
# val, vta, mix = valMix(model, dataloaders, n=5)

# %% [raw]
# # 例
# def showRes(n, df, preds, preds2=None, start=0):
#     n_cols = 5
#     n_rows = (n-1)//5+1
#
#     fig = plt.figure(figsize=(n_cols*2, n_rows*2))
#
#     for i in range(n):
#         loc = i + start
#         num = df['num'].iloc[loc]
#         lab = df['label'].iloc[loc]
#         im = image = load_img(num)
#
#         ax = fig.add_subplot(n_rows, n_cols, i+1)
#         im = np.asarray(im)
#         ax.imshow(im)
#         ax.axes.xaxis.set_visible(False)
#         ax.axes.yaxis.set_visible(False)
#         if preds2 is None:
#             ax.set_title(f'Label: {lab}\nPred: {preds[loc]:.2f}')
#         else:
#             ax.set_title(f'Label: {lab}\nPred: {preds[loc]:.2f}\nPred2: {preds2[loc]:.2f}')
#
#     fig.suptitle('Prediction')
#     fig.tight_layout()
#     fig.show()

# %% [raw]
# showRes(20, df_train[df_train['fold']==fold], val, vta, mix, start=20)

# %% [markdown]
# ## 推論・提出

# %%
df_submit = df_test[['image_name', 'label']].copy()

# %%
def predictCV(fold):
    model = torch.load(f'model_{fold}.pth')
    model.to(device)
    
    _, dataloaders = foldData(fold)
    test, tta, tmix = valMix(model, dataloaders, n=5, mode='test')
    
    df_submit[f'label_test_{fold}'] = test
    df_submit[f'label_tta_{fold}'] = tta
    df_submit[f'label_tmix_{fold}'] = tmix
    
    del model
    torch.cuda.empty_cache()

# %%
for fold in range(n_folds):
    predictCV(fold)
# Out:
# === Normal Test ===
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Batch: 68/68
#
# Norml Valid AUC: 0.5000
#
# === Test Time Augmentation ===
# n: 0/4
# ----------
# Batch: 68/68
# n: 1/4
# ----------
# Batch: 68/68
# n: 2/4
# ----------
# Batch: 68/68
# n: 3/4
# ----------
# Batch: 68/68
# n: 4/4
# ----------
# Batch: 68/68
#
# VTA AUC: 0.5000
#
# === Mixed Valid ===
#
# Mixed AUC: 0.5000
# === Normal Test ===
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Batch: 68/68
#
# Norml Valid AUC: 0.5000
#
# === Test Time Augmentation ===
# n: 0/4
# ----------
# Batch: 68/68
# n: 1/4
# ----------
# Batch: 68/68
# n: 2/4
# ----------
# Batch: 68/68
# n: 3/4
# ----------
# Batch: 68/68
# n: 4/4
# ----------
# Batch: 68/68
#
# VTA AUC: 0.5000
#
# === Mixed Valid ===
#
# Mixed AUC: 0.5000
# === Normal Test ===
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Batch: 68/68
#
# Norml Valid AUC: 0.5000
#
# === Test Time Augmentation ===
# n: 0/4
# ----------
# Batch: 68/68
# n: 1/4
# ----------
# Batch: 68/68
# n: 2/4
# ----------
# Batch: 68/68
# n: 3/4
# ----------
# Batch: 68/68
# n: 4/4
# ----------
# Batch: 68/68
#
# VTA AUC: 0.5000
#
# === Mixed Valid ===
#
# Mixed AUC: 0.5000
# === Normal Test ===
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Batch: 68/68
#
# Norml Valid AUC: 0.5000
#
# === Test Time Augmentation ===
# n: 0/4
# ----------
# Batch: 68/68
# n: 1/4
# ----------
# Batch: 68/68
# n: 2/4
# ----------
# Batch: 68/68
# n: 3/4
# ----------
# Batch: 68/68
# n: 4/4
# ----------
# Batch: 68/68
#
# VTA AUC: 0.5000
#
# === Mixed Valid ===
#
# Mixed AUC: 0.5000
# === Normal Test ===
# /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Batch: 68/68
#
# Norml Valid AUC: 0.5000
#
# === Test Time Augmentation ===
# n: 0/4
# ----------
# Batch: 68/68
# n: 1/4
# ----------
# Batch: 68/68
# n: 2/4
# ----------
# Batch: 68/68
# n: 3/4
# ----------
# Batch: 68/68
# n: 4/4
# ----------
# Batch: 68/68
#
# VTA AUC: 0.5000
#
# === Mixed Valid ===
#
# Mixed AUC: 0.5000

# %%
# 平均対象を抽出して提出
targ = 'tmix'

mean = df_submit[[f'label_{targ}_{fold}' for fold in range(n_folds)]].mean(axis=1)
df_submit['label'] = mean

df_submit[['image_name', 'label']].to_csv('submit.csv', header=None, index=None)

# %%
df_submit.to_csv('model_v1-cv.csv', index=False)

# %% [markdown]
# 提出

# %%
# %%bash
# signate submit --competition-id=1106 submit.csv --note model1_CV_tmix
# Out:
# You have successfully submitted your predictions.We will send you the submission result to your email address.
